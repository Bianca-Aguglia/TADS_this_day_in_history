# %% [markdown]
# # Wikipedia - this day in history <small>(step 1 - get day data and save it to database)</small>
# ---
# **Goal:** get events, births, deaths, and holidays_and_observances for each day of the year (using Wikipedia API)
#
# **Notes:**
# - this notebook is for the first step of this project. It consists of:
#     - using the Wikipedia api to get the events for each day of the year
#     - parsing the Wikipedia data, cleaning it up, and getting it in the right format needed for the SQLite database created for this project
# - the notebook for the second step is [TADS_wikipedia_tdih_main_step_02_get_link_data_07feb21
# ](https://github.com/Bianca-Aguglia/TADS_wikipedia_this_day_in_history_build_dataset/tree/master/notebooks)
# - the notebook for the third step is [TADS_wikipedia_tdih_main_step_03_get_image_data_10feb21](https://github.com/Bianca-Aguglia/TADS_wikipedia_this_day_in_history_build_dataset/tree/master/notebooks)
# - to get data for a specific day run get_day_data(day_name). It returns a dictionary with day data.

# %%
import os
import requests
import re
import sqlite3
import config
import datetime as dt
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
EVENT_TYPES = ['Events', 'Births', 'Deaths', 'Holidays_and_observances']

URL = config.WIKIPEDIA_URL
HEADERS = config.HEADERS
PARAMS = {'format': 'json',
         'action': 'parse'}

DATABASE_FILE = config.DATABASE_FILE
DOE = config.DOE

# %% [markdown]
# **Notes about the data:**
# - processing the data
#     - I decided to process the data for the entire page
#     - the alternative is a multi-step process:
#         1. get the data for the page
#         2. find the section number for each type of event
#         2. find possible subsections for each section (see January_1 page)
#         4. make separate API calls for each section or subsection
#         5. process the data for each section or subsection
#     - processing the data for the whole page reduces the number of API calls by a factor of 4 or more (since there are four types of events, and some types might have subsections)
# - most days have data in the following format:
#     - for 'Events', 'Births', 'Deaths':
#         - { year_link } - { link_to_event or link_to_person } some text
#     - for 'Holidays_and_observances':
#         - { holiday_link } some text
# - edge cases I found:
#     - 'Events' data is separated into sections based on different calendars (see January_1 page)
#     - 'Deaths' data has nested lists (see February_29 page)
#     - 'Holidays_and_observances' has more than one level deep nested lists (see January_1 page)

# %%
# %%html
# <div style='box-sizing: border-box; margin: 0; padding: 0; display: flex; justify-content: space-between'>
#     <img src='../../images/img_ss_wikipedia_edge_case_01_for_jan_1_19jan21.jpg' width='300px'/>
#     <img src='../../images/img_ss_wikipedia_edge_case_02_for_jan_1_19jan21.jpg' width='300px'/>
#     <img src='../../images/img_ss_wikipedia_edge_case_01_for_feb_29_19jan21.jpg' width='300px'/>
# </div>
# Out:
# <div style='box-sizing: border-box; margin: 0; padding: 0; display: flex; justify-content: space-between'>
#     <img src='../../images/img_ss_wikipedia_edge_case_01_for_jan_1_19jan21.jpg' width='300px'/>
#     <img src='../../images/img_ss_wikipedia_edge_case_02_for_jan_1_19jan21.jpg' width='300px'/>
#     <img src='../../images/img_ss_wikipedia_edge_case_01_for_feb_29_19jan21.jpg' width='300px'/>
# </div>

# %% [markdown]
# ### Process flow: <small>(with checkmarks for steps done in this notebook)</small>
# - [x] get day data
#     - [x] get json day data from wikipedia API
#     - [x] extract data for 'events', 'births', 'deaths'
#     - [x] extract data for 'holidays_and_observances'
#     - [x] save data to wikipedia_tdih.db
#     - [ ] write function is_subject_link(wiki_link)
# - get link data
# - get image data

# %%
def day_data_main(day_name = 'January_1', url = URL, event_types = EVENT_TYPES, database_file = DATABASE_FILE, 
                  doe = DOE, print_status = True):
    """
    Main function for requesting the data for a specific day, processing it, and saving it to database
    wikipedia_tdih.db.
    It uses two helper functions:
        - get_and_process_day_data
        - add_day_data_to_db
        
    Params:
        day_name: the name of the day to be processed
                  (needs to be a string in the format Month_dd (eg. 'January_1'))
        url: url for the wikipedia API
        event_types: list of events to request and process data for
                     (event_types common to all days are:
                         - Events
                         - Births
                         - Deaths
                         - Holidays_and_observances)
        database_file: database file to save the data to
        doe: date of entry (defaults to current day)
        print_status: True or False (if True, prints message about what's being processed)
        
    Returns:
        day_data_dict
        update_results
    
    """
    # get day data from Wikipedia API and process it as needed for the database
    day_data_dict = get_and_process_day_data(day_name, url, event_types)
    
    if print_status:
        print(day_name)
        print('--------')
        print('status_code: ',day_data_dict['status_code'])
        print('adding data to db')
    
    # add day_data to database
    update_results = add_day_data_to_db(day_data_dict, database_file, doe)
    
    if print_status:
        print('data added\n')

    return day_data_dict, update_results

# %% [markdown]
# ### Helper functions for day_data_main

# %% [markdown]
# #### Section 1 - get and process day data

# %%
def get_and_process_day_data(day_name, url = URL, event_types = EVENT_TYPES):
    """
    Main function for requesting and processing the data for a specific day.
    It uses several helper functions to break down the process into simple steps.
    
    Params:
        day_name: the name of the day to be processed
                  (needs to be a string in the format Month_dd (eg. 'January_1'))
        url: url for the wikipedia API
        event_types: list of events to request and process data for
                     (event_types common to all days are:
                         - Events
                         - Births
                         - Deaths
                         - Holidays_and_observances)
        
    Returns:
        day_data_dict: a dictionary with day_data
                       eg. {'day': 1,
                            'month': 1,
                            'status_code': status_code,
                            'day_soup': day_soup,
                            'events': events_list_items,
                            'births': 'births_list_items',
                            'deaths': deaths_list_items,
                            'holidays_and_observances' : holidays_list_items
                            'no_event_for': no_event_for_list}
    """
    # request day_data
    status_code, day_soup = get_day_data(day_name = day_name)
    
    # check that status_code is OK
    if status_code == requests.codes.ok:
        # call process_day_soup to process day_soup and get the starting day_data_dict
        day_data_dict = process_day_soup(day_soup, event_types)
    else:
        day_data_dict = {'events': np.nan,
                         'births': np.nan,
                         'deaths': np.nan,
                         'holidays_and_observances': np.nan,
                         'no_event_for': np.nan}
        
    # add 'day', 'month', 'status_code', and 'day_soup' data to the day_data_dict  
    # (adding '_2020' to day_name to avoid ValueError caused by 'February_29')
    day_data_dict['day'] = dt.datetime.strptime(day_name + '_2020', '%B_%d_%Y').day
    day_data_dict['month'] = dt.datetime.strptime(day_name + '_2020', '%B_%d_%Y').month
    day_data_dict['status_code'] = status_code
    day_data_dict['day_soup'] = day_soup
            
    return day_data_dict

# %%
def get_day_data(day_name = 'January_1', url = URL, headers=HEADERS, params = PARAMS):
    """
    Use requests to get day_data from wikipedia API.
    
    Params:
        day_name: needs to be in the format Month_dd (eg. 'January_1')
        url: first part of the Wikipedia API url for each day of the year
        headers: dictionary of headers data such as user_agent, etc
        params: dictionary of params used in requests.get, such as 'format', 'action', etc
        
    Returns:
        status_code: status code of the request
        day_text_soup: BeautifulSoup object of the response text
        
    """
    params['page'] = day_name
    url = f'{url}{day_name}'
    result = requests.get(url, headers=headers, params=params)
    
    if result.status_code == requests.codes.ok:
        # result is json file with one key ('parse') whose value is a nested dictionary
        # data is in result['parse']['text']['*']
        result_text = result.json()['parse']['text']['*']
        day_text_soup = BeautifulSoup(result_text, 'html.parser')
    else:
        day_text_soup = ''
        
    return result.status_code, day_text_soup

# %%
def process_day_soup(day_soup, event_types = EVENT_TYPES):
    """
    Take the raw data for a specific day, clean it up, and format it as needed for the database.
    
    Params:
        day_soup: BeautifulSoup object representing the raw data for a specific day
        event_types: list of event_types for which to extract event items 
        
    Returns:
        day_data_dict: dictionary with day_data
                       e.g. {'events': events_list_items,
                             'births': 'births_list_items',
                             'deaths': deaths_list_items,
                             'holidays_and_observances' : holidays_list_items,
                             'no_event_for': no_event_for_list}
    """
    # initialize day_data_dict
    day_data_dict = {}
    
    # keep track of event types that don't have event items
    # this list is expected to stay empty
    no_event_for = []
    day_data_dict['no_event_for'] = no_event_for
    
    for event_type in event_types:
        # find section_span
        # events are in an <ul> element preceeded by an <h2> with two <span> children
        # the first <span> child has an id equal to the event_type (eg. <span class="mw-headline" id="Events">)
        section_span = day_soup.find(id = event_type)
        # if there are no events for the event_type
        if not section_span:
            # add the event_type for which there are no events to the list no_event_for
            no_event_for.append(event_type)
            day_data_dict['no_event_for'] = no_event_for
            # assign np.nan to day_data_dict[event_type]
            day_data_dict[event_type.lower()] = np.nan
            continue

        # if there are events for event_type
        section_h2 = section_span.find_parent()

        # event_type 'holiday' items have different data format than 'events', 'deaths', 'births'
        # need to process differently (they don't have year data)
        if 'holiday' in event_type.lower():
            day_data_dict[event_type.lower()] = extract_and_process_holiday_data(section_h2)

        else:
            day_data_dict[event_type.lower()] = extract_and_process_event_data(section_h2)
            
    return day_data_dict

# %% [markdown]
# **Sample html for events section on wikipedia page.**
#
# ![sample_section_html](../../images/img_ss_wikipedia_html_explore_events_section_14feb21.jpg)

# %%
def extract_and_process_holiday_data(section_h2, event_category = np.nan):
    """
    Process holiday data.
    
    Params:
        section_h2: a BeautifulSoup object (<h2> element) marking the start of event_type 'holiday'
        event_category: indicates if event is 'Christian feast day' or not
        
    Returns:
        holiday_list: list of dictionaries (each holiday item is a dictionary)  
                      eg. {'year': np.nan, # holidays don't have years
                           'event_description': ,
                           'event_links_list': ,
                           'event_first_link': ,
                           'event_category': ,
                           'event_contents_list': (optional)
                          }
    
    """
    holiday_list = []
    
    # section_h2 has one or more <ul> siblings
    sibling = section_h2.next_sibling
    
    # another <h2> sibling indicates the current section is over and another section starts
    # check that we are not into a new section
    while sibling.name != 'h2':
        
        # check sibling is indeed ul_element and loop through its <li> children (they contain holiday data)
        if sibling.name == 'ul':
            # loop through the <li> items
            for child in sibling.children:
                
                # check if child is emtpy string or new line character; continue to next child if yes
                if not str(child).strip():
                    continue
                    
                # check if child has sub lists
                if child.find('ul'):
                # check if child is list of 'Christian feast day' elements
                    if is_christian_feast_day(child):
                        # change event_category
                        # don't add child data to holiday_list (even though it's an <li> item, it is just a category name)
                        event_category = 'christian feast day'

                    else:
                        # add child to holiday_list
                        child_data_dict = extract_single_li_event_data(child,
                                                                       get_li_element_contents = False,
                                                                       event_category = event_category)
                        holiday_list.append(child_data_dict)

                    # get the data for sub_items and add it to holiday_list
                    sub_items_data_list = get_sub_items_data(child, event_category = event_category)
                    holiday_list.extend(sub_items_data_list)

                    # re-set event_category to np.nan
                    event_category = np.nan
                
                else:
                    # child does not have nested lists
                    # add child data to holiday_list
                    child_data_dict = extract_single_li_event_data(child,
                                                                   get_li_element_contents = False,
                                                                   event_category = event_category)
                    holiday_list.append(child_data_dict)
                    
        sibling = sibling.next_sibling
                
    return holiday_list

# %%
def extract_and_process_event_data(section_h2):
    """
    Extract and process event_data for event of type 'Events', 'Births', or 'Deaths'
    
    Params:
        section_h2: a BeautifulSoup object (<h2> element) marking the start of event_type 'Events', 'Births', or 'Deaths'
        event_category: indicates if event date is specific to a certain calendar 
                        (eg. Pre-Julian calendar, Julian calendar, Gregorian calendar, etc)
                        (see wikipedia page for January_1)
        
    Returns:
        event_list: list of dictionaries (each event item is a dictionary called child_data_dict) 
                    eg. child_data_dict = {'year': ,
                                           'event_description': ,
                                           'event_links_list': ,
                                           'event_first_link': ,
                                           'event_category': ,
                                           'event_contents_list': (optional)
                          }
    """
    event_list = []
    
    # only a small number of events is grouped in sub_lists based on the type of calendar used for their date
    # the event_category is changed if section_h2 has <h3> elements (they contain calendar data)
    event_category = np.nan
    
    # section_h2 usually has just one <ul> sibling (except days like January_1, which is divided in 
    # three parts based on the type of calendar used)
    sibling = section_h2.next_sibling
    
    while sibling.name != 'h2':
            
        # if sibling is an <h3> element, it containg the name of the calendar under which several events are grouped
        # (eg. Julian Calendar, Gregorian Calendar, etc)
        # (see wikipedia page for January_1)
        if sibling.name == 'h3':
            event_category = sibling.text.replace('[edit]', '') # '[edit]' is included in text of <h3> elements
            sibling = sibling.next_sibling
            continue
            
        if sibling.name == 'ul': # this is the list that has the <li> events
            # each <li> should hold one event and have no sub_lists
            # in some instances (see February_29), the year is in <li> element and the actual events are 
            # sub_items of the year (according to the Wikipedia page, this needs to be fixed)
            for child in sibling.children:
                
                # if child is empty string or a new line character ('\n') continue to next child
                if not str(child).strip():
                    continue
                    
                # check if child has sub_lists
                if child.find_all('li'):
                    # the child.text is the year under which several events are grouped
                    # use regex to eliminate '-' or empty spaces
                    year, bc_ad, bc_ad_note = get_year(child.text)
                    for li in child.find_all('li'):
                        child_data_dict = extract_single_li_event_data(li, event_category = event_category, year = year)
                        child_data_dict['bc_ad'] = bc_ad
                        child_data_dict['bc_ad_note'] = 'nested year ' + bc_ad_note
                        event_list.append(child_data_dict)
                    continue

                    
                child_data_dict = extract_single_li_event_data(child, event_category = event_category)
                # finds the year (using the first or second element in child.contents)
                # most of the time year data is in first element
                # exception: style data is in first element (see January_1, years 193, 404, and 417)
                year_element = [str(child.contents[0]), str(child.contents[1])]
                year, bc_ad, bc_ad_note = get_year(year_element[0])
                if not year or year == '0':
                    year, bc_ad, bc_ad_note = get_year(year_element[1], bc_ad_note = 'content_2_')
                # add year data to child_data_dict
                child_data_dict['year'] = year
                child_data_dict['bc_ad'] = bc_ad
                child_data_dict['bc_ad_note'] = bc_ad_note
                event_list.append(child_data_dict)
                    
        sibling = sibling.next_sibling
        
    return event_list

# %%
def get_year(year_element, bc_ad_note = ''):
    """
    Get the year from the year_element of an event
    
    Params:
        year_element: the first item in the contents of an <li> element for an event 
                      (passed in from extract_event_data)
        bc_ad_note: defaults to np.nan
                    changes value if year pattern in found in first element of an <li> event element
                    helps identify exception <li> elements (see wikipedia page for January_1)
                                                            years 193, 404, and 417 have style data in their
                                                            first element)
        
    Returns:
        year:
        bc_ad:
        bc_ad_note: indicates if bc_ad info was included in wikipedia link, or it is assumed to be 'ad'
    """
    year= ''
    bc_ad = ''
    bc_ad_note = bc_ad_note

    # pattern: wiki/ad_100 or wiki/100
    year_pattern_1 = re.compile(r'wiki/(bc|ad)_{0,1}(\d{1,4})', re.IGNORECASE)
    # pattern: wiki/100_ad or wiki/100
    year_pattern_2 = re.compile(r'wiki/(\d{1,4})_{0,1}(bc|ad)', re.IGNORECASE)
    # pattern: wiki/100
    year_pattern_3 = re.compile(r'wiki/(\d{1,4})')
    # pattern: 1919 -  (note: if one year has several events, only the first year occurence has link to wikipedia year page)
    year_pattern_4 = re.compile(r'\b(\d{1,4})\b')
    
    result = year_pattern_1.search(year_element)
    if result:  
        bc_ad = result.groups()[0].lower()
        year = result.groups()[1]
        bc_ad_note += 'included'
        return year, bc_ad, bc_ad_note

    result = year_pattern_2.search(year_element)
    if result:  
        bc_ad = result.groups()[1].lower()
        year = result.groups()[0]
        bc_ad_note += 'included'
        return year, bc_ad, bc_ad_note
    
    result = year_pattern_3.search(year_element)
    if result:  
        bc_ad = 'ad'
        year = result.groups()[0]
        bc_ad_note += 'assumed'
        return year, bc_ad, bc_ad_note
    
    result = year_pattern_4.search(year_element)
    if result:  
        bc_ad = 'ad'
        year = result.groups()[0]
        bc_ad_note += 'assumed'
        return year, bc_ad, bc_ad_note

    return year, bc_ad, bc_ad_note

# %%
def get_first_link(element_links_list):
    """
    Get the first non-year link (i.e. it doesn't link to the year of the event, but to something in the event)
    
    Params:
        element_links_list: list of links in the element (extracted with function extract_links_data)
                            each list item is a tuple of the form (elem_url, elem_title, elem_text)
        
    Returns:
        first_link: tuple of the form (first_link_url, first_link_title, first_link_text)
    """
    # match patterns like: wiki/AD_100, wiki/AD100, wiki/100, wiki/100_AD, wiki/100AD (for AD or BC)
    # in most cases these are links to wikipedia page for a specific year
    event_year = re.compile(r'(/wiki/ad_*\d{1,4})|(/wiki/bc_*\d{1,4})|(/wiki/\d{1,4})|(/wiki/\d{1,4}_*ad)|(/wiki/\d{1,4}_*bc)', re.IGNORECASE)
    first_link = (np.nan, np.nan, np.nan)
    
    for link in element_links_list:
        link_url = link[0]
        year_match = event_year.search(link_url)
        # in some cases, link_url has a year in its href and title
        # to distinguish it from plain wikipedia year, check its length
        # if length is greater than event_year pattern match + 3, consider this a valid link_url
        # 3 is chosen because some year_links include ' - '
        if (year_match and len(link_url) > (year_match.end() - year_match.start() + 3)) or not year_match:
            if np.isnan(first_link).all():
                first_link = link
                return first_link
            
    return first_link

# %%
def extract_links_data(li_element, exclude_reference_links = True):
    """
    Get element_links_list and first_link for li_element.
    
    Params:
        li_element: <li> element to extract data for
        exclude_reference_links: if True, exclude links to Reference section on Wikipedia page
        
    Returns:
        element_links_list: a list of tuples with data about the links in the element 
                            (exclude links in <sup> tags - they link to references)
                            tuples are of the form (elem_href, elem_title, elem_text)
                            the elem_title is used to retrive event_page from Wikipedia API
                            the elem_text is used to determine subject of event_description
        first_link: the first link that is not a link to a year
    """
    element_links_list = []
    first_link = (np.nan, np.nan, np.nan)
    
    for element in li_element.find_all('a'):
        if exclude_reference_links:
            if element.parent.name != 'sup':
                # append the element's href and title to element_links_list
                element_links_list.append((element['href'], 
                                           element.get('title', np.nan),
                                           element.text.strip()))
        else:
            element_links_list.append((element['href'], 
                                       element.get('title', np.nan),
                                       element.text.strip()))
            
    # get the first link that is not a year link
    first_link = get_first_link(element_links_list)
    
    return element_links_list, first_link

# %%
#
def extract_single_li_event_data(li_element, get_li_element_contents = False, 
                                 event_category = np.nan, year = np.nan):
    """
    Extract data for a single <li> element represent an event (regardless of the event_type, of whether the 
    <li> element is a sub_item of a different <li> element, etc)
    
    Params:
        li_element:
        get_li_element_contents: True only if I need to get li_element contents to troubleshoot missing li_element data
                                 (otherwise seems unncessary - waste of memory)
        event_category: used to mark 'Christian feast day' holidays or events grouped by calendar type (see January_1)
        year: applies to 'Events', 'Births', 'Deaths', not 'Holidays_and_observances'
              defaults to np.nan
              if needed, it is passed from extract_and_process_event_data, or assigned within that function
        
    Returns:
        li_element_dict: dictionary of fields common to all event elements (regardless of event_type, etc)
                         eg. {'year': ,
                              'event_description': ,
                              'event_links_list': ,
                              'event_links_text': ,
                              'event_first_link': ,
                              'event_category': ,
                              'event_contents_list': (optional)
                              }
    """
    li_element_dict = {}

    # get li_element data and build li_element_dict
    li_element_dict['year'] = year
    li_element_dict['event_description'] = get_event_description(li_element.text)
    
    try:        
        (li_element_dict['event_links_list'],
         li_element_dict['event_first_link']) = extract_links_data(li_element)
    except:
        li_element_dict['event_links_list'] = 'NavigableString'
        li_element_dict['event_first_link'] = 'NavigableString'
    
    li_element_dict['event_category'] = event_category
    
    
    # seems unncessary, but get li_element contents in case I need to troubleshoot missing li_element data
    if get_li_element_contents:
        li_element_dict['event_contents_list'] = li_element.contents
        
    return li_element_dict

# %%
# changed from get_sub_items to get_sub_items_data
def get_sub_items_data(child, event_category = np.nan):
    """
    Get data of sub_items of child event element.
    Loops through sub_items, uses function extract_single_li_event_data to extract sub_item data.
    
    Params:
        child:
        event_category: indicates if item is a 'Christian feast day' event type
        
    Returns:
        sub_items_data_list: list of dictionaries
                             each dictionary has fields common to all event elements
                             eg. {'event_description': ,
                                  'event_links_list': ,
                                  'event_first_link': ,
                                  'event_category': ,
                                  'event_contents_list': (optional)
                                  }
    """
    sub_items_data_list = []
    
    for li in child.find_all('li'):
        sub_item_dict = extract_single_li_event_data(li, event_category = event_category)
        sub_items_data_list.append(sub_item_dict)
            
    return sub_items_data_list

# %%
def is_christian_feast_day(ul_element):
    """
    Check if <ul> element is a list of 'Christian feast day' holidays
    
    Params:
        ul_element
        
    Returns:
        True or False
    """
    is_christian_feast_day = False
    
    # get the first line of the ul_element
    first_line = ul_element.text.split('\n')[0].lower()
    if 'christian' in first_line and 'feast' in first_line and 'day' in first_line:
        is_christian_feast_day = True

    return is_christian_feast_day

# %%
def get_event_description(li_element_text):
    """
    Get the description of an event using the event's li_element_text.
    Eliminate the year data from the event description (it is already captured in a field called 'year')
    
    Params:
        li_element_text: a string containing the text of the li_element
        
    Returns:
        li_element_description: the li_element description stripped of year data
    """
    # strip li_element_text of any white spaces
    li_element_text = li_element_text.strip()
    
    # compile year_pattern (year is at the beginning of li_element_text)
    # \W character is for matching - and –
    year_pattern = re.compile(r'^\d{1,4}\s{0,2}\W\s{0,2}')
    
    # compile dash_pattern (if li_element_text starts with - or –)
    dash_pattern = re.compile(r'^\W\s{1,2}')
    
    # if year_pattern in li_element_text, replace with ''
    li_element_description = year_pattern.sub('', li_element_text)
    
    # if dash_pattern in li_element_text, replace with ''
    li_element_description = dash_pattern.sub('', li_element_description)
    
    return li_element_description

# %% [markdown]
# #### Section 2 - add day data to database
# Tables affected:
# - wiki_day_data_log
# - wiki_link
# - wiki_event
# - wiki_link_usage

# %%
def add_day_data_to_db(day_data_dict, database_file = DATABASE_FILE, doe = DOE):
    """
    Main function for adding a day's data to wikipedia_tdih.db.
    It takes the day data retrieved and cleaned up with get_and_process_day_data and uses it to update
    the following tables:
        - wiki_day_data_log
        - wiki_link (if link not already in wiki_link)
        - wiki_event        
        - wiki_link_usage
    
    Params:
        day_data_dict: dictionary with day data (created with day_data_main)
        database_file: database to save data to
        doe: date of entry (defaults to current day)
        
    Returns:
        update_results: a list of dictionaries with the status of each table update
                        e.g. {'doe': doe,
                              'wiki_table_name': 'wiki_event',
                              'update_status': 'update_complete',
                              'update_note': 'events'}
    """
    update_results = []
    
    # make smaller dictionaries based on which table data belongs in
    # data for the wiki_day_data_log
    day_data = {key: day_data_dict[key] for key in ['status_code', 'day_soup', 'no_event_for']}

    # data for wiki_event (and, if needed, wiki_link)
    event_data = {key: day_data_dict.get(key, []) for key in ['events', 'births', 'deaths',
                                                            'holidays_and_observances']}

    
    # get day and month for the data being looged
    day = day_data_dict['day']
    month = day_data_dict['month']
    
    with sqlite3.connect(database_file) as conn:
        cursor = conn.cursor()
        
        # log data into wiki_day_data_log
        update_wiki_day_data_log = update_table_wiki_day_data_log(day_data, day, month, cursor, doe)
        update_results.append(update_wiki_day_data_log)
        
        # log data into wiki_event (and, if needed, in wiki_link)
        for event_type in event_data:
            update_wiki_event = update_table_wiki_event(event_data[event_type], event_type, day, month, cursor, doe)
            update_results.append(update_wiki_event)
            
        # update table wiki_log
        update_table_wiki_log(update_results, cursor, doe)
        
    return update_results

# %%
def update_table_wiki_day_data_log(day_data, day, month, database_cursor, doe = DOE):
    """
    Add to table wiki_day_data_log the data received from Wikipedia API. 
    This data is minimally processed and is used as restore point in case subsequent CRUD operations
    involving cleaned-up and processed data fail.
    
    Params:
        day_data: dictionary with minimally processed data retrived from Wikipedia for a specific day of the year
                  e.g. {'status_code': status_code_of_the_API_request,
                        'day_soup': : BeautifulSoup_object_representing_day_data,
                        'no_event_for': list_of_event_types_without_events}
        day: day of the events retrieved from Wikipedia
        month: month of the events retrieved from Wikipedia
    
    Returns:
        update_status_dict: dictionary with status of wiki_day_data_log update
                            e.g. {'doe': doe,
                                  'wiki_table_name': 'wiki_day_data_log',
                                  'update_status': update_status
                                  'update_note': np.nan}  # this is relevant to other tables (e.g. wiki_event)
    """
    cursor = database_cursor
    
    # data to be logged into wiki_day_data_log
    status_code = day_data['status_code']
    day_soup = str(day_data['day_soup']).encode('utf-8') # change BeautifulSoup object to Python blob
    no_event_for = str(day_data['no_event_for'])
    
    # organize the data into a tuple
    data = (doe, day, month, status_code, day_soup, no_event_for)
   
    
    try:
        cursor.execute('INSERT INTO wiki_day_data_log VALUES (null, ?, ?, ?, ?, ?, ?)', data)
        update_status = 'update_complete'
    except Exception as e:
        update_status = repr(e)
        
    update_status_dict = {'doe': doe,
                          'wiki_table_name': 'wiki_day_data_log',
                          'update_status': update_status,
                          'update_note': np.nan}
        
    return update_status_dict

# %%
def update_table_wiki_event(event_data, event_type, day, month, database_cursor, doe = DOE):
    """
    Add data received from Wikipedia API into the wiki_event table.
    (This data has been cleaned-up and formatted to match the specifications of wikipedia_tdih.db database.)
    
    Params:
        event_data: list of dictionaries with data for the event
                    (eg. {'year': year,
                          'bc_ad': bc_ad,
                          'bc_ad_note': bc_ad_note,
                          'event_description': event_description`,
                          'event_category': event_category, # e.g. 'Christian feast day'
                          'event_first_link': event_first_link,
                          'event_links_list': list_of_links,
                          'event_links_text': list_of_text_of_links} 
        event_type: event type being processed
                    (i.e. - events
                          - births
                          - deaths
                          - holidays_and_observances)
        day: day of the event
        month: month of the event
        database_cursor: cursor object for wikipedia_tdih.db
        doe: date of entry
       
    Returns:
        update_table_status: a dictionary with the update status for each event type
                             e.g {'doe': date_of_entry,
                                  'wiki_table_name': 'wiki_event',
                                  'update_status': update_status,
                                  'event_type': event_type,              
                                  'update_note': f'{event_type}: update_complete'}
    """
    cursor = database_cursor
    
    for event in event_data:
        # get the data the needs to be logged
        year = event['year']
        bc_ad = event.get('bc_ad', np.nan) # event_type 'holidays_and_observances' has no bc_ad data
        bc_ad_note = event.get('bc_ad_note', np.nan)
        event_description = event['event_description']
        event_category = event['event_category']
        event_links_list = event['event_links_list']
        
        # organize the event data into a tuple
        data = (doe, day, month, year, bc_ad, bc_ad_note, event_type, event_description, event_category)
        
        # insert data into wiki_event
        cursor.execute('INSERT INTO wiki_event VALUES (null, ?, ?, ?, ?, ?, ?, ?, ?, ?)', data)
        
        # update table wiki_link_usage
        event_id = cursor.lastrowid
        update_table_wiki_link_usage(event_links_list, event['event_first_link'], event_id, cursor, doe)
        
    update_note = event_type if event_data else f'{event_type}: no_data'
    
    update_table_status = {'doe': doe,
                           'wiki_table_name': 'wiki_event',
                           'update_status': 'update_complete',
                           'update_note': update_note}
    
    return update_table_status

# %%
def update_table_wiki_link_usage(event_links_list, event_first_link, event_id, database_cursor, doe = DOE):
    """
    Add link usage info to wiki_link_usage.
    
    Params:
        event_links_list: list of tuples with data for wiki links found in the description of an event
                          tuples are in the form (link_url, link_title, link_text)
        event_first_link: the first link in the event description (that is not a year_link)
        database_cursor: cursor object for wikipedia_tdih.db
        doe: date of entry (defaults to current day)
        
    Returns:
        None
        
    """
    cursor = database_cursor
    
    # initialize is_subject_link to np.nan
    # true value is computed in different step (function on TO-DO list)
    
    for link in event_links_list:
        # initialize is_first_link
        is_first_link = 0
        # check that link is not the year link (found at the beginning of most events)
        # use link_url (i.e. link[0] to do the check)
        if not is_year_link(link[0]):
            if link == event_first_link:
                is_first_link = 1
            link_id, link_text_id = get_id_or_update_wiki_link(link, cursor, doe)
            
            # data for the wiki_link_usage table
            data = (doe, link_id, event_id, link_text_id, is_first_link)
            
            # update wiki_link_usage table
            # second null is for is_subject_link (true value is calculated separately in function is_subject_link)
            cursor.execute('INSERT INTO wiki_link_usage VALUES (null,?,?,?,?,?,null)', data)

# %%
def is_year_link(wiki_link_url):
    """
    Check if wiki_link is a year link (in most cases the year links are not relevant to the description 
    of an event. They just link to the wikipedia page for a specific year.)
    
    Params:
        wiki_link_url: url of the link found in the description of an event
        
    Returns:
        True or False
    """
    # match patterns like: wiki/AD_100, wiki/AD100, wiki/100, wiki/100_AD, wiki/100AD (for AD or BC)
    event_year = re.compile(r'(wiki/ad_*\d{1,4})|(wiki/bc_*\d{1,4})|(wiki/\d{1,4})|(wiki/\d{1,4}_*ad)|(wiki/\d{1,4}_*bc)', re.IGNORECASE)
    
    return event_year.search(wiki_link_url)

# %%
def get_id_or_update_wiki_link(wiki_link, database_cursor, doe = DOE):
    """
    Get the id of wiki_link from wiki_link table. If wiki_link is not in wiki_link, 
    add wiki_link to wiki_link and return the id of the newly added link.
    
    Update table wiki_link_text if link_text not already in table.
    
    Params:
        wiki_link: tuple with data for a wiki_link
                   tuple is in form (wiki_link_url, wiki_link_title, wiki_link_text)
                   e.g. ('wiki/Albert_Einstein', 'Albert Einstein', 'Albert Einstein')
        database_cursor: cursor object for the wikipedia_tdih.db
        doe: date of entry
          
    Returns:
        link_id    
    """
    cursor = database_cursor
    link_id = ''
    
    link_url = wiki_link[0]
    link_title = wiki_link[1]
    link_text = wiki_link[2]
    
    # organizing wiki_link data into a tuple
    data = (doe, link_url, link_title)
    cursor.execute('INSERT OR IGNORE INTO wiki_link VALUES (null,?,?,?)', data)
    
    # get the id of (newly added) wiki_link for use in wiki_link_usage
    cursor.execute('SELECT link_id FROM wiki_link WHERE link_url = ?', (link_url, ))
    link_id = cursor.fetchone()[0]
    
    # update (if needed) table wiki_link_text
    link_text_id = update_table_wiki_link_text(link_text, link_id, cursor, doe)
        
    return link_id, link_text_id

# %%
def update_table_wiki_link_text(wiki_link_text, link_id, database_cursor, doe = DOE):
    """
    Update table wiki_link_text if link_text not already in table.
    
    Params:
        wiki_link_text: string representing text of wiki_link
        database_cursor: cursor object for the wikipedia_tdih.db
        doe: date of entry
          
    Returns:
        link_text_id    
    """
    cursor = database_cursor
    
    # organize data into a tuple
    data = (doe, link_id, wiki_link_text)
    
    # insert data (if needed)
    cursor.execute('INSERT OR IGNORE INTO wiki_link_text VALUES (null,?,?,?)', data)
    
    # get link_text_id of (newly added) wiki_link_text
    cursor.execute('SELECT link_text_id FROM wiki_link_text WHERE link_text = ?', (wiki_link_text,))
    link_text_id = cursor.fetchone()[0]
    
    return link_text_id

# %%
def update_table_wiki_log(update_results, database_cursor, doe = DOE):
    """
    Update table wiki_log with the results of updating wiki_day_data_log and wiki_event.
    
    Params:
        update_results: dictionary with update status
                        e.g. {'doe': '2021-02-15',
                              'wiki_table_name': 'wiki_day_data_log',
                              'update_status': 'update_complete',
                              'update_note': nan}
        cursor: database cursor
        doe: date of entry (defaults to current day)
        
    Return:
        None
    """
    cursor = database_cursor
    
    for update in update_results:
        data = (update['doe'], 
                update['wiki_table_name'],
                update['update_status'],
                update['update_note'])
        
        cursor.execute('INSERT INTO wiki_log VALUES (null,?,?,?,?)', data)

# %% [markdown]
# ## Test day_data_main

# %%
day_data_dict, update_results = day_data_main('February_29')
# Out:
# February_29
# --------
# status_code:  200
# adding data to db
# data added

# %%
day_data_dict, update_results = day_data_main('February_23')
# Out:
# 200
# February_23
# --------
# status_code:  200
# adding data to db
# event_link:  ('/wiki/Roman_emperor', 'Roman emperor')
# /wiki/Roman_emperor
# Roman emperor
#
# event_link:  ('/wiki/Roman_emperor', 'Roman emperor')
# /wiki/Roman_emperor
# Roman emperor
#
# event_link:  ('/wiki/Diocletian', 'Diocletian')
# /wiki/Diocletian
# Diocletian
#
# event_link:  ('/wiki/Nicomedia', 'Nicomedia')
# /wiki/Nicomedia
# Nicomedia
#
# event_link:  ('/wiki/Diocletianic_Persecution', 'Diocletianic Persecution')
# /wiki/Diocletianic_Persecution
# Diocletianic Persecution
#
# event_link:  ('/wiki/Byzantine_emperor', 'Byzantine emperor')
# /wiki/Byzantine_emperor
# Byzantine emperor
#
# event_link:  ('/wiki/Byzantine_emperor', 'Byzantine emperor')
# /wiki/Byzantine_emperor
# Byzantine emperor
#
# event_link:  ('/wiki/Justinian_I', 'Justinian I')
# /wiki/Justinian_I
# Justinian I
#
# event_link:  ('/wiki/Eastern_Orthodox_Church', 'Eastern Orthodox Church')
# /wiki/Eastern_Orthodox_Church
# Eastern Orthodox Church
#
# event_link:  ('/wiki/Basilica', 'Basilica')
# /wiki/Basilica
# Basilica
#
# event_link:  ('/wiki/Constantinople', 'Constantinople')
# /wiki/Constantinople
# Constantinople
#
# event_link:  ('/wiki/Hagia_Sophia', 'Hagia Sophia')
# /wiki/Hagia_Sophia
# Hagia Sophia
#
# event_link:  ('/wiki/Gutenberg_Bible', 'Gutenberg Bible')
# /wiki/Gutenberg_Bible
# Gutenberg Bible
#
# event_link:  ('/wiki/Gutenberg_Bible', 'Gutenberg Bible')
# /wiki/Gutenberg_Bible
# Gutenberg Bible
#
# event_link:  ('/wiki/Western_culture', 'Western culture')
# /wiki/Western_culture
# Western culture
#
# event_link:  ('/wiki/Book', 'Book')
# /wiki/Book
# Book
#
# event_link:  ('/wiki/Movable_type', 'Movable type')
# /wiki/Movable_type
# Movable type
#
# event_link:  ('/wiki/Mapuche', 'Mapuche')
# /wiki/Mapuche
# Mapuche
#
# event_link:  ('/wiki/Mapuche', 'Mapuche')
# /wiki/Mapuche
# Mapuche
#
# event_link:  ('/wiki/Lautaro', 'Lautaro')
# /wiki/Lautaro
# Lautaro
#
# event_link:  ('/wiki/Spanish_Empire', 'Spanish Empire')
# /wiki/Spanish_Empire
# Spanish Empire
#
# event_link:  ('/wiki/Battle_of_Marihue%C3%B1u', 'Battle of Marihueñu')
# /wiki/Battle_of_Marihue%C3%B1u
# Battle of Marihueñu
#
# event_link:  ('/wiki/Chile', 'Chile')
# /wiki/Chile
# Chile
#
# event_link:  ('/wiki/Ballet_Royal_de_la_Nuit', 'Ballet Royal de la Nuit')
# /wiki/Ballet_Royal_de_la_Nuit
# Ballet Royal de la Nuit
#
# event_link:  ('/wiki/Ballet_Royal_de_la_Nuit', 'Ballet Royal de la Nuit')
# /wiki/Ballet_Royal_de_la_Nuit
# Ballet Royal de la Nuit
#
# event_link:  ('/wiki/Salle_du_Petit-Bourbon', 'Salle du Petit-Bourbon')
# /wiki/Salle_du_Petit-Bourbon
# Salle du Petit-Bourbon
#
# event_link:  ('/wiki/Paris', 'Paris')
# /wiki/Paris
# Paris
#
# event_link:  ('/wiki/York_Castle', 'York Castle')
# /wiki/York_Castle
# York Castle
#
# event_link:  ('/wiki/York_Castle', 'York Castle')
# /wiki/York_Castle
# York Castle
#
# event_link:  ('/wiki/Dick_Turpin', 'Dick Turpin')
# /wiki/Dick_Turpin
# Dick Turpin
#
# event_link:  ('/wiki/American_Revolutionary_War', 'American Revolutionary War')
# /wiki/American_Revolutionary_War
# American Revolutionary War
#
# event_link:  ('/wiki/American_Revolutionary_War', 'American Revolutionary War')
# /wiki/American_Revolutionary_War
# American Revolutionary War
#
# event_link:  ('/wiki/Friedrich_Wilhelm_von_Steuben', 'Friedrich Wilhelm von Steuben')
# /wiki/Friedrich_Wilhelm_von_Steuben
# Friedrich Wilhelm von Steuben
#
# event_link:  ('/wiki/Valley_Forge,_Pennsylvania', 'Valley Forge, Pennsylvania')
# /wiki/Valley_Forge,_Pennsylvania
# Valley Forge, Pennsylvania
#
# event_link:  ('/wiki/Continental_Army', 'Continental Army')
# /wiki/Continental_Army
# Continental Army
#
# event_link:  ('/wiki/Cato_Street_Conspiracy', 'Cato Street Conspiracy')
# /wiki/Cato_Street_Conspiracy
# Cato Street Conspiracy
#
# event_link:  ('/wiki/Cato_Street_Conspiracy', 'Cato Street Conspiracy')
# /wiki/Cato_Street_Conspiracy
# Cato Street Conspiracy
#
# event_link:  ('/wiki/Texas_Revolution', 'Texas Revolution')
# /wiki/Texas_Revolution
# Texas Revolution
#
# event_link:  ('/wiki/Texas_Revolution', 'Texas Revolution')
# /wiki/Texas_Revolution
# Texas Revolution
#
# event_link:  ('/wiki/Siege_of_the_Alamo', 'Siege of the Alamo')
# /wiki/Siege_of_the_Alamo
# Siege of the Alamo
#
# event_link:  ('/wiki/Battle_of_the_Alamo', 'Battle of the Alamo')
# /wiki/Battle_of_the_Alamo
# Battle of the Alamo
#
# event_link:  ('/wiki/San_Antonio,_Texas', 'San Antonio, Texas')
# /wiki/San_Antonio,_Texas
# San Antonio, Texas
#
# event_link:  ('/wiki/Mexican%E2%80%93American_War', 'Mexican–American War')
# /wiki/Mexican%E2%80%93American_War
# Mexican–American War
#
# event_link:  ('/wiki/Mexican%E2%80%93American_War', 'Mexican–American War')
# /wiki/Mexican%E2%80%93American_War
# Mexican–American War
#
# event_link:  ('/wiki/Battle_of_Buena_Vista', 'Battle of Buena Vista')
# /wiki/Battle_of_Buena_Vista
# Battle of Buena Vista
#
# event_link:  ('/wiki/Zachary_Taylor', 'Zachary Taylor')
# /wiki/Zachary_Taylor
# Zachary Taylor
#
# event_link:  ('/wiki/Antonio_L%C3%B3pez_de_Santa_Anna', 'Antonio López de Santa Anna')
# /wiki/Antonio_L%C3%B3pez_de_Santa_Anna
# Antonio López de Santa Anna
#
# event_link:  ('/wiki/Orange_Free_State', 'Orange Free State')
# /wiki/Orange_Free_State
# Orange Free State
#
# event_link:  ('/wiki/Orange_Free_State', 'Orange Free State')
# /wiki/Orange_Free_State
# Orange Free State
#
# event_link:  ('/wiki/Abraham_Lincoln', 'Abraham Lincoln')
# /wiki/Abraham_Lincoln
# Abraham Lincoln
#
# event_link:  ('/wiki/Abraham_Lincoln', 'Abraham Lincoln')
# /wiki/Abraham_Lincoln
# Abraham Lincoln
#
# event_link:  ('/wiki/Baltimore_Plot', 'Baltimore Plot')
# /wiki/Baltimore_Plot
# Baltimore Plot
#
# event_link:  ('/wiki/Baltimore', 'Baltimore')
# /wiki/Baltimore
# Baltimore
#
# event_link:  ('/wiki/Maryland', 'Maryland')
# /wiki/Maryland
# Maryland
#
# event_link:  ('/wiki/Reconstruction_Era', 'Reconstruction Era')
# /wiki/Reconstruction_Era
# Reconstruction Era
#
# event_link:  ('/wiki/Reconstruction_Era', 'Reconstruction Era')
# /wiki/Reconstruction_Era
# Reconstruction Era
#
# event_link:  ('/wiki/American_Civil_War', 'American Civil War')
# /wiki/American_Civil_War
# American Civil War
#
# event_link:  ('/wiki/Mississippi', 'Mississippi')
# /wiki/Mississippi
# Mississippi
#
# event_link:  ('/wiki/Union_(American_Civil_War)', 'Union (American Civil War)')
# /wiki/Union_(American_Civil_War)
# Union (American Civil War)
#
# event_link:  ('/wiki/Alabama', 'Alabama')
# /wiki/Alabama
# Alabama
#
# event_link:  ('/wiki/Alabama', 'Alabama')
# /wiki/Alabama
# Alabama
#
# event_link:  ('/wiki/U.S._state', 'U.S. state')
# /wiki/U.S._state
# U.S. state
#
# event_link:  ('/wiki/Competition_law', 'Competition law')
# /wiki/Competition_law
# Competition law
#
# event_link:  ('/wiki/Sino-French_War', 'Sino-French War')
# /wiki/Sino-French_War
# Sino-French War
#
# event_link:  ('/wiki/Sino-French_War', 'Sino-French War')
# /wiki/Sino-French_War
# Sino-French War
#
# event_link:  ('/wiki/Battle_of_%C4%90%E1%BB%93ng_%C4%90%C4%83ng_(1885)', 'Battle of Đồng Đăng (1885)')
# /wiki/Battle_of_%C4%90%E1%BB%93ng_%C4%90%C4%83ng_(1885)
# Battle of Đồng Đăng (1885)
#
# event_link:  ('/wiki/Tonkin', 'Tonkin')
# /wiki/Tonkin
# Tonkin
#
# event_link:  ('/wiki/Charles_Martin_Hall', 'Charles Martin Hall')
# /wiki/Charles_Martin_Hall
# Charles Martin Hall
#
# event_link:  ('/wiki/Charles_Martin_Hall', 'Charles Martin Hall')
# /wiki/Charles_Martin_Hall
# Charles Martin Hall
#
# event_link:  ('/wiki/Aluminium', 'Aluminium')
# /wiki/Aluminium
# Aluminium
#
# event_link:  ('/wiki/Julia_Brainerd_Hall', 'Julia Brainerd Hall')
# /wiki/Julia_Brainerd_Hall
# Julia Brainerd Hall
#
# event_link:  ('/wiki/French_Riviera', 'French Riviera')
# /wiki/French_Riviera
# French Riviera
#
# event_link:  ('/wiki/French_Riviera', 'French Riviera')
# /wiki/French_Riviera
# French Riviera
#
# event_link:  ('/wiki/%C3%89mile_Zola', 'Émile Zola')
# /wiki/%C3%89mile_Zola
# Émile Zola
#
# event_link:  ('/wiki/%C3%89mile_Zola', 'Émile Zola')
# /wiki/%C3%89mile_Zola
# Émile Zola
#
# event_link:  ('/wiki/J%27Accuse%E2%80%A6!', "J'Accuse…!")
# /wiki/J%27Accuse%E2%80%A6!
# J'Accuse…!
#
# event_link:  ('/wiki/Antisemitism', 'Antisemitism')
# /wiki/Antisemitism
# Antisemitism
#
# event_link:  ('/wiki/Captain_(OF-2)', 'Captain (OF-2)')
# /wiki/Captain_(OF-2)
# Captain (OF-2)
#
# event_link:  ('/wiki/Alfred_Dreyfus', 'Alfred Dreyfus')
# /wiki/Alfred_Dreyfus
# Alfred Dreyfus
#
# event_link:  ('/wiki/Second_Boer_War', 'Second Boer War')
# /wiki/Second_Boer_War
# Second Boer War
#
# event_link:  ('/wiki/Second_Boer_War', 'Second Boer War')
# /wiki/Second_Boer_War
# Second Boer War
#
# event_link:  ('/wiki/Battle_of_the_Tugela_Heights', 'Battle of the Tugela Heights')
# /wiki/Battle_of_the_Tugela_Heights
# Battle of the Tugela Heights
#
# event_link:  ('/wiki/Cuba', 'Cuba')
# /wiki/Cuba
# Cuba
#
# event_link:  ('/wiki/Cuba', 'Cuba')
# /wiki/Cuba
# Cuba
#
# event_link:  ('/wiki/Guantanamo_Bay_Naval_Base', 'Guantanamo Bay Naval Base')
# /wiki/Guantanamo_Bay_Naval_Base
# Guantanamo Bay Naval Base
#
# event_link:  ('/wiki/Paul_P._Harris', 'Paul P. Harris')
# /wiki/Paul_P._Harris
# Paul P. Harris
#
# event_link:  ('/wiki/Paul_P._Harris', 'Paul P. Harris')
# /wiki/Paul_P._Harris
# Paul P. Harris
#
# event_link:  ('/wiki/Rotary_Club', 'Rotary Club')
# /wiki/Rotary_Club
# Rotary Club
#
# event_link:  ('/wiki/Service_club', 'Service club')
# /wiki/Service_club
# Service club
#
# event_link:  ('/wiki/AEA_Silver_Dart', 'AEA Silver Dart')
# /wiki/AEA_Silver_Dart
# AEA Silver Dart
#
# event_link:  ('/wiki/AEA_Silver_Dart', 'AEA Silver Dart')
# /wiki/AEA_Silver_Dart
# AEA Silver Dart
#
# event_link:  ('/wiki/British_Empire', 'British Empire')
# /wiki/British_Empire
# British Empire
#
# event_link:  ('/wiki/Saint_Petersburg', 'Saint Petersburg')
# /wiki/Saint_Petersburg
# Saint Petersburg
#
# event_link:  ('/wiki/Saint_Petersburg', 'Saint Petersburg')
# /wiki/Saint_Petersburg
# Saint Petersburg
#
# event_link:  ('/wiki/February_Revolution', 'February Revolution')
# /wiki/February_Revolution
# February Revolution
#
# event_link:  ('/wiki/Gregorian_calendar', 'Gregorian calendar')
# /wiki/Gregorian_calendar
# Gregorian calendar
#
# event_link:  ('/wiki/Calvin_Coolidge', 'Calvin Coolidge')
# /wiki/Calvin_Coolidge
# Calvin Coolidge
#
# event_link:  ('/wiki/Calvin_Coolidge', 'Calvin Coolidge')
# /wiki/Calvin_Coolidge
# Calvin Coolidge
#
# event_link:  ('/wiki/United_States_Congress', 'United States Congress')
# /wiki/United_States_Congress
# United States Congress
#
# event_link:  ('/wiki/Federal_Radio_Commission', 'Federal Radio Commission')
# /wiki/Federal_Radio_Commission
# Federal Radio Commission
#
# event_link:  ('/wiki/Federal_Communications_Commission', 'Federal Communications Commission')
# /wiki/Federal_Communications_Commission
# Federal Communications Commission
#
# event_link:  ('/wiki/Theoretical_physics', 'Theoretical physics')
# /wiki/Theoretical_physics
# Theoretical physics
#
# event_link:  ('/wiki/Theoretical_physics', 'Theoretical physics')
# /wiki/Theoretical_physics
# Theoretical physics
#
# event_link:  ('/wiki/Werner_Heisenberg', 'Werner Heisenberg')
# /wiki/Werner_Heisenberg
# Werner Heisenberg
#
# event_link:  ('/wiki/Wolfgang_Pauli', 'Wolfgang Pauli')
# /wiki/Wolfgang_Pauli
# Wolfgang Pauli
#
# event_link:  ('/wiki/Uncertainty_principle', 'Uncertainty principle')
# /wiki/Uncertainty_principle
# Uncertainty principle
#
# event_link:  ('/wiki/Leopold_III_of_Belgium', 'Leopold III of Belgium')
# /wiki/Leopold_III_of_Belgium
# Leopold III of Belgium
#
# event_link:  ('/wiki/Leopold_III_of_Belgium', 'Leopold III of Belgium')
# /wiki/Leopold_III_of_Belgium
# Leopold III of Belgium
#
# event_link:  ('/wiki/Belgium', 'Belgium')
# /wiki/Belgium
# Belgium
#
# event_link:  ('/wiki/Plutonium', 'Plutonium')
# /wiki/Plutonium
# Plutonium
#
# event_link:  ('/wiki/Plutonium', 'Plutonium')
# /wiki/Plutonium
# Plutonium
#
# event_link:  ('/wiki/Glenn_T._Seaborg', 'Glenn T. Seaborg')
# /wiki/Glenn_T._Seaborg
# Glenn T. Seaborg
#
# event_link:  ('/wiki/World_War_II', 'World War II')
# /wiki/World_War_II
# World War II
#
# event_link:  ('/wiki/World_War_II', 'World War II')
# /wiki/World_War_II
# World War II
#
# event_link:  ('/wiki/Empire_of_Japan', 'Empire of Japan')
# /wiki/Empire_of_Japan
# Empire of Japan
#
# event_link:  ('/wiki/Bombardment_of_Ellwood', 'Bombardment of Ellwood')
# /wiki/Bombardment_of_Ellwood
# Bombardment of Ellwood
#
# event_link:  ('/wiki/Santa_Barbara,_California', 'Santa Barbara, California')
# /wiki/Santa_Barbara,_California
# Santa Barbara, California
#
# event_link:  ('/wiki/County_Cavan', 'County Cavan')
# /wiki/County_Cavan
# County Cavan
#
# event_link:  ('/wiki/County_Cavan', 'County Cavan')
# /wiki/County_Cavan
# County Cavan
#
# event_link:  ('/wiki/Greek_Resistance', 'Greek Resistance')
# /wiki/Greek_Resistance
# Greek Resistance
#
# event_link:  ('/wiki/Greek_Resistance', 'Greek Resistance')
# /wiki/Greek_Resistance
# Greek Resistance
#
# event_link:  ('/wiki/United_Panhellenic_Organization_of_Youth', 'United Panhellenic Organization of Youth')
# /wiki/United_Panhellenic_Organization_of_Youth
# United Panhellenic Organization of Youth
#
# event_link:  ('/wiki/Soviet_Union', 'Soviet Union')
# /wiki/Soviet_Union
# Soviet Union
#
# event_link:  ('/wiki/Soviet_Union', 'Soviet Union')
# /wiki/Soviet_Union
# Soviet Union
#
# event_link:  ('/wiki/Operation_Lentil_(Caucasus)', 'Operation Lentil (Caucasus)')
# /wiki/Operation_Lentil_(Caucasus)
# Operation Lentil (Caucasus)
#
# event_link:  ('/wiki/Chechens', 'Chechens')
# /wiki/Chechens
# Chechens
#
# event_link:  ('/wiki/Ingush_people', 'Ingush people')
# /wiki/Ingush_people
# Ingush people
#
# event_link:  ('/wiki/North_Caucasus', 'North Caucasus')
# /wiki/North_Caucasus
# North Caucasus
#
# event_link:  ('/wiki/Battle_of_Iwo_Jima', 'Battle of Iwo Jima')
# /wiki/Battle_of_Iwo_Jima
# Battle of Iwo Jima
#
# event_link:  ('/wiki/Battle_of_Iwo_Jima', 'Battle of Iwo Jima')
# /wiki/Battle_of_Iwo_Jima
# Battle of Iwo Jima
#
# event_link:  ('/wiki/United_States_Marine', 'United States Marine')
# /wiki/United_States_Marine
# United States Marine
#
# event_link:  ('/wiki/Mount_Suribachi', 'Mount Suribachi')
# /wiki/Mount_Suribachi
# Mount Suribachi
#
# event_link:  ('/wiki/Raising_the_Flag_on_Iwo_Jima', 'Raising the Flag on Iwo Jima')
# /wiki/Raising_the_Flag_on_Iwo_Jima
# Raising the Flag on Iwo Jima
#
# event_link:  ('/wiki/11th_Airborne_Division_(United_States)', '11th Airborne Division (United States)')
# /wiki/11th_Airborne_Division_(United_States)
# 11th Airborne Division (United States)
#
# event_link:  ('/wiki/Filipinos', 'Filipinos')
# /wiki/Filipinos
# Filipinos
#
# event_link:  ('/wiki/Los_Ba%C3%B1os,_Laguna', 'Los Baños, Laguna')
# /wiki/Los_Ba%C3%B1os,_Laguna
# Los Baños, Laguna
#
# event_link:  ('/wiki/Philippines', 'Philippines')
# /wiki/Philippines
# Philippines
#
# event_link:  ('/wiki/Philippines', 'Philippines')
# /wiki/Philippines
# Philippines
#
# event_link:  ('/wiki/Manila', 'Manila')
# /wiki/Manila
# Manila
#
# event_link:  ('/wiki/Nazi_Germany', 'Nazi Germany')
# /wiki/Nazi_Germany
# Nazi Germany
#
# event_link:  ('/wiki/Nazi_Germany', 'Nazi Germany')
# /wiki/Nazi_Germany
# Nazi Germany
#
# event_link:  ('/wiki/Pozna%C5%84', 'Poznań')
# /wiki/Pozna%C5%84
# Poznań
#
# event_link:  ('/wiki/Soviet_Union', 'Soviet Union')
# /wiki/Soviet_Union
# Soviet Union
#
# event_link:  ('/wiki/History_of_Poland_(1939%E2%80%9345)', 'History of Poland (1939–45)')
# /wiki/History_of_Poland_(1939%E2%80%9345)
# History of Poland (1939–45)
#
# event_link:  ('/wiki/Pforzheim', 'Pforzheim')
# /wiki/Pforzheim
# Pforzheim
#
# event_link:  ('/wiki/Pforzheim', 'Pforzheim')
# /wiki/Pforzheim
# Pforzheim
#
# event_link:  ('/wiki/Bombing_of_Pforzheim_in_World_War_II', 'Bombing of Pforzheim in World War II')
# /wiki/Bombing_of_Pforzheim_in_World_War_II
# Bombing of Pforzheim in World War II
#
# event_link:  ('/wiki/International_Organization_for_Standardization', 'International Organization for Standardization')
# /wiki/International_Organization_for_Standardization
# International Organization for Standardization
#
# event_link:  ('/wiki/International_Organization_for_Standardization', 'International Organization for Standardization')
# /wiki/International_Organization_for_Standardization
# International Organization for Standardization
#
# event_link:  ('/wiki/Poliomyelitis', 'Poliomyelitis')
# /wiki/Poliomyelitis
# Poliomyelitis
#
# event_link:  ('/wiki/Poliomyelitis', 'Poliomyelitis')
# /wiki/Poliomyelitis
# Poliomyelitis
#
# event_link:  ('/wiki/Jonas_Salk', 'Jonas Salk')
# /wiki/Jonas_Salk
# Jonas Salk
#
# event_link:  ('/wiki/Vaccine', 'Vaccine')
# /wiki/Vaccine
# Vaccine
#
# event_link:  ('/wiki/Pittsburgh', 'Pittsburgh')
# /wiki/Pittsburgh
# Pittsburgh
#
# event_link:  ('/wiki/Syria', 'Syria')
# /wiki/Syria
# Syria
#
# event_link:  ('/wiki/Syria', 'Syria')
# /wiki/Syria
# Syria
#
# event_link:  ('/wiki/Ba%27ath_Party', "Ba'ath Party")
# /wiki/Ba%27ath_Party
# Ba'ath Party
#
# event_link:  ('/wiki/Salah_Jadid', 'Salah Jadid')
# /wiki/Salah_Jadid
# Salah Jadid
#
# event_link:  ('/wiki/Coup', 'Coup')
# /wiki/Coup
# Coup
#
# event_link:  ('/wiki/Amin_al-Hafiz', 'Amin al-Hafiz')
# /wiki/Amin_al-Hafiz
# Amin al-Hafiz
#
# event_link:  ('/wiki/Operation_Lam_Son_719', 'Operation Lam Son 719')
# /wiki/Operation_Lam_Son_719
# Operation Lam Son 719
#
# event_link:  ('/wiki/Operation_Lam_Son_719', 'Operation Lam Son 719')
# /wiki/Operation_Lam_Son_719
# Operation Lam Son 719
#
# event_link:  ('/wiki/Do_Cao_Tri', 'Do Cao Tri')
# /wiki/Do_Cao_Tri
# Do Cao Tri
#
# event_link:  ('/wiki/Symbionese_Liberation_Army', 'Symbionese Liberation Army')
# /wiki/Symbionese_Liberation_Army
# Symbionese Liberation Army
#
# event_link:  ('/wiki/Symbionese_Liberation_Army', 'Symbionese Liberation Army')
# /wiki/Symbionese_Liberation_Army
# Symbionese Liberation Army
#
# event_link:  ('/wiki/Patty_Hearst', 'Patty Hearst')
# /wiki/Patty_Hearst
# Patty Hearst
#
# event_link:  ('/wiki/Iran_hostage_crisis', 'Iran hostage crisis')
# /wiki/Iran_hostage_crisis
# Iran hostage crisis
#
# event_link:  ('/wiki/Iran_hostage_crisis', 'Iran hostage crisis')
# /wiki/Iran_hostage_crisis
# Iran hostage crisis
#
# event_link:  ('/wiki/Supreme_Leader_of_Iran', 'Supreme Leader of Iran')
# /wiki/Supreme_Leader_of_Iran
# Supreme Leader of Iran
#
# event_link:  ('/wiki/Ayatollah', 'Ayatollah')
# /wiki/Ayatollah
# Ayatollah
#
# event_link:  ('/wiki/Ruhollah_Khomeini', 'Ruhollah Khomeini')
# /wiki/Ruhollah_Khomeini
# Ruhollah Khomeini
#
# event_link:  ('/wiki/Antonio_Tejero', 'Antonio Tejero')
# /wiki/Antonio_Tejero
# Antonio Tejero
#
# event_link:  ('/wiki/Antonio_Tejero', 'Antonio Tejero')
# /wiki/Antonio_Tejero
# Antonio Tejero
#
# event_link:  ('/wiki/Congress_of_Deputies_(Spain)', 'Congress of Deputies (Spain)')
# /wiki/Congress_of_Deputies_(Spain)
# Congress of Deputies (Spain)
#
# event_link:  ('/wiki/United_States_Environmental_Protection_Agency', 'United States Environmental Protection Agency')
# /wiki/United_States_Environmental_Protection_Agency
# United States Environmental Protection Agency
#
# event_link:  ('/wiki/United_States_Environmental_Protection_Agency', 'United States Environmental Protection Agency')
# /wiki/United_States_Environmental_Protection_Agency
# United States Environmental Protection Agency
#
# event_link:  ('/wiki/Polychlorinated_dibenzodioxins', 'Polychlorinated dibenzodioxins')
# /wiki/Polychlorinated_dibenzodioxins
# Polychlorinated dibenzodioxins
#
# event_link:  ('/wiki/Times_Beach,_Missouri', 'Times Beach, Missouri')
# /wiki/Times_Beach,_Missouri
# Times Beach, Missouri
#
# event_link:  ('/wiki/Supernova_1987a', 'Supernova 1987a')
# /wiki/Supernova_1987a
# Supernova 1987a
#
# event_link:  ('/wiki/Supernova_1987a', 'Supernova 1987a')
# /wiki/Supernova_1987a
# Supernova 1987a
#
# event_link:  ('/wiki/Large_Magellanic_Cloud', 'Large Magellanic Cloud')
# /wiki/Large_Magellanic_Cloud
# Large Magellanic Cloud
#
# event_link:  ('/wiki/Anfal_genocide', 'Anfal genocide')
# /wiki/Anfal_genocide
# Anfal genocide
#
# event_link:  ('/wiki/Anfal_genocide', 'Anfal genocide')
# /wiki/Anfal_genocide
# Anfal genocide
#
# event_link:  ('/wiki/Thailand', 'Thailand')
# /wiki/Thailand
# Thailand
#
# event_link:  ('/wiki/Thailand', 'Thailand')
# /wiki/Thailand
# Thailand
#
# event_link:  ('/wiki/Sunthorn_Kongsompong', 'Sunthorn Kongsompong')
# /wiki/Sunthorn_Kongsompong
# Sunthorn Kongsompong
#
# event_link:  ('/wiki/Coup_d%27%C3%A9tat', "Coup d'état")
# /wiki/Coup_d%27%C3%A9tat
# Coup d'état
#
# event_link:  ('/wiki/Chatichai_Choonhavan', 'Chatichai Choonhavan')
# /wiki/Chatichai_Choonhavan
# Chatichai Choonhavan
#
# event_link:  ('/wiki/1998_Kissimmee_tornado_outbreak', '1998 Kissimmee tornado outbreak')
# /wiki/1998_Kissimmee_tornado_outbreak
# 1998 Kissimmee tornado outbreak
#
# event_link:  ('/wiki/Kurds', 'Kurds')
# /wiki/Kurds
# Kurds
#
# event_link:  ('/wiki/Kurds', 'Kurds')
# /wiki/Kurds
# Kurds
#
# event_link:  ('/wiki/Abdullah_%C3%96calan', 'Abdullah Öcalan')
# /wiki/Abdullah_%C3%96calan
# Abdullah Öcalan
#
# event_link:  ('/wiki/Treason', 'Treason')
# /wiki/Treason
# Treason
#
# event_link:  ('/wiki/Ankara', 'Ankara')
# /wiki/Ankara
# Ankara
#
# event_link:  ('/wiki/Grayrigg_derailment', 'Grayrigg derailment')
# /wiki/Grayrigg_derailment
# Grayrigg derailment
#
# event_link:  ('/wiki/Grayrigg_derailment', 'Grayrigg derailment')
# /wiki/Grayrigg_derailment
# Grayrigg derailment
#
# event_link:  ('/wiki/Grayrigg', 'Grayrigg')
# /wiki/Grayrigg
# Grayrigg
#
# event_link:  ('/wiki/Cumbria', 'Cumbria')
# /wiki/Cumbria
# Cumbria
#
# event_link:  ('/wiki/United_States_Air_Force', 'United States Air Force')
# /wiki/United_States_Air_Force
# United States Air Force
#
# event_link:  ('/wiki/United_States_Air_Force', 'United States Air Force')
# /wiki/United_States_Air_Force
# United States Air Force
#
# event_link:  ('/wiki/B-2_Spirit', 'B-2 Spirit')
# /wiki/B-2_Spirit
# B-2 Spirit
#
# event_link:  ('/wiki/Diesel_oil', 'Diesel oil')
# /wiki/Diesel_oil
# Diesel oil
#
# event_link:  ('/wiki/Diesel_oil', 'Diesel oil')
# /wiki/Diesel_oil
# Diesel oil
#
# event_link:  ('/wiki/Hydrocarbon', 'Hydrocarbon')
# /wiki/Hydrocarbon
# Hydrocarbon
#
# event_link:  ('/wiki/Lambro', 'Lambro')
# /wiki/Lambro
# Lambro
#
# event_link:  ('/wiki/Environmental_disaster', 'Environmental disaster')
# /wiki/Environmental_disaster
# Environmental disaster
#
# event_link:  ('/wiki/23_February_2012_Iraq_attacks', '23 February 2012 Iraq attacks')
# /wiki/23_February_2012_Iraq_attacks
# 23 February 2012 Iraq attacks
#
# event_link:  ('/wiki/Iraq', 'Iraq')
# /wiki/Iraq
# Iraq
#
# event_link:  ('/wiki/Free_Syrian_Army', 'Free Syrian Army')
# /wiki/Free_Syrian_Army
# Free Syrian Army
#
# event_link:  ('/wiki/Free_Syrian_Army', 'Free Syrian Army')
# /wiki/Free_Syrian_Army
# Free Syrian Army
#
# event_link:  ('/wiki/Battle_of_al-Bab', 'Battle of al-Bab')
# /wiki/Battle_of_al-Bab
# Battle of al-Bab
#
# event_link:  ('/wiki/ISIL', 'ISIL')
# /wiki/ISIL
# ISIL
#
# event_link:  ('/wiki/Atlas_Air_Flight_3591', 'Atlas Air Flight 3591')
# /wiki/Atlas_Air_Flight_3591
# Atlas Air Flight 3591
#
# event_link:  ('/wiki/Atlas_Air_Flight_3591', 'Atlas Air Flight 3591')
# /wiki/Atlas_Air_Flight_3591
# Atlas Air Flight 3591
#
# event_link:  ('/wiki/Boeing_767', 'Boeing 767')
# /wiki/Boeing_767
# Boeing 767
#
# event_link:  ('/wiki/Trinity_Bay_(Texas)', 'Trinity Bay (Texas)')
# /wiki/Trinity_Bay_(Texas)
# Trinity Bay (Texas)
#
# event_link:  ('/wiki/Anahuac,_Texas', 'Anahuac, Texas')
# /wiki/Anahuac,_Texas
# Anahuac, Texas
#
# event_link:  ('/wiki/Pope_Paul_II', 'Pope Paul II')
# /wiki/Pope_Paul_II
# Pope Paul II
#
# event_link:  ('/wiki/Pope_Paul_II', 'Pope Paul II')
# /wiki/Pope_Paul_II
# Pope Paul II
#
# event_link:  ('/wiki/Louis_IX,_Duke_of_Bavaria', 'Louis IX, Duke of Bavaria')
# /wiki/Louis_IX,_Duke_of_Bavaria
# Louis IX, Duke of Bavaria
#
# event_link:  ('/wiki/Louis_IX,_Duke_of_Bavaria', 'Louis IX, Duke of Bavaria')
# /wiki/Louis_IX,_Duke_of_Bavaria
# Louis IX, Duke of Bavaria
#
# event_link:  ('/wiki/Matthias_Corvinus', 'Matthias Corvinus')
# /wiki/Matthias_Corvinus
# Matthias Corvinus
#
# event_link:  ('/wiki/Matthias_Corvinus', 'Matthias Corvinus')
# /wiki/Matthias_Corvinus
# Matthias Corvinus
#
# event_link:  ('/wiki/Onofrio_Panvinio', 'Onofrio Panvinio')
# /wiki/Onofrio_Panvinio
# Onofrio Panvinio
#
# event_link:  ('/wiki/Onofrio_Panvinio', 'Onofrio Panvinio')
# /wiki/Onofrio_Panvinio
# Onofrio Panvinio
#
# event_link:  ('/wiki/Henry_XI_of_Legnica', 'Henry XI of Legnica')
# /wiki/Henry_XI_of_Legnica
# Henry XI of Legnica
#
# event_link:  ('/wiki/Henry_XI_of_Legnica', 'Henry XI of Legnica')
# /wiki/Henry_XI_of_Legnica
# Henry XI of Legnica
#
# event_link:  ('/wiki/Salima_Sultan_Begum', 'Salima Sultan Begum')
# /wiki/Salima_Sultan_Begum
# Salima Sultan Begum
#
# event_link:  ('/wiki/Salima_Sultan_Begum', 'Salima Sultan Begum')
# /wiki/Salima_Sultan_Begum
# Salima Sultan Begum
#
# event_link:  ('/wiki/Jean-Baptiste_Morin_(mathematician)', 'Jean-Baptiste Morin (mathematician)')
# /wiki/Jean-Baptiste_Morin_(mathematician)
# Jean-Baptiste Morin (mathematician)
#
# event_link:  ('/wiki/Jean-Baptiste_Morin_(mathematician)', 'Jean-Baptiste Morin (mathematician)')
# /wiki/Jean-Baptiste_Morin_(mathematician)
# Jean-Baptiste Morin (mathematician)
#
# event_link:  ('/wiki/Balthazar_Gerbier', 'Balthazar Gerbier')
# /wiki/Balthazar_Gerbier
# Balthazar Gerbier
#
# event_link:  ('/wiki/Balthazar_Gerbier', 'Balthazar Gerbier')
# /wiki/Balthazar_Gerbier
# Balthazar Gerbier
#
# event_link:  ('/wiki/Samuel_Pepys', 'Samuel Pepys')
# /wiki/Samuel_Pepys
# Samuel Pepys
#
# event_link:  ('/wiki/Samuel_Pepys', 'Samuel Pepys')
# /wiki/Samuel_Pepys
# Samuel Pepys
#
# event_link:  ('/wiki/Tokugawa_Tsunayoshi', 'Tokugawa Tsunayoshi')
# /wiki/Tokugawa_Tsunayoshi
# Tokugawa Tsunayoshi
#
# event_link:  ('/wiki/Tokugawa_Tsunayoshi', 'Tokugawa Tsunayoshi')
# /wiki/Tokugawa_Tsunayoshi
# Tokugawa Tsunayoshi
#
# event_link:  ('/wiki/Jean-Baptiste_Le_Moyne,_Sieur_de_Bienville', 'Jean-Baptiste Le Moyne, Sieur de Bienville')
# /wiki/Jean-Baptiste_Le_Moyne,_Sieur_de_Bienville
# Jean-Baptiste Le Moyne, Sieur de Bienville
#
# event_link:  ('/wiki/Jean-Baptiste_Le_Moyne,_Sieur_de_Bienville', 'Jean-Baptiste Le Moyne, Sieur de Bienville')
# /wiki/Jean-Baptiste_Le_Moyne,_Sieur_de_Bienville
# Jean-Baptiste Le Moyne, Sieur de Bienville
#
# event_link:  ('/wiki/List_of_colonial_governors_of_Louisiana', 'List of colonial governors of Louisiana')
# /wiki/List_of_colonial_governors_of_Louisiana
# List of colonial governors of Louisiana
#
# event_link:  ('/wiki/George_Frideric_Handel', 'George Frideric Handel')
# /wiki/George_Frideric_Handel
# George Frideric Handel
#
# event_link:  ('/wiki/George_Frideric_Handel', 'George Frideric Handel')
# /wiki/George_Frideric_Handel
# George Frideric Handel
#
# event_link:  ('/wiki/Richard_Price', 'Richard Price')
# /wiki/Richard_Price
# Richard Price
#
# event_link:  ('/wiki/Richard_Price', 'Richard Price')
# /wiki/Richard_Price
# Richard Price
#
# event_link:  ('/wiki/Mayer_Amschel_Rothschild', 'Mayer Amschel Rothschild')
# /wiki/Mayer_Amschel_Rothschild
# Mayer Amschel Rothschild
#
# event_link:  ('/wiki/Mayer_Amschel_Rothschild', 'Mayer Amschel Rothschild')
# /wiki/Mayer_Amschel_Rothschild
# Mayer Amschel Rothschild
#
# event_link:  ('/wiki/Jos%C3%A9_Joaqu%C3%ADn_de_Herrera', 'José Joaquín de Herrera')
# /wiki/Jos%C3%A9_Joaqu%C3%ADn_de_Herrera
# José Joaquín de Herrera
#
# event_link:  ('/wiki/Jos%C3%A9_Joaqu%C3%ADn_de_Herrera', 'José Joaquín de Herrera')
# /wiki/Jos%C3%A9_Joaqu%C3%ADn_de_Herrera
# José Joaquín de Herrera
#
# event_link:  ('/wiki/Hendrik_Willem_Mesdag', 'Hendrik Willem Mesdag')
# /wiki/Hendrik_Willem_Mesdag
# Hendrik Willem Mesdag
#
# event_link:  ('/wiki/Hendrik_Willem_Mesdag', 'Hendrik Willem Mesdag')
# /wiki/Hendrik_Willem_Mesdag
# Hendrik Willem Mesdag
#
# event_link:  ('/wiki/Carl_Menger', 'Carl Menger')
# /wiki/Carl_Menger
# Carl Menger
#
# event_link:  ('/wiki/Carl_Menger', 'Carl Menger')
# /wiki/Carl_Menger
# Carl Menger
#
# event_link:  ('/wiki/Karl_Robert_Eduard_von_Hartmann', 'Karl Robert Eduard von Hartmann')
# /wiki/Karl_Robert_Eduard_von_Hartmann
# Karl Robert Eduard von Hartmann
#
# event_link:  ('/wiki/Karl_Robert_Eduard_von_Hartmann', 'Karl Robert Eduard von Hartmann')
# /wiki/Karl_Robert_Eduard_von_Hartmann
# Karl Robert Eduard von Hartmann
#
# event_link:  ('/wiki/C%C3%A9sar_Ritz', 'César Ritz')
# /wiki/C%C3%A9sar_Ritz
# César Ritz
#
# event_link:  ('/wiki/C%C3%A9sar_Ritz', 'César Ritz')
# /wiki/C%C3%A9sar_Ritz
# César Ritz
#
# event_link:  ('/wiki/The_Ritz_Hotel,_London', 'The Ritz Hotel, London')
# /wiki/The_Ritz_Hotel,_London
# The Ritz Hotel, London
#
# event_link:  ('/wiki/H%C3%B4tel_Ritz_Paris', 'Hôtel Ritz Paris')
# /wiki/H%C3%B4tel_Ritz_Paris
# Hôtel Ritz Paris
#
# event_link:  ('/wiki/W._E._B._Du_Bois', 'W. E. B. Du Bois')
# /wiki/W._E._B._Du_Bois
# W. E. B. Du Bois
#
# event_link:  ('/wiki/W._E._B._Du_Bois', 'W. E. B. Du Bois')
# /wiki/W._E._B._Du_Bois
# W. E. B. Du Bois
#
# event_link:  ('/wiki/Anna_Hofman-Uddgren', 'Anna Hofman-Uddgren')
# /wiki/Anna_Hofman-Uddgren
# Anna Hofman-Uddgren
#
# event_link:  ('/wiki/Anna_Hofman-Uddgren', 'Anna Hofman-Uddgren')
# /wiki/Anna_Hofman-Uddgren
# Anna Hofman-Uddgren
#
# event_link:  ('/wiki/Liang_Qichao', 'Liang Qichao')
# /wiki/Liang_Qichao
# Liang Qichao
#
# event_link:  ('/wiki/Liang_Qichao', 'Liang Qichao')
# /wiki/Liang_Qichao
# Liang Qichao
#
# event_link:  ('/wiki/Konstantin_P%C3%A4ts', 'Konstantin Päts')
# /wiki/Konstantin_P%C3%A4ts
# Konstantin Päts
#
# event_link:  ('/wiki/Konstantin_P%C3%A4ts', 'Konstantin Päts')
# /wiki/Konstantin_P%C3%A4ts
# Konstantin Päts
#
# event_link:  ('/wiki/President_of_Estonia', 'President of Estonia')
# /wiki/President_of_Estonia
# President of Estonia
#
# event_link:  ('/wiki/Kazimir_Malevich', 'Kazimir Malevich')
# /wiki/Kazimir_Malevich
# Kazimir Malevich
#
# event_link:  ('/wiki/Kazimir_Malevich', 'Kazimir Malevich')
# /wiki/Kazimir_Malevich
# Kazimir Malevich
#
# event_link:  ('/wiki/Karl_Jaspers', 'Karl Jaspers')
# /wiki/Karl_Jaspers
# Karl Jaspers
#
# event_link:  ('/wiki/Karl_Jaspers', 'Karl Jaspers')
# /wiki/Karl_Jaspers
# Karl Jaspers
#
# event_link:  ('/wiki/Guy_C._Wiggins', 'Guy C. Wiggins')
# /wiki/Guy_C._Wiggins
# Guy C. Wiggins
#
# event_link:  ('/wiki/Guy_C._Wiggins', 'Guy C. Wiggins')
# /wiki/Guy_C._Wiggins
# Guy C. Wiggins
#
# event_link:  ('/wiki/Musidora', 'Musidora')
# /wiki/Musidora
# Musidora
#
# event_link:  ('/wiki/Musidora', 'Musidora')
# /wiki/Musidora
# Musidora
#
# event_link:  ('/wiki/Cyril_Delevanti', 'Cyril Delevanti')
# /wiki/Cyril_Delevanti
# Cyril Delevanti
#
# event_link:  ('/wiki/Cyril_Delevanti', 'Cyril Delevanti')
# /wiki/Cyril_Delevanti
# Cyril Delevanti
#
# event_link:  ('/wiki/Victor_Fleming', 'Victor Fleming')
# /wiki/Victor_Fleming
# Victor Fleming
#
# event_link:  ('/wiki/Victor_Fleming', 'Victor Fleming')
# /wiki/Victor_Fleming
# Victor Fleming
#
# event_link:  ('/wiki/John_Gilbert_Winant', 'John Gilbert Winant')
# /wiki/John_Gilbert_Winant
# John Gilbert Winant
#
# event_link:  ('/wiki/John_Gilbert_Winant', 'John Gilbert Winant')
# /wiki/John_Gilbert_Winant
# John Gilbert Winant
#
# event_link:  ('/wiki/Governor_of_New_Hampshire', 'Governor of New Hampshire')
# /wiki/Governor_of_New_Hampshire
# Governor of New Hampshire
#
# event_link:  ('/wiki/Kathleen_Harrison', 'Kathleen Harrison')
# /wiki/Kathleen_Harrison
# Kathleen Harrison
#
# event_link:  ('/wiki/Kathleen_Harrison', 'Kathleen Harrison')
# /wiki/Kathleen_Harrison
# Kathleen Harrison
#
# event_link:  ('/wiki/Agnes_Smedley', 'Agnes Smedley')
# /wiki/Agnes_Smedley
# Agnes Smedley
#
# event_link:  ('/wiki/Agnes_Smedley', 'Agnes Smedley')
# /wiki/Agnes_Smedley
# Agnes Smedley
#
# event_link:  ('/wiki/Harold_Horder', 'Harold Horder')
# /wiki/Harold_Horder
# Harold Horder
# event_link:  ('/wiki/Harold_Horder', 'Harold Horder')
# /wiki/Harold_Horder
# Harold Horder
#
# event_link:  ('/wiki/Erich_K%C3%A4stner', 'Erich Kästner')
# /wiki/Erich_K%C3%A4stner
# Erich Kästner
#
# event_link:  ('/wiki/Erich_K%C3%A4stner', 'Erich Kästner')
# /wiki/Erich_K%C3%A4stner
# Erich Kästner
#
# event_link:  ('/wiki/Norman_Taurog', 'Norman Taurog')
# /wiki/Norman_Taurog
# Norman Taurog
#
# event_link:  ('/wiki/Norman_Taurog', 'Norman Taurog')
# /wiki/Norman_Taurog
# Norman Taurog
#
# event_link:  ('/wiki/Terence_Fisher', 'Terence Fisher')
# /wiki/Terence_Fisher
# Terence Fisher
#
# event_link:  ('/wiki/Terence_Fisher', 'Terence Fisher')
# /wiki/Terence_Fisher
# Terence Fisher
#
# event_link:  ('/wiki/William_L._Shirer', 'William L. Shirer')
# /wiki/William_L._Shirer
# William L. Shirer
#
# event_link:  ('/wiki/William_L._Shirer', 'William L. Shirer')
# /wiki/William_L._Shirer
# William L. Shirer
#
# event_link:  ('/wiki/William_McMahon', 'William McMahon')
# /wiki/William_McMahon
# William McMahon
#
# event_link:  ('/wiki/William_McMahon', 'William McMahon')
# /wiki/William_McMahon
# William McMahon
#
# event_link:  ('/wiki/Prime_Minister_of_Australia', 'Prime Minister of Australia')
# /wiki/Prime_Minister_of_Australia
# Prime Minister of Australia
#
# event_link:  ('/wiki/Jon_Hall_(actor)', 'Jon Hall (actor)')
# /wiki/Jon_Hall_(actor)
# Jon Hall (actor)
#
# event_link:  ('/wiki/Jon_Hall_(actor)', 'Jon Hall (actor)')
# /wiki/Jon_Hall_(actor)
# Jon Hall (actor)
#
# event_link:  ('/wiki/Paul_Tibbets', 'Paul Tibbets')
# /wiki/Paul_Tibbets
# Paul Tibbets
#
# event_link:  ('/wiki/Paul_Tibbets', 'Paul Tibbets')
# /wiki/Paul_Tibbets
# Paul Tibbets
#
# event_link:  ('/wiki/Johnny_Carey', 'Johnny Carey')
# /wiki/Johnny_Carey
# Johnny Carey
#
# event_link:  ('/wiki/Johnny_Carey', 'Johnny Carey')
# /wiki/Johnny_Carey
# Johnny Carey
#
# event_link:  ('/wiki/Paul_G%C3%A9rin-Lajoie', 'Paul Gérin-Lajoie')
# /wiki/Paul_G%C3%A9rin-Lajoie
# Paul Gérin-Lajoie
#
# event_link:  ('/wiki/Paul_G%C3%A9rin-Lajoie', 'Paul Gérin-Lajoie')
# /wiki/Paul_G%C3%A9rin-Lajoie
# Paul Gérin-Lajoie
#
# event_link:  ('/wiki/Rafael_Addiego_Bruno', 'Rafael Addiego Bruno')
# /wiki/Rafael_Addiego_Bruno
# Rafael Addiego Bruno
#
# event_link:  ('/wiki/Rafael_Addiego_Bruno', 'Rafael Addiego Bruno')
# /wiki/Rafael_Addiego_Bruno
# Rafael Addiego Bruno
#
# event_link:  ('/wiki/President_of_Uruguay', 'President of Uruguay')
# /wiki/President_of_Uruguay
# President of Uruguay
#
# event_link:  ('/wiki/Harry_Clarke_(footballer,_born_1923)', 'Harry Clarke (footballer, born 1923)')
# /wiki/Harry_Clarke_(footballer,_born_1923)
# Harry Clarke (footballer, born 1923)
#
# event_link:  ('/wiki/Harry_Clarke_(footballer,_born_1923)', 'Harry Clarke (footballer, born 1923)')
# /wiki/Harry_Clarke_(footballer,_born_1923)
# Harry Clarke (footballer, born 1923)
#
# event_link:  ('/wiki/Ioannis_Grivas', 'Ioannis Grivas')
# /wiki/Ioannis_Grivas
# Ioannis Grivas
#
# event_link:  ('/wiki/Ioannis_Grivas', 'Ioannis Grivas')
# /wiki/Ioannis_Grivas
# Ioannis Grivas
#
# event_link:  ('/wiki/Prime_Minister_of_Greece', 'Prime Minister of Greece')
# /wiki/Prime_Minister_of_Greece
# Prime Minister of Greece
#
# event_link:  ('/wiki/Dante_Lavelli', 'Dante Lavelli')
# /wiki/Dante_Lavelli
# Dante Lavelli
#
# event_link:  ('/wiki/Dante_Lavelli', 'Dante Lavelli')
# /wiki/Dante_Lavelli
# Dante Lavelli
#
# event_link:  ('/wiki/Clarence_D._Lester', 'Clarence D. Lester')
# /wiki/Clarence_D._Lester
# Clarence D. Lester
#
# event_link:  ('/wiki/Clarence_D._Lester', 'Clarence D. Lester')
# /wiki/Clarence_D._Lester
# Clarence D. Lester
#
# event_link:  ('/wiki/Mary_Francis_Shura', 'Mary Francis Shura')
# /wiki/Mary_Francis_Shura
# Mary Francis Shura
#
# event_link:  ('/wiki/Mary_Francis_Shura', 'Mary Francis Shura')
# /wiki/Mary_Francis_Shura
# Mary Francis Shura
#
# event_link:  ('/wiki/Allan_McLeod_Cormack', 'Allan McLeod Cormack')
# /wiki/Allan_McLeod_Cormack
# Allan McLeod Cormack
#
# event_link:  ('/wiki/Allan_McLeod_Cormack', 'Allan McLeod Cormack')
# /wiki/Allan_McLeod_Cormack
# Allan McLeod Cormack
#
# event_link:  ('/wiki/Nobel_Prize_in_Physiology_or_Medicine', 'Nobel Prize in Physiology or Medicine')
# /wiki/Nobel_Prize_in_Physiology_or_Medicine
# Nobel Prize in Physiology or Medicine
#
# event_link:  ('/wiki/Louis_Stokes', 'Louis Stokes')
# /wiki/Louis_Stokes
# Louis Stokes
#
# event_link:  ('/wiki/Louis_Stokes', 'Louis Stokes')
# /wiki/Louis_Stokes
# Louis Stokes
#
# event_link:  ('/wiki/R%C3%A9gine_Crespin', 'Régine Crespin')
# /wiki/R%C3%A9gine_Crespin
# Régine Crespin
#
# event_link:  ('/wiki/R%C3%A9gine_Crespin', 'Régine Crespin')
# /wiki/R%C3%A9gine_Crespin
# Régine Crespin
#
# event_link:  ('/wiki/Hans_Herrmann', 'Hans Herrmann')
# /wiki/Hans_Herrmann
# Hans Herrmann
#
# event_link:  ('/wiki/Hans_Herrmann', 'Hans Herrmann')
# /wiki/Hans_Herrmann
# Hans Herrmann
#
# event_link:  ('/wiki/Vasily_Lazarev', 'Vasily Lazarev')
# /wiki/Vasily_Lazarev
# Vasily Lazarev
#
# event_link:  ('/wiki/Vasily_Lazarev', 'Vasily Lazarev')
# /wiki/Vasily_Lazarev
# Vasily Lazarev
#
# event_link:  ('/wiki/Patriarch_Alexy_II_of_Moscow', 'Patriarch Alexy II of Moscow')
# /wiki/Patriarch_Alexy_II_of_Moscow
# Patriarch Alexy II of Moscow
#
# event_link:  ('/wiki/Patriarch_Alexy_II_of_Moscow', 'Patriarch Alexy II of Moscow')
# /wiki/Patriarch_Alexy_II_of_Moscow
# Patriarch Alexy II of Moscow
#
# event_link:  ('/wiki/Elston_Howard', 'Elston Howard')
# /wiki/Elston_Howard
# Elston Howard
#
# event_link:  ('/wiki/Elston_Howard', 'Elston Howard')
# /wiki/Elston_Howard
# Elston Howard
#
# event_link:  ('/wiki/Paul_West_(writer)', 'Paul West (writer)')
# /wiki/Paul_West_(writer)
# Paul West (writer)
#
# event_link:  ('/wiki/Paul_West_(writer)', 'Paul West (writer)')
# /wiki/Paul_West_(writer)
# Paul West (writer)
#
# event_link:  ('/wiki/Tom_Wesselmann', 'Tom Wesselmann')
# /wiki/Tom_Wesselmann
# Tom Wesselmann
#
# event_link:  ('/wiki/Tom_Wesselmann', 'Tom Wesselmann')
# /wiki/Tom_Wesselmann
# Tom Wesselmann
#
# event_link:  ('/wiki/Majel_Barrett', 'Majel Barrett')
# /wiki/Majel_Barrett
# Majel Barrett
#
# event_link:  ('/wiki/Majel_Barrett', 'Majel Barrett')
# /wiki/Majel_Barrett
# Majel Barrett
#
# event_link:  ('/wiki/Tom_Osborne', 'Tom Osborne')
# /wiki/Tom_Osborne
# Tom Osborne
#
# event_link:  ('/wiki/Tom_Osborne', 'Tom Osborne')
# /wiki/Tom_Osborne
# Tom Osborne
#
# event_link:  ('/wiki/Sylvia_Chase', 'Sylvia Chase')
# /wiki/Sylvia_Chase
# Sylvia Chase
#
# event_link:  ('/wiki/Sylvia_Chase', 'Sylvia Chase')
# /wiki/Sylvia_Chase
# Sylvia Chase
#
# event_link:  ('/wiki/Paul_Morrissey', 'Paul Morrissey')
# /wiki/Paul_Morrissey
# Paul Morrissey
#
# event_link:  ('/wiki/Paul_Morrissey', 'Paul Morrissey')
# /wiki/Paul_Morrissey
# Paul Morrissey
#
# event_link:  ('/wiki/Diane_Varsi', 'Diane Varsi')
# /wiki/Diane_Varsi
# Diane Varsi
#
# event_link:  ('/wiki/Diane_Varsi', 'Diane Varsi')
# /wiki/Diane_Varsi
# Diane Varsi
#
# event_link:  ('/wiki/Peter_Fonda', 'Peter Fonda')
# /wiki/Peter_Fonda
# Peter Fonda
#
# event_link:  ('/wiki/Peter_Fonda', 'Peter Fonda')
# /wiki/Peter_Fonda
# Peter Fonda
#
# event_link:  ('/wiki/Jackie_Smith', 'Jackie Smith')
# /wiki/Jackie_Smith
# Jackie Smith
#
# event_link:  ('/wiki/Jackie_Smith', 'Jackie Smith')
# /wiki/Jackie_Smith
# Jackie Smith
#
# event_link:  ('/wiki/Ron_Hunt', 'Ron Hunt')
# /wiki/Ron_Hunt
# Ron Hunt
#
# event_link:  ('/wiki/Ron_Hunt', 'Ron Hunt')
# /wiki/Ron_Hunt
# Ron Hunt
#
# event_link:  ('/wiki/Fred_Biletnikoff', 'Fred Biletnikoff')
# /wiki/Fred_Biletnikoff
# Fred Biletnikoff
#
# event_link:  ('/wiki/Fred_Biletnikoff', 'Fred Biletnikoff')
# /wiki/Fred_Biletnikoff
# Fred Biletnikoff
#
# event_link:  ('/wiki/Bobby_Mitchell_(golfer)', 'Bobby Mitchell (golfer)')
# /wiki/Bobby_Mitchell_(golfer)
# Bobby Mitchell (golfer)
#
# event_link:  ('/wiki/Bobby_Mitchell_(golfer)', 'Bobby Mitchell (golfer)')
# /wiki/Bobby_Mitchell_(golfer)
# Bobby Mitchell (golfer)
#
# event_link:  ('/wiki/Bernard_Cornwell', 'Bernard Cornwell')
# /wiki/Bernard_Cornwell
# Bernard Cornwell
#
# event_link:  ('/wiki/Bernard_Cornwell', 'Bernard Cornwell')
# /wiki/Bernard_Cornwell
# Bernard Cornwell
#
# event_link:  ('/wiki/Florian_Fricke', 'Florian Fricke')
# /wiki/Florian_Fricke
# Florian Fricke
#
# event_link:  ('/wiki/Florian_Fricke', 'Florian Fricke')
# /wiki/Florian_Fricke
# Florian Fricke
#
# event_link:  ('/wiki/Johnny_Winter', 'Johnny Winter')
# /wiki/Johnny_Winter
# Johnny Winter
#
# event_link:  ('/wiki/Johnny_Winter', 'Johnny Winter')
# /wiki/Johnny_Winter
# Johnny Winter
#
# event_link:  ('/wiki/Allan_Boesak', 'Allan Boesak')
# /wiki/Allan_Boesak
# Allan Boesak
#
# event_link:  ('/wiki/Allan_Boesak', 'Allan Boesak')
# /wiki/Allan_Boesak
# Allan Boesak
#
# event_link:  ('/wiki/Rusty_Young_(musician)', 'Rusty Young (musician)')
# /wiki/Rusty_Young_(musician)
# Rusty Young (musician)
#
# event_link:  ('/wiki/Rusty_Young_(musician)', 'Rusty Young (musician)')
# /wiki/Rusty_Young_(musician)
# Rusty Young (musician)
#
# event_link:  ('/wiki/Pia_Kj%C3%A6rsgaard', 'Pia Kjærsgaard')
# /wiki/Pia_Kj%C3%A6rsgaard
# Pia Kjærsgaard
#
# event_link:  ('/wiki/Pia_Kj%C3%A6rsgaard', 'Pia Kjærsgaard')
# /wiki/Pia_Kj%C3%A6rsgaard
# Pia Kjærsgaard
#
# event_link:  ('/wiki/List_of_Speakers_of_the_Folketing', 'List of Speakers of the Folketing')
# /wiki/List_of_Speakers_of_the_Folketing
# List of Speakers of the Folketing
#
# event_link:  ('/wiki/Anton_Mosimann', 'Anton Mosimann')
# /wiki/Anton_Mosimann
# Anton Mosimann
#
# event_link:  ('/wiki/Anton_Mosimann', 'Anton Mosimann')
# /wiki/Anton_Mosimann
# Anton Mosimann
#
# event_link:  ('/wiki/Bill_Alexander_(director)', 'Bill Alexander (director)')
# /wiki/Bill_Alexander_(director)
# Bill Alexander (director)
#
# event_link:  ('/wiki/Bill_Alexander_(director)', 'Bill Alexander (director)')
# /wiki/Bill_Alexander_(director)
# Bill Alexander (director)
#
# event_link:  ('/wiki/Trevor_Cherry', 'Trevor Cherry')
# /wiki/Trevor_Cherry
# Trevor Cherry
#
# event_link:  ('/wiki/Trevor_Cherry', 'Trevor Cherry')
# /wiki/Trevor_Cherry
# Trevor Cherry
#
# event_link:  ('/wiki/Steve_Priest', 'Steve Priest')
# /wiki/Steve_Priest
# Steve Priest
#
# event_link:  ('/wiki/Steve_Priest', 'Steve Priest')
# /wiki/Steve_Priest
# Steve Priest
#
# event_link:  ('/wiki/C%C3%A9sar_Aira', 'César Aira')
# /wiki/C%C3%A9sar_Aira
# César Aira
#
# event_link:  ('/wiki/C%C3%A9sar_Aira', 'César Aira')
# /wiki/C%C3%A9sar_Aira
# César Aira
#
# event_link:  ('/wiki/Marc_Garneau', 'Marc Garneau')
# /wiki/Marc_Garneau
# Marc Garneau
#
# event_link:  ('/wiki/Marc_Garneau', 'Marc Garneau')
# /wiki/Marc_Garneau
# Marc Garneau
#
# event_link:  ('/wiki/Rebecca_Goldstein', 'Rebecca Goldstein')
# /wiki/Rebecca_Goldstein
# Rebecca Goldstein
#
# event_link:  ('/wiki/Rebecca_Goldstein', 'Rebecca Goldstein')
# /wiki/Rebecca_Goldstein
# Rebecca Goldstein
#
# event_link:  ('/wiki/John_Greaves_(musician)', 'John Greaves (musician)')
# /wiki/John_Greaves_(musician)
# John Greaves (musician)
#
# event_link:  ('/wiki/John_Greaves_(musician)', 'John Greaves (musician)')
# /wiki/John_Greaves_(musician)
# John Greaves (musician)
#
# event_link:  ('/wiki/Eddie_Dibbs', 'Eddie Dibbs')
# /wiki/Eddie_Dibbs
# Eddie Dibbs
#
# event_link:  ('/wiki/Eddie_Dibbs', 'Eddie Dibbs')
# /wiki/Eddie_Dibbs
# Eddie Dibbs
#
# event_link:  ('/wiki/Debbie_Friedman', 'Debbie Friedman')
# /wiki/Debbie_Friedman
# Debbie Friedman
#
# event_link:  ('/wiki/Debbie_Friedman', 'Debbie Friedman')
# /wiki/Debbie_Friedman
# Debbie Friedman
#
# event_link:  ('/wiki/Ed_%22Too_Tall%22_Jones', 'Ed "Too Tall" Jones')
# /wiki/Ed_%22Too_Tall%22_Jones
# Ed "Too Tall" Jones
#
# event_link:  ('/wiki/Ed_%22Too_Tall%22_Jones', 'Ed "Too Tall" Jones')
# /wiki/Ed_%22Too_Tall%22_Jones
# Ed "Too Tall" Jones
#
# event_link:  ('/wiki/Patricia_Richardson', 'Patricia Richardson')
# /wiki/Patricia_Richardson
# Patricia Richardson
#
# event_link:  ('/wiki/Patricia_Richardson', 'Patricia Richardson')
# /wiki/Patricia_Richardson
# Patricia Richardson
#
# event_link:  ('/wiki/Brad_Whitford', 'Brad Whitford')
# /wiki/Brad_Whitford
# Brad Whitford
#
# event_link:  ('/wiki/Brad_Whitford', 'Brad Whitford')
# /wiki/Brad_Whitford
# Brad Whitford
#
# event_link:  ('/wiki/Kenny_Bee', 'Kenny Bee')
# /wiki/Kenny_Bee
# Kenny Bee
#
# event_link:  ('/wiki/Kenny_Bee', 'Kenny Bee')
# /wiki/Kenny_Bee
# Kenny Bee
#
# event_link:  ('/wiki/Satoru_Nakajima', 'Satoru Nakajima')
# /wiki/Satoru_Nakajima
# Satoru Nakajima
#
# event_link:  ('/wiki/Satoru_Nakajima', 'Satoru Nakajima')
# /wiki/Satoru_Nakajima
# Satoru Nakajima
#
# event_link:  ('/wiki/Rajini_Thiranagama', 'Rajini Thiranagama')
# /wiki/Rajini_Thiranagama
# Rajini Thiranagama
#
# event_link:  ('/wiki/Rajini_Thiranagama', 'Rajini Thiranagama')
# /wiki/Rajini_Thiranagama
# Rajini Thiranagama
#
# event_link:  ('/wiki/Viktor_Yushchenko', 'Viktor Yushchenko')
# /wiki/Viktor_Yushchenko
# Viktor Yushchenko
#
# event_link:  ('/wiki/Viktor_Yushchenko', 'Viktor Yushchenko')
# /wiki/Viktor_Yushchenko
# Viktor Yushchenko
#
# event_link:  ('/wiki/President_of_Ukraine', 'President of Ukraine')
# /wiki/President_of_Ukraine
# President of Ukraine
#
# event_link:  ('/wiki/Howard_Jones_(musician)', 'Howard Jones (musician)')
# /wiki/Howard_Jones_(musician)
# Howard Jones (musician)
#
# event_link:  ('/wiki/Howard_Jones_(musician)', 'Howard Jones (musician)')
# /wiki/Howard_Jones_(musician)
# Howard Jones (musician)
#
# event_link:  ('/wiki/Flip_Saunders', 'Flip Saunders')
# /wiki/Flip_Saunders
# Flip Saunders
#
# event_link:  ('/wiki/Flip_Saunders', 'Flip Saunders')
# /wiki/Flip_Saunders
# Flip Saunders
#
# event_link:  ('/wiki/Sandra_Osborne', 'Sandra Osborne')
# /wiki/Sandra_Osborne
# Sandra Osborne
#
# event_link:  ('/wiki/Sandra_Osborne', 'Sandra Osborne')
# /wiki/Sandra_Osborne
# Sandra Osborne
#
# event_link:  ('/wiki/David_Sylvian', 'David Sylvian')
# /wiki/David_Sylvian
# David Sylvian
#
# event_link:  ('/wiki/David_Sylvian', 'David Sylvian')
# /wiki/David_Sylvian
# David Sylvian
#
# event_link:  ('/wiki/Clayton_Anderson', 'Clayton Anderson')
# /wiki/Clayton_Anderson
# Clayton Anderson
#
# event_link:  ('/wiki/Clayton_Anderson', 'Clayton Anderson')
# /wiki/Clayton_Anderson
# Clayton Anderson
#
# event_link:  ('/wiki/Nick_de_Bois', 'Nick de Bois')
# /wiki/Nick_de_Bois
# Nick de Bois
#
# event_link:  ('/wiki/Nick_de_Bois', 'Nick de Bois')
# /wiki/Nick_de_Bois
# Nick de Bois
#
# event_link:  ('/wiki/Ian_Liddell-Grainger', 'Ian Liddell-Grainger')
# /wiki/Ian_Liddell-Grainger
# Ian Liddell-Grainger
#
# event_link:  ('/wiki/Ian_Liddell-Grainger', 'Ian Liddell-Grainger')
# /wiki/Ian_Liddell-Grainger
# Ian Liddell-Grainger
#
# event_link:  ('/wiki/Linda_Nolan', 'Linda Nolan')
# /wiki/Linda_Nolan
# Linda Nolan
#
# event_link:  ('/wiki/Linda_Nolan', 'Linda Nolan')
# /wiki/Linda_Nolan
# Linda Nolan
#
# event_link:  ('/wiki/Naruhito,_Emperor_of_Japan', 'Naruhito, Emperor of Japan')
# /wiki/Naruhito,_Emperor_of_Japan
# Naruhito, Emperor of Japan
#
# event_link:  ('/wiki/Naruhito,_Emperor_of_Japan', 'Naruhito, Emperor of Japan')
# /wiki/Naruhito,_Emperor_of_Japan
# Naruhito, Emperor of Japan
#
# event_link:  ('/wiki/Michael_Wilton', 'Michael Wilton')
# /wiki/Michael_Wilton
# Michael Wilton
#
# event_link:  ('/wiki/Michael_Wilton', 'Michael Wilton')
# /wiki/Michael_Wilton
# Michael Wilton
#
# event_link:  ('/wiki/Bobby_Bonilla', 'Bobby Bonilla')
# /wiki/Bobby_Bonilla
# Bobby Bonilla
#
# event_link:  ('/wiki/Bobby_Bonilla', 'Bobby Bonilla')
# /wiki/Bobby_Bonilla
# Bobby Bonilla
#
# event_link:  ('/wiki/Rados%C5%82aw_Sikorski', 'Radosław Sikorski')
# /wiki/Rados%C5%82aw_Sikorski
# Radosław Sikorski
#
# event_link:  ('/wiki/Rados%C5%82aw_Sikorski', 'Radosław Sikorski')
# /wiki/Rados%C5%82aw_Sikorski
# Radosław Sikorski
#
# event_link:  ('/wiki/Minister_of_Foreign_Affairs_of_Poland', 'Minister of Foreign Affairs of Poland')
# /wiki/Minister_of_Foreign_Affairs_of_Poland
# Minister of Foreign Affairs of Poland
#
# event_link:  ('/wiki/John_Norum', 'John Norum')
# /wiki/John_Norum
# John Norum
#
# event_link:  ('/wiki/John_Norum', 'John Norum')
# /wiki/John_Norum
# John Norum
#
# event_link:  ('/wiki/Michael_Dell', 'Michael Dell')
# /wiki/Michael_Dell
# Michael Dell
#
# event_link:  ('/wiki/Michael_Dell', 'Michael Dell')
# /wiki/Michael_Dell
# Michael Dell
#
# event_link:  ('/wiki/Helena_Sukov%C3%A1', 'Helena Suková')
# /wiki/Helena_Sukov%C3%A1
# Helena Suková
#
# event_link:  ('/wiki/Helena_Sukov%C3%A1', 'Helena Suková')
# /wiki/Helena_Sukov%C3%A1
# Helena Suková
#
# event_link:  ('/wiki/Steve_Stricker', 'Steve Stricker')
# /wiki/Steve_Stricker
# Steve Stricker
#
# event_link:  ('/wiki/Steve_Stricker', 'Steve Stricker')
# /wiki/Steve_Stricker
# Steve Stricker
#
# event_link:  ('/wiki/Chris_Vrenna', 'Chris Vrenna')
# /wiki/Chris_Vrenna
# Chris Vrenna
#
# event_link:  ('/wiki/Chris_Vrenna', 'Chris Vrenna')
# /wiki/Chris_Vrenna
# Chris Vrenna
#
# event_link:  ('/wiki/Michael_Campbell', 'Michael Campbell')
# /wiki/Michael_Campbell
# Michael Campbell
#
# event_link:  ('/wiki/Michael_Campbell', 'Michael Campbell')
# /wiki/Michael_Campbell
# Michael Campbell
#
# event_link:  ('/wiki/Martine_Croxall', 'Martine Croxall')
# /wiki/Martine_Croxall
# Martine Croxall
#
# event_link:  ('/wiki/Martine_Croxall', 'Martine Croxall')
# /wiki/Martine_Croxall
# Martine Croxall
#
# event_link:  ('/wiki/Daymond_John', 'Daymond John')
# /wiki/Daymond_John
# Daymond John
#
# event_link:  ('/wiki/Daymond_John', 'Daymond John')
# /wiki/Daymond_John
# Daymond John
#
# event_link:  ('/wiki/FUBU', 'FUBU')
# /wiki/FUBU
# FUBU
#
# event_link:  ('/wiki/Niecy_Nash', 'Niecy Nash')
# /wiki/Niecy_Nash
# Niecy Nash
#
# event_link:  ('/wiki/Niecy_Nash', 'Niecy Nash')
# /wiki/Niecy_Nash
# Niecy Nash
#
# event_link:  ('/wiki/Carin_Koch', 'Carin Koch')
# /wiki/Carin_Koch
# Carin Koch
#
# event_link:  ('/wiki/Carin_Koch', 'Carin Koch')
# /wiki/Carin_Koch
# Carin Koch
#
# event_link:  ('/wiki/Melinda_Messenger', 'Melinda Messenger')
# /wiki/Melinda_Messenger
# Melinda Messenger
#
# event_link:  ('/wiki/Melinda_Messenger', 'Melinda Messenger')
# /wiki/Melinda_Messenger
# Melinda Messenger
#
# event_link:  ('/wiki/Joe-Max_Moore', 'Joe-Max Moore')
# /wiki/Joe-Max_Moore
# Joe-Max Moore
#
# event_link:  ('/wiki/Joe-Max_Moore', 'Joe-Max Moore')
# /wiki/Joe-Max_Moore
# Joe-Max Moore
#
# event_link:  ('/wiki/Alessandro_Sturba', 'Alessandro Sturba')
# /wiki/Alessandro_Sturba
# Alessandro Sturba
#
# event_link:  ('/wiki/Alessandro_Sturba', 'Alessandro Sturba')
# /wiki/Alessandro_Sturba
# Alessandro Sturba
#
# event_link:  ('/wiki/Rondell_White', 'Rondell White')
# /wiki/Rondell_White
# Rondell White
#
# event_link:  ('/wiki/Rondell_White', 'Rondell White')
# /wiki/Rondell_White
# Rondell White
#
# event_link:  ('/wiki/Jeff_Nordgaard', 'Jeff Nordgaard')
# /wiki/Jeff_Nordgaard
# Jeff Nordgaard
#
# event_link:  ('/wiki/Jeff_Nordgaard', 'Jeff Nordgaard')
# /wiki/Jeff_Nordgaard
# Jeff Nordgaard
#
# event_link:  ('/wiki/Herschelle_Gibbs', 'Herschelle Gibbs')
# /wiki/Herschelle_Gibbs
# Herschelle Gibbs
#
# event_link:  ('/wiki/Herschelle_Gibbs', 'Herschelle Gibbs')
# /wiki/Herschelle_Gibbs
# Herschelle Gibbs
#
# event_link:  ('/wiki/Robbi_Kempson', 'Robbi Kempson')
# ...
# Ernest Dowson
#
# event_link:  ('/wiki/Ernest_Dowson', 'Ernest Dowson')
# /wiki/Ernest_Dowson
# Ernest Dowson
#
# event_link:  ('/wiki/Friedrich_von_Esmarch', 'Friedrich von Esmarch')
# /wiki/Friedrich_von_Esmarch
# Friedrich von Esmarch
#
# event_link:  ('/wiki/Friedrich_von_Esmarch', 'Friedrich von Esmarch')
# /wiki/Friedrich_von_Esmarch
# Friedrich von Esmarch
#
# event_link:  ('/wiki/Adolphus_Frederick_VI,_Grand_Duke_of_Mecklenburg-Strelitz', 'Adolphus Frederick VI, Grand Duke of Mecklenburg-Strelitz')
# /wiki/Adolphus_Frederick_VI,_Grand_Duke_of_Mecklenburg-Strelitz
# Adolphus Frederick VI, Grand Duke of Mecklenburg-Strelitz
#
# event_link:  ('/wiki/Adolphus_Frederick_VI,_Grand_Duke_of_Mecklenburg-Strelitz', 'Adolphus Frederick VI, Grand Duke of Mecklenburg-Strelitz')
# /wiki/Adolphus_Frederick_VI,_Grand_Duke_of_Mecklenburg-Strelitz
# Adolphus Frederick VI, Grand Duke of Mecklenburg-Strelitz
#
# event_link:  ('/wiki/Horst_Wessel', 'Horst Wessel')
# /wiki/Horst_Wessel
# Horst Wessel
#
# event_link:  ('/wiki/Horst_Wessel', 'Horst Wessel')
# /wiki/Horst_Wessel
# Horst Wessel
#
# event_link:  ('/wiki/Sturmabteilung', 'Sturmabteilung')
# /wiki/Sturmabteilung
# Sturmabteilung
#
# event_link:  ('/wiki/Nellie_Melba', 'Nellie Melba')
# /wiki/Nellie_Melba
# Nellie Melba
#
# event_link:  ('/wiki/Nellie_Melba', 'Nellie Melba')
# /wiki/Nellie_Melba
# Nellie Melba
#
# event_link:  ('/wiki/Edward_Elgar', 'Edward Elgar')
# /wiki/Edward_Elgar
# Edward Elgar
#
# event_link:  ('/wiki/Edward_Elgar', 'Edward Elgar')
# /wiki/Edward_Elgar
# Edward Elgar
#
# event_link:  ('/wiki/Leo_Baekeland', 'Leo Baekeland')
# /wiki/Leo_Baekeland
# Leo Baekeland
#
# event_link:  ('/wiki/Leo_Baekeland', 'Leo Baekeland')
# /wiki/Leo_Baekeland
# Leo Baekeland
#
# event_link:  ('/wiki/Tomoyuki_Yamashita', 'Tomoyuki Yamashita')
# /wiki/Tomoyuki_Yamashita
# Tomoyuki Yamashita
# event_link:  ('/wiki/Tomoyuki_Yamashita', 'Tomoyuki Yamashita')
# /wiki/Tomoyuki_Yamashita
# Tomoyuki Yamashita
#
# event_link:  ('/wiki/John_Robert_Gregg', 'John Robert Gregg')
# /wiki/John_Robert_Gregg
# John Robert Gregg
#
# event_link:  ('/wiki/John_Robert_Gregg', 'John Robert Gregg')
# /wiki/John_Robert_Gregg
# John Robert Gregg
#
# event_link:  ('/wiki/Paul_Claudel', 'Paul Claudel')
# /wiki/Paul_Claudel
# Paul Claudel
#
# event_link:  ('/wiki/Paul_Claudel', 'Paul Claudel')
# /wiki/Paul_Claudel
# Paul Claudel
#
# event_link:  ('/wiki/Stan_Laurel', 'Stan Laurel')
# /wiki/Stan_Laurel
# Stan Laurel
#
# event_link:  ('/wiki/Stan_Laurel', 'Stan Laurel')
# /wiki/Stan_Laurel
# Stan Laurel
#
# event_link:  ('/wiki/Madhubala', 'Madhubala')
# /wiki/Madhubala
# Madhubala
#
# event_link:  ('/wiki/Madhubala', 'Madhubala')
# /wiki/Madhubala
# Madhubala
#
# event_link:  ('/wiki/Saud_of_Saudi_Arabia', 'Saud of Saudi Arabia')
# /wiki/Saud_of_Saudi_Arabia
# Saud of Saudi Arabia
#
# event_link:  ('/wiki/Saud_of_Saudi_Arabia', 'Saud of Saudi Arabia')
# /wiki/Saud_of_Saudi_Arabia
# Saud of Saudi Arabia
#
# event_link:  ('/wiki/King_of_Saudi_Arabia', 'King of Saudi Arabia')
# /wiki/King_of_Saudi_Arabia
# King of Saudi Arabia
#
# event_link:  ('/wiki/Dickinson_W._Richards', 'Dickinson W. Richards')
# /wiki/Dickinson_W._Richards
# Dickinson W. Richards
#
# event_link:  ('/wiki/Dickinson_W._Richards', 'Dickinson W. Richards')
# /wiki/Dickinson_W._Richards
# Dickinson W. Richards
#
# event_link:  ('/wiki/Nobel_Prize_in_Physiology_or_Medicine', 'Nobel Prize in Physiology or Medicine')
# /wiki/Nobel_Prize_in_Physiology_or_Medicine
# Nobel Prize in Physiology or Medicine
#
# event_link:  ('/wiki/Harry_Ruby', 'Harry Ruby')
# /wiki/Harry_Ruby
# Harry Ruby
#
# event_link:  ('/wiki/Harry_Ruby', 'Harry Ruby')
# /wiki/Harry_Ruby
# Harry Ruby
#
# event_link:  ('/wiki/L._S._Lowry', 'L. S. Lowry')
# /wiki/L._S._Lowry
# L. S. Lowry
#
# event_link:  ('/wiki/L._S._Lowry', 'L. S. Lowry')
# /wiki/L._S._Lowry
# L. S. Lowry
#
# event_link:  ('/wiki/W._A._C._Bennett', 'W. A. C. Bennett')
# /wiki/W._A._C._Bennett
# W. A. C. Bennett
#
# event_link:  ('/wiki/W._A._C._Bennett', 'W. A. C. Bennett')
# /wiki/W._A._C._Bennett
# W. A. C. Bennett
#
# event_link:  ('/wiki/Premier_of_British_Columbia', 'Premier of British Columbia')
# /wiki/Premier_of_British_Columbia
# Premier of British Columbia
#
# event_link:  ('/wiki/Herbert_Howells', 'Herbert Howells')
# /wiki/Herbert_Howells
# Herbert Howells
#
# event_link:  ('/wiki/Herbert_Howells', 'Herbert Howells')
# /wiki/Herbert_Howells
# Herbert Howells
#
# event_link:  ('/wiki/Jos%C3%A9_Napole%C3%B3n_Duarte', 'José Napoleón Duarte')
# /wiki/Jos%C3%A9_Napole%C3%B3n_Duarte
# José Napoleón Duarte
#
# event_link:  ('/wiki/Jos%C3%A9_Napole%C3%B3n_Duarte', 'José Napoleón Duarte')
# /wiki/Jos%C3%A9_Napole%C3%B3n_Duarte
# José Napoleón Duarte
#
# event_link:  ('/wiki/President_of_El_Salvador', 'President of El Salvador')
# /wiki/President_of_El_Salvador
# President of El Salvador
#
# event_link:  ('/wiki/James_Herriot', 'James Herriot')
# /wiki/James_Herriot
# James Herriot
#
# event_link:  ('/wiki/James_Herriot', 'James Herriot')
# /wiki/James_Herriot
# James Herriot
#
# event_link:  ('/wiki/Tony_Williams_(drummer)', 'Tony Williams (drummer)')
# /wiki/Tony_Williams_(drummer)
# Tony Williams (drummer)
#
# event_link:  ('/wiki/Tony_Williams_(drummer)', 'Tony Williams (drummer)')
# /wiki/Tony_Williams_(drummer)
# Tony Williams (drummer)
#
# event_link:  ('/wiki/Philip_Abbott', 'Philip Abbott')
# /wiki/Philip_Abbott
# Philip Abbott
#
# event_link:  ('/wiki/Philip_Abbott', 'Philip Abbott')
# /wiki/Philip_Abbott
# Philip Abbott
#
# event_link:  ('/wiki/The_Renegade_(wrestler)', 'The Renegade (wrestler)')
# /wiki/The_Renegade_(wrestler)
# The Renegade (wrestler)
#
# event_link:  ('/wiki/The_Renegade_(wrestler)', 'The Renegade (wrestler)')
# /wiki/The_Renegade_(wrestler)
# The Renegade (wrestler)
#
# event_link:  ('/wiki/Ofra_Haza', 'Ofra Haza')
# /wiki/Ofra_Haza
# Ofra Haza
#
# event_link:  ('/wiki/Ofra_Haza', 'Ofra Haza')
# /wiki/Ofra_Haza
# Ofra Haza
#
# event_link:  ('/wiki/Stanley_Matthews', 'Stanley Matthews')
# /wiki/Stanley_Matthews
# Stanley Matthews
#
# event_link:  ('/wiki/Stanley_Matthews', 'Stanley Matthews')
# /wiki/Stanley_Matthews
# Stanley Matthews
#
# event_link:  ('/wiki/Howie_Epstein', 'Howie Epstein')
# /wiki/Howie_Epstein
# Howie Epstein
#
# event_link:  ('/wiki/Howie_Epstein', 'Howie Epstein')
# /wiki/Howie_Epstein
# Howie Epstein
#
# event_link:  ('/wiki/Robert_K._Merton', 'Robert K. Merton')
# /wiki/Robert_K._Merton
# Robert K. Merton
#
# event_link:  ('/wiki/Robert_K._Merton', 'Robert K. Merton')
# /wiki/Robert_K._Merton
# Robert K. Merton
#
# event_link:  ('/wiki/Vijay_Anand_(Hindi_film_maker)', 'Vijay Anand (Hindi film maker)')
# /wiki/Vijay_Anand_(Hindi_film_maker)
# Vijay Anand (Hindi film maker)
#
# event_link:  ('/wiki/Vijay_Anand_(Hindi_film_maker)', 'Vijay Anand (Hindi film maker)')
# /wiki/Vijay_Anand_(Hindi_film_maker)
# Vijay Anand (Hindi film maker)
#
# event_link:  ('/wiki/Sikander_Bakht', 'Sikander Bakht')
# /wiki/Sikander_Bakht
# Sikander Bakht
#
# event_link:  ('/wiki/Sikander_Bakht', 'Sikander Bakht')
# /wiki/Sikander_Bakht
# Sikander Bakht
#
# event_link:  ('/wiki/Minister_of_External_Affairs_(India)', 'Minister of External Affairs (India)')
# /wiki/Minister_of_External_Affairs_(India)
# Minister of External Affairs (India)
#
# event_link:  ('/wiki/Telmo_Zarra', 'Telmo Zarra')
# /wiki/Telmo_Zarra
# Telmo Zarra
#
# event_link:  ('/wiki/Telmo_Zarra', 'Telmo Zarra')
# /wiki/Telmo_Zarra
# Telmo Zarra
#
# event_link:  ('/wiki/John_Ritchie_(footballer,_born_1941)', 'John Ritchie (footballer, born 1941)')
# /wiki/John_Ritchie_(footballer,_born_1941)
# John Ritchie (footballer, born 1941)
#
# event_link:  ('/wiki/John_Ritchie_(footballer,_born_1941)', 'John Ritchie (footballer, born 1941)')
# /wiki/John_Ritchie_(footballer,_born_1941)
# John Ritchie (footballer, born 1941)
#
# event_link:  ('/wiki/Janez_Drnov%C5%A1ek', 'Janez Drnovšek')
# /wiki/Janez_Drnov%C5%A1ek
# Janez Drnovšek
#
# event_link:  ('/wiki/Janez_Drnov%C5%A1ek', 'Janez Drnovšek')
# /wiki/Janez_Drnov%C5%A1ek
# Janez Drnovšek
#
# event_link:  ('/wiki/President_of_Slovenia', 'President of Slovenia')
# /wiki/President_of_Slovenia
# President of Slovenia
#
# event_link:  ('/wiki/Paul_Fr%C3%A8re', 'Paul Frère')
# /wiki/Paul_Fr%C3%A8re
# Paul Frère
#
# event_link:  ('/wiki/Paul_Fr%C3%A8re', 'Paul Frère')
# /wiki/Paul_Fr%C3%A8re
# Paul Frère
#
# event_link:  ('/wiki/Orlando_Zapata', 'Orlando Zapata')
# /wiki/Orlando_Zapata
# Orlando Zapata
#
# event_link:  ('/wiki/Orlando_Zapata', 'Orlando Zapata')
# /wiki/Orlando_Zapata
# Orlando Zapata
#
# event_link:  ('/wiki/Nirmala_Srivastava', 'Nirmala Srivastava')
# /wiki/Nirmala_Srivastava
# Nirmala Srivastava
#
# event_link:  ('/wiki/Nirmala_Srivastava', 'Nirmala Srivastava')
# /wiki/Nirmala_Srivastava
# Nirmala Srivastava
#
# event_link:  ('/wiki/Sahaja_Yoga', 'Sahaja Yoga')
# /wiki/Sahaja_Yoga
# Sahaja Yoga
#
# event_link:  ('/wiki/William_Raggio', 'William Raggio')
# /wiki/William_Raggio
# William Raggio
#
# event_link:  ('/wiki/William_Raggio', 'William Raggio')
# /wiki/William_Raggio
# William Raggio
#
# event_link:  ('/wiki/David_Sayre', 'David Sayre')
# /wiki/David_Sayre
# David Sayre
#
# event_link:  ('/wiki/David_Sayre', 'David Sayre')
# /wiki/David_Sayre
# David Sayre
#
# event_link:  ('/wiki/Kazimierz_%C5%BBygulski', 'Kazimierz Żygulski')
# /wiki/Kazimierz_%C5%BBygulski
# Kazimierz Żygulski
#
# event_link:  ('/wiki/Kazimierz_%C5%BBygulski', 'Kazimierz Żygulski')
# /wiki/Kazimierz_%C5%BBygulski
# Kazimierz Żygulski
#
# event_link:  ('/wiki/Eugene_Bookhammer', 'Eugene Bookhammer')
# /wiki/Eugene_Bookhammer
# Eugene Bookhammer
#
# event_link:  ('/wiki/Eugene_Bookhammer', 'Eugene Bookhammer')
# /wiki/Eugene_Bookhammer
# Eugene Bookhammer
#
# event_link:  ('/wiki/Lieutenant_Governor_of_Delaware', 'Lieutenant Governor of Delaware')
# /wiki/Lieutenant_Governor_of_Delaware
# Lieutenant Governor of Delaware
#
# event_link:  ('/wiki/Joseph_Friedenson', 'Joseph Friedenson')
# /wiki/Joseph_Friedenson
# Joseph Friedenson
#
# event_link:  ('/wiki/Joseph_Friedenson', 'Joseph Friedenson')
# /wiki/Joseph_Friedenson
# Joseph Friedenson
#
# event_link:  ('/wiki/Julien_Ries', 'Julien Ries')
# /wiki/Julien_Ries
# Julien Ries
#
# event_link:  ('/wiki/Julien_Ries', 'Julien Ries')
# /wiki/Julien_Ries
# Julien Ries
#
# event_link:  ('/wiki/Lotika_Sarkar', 'Lotika Sarkar')
# /wiki/Lotika_Sarkar
# Lotika Sarkar
#
# event_link:  ('/wiki/Lotika_Sarkar', 'Lotika Sarkar')
# /wiki/Lotika_Sarkar
# Lotika Sarkar
#
# event_link:  ('/wiki/Alice_Herz-Sommer', 'Alice Herz-Sommer')
# /wiki/Alice_Herz-Sommer
# Alice Herz-Sommer
#
# event_link:  ('/wiki/Alice_Herz-Sommer', 'Alice Herz-Sommer')
# /wiki/Alice_Herz-Sommer
# Alice Herz-Sommer
#
# event_link:  ('/wiki/Holocaust_survivor', 'Holocaust survivor')
# /wiki/Holocaust_survivor
# Holocaust survivor
#
# event_link:  ('/wiki/Roger_Hilsman', 'Roger Hilsman')
# /wiki/Roger_Hilsman
# Roger Hilsman
#
# event_link:  ('/wiki/Roger_Hilsman', 'Roger Hilsman')
# /wiki/Roger_Hilsman
# Roger Hilsman
#
# event_link:  ('/wiki/James_Aldridge', 'James Aldridge')
# /wiki/James_Aldridge
# James Aldridge
#
# event_link:  ('/wiki/James_Aldridge', 'James Aldridge')
# /wiki/James_Aldridge
# James Aldridge
#
# event_link:  ('/wiki/Rana_Bhagwandas', 'Rana Bhagwandas')
# /wiki/Rana_Bhagwandas
# Rana Bhagwandas
#
# event_link:  ('/wiki/Rana_Bhagwandas', 'Rana Bhagwandas')
# /wiki/Rana_Bhagwandas
# Rana Bhagwandas
#
# event_link:  ('/wiki/Chief_Justice_of_Pakistan', 'Chief Justice of Pakistan')
# /wiki/Chief_Justice_of_Pakistan
# Chief Justice of Pakistan
#
# event_link:  ('/wiki/W._E._%22Bill%22_Dykes', 'W. E. "Bill" Dykes')
# /wiki/W._E._%22Bill%22_Dykes
# W. E. "Bill" Dykes
#
# event_link:  ('/wiki/W._E._%22Bill%22_Dykes', 'W. E. "Bill" Dykes')
# /wiki/W._E._%22Bill%22_Dykes
# W. E. "Bill" Dykes
#
# event_link:  ('/wiki/Peter_Lustig', 'Peter Lustig')
# /wiki/Peter_Lustig
# Peter Lustig
#
# event_link:  ('/wiki/Peter_Lustig', 'Peter Lustig')
# /wiki/Peter_Lustig
# Peter Lustig
#
# event_link:  ('/wiki/Jacqueline_Mattson', 'Jacqueline Mattson')
# /wiki/Jacqueline_Mattson
# Jacqueline Mattson
#
# event_link:  ('/wiki/Jacqueline_Mattson', 'Jacqueline Mattson')
# /wiki/Jacqueline_Mattson
# Jacqueline Mattson
#
# event_link:  ('/wiki/Katherine_Helmond', 'Katherine Helmond')
# /wiki/Katherine_Helmond
# Katherine Helmond
#
# event_link:  ('/wiki/Katherine_Helmond', 'Katherine Helmond')
# /wiki/Katherine_Helmond
# Katherine Helmond
#
# event_link:  ('/wiki/Polycarp', 'Polycarp')
# /wiki/Polycarp
# Polycarp
#
# event_link:  ('/wiki/Polycarp', 'Polycarp')
# /wiki/Polycarp
# Polycarp
#
# event_link:  ('/wiki/Serenus_the_Gardener', 'Serenus the Gardener')
# /wiki/Serenus_the_Gardener
# Serenus the Gardener
#
# event_link:  ('/wiki/Serenus_the_Gardener', 'Serenus the Gardener')
# /wiki/Serenus_the_Gardener
# Serenus the Gardener
#
# event_link:  ('/wiki/February_23_(Eastern_Orthodox_liturgics)', 'February 23 (Eastern Orthodox liturgics)')
# /wiki/February_23_(Eastern_Orthodox_liturgics)
# February 23 (Eastern Orthodox liturgics)
#
# event_link:  ('/wiki/February_23_(Eastern_Orthodox_liturgics)', 'February 23 (Eastern Orthodox liturgics)')
# /wiki/February_23_(Eastern_Orthodox_liturgics)
# February 23 (Eastern Orthodox liturgics)
#
# event_link:  ('/wiki/The_Emperor%27s_Birthday', "The Emperor's Birthday")
# /wiki/The_Emperor%27s_Birthday
# The Emperor's Birthday
#
# event_link:  ('/wiki/The_Emperor%27s_Birthday', "The Emperor's Birthday")
# /wiki/The_Emperor%27s_Birthday
# The Emperor's Birthday
#
# event_link:  ('/wiki/Naruhito', 'Naruhito')
# /wiki/Naruhito
# Naruhito
#
# event_link:  ('/wiki/Emperor_of_Japan', 'Emperor of Japan')
# /wiki/Emperor_of_Japan
# Emperor of Japan
#
# event_link:  ('/wiki/Mashramani-Republic_Day', 'Mashramani-Republic Day')
# /wiki/Mashramani-Republic_Day
# Mashramani-Republic Day
#
# event_link:  ('/wiki/Mashramani-Republic_Day', 'Mashramani-Republic Day')
# /wiki/Mashramani-Republic_Day
# Mashramani-Republic Day
#
# event_link:  ('/wiki/Guyana', 'Guyana')
# /wiki/Guyana
# Guyana
#
# event_link:  ('/wiki/Mete%C5%86i', 'Meteņi')
# /wiki/Mete%C5%86i
# Meteņi
#
# event_link:  ('/wiki/Mete%C5%86i', 'Meteņi')
# /wiki/Mete%C5%86i
# Meteņi
#
# event_link:  ('/wiki/Latvia', 'Latvia')
# /wiki/Latvia
# Latvia
#
# event_link:  ('/wiki/National_Day_(Brunei)', 'National Day (Brunei)')
# /wiki/National_Day_(Brunei)
# National Day (Brunei)
#
# event_link:  ('/wiki/National_Day_(Brunei)', 'National Day (Brunei)')
# /wiki/National_Day_(Brunei)
# National Day (Brunei)
#
# event_link:  ('/wiki/Red_Army_Day', 'Red Army Day')
# /wiki/Red_Army_Day
# Red Army Day
#
# event_link:  ('/wiki/Red_Army_Day', 'Red Army Day')
# /wiki/Red_Army_Day
# Red Army Day
#
# event_link:  ('/wiki/Soviet_Union', 'Soviet Union')
# /wiki/Soviet_Union
# Soviet Union
#
# event_link:  ('/wiki/Defender_of_the_Fatherland_Day', 'Defender of the Fatherland Day')
# /wiki/Defender_of_the_Fatherland_Day
# Defender of the Fatherland Day
#
# event_link:  ('/wiki/Russia', 'Russia')
# /wiki/Russia
# Russia
#
# event_link:  ('/wiki/Defender_of_the_Fatherland_and_Armed_Forces_day', 'Defender of the Fatherland and Armed Forces day')
# /wiki/Defender_of_the_Fatherland_and_Armed_Forces_day
# Defender of the Fatherland and Armed Forces day
#
# event_link:  ('/wiki/Belarus', 'Belarus')
# /wiki/Belarus
# Belarus
#
# event_link:  ('/wiki/Armed_Forces_Day_(Tajikistan)', 'Armed Forces Day (Tajikistan)')
# /wiki/Armed_Forces_Day_(Tajikistan)
# Armed Forces Day (Tajikistan)
#
# event_link:  ('/wiki/Tajikistan', 'Tajikistan')
# /wiki/Tajikistan
# Tajikistan
#
# event_link:  ('/wiki/Defender_of_the_Fatherland_Day', 'Defender of the Fatherland Day')
# /wiki/Defender_of_the_Fatherland_Day
# Defender of the Fatherland Day
#
# event_link:  ('/wiki/Defender_of_the_Fatherland_Day', 'Defender of the Fatherland Day')
# /wiki/Defender_of_the_Fatherland_Day
# Defender of the Fatherland Day
#
# event_link:  ('/wiki/Russia', 'Russia')
# /wiki/Russia
# Russia
#
# event_link:  ('/wiki/Defender_of_the_Fatherland_and_Armed_Forces_day', 'Defender of the Fatherland and Armed Forces day')
# /wiki/Defender_of_the_Fatherland_and_Armed_Forces_day
# Defender of the Fatherland and Armed Forces day
#
# event_link:  ('/wiki/Defender_of_the_Fatherland_and_Armed_Forces_day', 'Defender of the Fatherland and Armed Forces day')
# /wiki/Defender_of_the_Fatherland_and_Armed_Forces_day
# Defender of the Fatherland and Armed Forces day
#
# event_link:  ('/wiki/Belarus', 'Belarus')
# /wiki/Belarus
# Belarus
#
# event_link:  ('/wiki/Armed_Forces_Day_(Tajikistan)', 'Armed Forces Day (Tajikistan)')
# /wiki/Armed_Forces_Day_(Tajikistan)
# Armed Forces Day (Tajikistan)
#
# event_link:  ('/wiki/Armed_Forces_Day_(Tajikistan)', 'Armed Forces Day (Tajikistan)')
# /wiki/Armed_Forces_Day_(Tajikistan)
# Armed Forces Day (Tajikistan)
#
# event_link:  ('/wiki/Tajikistan', 'Tajikistan')
# /wiki/Tajikistan
# Tajikistan
#
# data added

# %%
update_results
# Out:
# [{'doe': '2021-02-16',
#   'wiki_table_name': 'wiki_day_data_log',
#   'update_status': 'update_complete',
#   'update_note': nan},
#  {'doe': '2021-02-16',
#   'wiki_table_name': 'wiki_event',
#   'update_status': 'update_complete',
#   'update_note': 'events'},
#  {'doe': '2021-02-16',
#   'wiki_table_name': 'wiki_event',
#   'update_status': 'update_complete',
#   'update_note': 'births'},
#  {'doe': '2021-02-16',
#   'wiki_table_name': 'wiki_event',
#   'update_status': 'update_complete',
#   'update_note': 'deaths'},
#  {'doe': '2021-02-16',
#   'wiki_table_name': 'wiki_event',
#   'update_status': 'update_complete',
#   'update_note': 'holidays_and_observances'}]

# %% [markdown]
# #### Keeping the cells below for future reference (if needed)

# %%
d1 = day_data_main('February_29')
# d1

# %%
d1.keys()
# Out:
# dict_keys(['no_event_for', 'events', 'births', 'deaths', 'holidays_and_observances', 'day', 'month', 'status_code', 'day_soup'])

# %%
dfev = pd.DataFrame(d1['events'])
dfev
# Out:
#     year                                  event_description  \
# 0   1504  Christopher Columbus uses his knowledge of a l...
# 1   1644        Abel Tasman's second Pacific voyage begins.
# 2   1704  Queen Anne's War: French forces and Native Ame...
# 3   1712  February 29 is followed by February 30 in Swed...
# 4   1720  Ulrika Eleonora, Queen of Sweden abdicates in ...
# 5   1752  King Alaungpaya founds Konbaung Dynasty, the l...
# 6   1768          Polish nobles form the Bar Confederation.
# 7   1796  The Jay Treaty between the United States and G...
# 8   1864  American Civil War: Kilpatrick–Dahlgren Raid f...
# 9   1892           St. Petersburg, Florida is incorporated.
# 10  1912  The Piedra Movediza (Moving Stone) of Tandil f...
# 11  1916          Tokelau is annexed by the United Kingdom.
# 12  1916  – Child labor: In South Carolina, the minimum ...
# 13  1920  Czechoslovak National Assembly adopts the Cons...
# 14  1936                February 26 Incident in Tokyo ends.
# 15  1940  12th Academy Awards: For her performance as "M...
# 16  1940  – Finland initiates Winter War peace negotiati...
# 17  1940  – In a ceremony held in Berkeley, California, ...
# 18  1944  World War II: The Admiralty Islands are invade...
# 19  1960  The 5.7 Mw  Agadir earthquake shakes coastal M...
# 20  1972  Vietnam War: Vietnamization: South Korea withd...
# 21  1980  Gordie Howe of the Hartford Whalers makes NHL ...
# 22  1984  Pierre Trudeau announces his retirement as Lib...
# 23  1988  South African archbishop Desmond Tutu is arres...
# 24  1988  – Svend Robinson becomes the first member of t...
# 25  1992  First day of Bosnia and Herzegovina independen...
# 26  1996  Faucett Flight 251 crashes in the Andes; all 1...
# 27  1996               – Siege of Sarajevo officially ends.
# 28  2000  Second Chechen War: Eighty-four Russian paratr...
# 29  2004  Jean-Bertrand Aristide is removed as President...
# 30  2008  The United Kingdom's Ministry of Defence decid...
# 31  2008  – Misha Defonseca admits to fabricating her me...
# 32  2020  2020 Democratic Party presidential primaries: ...
# 33  2020  – COVID-19 pandemic: South Korea reports a tot...
#
#                                      event_links_list  \
# 0   [/wiki/1504, /wiki/Christopher_Columbus, /wiki...
# 1                     [/wiki/1644, /wiki/Abel_Tasman]
# 2   [/wiki/1704, /wiki/Queen_Anne%27s_War, /wiki/N...
# 3   [/wiki/1712, /wiki/February_30, /wiki/Swedish_...
# 4   [/wiki/1720, /wiki/Ulrika_Eleonora,_Queen_of_S...
# 5   [/wiki/1752, /wiki/Alaungpaya, /wiki/Konbaung_...
# 6               [/wiki/1768, /wiki/Bar_Confederation]
# 7                      [/wiki/1796, /wiki/Jay_Treaty]
# 8   [/wiki/1864, /wiki/American_Civil_War, /wiki/K...
# 9         [/wiki/1892, /wiki/St._Petersburg,_Florida]
# 10  [/wiki/1912, /wiki/Piedra_Movediza, /wiki/Tandil]
# 11                        [/wiki/1916, /wiki/Tokelau]
# 12  [/wiki/Child_labor, /wiki/South_Carolina, /wik...
# 13  [/wiki/1920, /wiki/Czechoslovakia, /wiki/Czech...
# 14           [/wiki/1936, /wiki/February_26_Incident]
# 15  [/wiki/1940, /wiki/12th_Academy_Awards, /wiki/...
# 16                                 [/wiki/Winter_War]
# 17  [/wiki/Berkeley,_California, /wiki/Ernest_Lawr...
# 18  [/wiki/1944, /wiki/Admiralty_Islands, /wiki/Op...
# 19  [/wiki/1960, /wiki/1960_Agadir_earthquake, /wi...
# 20  [/wiki/1972, /wiki/Vietnam_War, /wiki/Vietnami...
# 21  [/wiki/1980, /wiki/Gordie_Howe, /wiki/Hartford...
# 22  [/wiki/1984, /wiki/Pierre_Trudeau, /wiki/Liber...
# 23  [/wiki/1988, /wiki/Desmond_Tutu, /wiki/Aparthe...
# 24  [/wiki/Svend_Robinson, /wiki/House_of_Commons_...
# 25  [/wiki/1992, /wiki/Bosnian_independence_refere...
# 26             [/wiki/1996, /wiki/Faucett_Flight_251]
# 27                          [/wiki/Siege_of_Sarajevo]
# 28             [/wiki/2000, /wiki/Second_Chechen_War]
# 29  [/wiki/2004, /wiki/Jean-Bertrand_Aristide, /wi...
# 30  [/wiki/2008, /wiki/Ministry_of_Defence_(United...
# 31  [/wiki/Misha_Defonseca, /wiki/Misha:_A_M%C3%A9...
# 32  [/wiki/2020, /wiki/2020_Democratic_Party_presi...
# 33          [/wiki/COVID-19_pandemic, /wiki/COVID-19]
#
#                                event_first_link  event_category bc_ad  \
# 0                    /wiki/Christopher_Columbus             NaN    ad
# 1                             /wiki/Abel_Tasman             NaN    ad
# 2                      /wiki/Queen_Anne%27s_War             NaN    ad
# 3                             /wiki/February_30             NaN    ad
# 4        /wiki/Ulrika_Eleonora,_Queen_of_Sweden             NaN    ad
# 5                              /wiki/Alaungpaya             NaN    ad
# 6                       /wiki/Bar_Confederation             NaN    ad
# 7                              /wiki/Jay_Treaty             NaN    ad
# 8                      /wiki/American_Civil_War             NaN    ad
# 9                 /wiki/St._Petersburg,_Florida             NaN    ad
# 10                        /wiki/Piedra_Movediza             NaN    ad
# 11                                /wiki/Tokelau             NaN    ad
# 12                            /wiki/Child_labor             NaN    ad
# 13                         /wiki/Czechoslovakia             NaN    ad
# 14                   /wiki/February_26_Incident             NaN    ad
# 15              /wiki/Gone_with_the_Wind_(film)             NaN    ad
# 16                             /wiki/Winter_War             NaN    ad
# 17                   /wiki/Berkeley,_California             NaN    ad
# 18                      /wiki/Admiralty_Islands             NaN    ad
# 19                                /wiki/Morocco             NaN    ad
# 20                            /wiki/Vietnam_War             NaN    ad
# 21                            /wiki/Gordie_Howe             NaN    ad
# 22                         /wiki/Pierre_Trudeau             NaN    ad
# 23                           /wiki/Desmond_Tutu             NaN    ad
# 24                         /wiki/Svend_Robinson             NaN    ad
# 25  /wiki/Bosnian_independence_referendum,_1992             NaN    ad
# 26                     /wiki/Faucett_Flight_251             NaN    ad
# 27                      /wiki/Siege_of_Sarajevo             NaN    ad
# 28                     /wiki/Second_Chechen_War             NaN    ad
# 29                 /wiki/Jean-Bertrand_Aristide             NaN    ad
# 30   /wiki/Ministry_of_Defence_(United_Kingdom)             NaN    ad
# 31                        /wiki/Misha_Defonseca             NaN    ad
# 32                              /wiki/Joe_Biden             NaN    ad
# 33                      /wiki/COVID-19_pandemic             NaN    ad
#
#    bc_ad_note
# 0     assumed
# 1     assumed
# 2     assumed
# 3     assumed
# 4     assumed
# 5     assumed
# 6     assumed
# 7     assumed
# 8     assumed
# 9     assumed
# 10    assumed
# 11    assumed
# 12    assumed
# 13    assumed
# 14    assumed
# 15    assumed
# 16    assumed
# 17    assumed
# 18    assumed
# 19    assumed
# 20    assumed
# 21    assumed
# 22    assumed
# 23    assumed
# 24    assumed
# 25    assumed
# 26    assumed
# 27    assumed
# 28    assumed
# 29    assumed
# 30    assumed
# 31    assumed
# 32    assumed
# 33    assumed

# %%
ddea = pd.DataFrame(d1['deaths'])
ddea
# Out:
#     year                                  event_description  \
# 0    468                                      Pope Hilarius
# 1    992  Oswald of Worcester, Anglo-Saxon archbishop an...
# 2   1212   Hōnen, Japanese monk, founded Jōdo-shū (b. 1133)
# 3   1460       Albert III, Duke of Bavaria-Munich (b. 1401)
# 4   1528  Patrick Hamilton, Scottish Protestant reformer...
# 5   1592  Alessandro Striggio, Italian composer and dipl...
# 6   1600  Caspar Hennenberger, German pastor, historian ...
# 7   1604  John Whitgift, English archbishop and academic...
# 8   1740        Pietro Ottoboni, Italian cardinal (b. 1667)
# 9   1744  John Theophilus Desaguliers, French-English ph...
# 10  1792  Johann Andreas Stein, German piano builder (b....
# 11  1820  Johann Joachim Eschenburg, German historian an...
# 12  1848  Louis-François Lejeune, French general, painte...
# 13  1852     Matsudaira Katataka, Japanese daimyō (b. 1806)
# 14  1868                      Ludwig I of Bavaria (b. 1786)
# 15  1880  James Milne Wilson, Scottish-Australian soldie...
# 16  1908            Pat Garrett, American sheriff (b. 1850)
# 17  1908  John Hope, 1st Marquess of Linlithgow, Scottis...
# 18  1920  Ernie Courtney, American baseball player (b. 1...
# 19  1928  Adolphe Appia, Swiss architect and theorist (b...
# 20  1928  Ina Coolbrith, American poet and librarian (b....
# 21  1940  E. F. Benson, English archaeologist and author...
# 22  1944  Pehr Evind Svinhufvud, Finnish lawyer, judge a...
# 23  1948  Robert Barrington-Ward, English lawyer and jou...
# 24  1948  Rebel Oakes, American baseball player and mana...
# 25  1952  Quo Tai-chi, Chinese politician and diplomat, ...
# 26  1956  Elpidio Quirino, Filipino lawyer and politicia...
# 27  1960  Melvin Purvis, American police officer and  FB...
# 28  1960  Walter Yust, American journalist and author (b...
# 29  1964  Frank Albertson, American actor and singer (b....
# 30  1968  Lena Blackburne, American baseball player, coa...
# 31  1968  Tore Ørjasæter, Norwegian poet and educator (b...
# 32  1972  Tom Davies, American football player and coach...
# 33  1976   Florence P. Dwyer, American politician (b. 1902)
# 34  1980  Yigal Allon, Israeli general and politician,  ...
# 35  1980  Gil Elvgren, American painter and illustrator ...
# 36  1984  Ludwik Starski, Polish screenwriter and songwr...
# 37  1988  Sidney Harmon, American screenwriter and produ...
# 38  1992     Ruth Pitter, English poet and author (b. 1897)
# 39  1996  Wes Farrell, American singer-songwriter and pr...
# 40  1996  Ralph Rowe, American baseball player, coach an...
# 41  2000        Dennis Danell, American guitarist (b. 1961)
# 42  2004  Kagamisato Kiyoji, Japanese sumo wrestler, the...
# 43  2004  Jerome Lawrence, American playwright and autho...
# 44  2004  Harold Bernard St. John, Barbadian lawyer and ...
# 45  2004   Lorrie Wilmot, South African cricketer (b. 1943)
# 46  2008             Janet Kagan, American author (b. 1946)
# 47  2008  Erik Ortvad, Danish painter and illustrator (b...
# 48  2008  Akira Yamada, Japanese scholar and philosopher...
# 49  2012      Roland Bautista, American guitarist (b. 1951)
# 50  2012  Davy Jones, English singer, guitarist and acto...
# 51  2012    Sheldon Moldoff, American illustrator (b. 1920)
# 52  2012  P. K. Narayana Panicker, Indian social leader ...
# 53  2016  Wenn V. Deramas, Filipino director and screenw...
# 54  2016  Gil Hill, American police officer, actor and p...
# 55  2016          Josefin Nilsson, Swedish singer (b. 1969)
# 56  2016      Louise Rennison, English author (b. 1951)[14]
# 57  2016     Mumtaz Qadri, Pakistani assassin (b. 1985)[15]
# 58  2020  Dieter Laser, German actor (Lexx, The Ogre, Th...
# 59  2020  Éva Székely, Hungarian Hall of Fame swimmer, O...
#
#                                      event_links_list  \
# 0                    [/wiki/468, /wiki/Pope_Hilarius]
# 1              [/wiki/992, /wiki/Oswald_of_Worcester]
# 2   [/wiki/1212, /wiki/H%C5%8Dnen, /wiki/J%C5%8Ddo...
# 3     [/wiki/1460, /wiki/Albert_III,_Duke_of_Bavaria]
# 4       [/wiki/1528, /wiki/Patrick_Hamilton_(martyr)]
# 5             [/wiki/1592, /wiki/Alessandro_Striggio]
# 6             [/wiki/1600, /wiki/Caspar_Hennenberger]
# 7                   [/wiki/1604, /wiki/John_Whitgift]
# 8      [/wiki/1740, /wiki/Pietro_Ottoboni_(cardinal)]
# 9     [/wiki/1744, /wiki/John_Theophilus_Desaguliers]
# 10           [/wiki/1792, /wiki/Johann_Andreas_Stein]
# 11      [/wiki/1820, /wiki/Johann_Joachim_Eschenburg]
# 12    [/wiki/1848, /wiki/Louis-Fran%C3%A7ois_Lejeune]
# 13            [/wiki/1852, /wiki/Matsudaira_Katataka]
# 14            [/wiki/1868, /wiki/Ludwig_I_of_Bavaria]
# 15  [/wiki/1880, /wiki/James_Milne_Wilson, /wiki/P...
# 16                                [/wiki/Pat_Garrett]
# 17  [/wiki/John_Hope,_1st_Marquess_of_Linlithgow, ...
# 18                 [/wiki/1920, /wiki/Ernie_Courtney]
# 19                              [/wiki/Adolphe_Appia]
# 20                              [/wiki/Ina_Coolbrith]
# 21                   [/wiki/1940, /wiki/E._F._Benson]
# 22  [/wiki/1944, /wiki/Pehr_Evind_Svinhufvud, /wik...
# 23                     [/wiki/Robert_Barrington-Ward]
# 24                                [/wiki/Rebel_Oakes]
# 25  [/wiki/1952, /wiki/Quo_Tai-chi, /wiki/Permanen...
# 26  [/wiki/1956, /wiki/Elpidio_Quirino, /wiki/Pres...
# 27                   [/wiki/Melvin_Purvis, /wiki/FBI]
# 28                                [/wiki/Walter_Yust]
# 29                [/wiki/1964, /wiki/Frank_Albertson]
# 30                            [/wiki/Lena_Blackburne]
# 31                   [/wiki/Tore_%C3%98rjas%C3%A6ter]
# 32  [/wiki/1972, /wiki/Tom_Davies_(American_footba...
# 33              [/wiki/1976, /wiki/Florence_P._Dwyer]
# 34  [/wiki/Yigal_Allon, /wiki/Prime_Minister_of_Is...
# 35                                [/wiki/Gil_Elvgren]
# 36                 [/wiki/1984, /wiki/Ludwik_Starski]
# 37                  [/wiki/1988, /wiki/Sidney_Harmon]
# 38                    [/wiki/1992, /wiki/Ruth_Pitter]
# 39                                [/wiki/Wes_Farrell]
# 40                                 [/wiki/Ralph_Rowe]
# 41                  [/wiki/2000, /wiki/Dennis_Danell]
# 42          [/wiki/Kagamisato_Kiyoji, /wiki/Yokozuna]
# 43                            [/wiki/Jerome_Lawrence]
# 44  [/wiki/Harold_Bernard_St._John, /wiki/Prime_Mi...
# 45                              [/wiki/Lorrie_Wilmot]
# 46                                [/wiki/Janet_Kagan]
# 47                                [/wiki/Erik_Ortvad]
# 48                               [/wiki/Akira_Yamada]
# 49                            [/wiki/Roland_Bautista]
# 50                      [/wiki/Davy_Jones_(musician)]
# 51                            [/wiki/Sheldon_Moldoff]
# 52                    [/wiki/P._K._Narayana_Panicker]
# 53                            [/wiki/Wenn_V._Deramas]
# 54                                   [/wiki/Gil_Hill]
# 55                            [/wiki/Josefin_Nilsson]
# 56                            [/wiki/Louise_Rennison]
# 57                               [/wiki/Mumtaz_Qadri]
# 58  [/wiki/Dieter_Laser, /wiki/Lexx, /wiki/The_Ogr...
# 59  [/wiki/%C3%89va_Sz%C3%A9kely, /wiki/Internatio...
#
#                                event_first_link  event_category bc_ad  \
# 0                           /wiki/Pope_Hilarius             NaN    ad
# 1                     /wiki/Oswald_of_Worcester             NaN    ad
# 2                              /wiki/H%C5%8Dnen             NaN    ad
# 3             /wiki/Albert_III,_Duke_of_Bavaria             NaN    ad
# 4               /wiki/Patrick_Hamilton_(martyr)             NaN    ad
# 5                     /wiki/Alessandro_Striggio             NaN    ad
# 6                     /wiki/Caspar_Hennenberger             NaN    ad
# 7                           /wiki/John_Whitgift             NaN    ad
# 8              /wiki/Pietro_Ottoboni_(cardinal)             NaN    ad
# 9             /wiki/John_Theophilus_Desaguliers             NaN    ad
# 10                   /wiki/Johann_Andreas_Stein             NaN    ad
# 11              /wiki/Johann_Joachim_Eschenburg             NaN    ad
# 12            /wiki/Louis-Fran%C3%A7ois_Lejeune             NaN    ad
# 13                    /wiki/Matsudaira_Katataka             NaN    ad
# 14                    /wiki/Ludwig_I_of_Bavaria             NaN    ad
# 15                     /wiki/James_Milne_Wilson             NaN    ad
# 16                            /wiki/Pat_Garrett             NaN    ad
# 17  /wiki/John_Hope,_1st_Marquess_of_Linlithgow             NaN    ad
# 18                         /wiki/Ernie_Courtney             NaN    ad
# 19                          /wiki/Adolphe_Appia             NaN    ad
# 20                          /wiki/Ina_Coolbrith             NaN    ad
# 21                           /wiki/E._F._Benson             NaN    ad
# 22                  /wiki/Pehr_Evind_Svinhufvud             NaN    ad
# 23                 /wiki/Robert_Barrington-Ward             NaN    ad
# 24                            /wiki/Rebel_Oakes             NaN    ad
# 25                            /wiki/Quo_Tai-chi             NaN    ad
# 26                        /wiki/Elpidio_Quirino             NaN    ad
# 27                          /wiki/Melvin_Purvis             NaN    ad
# 28                            /wiki/Walter_Yust             NaN    ad
# 29                        /wiki/Frank_Albertson             NaN    ad
# 30                        /wiki/Lena_Blackburne             NaN    ad
# 31               /wiki/Tore_%C3%98rjas%C3%A6ter             NaN    ad
# 32         /wiki/Tom_Davies_(American_football)             NaN    ad
# 33                      /wiki/Florence_P._Dwyer             NaN    ad
# 34                            /wiki/Yigal_Allon             NaN    ad
# 35                            /wiki/Gil_Elvgren             NaN    ad
# 36                         /wiki/Ludwik_Starski             NaN    ad
# 37                          /wiki/Sidney_Harmon             NaN    ad
# 38                            /wiki/Ruth_Pitter             NaN    ad
# 39                            /wiki/Wes_Farrell             NaN    ad
# 40                             /wiki/Ralph_Rowe             NaN    ad
# 41                          /wiki/Dennis_Danell             NaN    ad
# 42                      /wiki/Kagamisato_Kiyoji             NaN    ad
# 43                        /wiki/Jerome_Lawrence             NaN    ad
# 44                /wiki/Harold_Bernard_St._John             NaN    ad
# 45                          /wiki/Lorrie_Wilmot             NaN    ad
# 46                            /wiki/Janet_Kagan             NaN    ad
# 47                            /wiki/Erik_Ortvad             NaN    ad
# 48                           /wiki/Akira_Yamada             NaN    ad
# 49                        /wiki/Roland_Bautista             NaN    ad
# 50                  /wiki/Davy_Jones_(musician)             NaN    ad
# 51                        /wiki/Sheldon_Moldoff             NaN    ad
# 52                /wiki/P._K._Narayana_Panicker             NaN    ad
# 53                        /wiki/Wenn_V._Deramas             NaN    ad
# 54                               /wiki/Gil_Hill             NaN    ad
# 55                        /wiki/Josefin_Nilsson             NaN    ad
# 56                        /wiki/Louise_Rennison             NaN    ad
# 57                           /wiki/Mumtaz_Qadri             NaN    ad
# 58                           /wiki/Dieter_Laser             NaN    ad
# 59                  /wiki/%C3%89va_Sz%C3%A9kely             NaN    ad
#
#              bc_ad_note
# 0               assumed
# 1               assumed
# 2               assumed
# 3               assumed
# 4               assumed
# 5               assumed
# 6               assumed
# 7               assumed
# 8               assumed
# 9               assumed
# 10              assumed
# 11              assumed
# 12              assumed
# 13              assumed
# 14              assumed
# 15              assumed
# 16  nested year assumed
# 17  nested year assumed
# 18              assumed
# 19  nested year assumed
# 20  nested year assumed
# 21              assumed
# 22              assumed
# 23  nested year assumed
# 24  nested year assumed
# 25              assumed
# 26              assumed
# 27  nested year assumed
# 28  nested year assumed
# 29              assumed
# 30  nested year assumed
# 31  nested year assumed
# 32              assumed
# 33              assumed
# 34  nested year assumed
# 35  nested year assumed
# 36              assumed
# 37              assumed
# 38              assumed
# 39  nested year assumed
# 40  nested year assumed
# 41              assumed
# 42  nested year assumed
# 43  nested year assumed
# 44  nested year assumed
# 45  nested year assumed
# 46  nested year assumed
# 47  nested year assumed
# 48  nested year assumed
# 49  nested year assumed
# 50  nested year assumed
# 51  nested year assumed
# 52  nested year assumed
# 53  nested year assumed
# 54  nested year assumed
# 55  nested year assumed
# 56  nested year assumed
# 57  nested year assumed
# 58  nested year assumed
# 59  nested year assumed

# %%
dfhol = pd.DataFrame(d1['holidays_and_observances'])
dfhol
# Out:
#    year                                  event_description  \
# 0   NaN  Auguste Chapdelaine (one of the Martyr Saints ...
# 1   NaN            Oswald of Worcester (in leap year only)
# 2   NaN                                 Saint John Cassian
# 3   NaN                 February 29 in the Orthodox church
# 4   NaN  The fourth day of Ayyám-i-Há (Baháʼí Faith) (o...
# 5   NaN  Rare Disease Day (in leap years; celebrated in...
# 6   NaN           Bachelor's Day (Ireland, United Kingdom)
#
#                                     event_links_list  \
# 0  [/wiki/Auguste_Chapdelaine, /wiki/Martyr_Saint...
# 1                        [/wiki/Oswald_of_Worcester]
# 2                               [/wiki/John_Cassian]
# 3   [/wiki/February_29_(Eastern_Orthodox_liturgics)]
# 4  [/wiki/Ayy%C3%A1m-i-H%C3%A1, /wiki/Bah%C3%A1%C...
# 5                           [/wiki/Rare_Disease_Day]
# 6  [/wiki/Bachelor%27s_Day_(tradition), /wiki/Rep...
#
#                                  event_first_link       event_category
# 0                       /wiki/Auguste_Chapdelaine  christian feast day
# 1                       /wiki/Oswald_of_Worcester  christian feast day
# 2                              /wiki/John_Cassian  christian feast day
# 3  /wiki/February_29_(Eastern_Orthodox_liturgics)  christian feast day
# 4                      /wiki/Ayy%C3%A1m-i-H%C3%A1                  NaN
# 5                          /wiki/Rare_Disease_Day                  NaN
# 6              /wiki/Bachelor%27s_Day_(tradition)                  NaN
