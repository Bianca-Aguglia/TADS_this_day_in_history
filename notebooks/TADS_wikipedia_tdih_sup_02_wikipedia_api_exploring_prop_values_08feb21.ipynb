# %% [markdown]
# # Wikipedia API - 'prop'
# ---
# **Goal:** explore the results returned by using different values of the 'prop' parameter and find the values most useful for this project.
#
# **Notes:**
# - there are over thirty values for the 'prop' parameter in the calls to wikipedia API
# - documentation for the API parameters (including 'prop' values) is at https://www.mediawiki.org/wiki/API:Query
# - the page data needed for this project is:
#     - page size
#     - page views
#     - page incoming links
#     - coordinates (if any)
# - Section 1 of this notebook shows the 'prop' values most useful for this project:
# - Section 2 of the notebook shows results from trying out different 'prop' values (in the order they are listed on the Wikipedia API documentation page)

# %%
import requests
import time
import config

from bs4 import BeautifulSoup

# %%
URL = 'https://en.wikipedia.org/w/api.php/'
HEADERS = config.HEADERS
PARAMS = {'format': 'json',
         'action': 'parse'}

# %% [markdown]
# ## Section 1
# ---
# Building up the API request with 'prop' values useful for this project:
# - cirrusbuilddoc: for incoming_links
# - cirruscompsuggestbuilddoc: for page score
# - extracts: (with extra param 'exintro'): for the first paragraphs of a page
# - info: for page length

# %%
params = {'titles': 'Francis_I_of_France',
          'action': 'query',
          'format': 'json',
          'prop': 'cirrusbuilddoc|cirruscompsuggestbuilddoc|extracts|info|pageimages',
          'exintro': True # gives the first paragraphs of a page (before detail sections)
         }

r00 = requests.get(url = URL, headers = HEADERS, params = params)
r00.status_code

# %% [markdown]
# ## Section 2
# ---
# Trying out different prop values in the order they are listed on the Wikipedia API documentation page. Making a note whether results are useful or not for this project.

# %% [markdown]
# ### 1. prop = categories
# **Note:** results returned using this value are not needed for this project

# %%
params = {'titles': 'Francis_I_of_France',
          'action': 'query',
          'format': 'json',
          'prop': 'categories'}

r01 = requests.get(url = URL, headers = HEADERS, params = params)
r01.status_code
# Out:
# 200

# %%
r01.json()
# Out:
# {'continue': {'clcontinue': '50012|All_articles_with_failed_verification',
#   'continue': '||'},
#  'query': {'normalized': [{'from': 'Francis_I_of_France',
#     'to': 'Francis I of France'}],
#   'pages': {'50012': {'pageid': 50012,
#     'ns': 0,
#     'title': 'Francis I of France',
#     'categories': [{'ns': 14, 'title': 'Category:1494 births'},
#      {'ns': 14, 'title': 'Category:1510s in France'},
#      {'ns': 14, 'title': 'Category:1520s in France'},
#      {'ns': 14, 'title': 'Category:1530s in France'},
#      {'ns': 14, 'title': 'Category:1540s in France'},
#      {'ns': 14, 'title': 'Category:1547 deaths'},
#      {'ns': 14, 'title': 'Category:15th-century peers of France'},
#      {'ns': 14, 'title': 'Category:16th-century dukes of Brittany'},
#      {'ns': 14, 'title': 'Category:16th-century kings of France'},
#      {'ns': 14, 'title': 'Category:16th-century peers of France'}]}}}}

# %% [markdown]
# ### 2. prop = cirrusbuilddoc
# **Note:**
# - this returns useful results:
#     - incoming links
#         - r02.json()['query']['pages']['50012']['cirrusbuilddoc']['incoming_links']
#     - source text (clean regex for first paragraph):
#         - r02.json()['query']['pages']['50012']['cirrusbuilddoc']['source_text']
#         - better option is prop=extracts and exintro=True)
#     - page size (same data as length when prop=info):
#         - r02.json()['query']['pages']['50012']['cirrusbuilddoc']['text_bytes']
#     - coordinates (if any):
#         - r02.json()['query']['pages']['50012']['cirrusbuilddoc']['text_bytes']

# %%
params = {'titles': 'Francis_I_of_France',
          'action': 'query',
          'format': 'json',
          'prop': 'cirrusbuilddoc'}

r02 = requests.get(url = URL, headers = HEADERS, params = params)
r02.status_code
# Out:
# 200

# %%
r02.json()
# Out:
# {'batchcomplete': '',
#  'query': {'normalized': [{'from': 'Francis_I_of_France',
#     'to': 'Francis I of France'}],
#   'pages': {'50012': {'pageid': 50012,
#     'ns': 0,
#     'title': 'Francis I of France',
#     'cirrusbuilddoc': {'version': 1005165190,
#      'wiki': 'enwiki',
#      'namespace': 0,
#      'namespace_text': '',
#      'title': 'Francis I of France',
#      'timestamp': '2021-02-06T08:25:34Z',
#      'create_timestamp': '2002-04-21T20:28:56Z',
#      'redirect': [{'namespace': 0, 'title': 'François I of France'},
#       {'namespace': 0, 'title': 'Francis I of france'},
#       {'namespace': 0, 'title': 'Francis I, King of France'},
#       {'namespace': 0, 'title': 'Francois I of France'},
#       {'namespace': 0, 'title': 'François I'},
#       {'namespace': 0, 'title': 'Francois I'},
#       {'namespace': 0, 'title': 'King François I'},
#       {'namespace': 0, 'title': 'François Ier'},
#       {'namespace': 0, 'title': 'King of France François I'},
#       {'namespace': 0, 'title': 'François 1er'},
#       {'namespace': 0, 'title': 'Francois 1er'},
#       {'namespace': 0, 'title': 'King Francois I'},
#       {'namespace': 0, 'title': 'Francis 1 of France'},
#       {'namespace': 0, 'title': 'Francis i of france'},
#       {'namespace': 0, 'title': 'Francois Ier'},
#       {'namespace': 0, 'title': 'King of France Francois I'},
#       {'namespace': 0, 'title': 'King Francis I of France'},
#       {'namespace': 0, 'title': 'François Premier'},
#       {'namespace': 0, 'title': 'Francois Premier'},
#       {'namespace': 0, 'title': "François d'Angoulême"},
#       {'namespace': 0, 'title': "Francois d'Angouleme"},
#       {'namespace': 0, 'title': "D'Angoulême"},
#       {'namespace': 0, 'title': "D'Angouleme"},
#       {'namespace': 0, 'title': 'François I de France'},
#       {'namespace': 0, 'title': 'Francis, Count of Angoulême'}],
#      'incoming_links': 2187,
#      'category': ['CS1 maint: uses authors parameter',
#       'Wikipedia articles incorporating a citation from the 1911 Encyclopaedia Britannica with Wikisource reference',
#       'CS1 French-language sources (fr)',
#       'Articles with short description',
#       'Short description is different from Wikidata',
#       'Use dmy dates from July 2020',
#       'Articles containing French-language text',
#       'Articles containing Middle French (ca. 1400-1600)-language text',
#       'All articles with unsourced statements',
#       'Articles with unsourced statements from March 2014',
#       'All articles with failed verification',
#       'Articles with failed verification from May 2013',
#       'Commons category link is on Wikidata',
#       'Wikipedia articles with BIBSYS identifiers',
#       'Wikipedia articles with BNE identifiers',
#       'Wikipedia articles with BNF identifiers',
#       'Wikipedia articles with CANTIC identifiers',
#       'Wikipedia articles with GND identifiers',
#       'Wikipedia articles with HDS identifiers',
#       'Wikipedia articles with ICCU identifiers',
#       'Wikipedia articles with ISNI identifiers',
#       'Wikipedia articles with LCCN identifiers',
#       'Wikipedia articles with NDL identifiers',
#       'Wikipedia articles with NKC identifiers',
#       'Wikipedia articles with NLA identifiers',
#       'Wikipedia articles with NLI identifiers',
#       'Wikipedia articles with NLP identifiers',
#       'Wikipedia articles with NTA identifiers',
#       'Wikipedia articles with PLWABN identifiers',
#       'Wikipedia articles with RKDartists identifiers',
#       'Wikipedia articles with SELIBR identifiers',
#       'Wikipedia articles with SUDOC identifiers',
#       'Wikipedia articles with Trove identifiers',
#       'Wikipedia articles with ULAN identifiers',
#       'Wikipedia articles with VcBA identifiers',
#       'Wikipedia articles with VIAF identifiers',
#       'Wikipedia articles with WORLDCATID identifiers',
#       'Francis I of France',
#       '1494 births',
#       '1547 deaths',
#       '16th-century kings of France',
#       '16th-century dukes of Brittany',
#       'Ancien Régime in France',
#       'Counts of Angoulême',
#       'Dauphins of Viennois',
#       'Dauphins of France',
#       'Dukes of Milan',
#       'Dukes of Valois',
#       'French people of Cypriot descent',
#       'French Roman Catholics',
#       'House of Valois-Angoulême',
#       'Knights of the Garter',
#       'Knights of the Golden Fleece',
#       'People from Cognac',
#       'Burials at the Basilica of Saint-Denis',
#       '1510s in France',
#       '1520s in France',
#       '1530s in France',
#       '1540s in France',
#       '15th-century peers of France',
#       '16th-century peers of France',
#       'French art patrons',
#       'Monarchs imprisoned and detained during war'],
#      'external_link': ['//www.worldcat.org/oclc/862814775',
#       'https://books.google.com/books?id=yTqyEdU7fEcC&pg=PT61',
#       'https://en.wikisource.org/wiki/1911_Encyclop%C3%A6dia_Britannica/Francis_I._of_France',
#       '//doi.org/10.1080%2F03085695408592059',
#       '//www.worldcat.org/oclc/1752690',
#       'https://books.google.com/books?id=Y-08AAAAIAAJ&pg=PA61',
#       'https://books.google.com/books?id=HlibHoeruDUC&pg=PA123',
#       'https://books.google.com/books?id=P7OuMkzGKw0C&pg=PA57',
#       'https://books.google.com/books?id=Sl8fniRER4kC&pg=PA26',
#       'https://books.google.com/books?id=w5iJ1tfLnnoC&q=%22Franco-Turkish+alliance%22&pg=PA62',
#       'https://books.google.com/books?id=AkMHta3C7LUC&q=%22Franco-Turkish+alliance%22&pg=PA219',
#       'https://books.google.com/books?id=nuyx5E_wp7QC&pg=PA158',
#       'https://books.google.com/books?id=rvEBMIIcHQkC&pg=PA405',
#       'http://www.historytoday.com/richard-cavendish/marriage-mary-queen-scots',
#       'https://www.jstor.org/stable/24412871',
#       'https://archive.is/20130213110523/http://www.larousse.fr/encyclopedie/article/Laroussefr_-_Article/11020086',
#       'https://de.wikisource.org/wiki/BLK%C3%96:Habsburg,_Eleonore_von_Oesterreich_(Tochter_Philipp%E2%80%99s_von_Oesterreich)',
#       'https://books.google.com/books?id=pGgfAAAAMAAJ',
#       'https://archive.org/details/isbn_9791576070917',
#       'https://archive.org/details/isbn_9791576070917/page/231',
#       'http://www.sabaudia.org/3180-la-maison-de-savoie.htm',
#       'https://gallica.bnf.fr/ark:/12148/bpt6k76026j/f125.image',
#       'https://archive.org/details/creationbrittany00jone',
#       'https://archive.org/details/creationbrittany00jone/page/n137',
#       'https://books.google.com/books?id=SnCWSuZ-58oC&pg=PA468',
#       'https://books.google.com/books?id=DA1tMNYiny0C&pg=PA265',
#       'http://resources.huygens.knaw.nl/vrouwenlexicon/lemmata/data/MargarethaVanBeieren',
#       'https://www.wikidata.org/wiki/Q129857#identifiers',
#       'https://www.academia.edu/download/34174247/FHS030-03-03Isom-Verhaaren1pp.pdf',
#       'http://www.jstor.com/stable/2541220',
#       "https://books.google.com/books?hl=en&lr=lang_en&id=zGvoIW6Y_xAC&oi=fnd&pg=PR11&dq=Knecht,+R.J.+''Francis+I''&ots=a8JSfDN6I9&sig=Sd7eVr6LETir1zdzDntoU77owuE#v=onepage&q=Knecht,%20R.J.%20",
#       'https://archive.org/details/francisi00knec/page/n3/mode/2up',
#       'https://www.amazon.com/French-Renaissance-Monarchy-Francis-1984-03-19/dp/B01K0S5WQI/',
#       'https://doi-org/10.1111/j.1468-229X.1981.tb01357.x',
#       'https://archive.org/details/princeofrenaiss000desm',
#       'https://authority.bibsys.no/authority/rest/authorities/html/90236426',
#       'http://catalogo.bne.es/uhtbin/authoritybrowse.cgi?action=display&authority_id=XX1501310',
#       'https://catalogue.bnf.fr/ark:/12148/cb120127827',
#       'https://data.bnf.fr/ark:/12148/cb120127827',
#       'http://cantic.bnc.cat/registres/CUCId/a11379029',
#       'https://d-nb.info/gnd/118534947',
#       'https://hls-dhs-dss.ch/fr/articles/029215',
#       'https://opac.sbn.it/opacsbn/opac/iccu/scheda_authority.jsp?bid=IT%5CICCU%5CBVEV%5C022053',
#       'https://isni.org/isni/0000000121029337',
#       'https://id.loc.gov/authorities/names/n50038638',
#       'https://id.ndl.go.jp/auth/ndlna/001193472',
#       'https://aleph.nkp.cz/F/?func=find-c&local_base=aut&ccl_term=ica=jn20000700556&CON_LNG=ENG',
#       'https://nla.gov.au/anbd.aut-an49861380',
#       'http://uli.nli.org.il/F/?func=direct&doc_number=000048459&local_base=nlx10',
#       'https://tools.wmflabs.org/wikidata-externalid-url?p=1695&id=A11869732',
#       'http://data.bibliotheken.nl/id/thes/p069995168',
#       'http://mak.bn.org.pl/cgi-bin/KHW/makwww.exe?BM=1&NU=1&IM=4&WI=9810695005505606',
#       'https://rkd.nl/en/explore/artists/441278',
#       'https://libris.kb.se/auth/187794',
#       'https://www.idref.fr/028254287',
#       'https://trove.nla.gov.au/people/1526264',
#       'https://www.getty.edu/vow/ULANFullDisplay?find=&role=&nation=&subjectid=500122500',
#       'https://opac.vatlib.it/auth/detail/495_72801',
#       'https://viaf.org/viaf/88805531',
#       'https://www.worldcat.org/identities/lccn-n50038638'],
#      'outgoing_link': ['Category:Use_dmy_dates_from_July_2020',
#       'Category:Articles_with_unsourced_statements_from_March_2014',
#       'Category:Articles_with_failed_verification_from_May_2013',
#       'Category:Wikipedia_articles_with_BIBSYS_identifiers',
#       'Category:Wikipedia_articles_with_BNE_identifiers',
#       'Category:Wikipedia_articles_with_BNF_identifiers',
#       'Category:Wikipedia_articles_with_CANTIC_identifiers',
#       'Category:Wikipedia_articles_with_GND_identifiers',
#       'Category:Wikipedia_articles_with_HDS_identifiers',
#       'Category:Wikipedia_articles_with_ICCU_identifiers',
#       'Category:Wikipedia_articles_with_ISNI_identifiers',
#       'Category:Wikipedia_articles_with_LCCN_identifiers',
#       'Category:Wikipedia_articles_with_NDL_identifiers',
#       'Category:Wikipedia_articles_with_NKC_identifiers',
#       'Category:Wikipedia_articles_with_NLA_identifiers',
#       'Category:Wikipedia_articles_with_NLI_identifiers',
#       'Category:Wikipedia_articles_with_NLP_identifiers',
#       'Category:Wikipedia_articles_with_NTA_identifiers',
#       'Category:Wikipedia_articles_with_PLWABN_identifiers',
#       'Category:Wikipedia_articles_with_RKDartists_identifiers',
#       'Category:Wikipedia_articles_with_SELIBR_identifiers',
#       'Category:Wikipedia_articles_with_SUDOC_identifiers',
#       'Category:Wikipedia_articles_with_Trove_identifiers',
#       'Category:Wikipedia_articles_with_ULAN_identifiers',
#       'Category:Wikipedia_articles_with_VcBA_identifiers',
#       'Category:Wikipedia_articles_with_VIAF_identifiers',
#       'Category:Wikipedia_articles_with_WORLDCATID_identifiers',
#       'Category:CS1_maint:_uses_authors_parameter',
#       'Category:France',
#       'Category:French_society',
#       'Portal:France',
#       'Portal:Biography',
#       'France',
#       'Absolute_monarchy_in_France',
#       'Abu_al-Abbas_Ahmad_ibn_Muhammad',
#       'Administrative_divisions_of_France',
#       'Aeterni_regis',
#       'Affair_of_the_Placards',
#       'Agnes_of_Burgundy,_Duchess_of_Bourbon',
#       'Aimé_Simon-Girard',
#       'Alain_II_Hir',
#       'Alain_IX,_Viscount_of_Rohan',
#       'Alain_VIII,_Viscount_of_Rohan',
#       'Alan,_Count_of_Nantes_(988–90)',
#       'Alan_I,_King_of_Brittany',
#       'Alan_II,_Duke_of_Brittany',
#       'Alan_III,_Duke_of_Brittany',
#       'Alan_IV,_Duke_of_Brittany',
#       'Alexandre_Dumas,_père',
#       'Algiers',
#       'Alix,_Duchess_of_Brittany',
#       'Alonso_Pita_da_Veiga',
#       'Amadeus_VIII,_Duke_of_Savoy',
#       'Ancien_Régime',
#       'Andrea_del_Sarto',
#       'Anne_Boleyn',
#       'Anne_Fremantle',
#       "Anne_de_Pisseleu_d'Heilly",
#       'Anne_of_Brittany',
#       'Anne_of_Cyprus',
#       'Arabic',
#       'Arabic_language',
#       'Aramaic',
#       'Arithmetic',
#       'Arthur_I,_Duke_of_Brittany',
#       'Arthur_II,_Duke_of_Brittany',
#       'Arthur_III,_Duke_of_Brittany',
#       'Automotive_industry_in_France',
#       'BIBSYS_(identifier)',
#       'BNE_(identifier)',
#       'BNF_(identifier)',
#       'Baldassare_Castiglione',
#       'Bank_of_France',
#       'Banking_in_France',
#       'Basilica_of_St_Denis',
#       'Battle_of_Marignano',
#       'Battle_of_Pavia',
#       'Belle_Époque',
#       'Benvenuto_Cellini',
#       'Bernard_van_Orley',
#       'Bertha,_Duchess_of_Brittany',
#       "Bertrand_d'Ornesan",
#       'Bois_de_Boulogne',
#       'Book_of_the_Courtier',
#       'Bosonids',
#       'Bourbon_Restoration',
#       'Béatrix_de_Clisson',
#       'CANTIC_(identifier)',
#       'Calibres_de_France',
#       'Capetian_dynasty',
#       'Carloman_I',
#       'Carloman_II',
#       'Carlos,_rey_emperador',
#       'Carolingian_dynasty',
#       'Carry_On_Henry',
#       'Castell_del_Patriarca',
#       'Cathedral_of_Reims',
#       "Catherine_de'_Medici",
#       'Catholic_Church',
#       'Cesare_Hercolani',
#       'Charente',
#       'Charibert_I',
#       'Charlemagne',
#       'Charles,_Count_of_Angoulême',
#       'Charles,_Duke_of_Brittany',
#       'Charles,_Duke_of_Burgundy',
#       'Charles_I,_Duke_of_Bourbon',
#       'Charles_II_de_Valois,_Duke_of_Orléans',
#       'Charles_IV_of_France',
#       'Charles_IX_of_France',
#       'Charles_V,_Holy_Roman_Emperor',
#       'Charles_VIII_of_France',
#       'Charles_VII_of_France',
#       'Charles_VI_of_France',
#       'Charles_V_of_France',
#       'Charles_X',
#       "Charles_de_Valois,_Duc_d'Orléans",
#       'Charles_the_Bald',
#       'Charles_the_Fat',
#       'Charles_the_Simple',
#       'Charlotte_of_Bourbon,_Queen_of_Cyprus',
#       'Charlotte_of_Valois',
#       'Childebert_I',
#       'Childebert_II',
#       'Childebert_III',
#       'Childeric_II',
#       'Childeric_III',
#       'Chilperic_I',
#       'Chilperic_II',
#       'Chlothar_I',
#       'Chlothar_II',
#       'Chlothar_III',
#       'Chlothar_IV',
#       'Christianity',
#       'Christophe_de_Longueil',
#       "Château_d'Amboise",
#       'Château_de_Blois',
#       'Château_de_Chambord',
#       'Château_de_Cognac',
#       'Château_de_Fontainebleau',
#       'Château_de_Madrid',
#       'Château_de_Rambouillet',
#       'Château_de_Saint-Germain-en-Laye',
#       'Château_du_Louvre',
#       'Châteaubriant',
#       'Cinderella',
#       'Cinema_of_France',
#       'Circa',
#       'Claude,_Duchess_of_Brittany',
#       'Claude_Titre',
#       'Claude_de_Bectoz',
#       'Claude_of_France',
#       'Clovis_I',
#       'Clovis_II',
#       'Clovis_IV',
#       'Cognac,_France',
#       'Collège_de_France',
#       'Columbia_University_Press',
#       'Conan_II,_Duke_of_Brittany',
#       'Conan_III,_Duke_of_Brittany',
#       'Conan_IV,_Duke_of_Brittany',
#       'Conan_I_of_Rennes',
#       'Constance,_Duchess_of_Brittany',
#       'Constantin_von_Wurzbach',
#       'Constitution_of_France',
#       'Coronation_of_the_French_monarch',
#       'Count_of_Angoulême',
#       'Count_of_Rennes',
#       'Counts_and_dukes_of_Angoulême',
#       'Counts_and_dukes_of_Penthièvre',
#       'Counts_of_Dreux',
#       'County_of_Nantes',
#       'Courtesy_title',
#       'Crescent',
#       'Crime_in_France',
#       'Crown_of_Castile',
#       'Culture_of_France',
#       'Cèllere_Codex',
#       'Dagobert_I',
#       'Dagobert_III',
#       'Demographics_of_France',
#       'Departments_of_France',
#       'Der_Handschuh',
#       'Dieppe,_Seine-Maritime',
#       'Dieppe_maps',
#       'Diu,_India',
#       'Doi_(identifier)',
#       'Dougray_Scott',
#       'Drogo,_Duke_of_Brittany',
#       'Duchy_of_Aquitaine',
#       'Duchy_of_Brabant',
#       'Duchy_of_Brittany',
#       'Duke_of_Brittany',
#       'Duke_of_Valois',
#       'Duress',
#       'Dynasty',
#       'Early_modern_France',
#       'Economic_history_of_France',
#       'Economy_of_France',
#       'Edict_of_Fontainebleau_(1540)',
#       'Education_in_France',
#       'Eleanor_of_Austria',
#       'Elections_in_France',
#       'Emmanuel_Leconte',
#       'Emmanuel_Philibert,_Duke_of_Savoy',
#       'Emperor_Charles_V',
#       'Encyclopædia_Britannica_Eleventh_Edition',
#       'Energy_in_France',
#       'Erispoe',
#       'Etienne_Dolet',
#       'Euro',
#       'Euronext_Paris',
#       'Ever_After',
#       'Family_tree_of_French_monarchs',
#       'Family_tree_of_French_monarchs_(simple)',
#       'Fanny_Kemble',
#       'Fes',
#       'Field_of_Cloth_of_Gold',
#       'Field_of_the_Cloth_of_Gold',
#       'First_French_Empire',
#       'Flag_of_France',
#       'Fleur-de-Lis',
#       'Foreign_relations_of_France',
#       "Four_Years'_War",
#       'France-Americas_relations',
#       'France-Asia_relations',
#       'France-Morocco_relations',
#       'France_during_World_War_II',
#       'France_in_the_Middle_Ages',
#       'France_in_the_long_nineteenth_century',
#       'Francesco_II_Sforza',
#       'Francia',
#       'Francis_I,_Duke_of_Brittany',
#       'Francis_II,_Duke_of_Brittany',
#       'Francis_III,_Duke_of_Brittany',
#       'Francis_II_of_France',
#       'Franco-Ottoman_alliance',
#       'Françoise_de_Foix',
#       'Free_France',
#       'French_Armed_Forces',
#       'French_Fifth_Republic',
#       'French_First_Republic',
#       'French_Fourth_Republic',
#       'French_Parliament',
#       'French_Renaissance',
#       'French_Renaissance_architecture',
#       'French_Revolution',
#       'French_Second_Republic',
#       'French_Third_Republic',
#       'French_architecture',
#       'French_art',
#       'French_colonial_empire',
#       'French_cuisine',
#       'French_fashion',
#       'French_franc',
#       'French_language',
#       'French_literature',
#       'French_nobility',
#       'French_people',
#       'French_philosophy',
#       'Friedrich_Schiller',
#       'G._J._Toomer',
#       'GND_(identifier)',
#       'Gaul',
#       'Geoffrey_I,_Duke_of_Brittany',
#       'Geoffrey_II,_Duke_of_Brittany',
#       'Geography_of_France',
#       'George_Méliès',
#       'Gian_Galeazzo_Visconti',
#       'Giovanni_da_Verrazzano',
#       'Giulio_Romano',
#       'Giuseppe_Verdi',
#       'Gourmaëlon',
#       'Government_of_National_Defense',
#       'Grand_Almoner_of_France',
#       'Greek_language',
#       'Greeks_in_pre-Roman_Gaul',
#       'Guerech,_Duke_of_Brittany',
#       'Guillaume_Budé',
#       'Guillaume_Postel',
#       'Guntram',
#       'Gurvand',
#       'Guy_of_Thouars',
#       'Gérard_Oury',
#       'HDS_(identifier)',
#       'Habsburg_Monarchy',
#       'Harfleur',
#       'Hawise,_Duchess_of_Brittany',
#       'Health_care_in_France',
#       'Hebrew',
#       'Heir_presumptive',
#       'Henri,_Count_of_Chambord',
#       'Henry_III_of_France',
#       'Henry_II_of_France',
#       'Henry_IV_of_France',
#       'Henry_I_of_France',
#       'Henry_VIII_of_England',
#       'Henry_VI_of_England',
#       'Heptameron',
#       'Hilary_Mantel',
#       'History_of_France',
#       'History_of_France_(1900_to_present)',
#       'Holy_Roman_Emperor',
#       'Honfleur',
#       'House_of_Bonaparte',
#       'House_of_Bourbon',
#       'House_of_Capet',
#       'House_of_Habsburg',
#       'House_of_Lancaster',
#       'House_of_Orléans',
#       'House_of_Plantagenet',
#       'House_of_Valois',
#       'House_of_Valois-Angoulême',
#       'Hoël_I,_Duke_of_Brittany',
#       'Hoël_II,_Duke_of_Brittany',
#       'Hugh_Capet',
#       'Human_rights_in_France',
#       'Humanism',
#       'Hôtel_de_Ville,_Paris',
#       'ICCU_(identifier)',
#       'ISBN_(identifier)',
#       'ISNI_(identifier)',
#       'Imperial_election_of_1519',
#       'Ingres',
#       'Intersex_rights_in_France',
#       'Isabella,_Countess_of_Vertus',
#       'Italian_(language)',
#       'Italian_Renaissance',
#       'Italian_Renaissance_art',
#       'Italian_War_of_1536–1538',
#       'Italian_War_of_1542–1546',
#       'Italian_Wars',
#       'Jacques_Cartier',
#       'James_V_of_Scotland',
#       'Janus_of_Cyprus',
#       'Jean-François_Roberval',
#       'Jean_Ango',
#       'Jean_Clouet',
#       'Jean_Marais',
#       'Jean_Parmentier_(explorer)',
#       'Jean_Rotz',
#       'Joan,_Duchess_of_Brittany',
#       'Joan_of_Navarre,_Queen_of_England',
#       'Joanna_of_Bourbon',
#       'John,_Count_of_Angoulême',
#       'John_Calvin',
#       'John_I,_Duke_of_Bourbon',
#       'John_I,_Duke_of_Brittany',
#       'John_II,_Duke_of_Brittany',
#       'John_III,_Duke_of_Brittany',
#       'John_II_of_France',
#       'John_IV,_Duke_of_Brittany',
#       'John_I_of_France',
#       'John_V,_Duke_of_Brittany',
#       'John_of_Montfort',
#       'John_the_Fearless',
#       'Jonathan_Rhys_Meyers',
#       'João_de_Barros',
#       'Juan_de_Urbieta',
#       'Judicael,_Duke_of_Brittany',
#       'Judiciary_of_France',
#       'Jules_Isaac',
#       'Jules_Michelet',
#       'July_Monarchy',
#       'King_of_France',
#       'King_of_Naples',
#       'King_of_Spain',
#       'Kingdom_of_France',
#       'LCCN_(identifier)',
#       'LGBT_rights_in_France',
#       'La_Marseillaise',
#       'Languages_of_France',
#       'Latin',
#       'Latin_language',
#       'Laurence_Sterne',
#       'Law_enforcement_in_France',
#       'Law_of_France',
#       'Le_Havre',
#       "Le_Roi_s'amuse",
#       'League_of_Cognac',
#       'Leonardo_da_Vinci',
#       'List_of_Counts_and_Dukes_of_Valois',
#       'List_of_Frankish_kings',
#       'List_of_French_monarchs',
#       'List_of_French_mountains_by_prominence',
#       'List_of_French_regions_and_overseas_collectivities_by_GDP',
#       'List_of_Navarrese_monarchs',
#       'List_of_Remarkable_Gardens_of_France',
#       'List_of_World_Heritage_Sites_in_France',
#       'List_of_communes_in_France_with_over_20,000_inhabitants',
#       'List_of_cultural_icons_of_France',
#       'List_of_exports_of_France',
#       'List_of_islands_of_France',
#       'List_of_lakes_of_France',
#       'List_of_political_parties_in_France',
#       'List_of_rivers_of_France',
#       'List_of_rulers_of_Brittany',
#       'List_of_rulers_of_Milan',
#       'List_of_trade_unions_in_France',
#       'List_of_viscounts_of_Thouars',
#       'Lothair_of_France',
#       'Louis,_Duke_of_Brittany_(1707–1712)',
#       'Louis,_Duke_of_Savoy',
#       'Louis_Antoine,_Duke_of_Angoulême',
#       'Louis_I,_Duke_of_Orléans',
#       'Louis_III_of_France',
#       'Louis_IV_of_France',
#       'Louis_IX_of_France',
#       'Louis_Philippe_I',
#       'Louis_VIII_of_France',
#       'Louis_VII_of_France',
#       'Louis_VI_of_France',
#       'Louis_V_of_France',
#       'Louis_XI,_King_of_France',
#       'Louis_XIII',
#       'Louis_XII_of_France',
#       'Louis_XIV',
#       'Louis_XI_of_France',
#       'Louis_XV',
#       'Louis_XVI',
#       'Louis_XVII',
#       'Louis_XVIII',
#       'Louis_X_of_France',
#       'Louis_the_Pious',
#       'Louis_the_Stammerer',
#       'Louise_of_Savoy',
#       'Louvre_Palace',
#       'Lyon',
#       'Madeleine_of_France_(1520-1537)',
#       'Man_of_letters',
#       'Margaret_of_Bavaria',
#       'Margaret_of_Bourbon_(1438–1483)',
#       'Margaret_of_Brittany_(1392–1428)',
#       'Margaret_of_France,_Duchess_of_Berry',
#       'Margaret_of_Valois',
#       'Marguerite_de_Navarre',
#       'Marguerite_de_Rohan,_Countess_of_Angoulême',
#       'Marie,_Duchess_of_Auvergne',
#       'Martin_Luther',
#       'Mary_Boleyn',
#       'Mary_of_Burgundy,_Duchess_of_Savoy',
#       'Mass_(Catholicism)',
#       'Massacre_of_Mérindol',
#       'Maximilian_Sforza',
#       'Media_of_France',
#       'Merovingian_dynasty',
#       'Middle_French_language',
#       'Milan',
#       'Mona_Lisa',
#       'Montfort_of_Brittany',
#       'Morman',
#       'Morocco',
#       'Music_of_France',
#       "Musée_de_l'Armée",
#       'Mérindol_massacre',
#       'NDL_(identifier)',
#       'NKC_(identifier)',
#       'NLA_(identifier)',
#       'NLI_(identifier)',
#       'NLP_(identifier)',
#       'NTA_(identifier)',
#       'Napoleon',
#       'Napoleon_II',
#       'Napoleon_III',
#       'Napoleonic_era',
#       'Natalie_Dormer',
#       'National_emblem_of_France',
#       'New_Angoulême',
#       'New_World',
#       'New_York_City',
#       'Newfoundland_(island)',
#       'Nominoe',
#       'Normandy',
#       'OCLC_(identifier)',
#       'Odo,_Count_of_Penthièvre',
#       'Odo_II,_Viscount_of_Porhoët',
#       'Odo_of_France',
#       'Old_Swiss_Confederacy',
#       'Ordinance_of_Villers-Cotterêts',
#       'Ordonnance_de_Montpellier',
#       'Orientalism_in_early_modern_France',
#       'Ottoman_Empire',
#       'Outline_of_France',
#       'PLWABN_(identifier)',
#       'Papal_bull',
#       'Pascweten',
#       'Patrick_Godfrey',
#       'Patron_of_the_arts',
#       'Pedro_Armendáriz',
#       'Pepin_the_Short',
#       'Pernambuco',
#       'Peter_Gilmore',
#       'Peter_I,_Duke_of_Brittany',
#       'Peter_II,_Duke_of_Brittany',
#       'Philip_I,_Landgrave_of_Hesse',
#       'Philip_II,_Duke_of_Savoy',
#       'Philip_III_of_France',
#       'Philip_II_of_France',
#       'Philip_IV_of_France',
#       'Philip_I_of_France',
#       'Philip_VI_of_France',
#       'Philip_V_of_France',
#       'Pierre_Goubert',
#       'Pierre_de_Piton',
#       'Place_Maubert',
#       'Politics_of_France',
#       'Pope_Clement_VII',
#       'Pope_Sixtus_IV',
#       'Portugal',
#       'Poverty_in_France',
#       'Prehistory_of_France',
#       'Presidential_elections_in_France',
#       'Primaticcio',
#       'Printing',
#       'Protestant_Reformation',
#       'Protestant_reformers',
#       'Protestantism',
#       'Provisional_Government_of_the_French_Republic',
#       'Public_holidays_in_France',
#       'Quebec',
#       'Queen_consort_of_France',
#       'RKDartists_(identifier)',
#       'Real_tennis',
#       'Reign_of_Terror',
#       'Religion_in_France',
#       'Renaissance',
#       'Rigoletto_(opera)',
#       'Robert_II_of_France',
#       'Robert_I_of_France',
#       'Robertians',
#       'Roman_Gaul',
#       'Rosso_Fiorentino',
#       'Rouen',
#       'Rudolph_of_France',
#       'SELIBR_(identifier)',
#       'SUDOC_(identifier)',
#       'Sacha_Guitry',
#       'Saint_Denis_Basilica',
#       'Saint_Judicael',
#       'Saintonge',
#       'Salamander_(legendary_creature)',
#       'Salic_Law',
#       'Salomon,_King_of_Brittany',
#       'Samuel_Shellabarger',
#       'Schmalkaldic_League',
#       'Science_and_technology_in_France',
#       'Sebastiano_Serlio',
#       'Second_French_Empire',
#       'Secularism_in_France',
#       'Siege_of_Nice',
#       'Sigebert_I',
#       'Sigebert_II',
#       'Social_class_in_France',
#       'Social_protection_in_France',
#       'Spanish_(language)',
#       'Sport_in_France',
#       'St._Lawrence_River',
#       'Style_of_the_French_sovereign',
#       'Suleiman_the_Magnificent',
#       'Sumatra',
#       'Symbols_of_France',
#       'Tarascon',
#       'Taxation_in_France',
#       'Telecommunications_in_France',
#       'Televisión_Española',
#       'The_Other_Boleyn_Girl',
#       'The_Tudors',
#       'Theatre_of_France',
#       'Theuderic_III',
#       'Theuderic_IV',
#       'Thomas_Cromwell',
#       'Timeline_of_French_history',
#       'Timothy_West',
#       'Titian',
#       'Tourism_in_France',
#       'Transport_in_France',
#       'Treaty_of_Crépy',
#       'Treaty_of_Madrid_(1526)',
#       'Treaty_of_Tordesillas',
#       'Triboulet',
#       'Tristram_Shandy',
#       'Trove_(identifier)',
#       'Truce_of_Nice',
#       'ULAN_(identifier)',
#       'Ulrich,_Duke_of_Württemberg',
#       'VIAF_(identifier)',
#       'Valentina_Visconti',
#       'VcBA_(identifier)',
#       'Vichy_France',
#       'Victor_Hugo',
#       'Villers-Cotterêts',
#       'Visigothic_Kingdom',
#       'Waldensians',
#       'War_of_the_Breton_Succession',
#       'War_of_the_League_of_Cambrai',
#       'War_of_the_League_of_Cognac',
#       'Waroch_II',
#       'Wattassid',
#       'West_Francia',
#       'Wihomarc',
#       'WorldCat_Identities_(identifier)',
#       'Zuppa_alla_Pavese',
#       'Álvaro_Cervantes',
#       'Éditions_Larousse',
#       'François_Desmoulins_de_Rochefort',
#       'Nicholas_Vallard',
#       'Alfonso_Bassave',
#       'Template:Breton_monarchs',
#       'Template:Monarchs_of_France',
#       'Template:France_topics',
#       'Wikipedia:Citation_needed',
#       'Wikipedia:Verifiability',
#       'Wikipedia:WikiProject_France',
#       'Template_talk:Breton_monarchs',
#       'Template_talk:France_topics',
#       'Template_talk:Monarchs_of_France',
#       'Help:Authority_control',
#       'Book:France'],
#      'template': ['Template:Short description',
#       'Template:Pagetype',
#       'Template:Main other',
#       'Template:SDcat',
#       'Template:Use dmy dates',
#       'Template:DMCA',
#       'Template:Dated maintenance category',
#       'Template:FULLROOTPAGENAME',
#       'Template:Ns has subpages',
#       'Template:Infobox royalty',
#       'Template:Infobox royalty/short description',
#       'Template:Trim',
#       'Template:Delink',
#       'Template:Infobox',
#       'Template:Age',
#       'Template:Nowrap',
#       'Template:If empty',
#       'Template:Br separated entries',
#       'Template:Death date and age',
#       'Template:Marriage',
#       'Template:In string',
#       'Template:Str ≥ len',
#       'Template:If both',
#       'Template:Abbr',
#       'Template:Wbr',
#       'Template:Template other',
#       'Template:Lang-fr',
#       'Template:Lang-frm',
#       'Template:Citation needed',
#       'Template:Fix',
#       'Template:Category handler',
#       'Template:Fix/category',
#       'Template:Failed verification',
#       'Template:Further',
#       'Template:Ahnentafel',
#       'Template:Ahnentafel/styles.css',
#       'Template:Portal',
#       'Template:Reflist',
#       'Template:Cite book',
#       'Template:ISBN',
#       'Template:Catalog lookup link',
#       'Template:Yesno-no',
#       'Template:Yesno',
#       'Template:Yesno-yes',
#       'Template:Error-small',
#       'Template:Small',
#       'Template:Tl',
#       'Template:Cite EB1911',
#       'Template:Hide in print',
#       'Template:Cite wikisource/make link',
#       'Template:Cite encyclopedia',
#       'Template:Cite journal',
#       'Template:Cite web',
#       'Template:Commons category-inline',
#       'Template:Sister-inline',
#       'Template:Replace',
#       'Template:S-start',
#       'Template:S-hou',
#       'Template:S-reg',
#       'Template:S-bef',
#       'Template:Delink question hyphen-minus',
#       'Template:S-bef/filter',
#       'Template:S-ttl',
#       'Template:S-aft',
#       'Template:S-aft/filter',
#       'Template:S-vac',
#       'Template:S-end',
#       'Template:Breton monarchs',
#       'Template:Navbox',
#       'Template:Box-shadow border',
#       'Template:Monarchs of France',
#       'Template:Sup',
#       'Template:France topics',
#       'Template:Coat of arms',
#       'Template:Authority control',
#       'Template:EditAtWikidata',
#       'Module:Pagetype',
#       'Module:Pagetype/config',
#       'Module:Arguments',
#       'Module:Yesno',
#       'Module:Namespace detect',
#       'Module:Namespace detect/data',
#       'Module:Namespace detect/config',
#       'Module:Check for unknown parameters',
#       'Module:String',
#       'Module:SDcat',
#       'Module:Unsubst',
#       'Module:Ns has subpages',
#       'Module:Is infobox in lead',
#       'Module:String2',
#       'Module:GetParameters',
#       'Module:Delink',
#       'Module:No globals',
#       'Module:Infobox',
#       'Module:Navbar',
#       'Module:Navbar/configuration',
#       'Module:InfoboxImage',
#       'Module:Age',
#       'Module:Date',
#       'Module:ConvertNumeric',
#       'Module:If empty',
#       'Module:Separated entries',
#       'Module:TableTools',
#       'Module:Lang',
#       'Module:Unicode data',
#       'Module:Lang/data',
#       'Module:Language/data/iana languages',
#       'Module:Language/data/iana scripts',
#       'Module:Language/data/iana regions',
#       'Module:Language/data/iana variants',
#       'Module:Language/data/iana suppressed scripts',
#       'Module:Lang/ISO 639 synonyms',
#       'Module:Category handler',
#       'Module:Category handler/data',
#       'Module:Category handler/config',
#       'Module:Category handler/shared',
#       'Module:Category handler/blacklist',
#       'Module:Labelled list hatnote',
#       'Module:Hatnote',
#       'Module:Hatnote list',
#       'Module:Ahnentafel',
#       'Module:Portal',
#       'Module:Portal/styles.css',
#       'Module:Portal/images/b',
#       'Module:Portal/images/f',
#       'Module:Citation/CS1',
#       'Module:Citation/CS1/Configuration',
#       'Module:Citation/CS1/Whitelist',
#       'Module:Citation/CS1/Utilities',
#       'Module:Citation/CS1/Date validation',
#       'Module:Citation/CS1/Identifiers',
#       'Module:Citation/CS1/COinS',
#       'Module:Citation/CS1/styles.css',
#       'Module:Catalog lookup link',
#       'Module:Check isxn',
#       'Module:Error',
#       'Module:Template wrapper',
#       'Module:WikidataIB',
#       'Module:WikidataIB/nolinks',
#       'Module:WikidataIB/titleformats',
#       'Module:MultiReplace',
#       'Module:Navbox',
#       'Module:Navbar/styles.css',
#       'Module:Authority control',
#       'Module:ResolveEntityId',
#       'Module:EditAtWikidata',
#       'Francis I of France'],
#      'text': 'Francis I (French: François Ier; Middle French: Francoys; 12 September 1494 – 31 March 1547) was King of France from 1515 until his death in 1547. He was the son of Charles, Count of Angoulême, and Louise of Savoy. He succeeded his first cousin once removed Louis XII, who died without a son. A prodigious patron of the arts, he promoted the emergent French Renaissance by attracting many Italian artists to work for him, including Leonardo da Vinci, who brought the Mona Lisa with him, which Francis had acquired. Francis\' reign saw important cultural changes with the growth of central power in France, the spread of humanism and Protestantism, and the beginning of French exploration of the New World. Jacques Cartier and others claimed lands in the Americas for France and paved the way for the expansion of the first French colonial empire. For his role in the development and promotion of a standardized French language, he became known as le Père et Restaurateur des Lettres (the \'Father and Restorer of Letters\'). He was also known as François au Grand Nez (\'Francis of the Large Nose\'), the Grand Colas, and the Roi-Chevalier (the \'Knight-King\') for his personal involvement in the wars against his great rival Emperor Charles V, who was also King of Spain. Following the policy of his predecessors, Francis continued the Italian Wars. The succession of Charles V to the Burgundian Netherlands, the throne of Spain, and his subsequent election as Holy Roman Emperor, meant that France was geographically encircled by the Habsburg monarchy. In his struggle against Imperial hegemony, Francis sought the support of Henry VIII of England at the Field of the Cloth of Gold. When this was unsuccessful, he formed a Franco-Ottoman alliance with the Muslim sultan Suleiman the Magnificent, a controversial move for a Christian king at the time. Francis of Orléans was born on 12 September 1494 at the Château de Cognac in the town of Cognac, which at that time lay in the province of Saintonge, a part of the Duchy of Aquitaine. Today the town lies in the department of Charente. Francis was the only son of Charles of Orléans, Count of Angoulême, and Louise of Savoy and a great-great-grandson of King Charles V of France. His family was not expected to inherit the throne, as his third cousin King Charles VIII was still young at the time of his birth, as was his father\'s cousin the Duke of Orléans, later King Louis XII. However, Charles VIII died childless in 1498 and was succeeded by Louis XII, who himself had no male heir. The Salic Law prevented women from inheriting the throne. Therefore, the four-year-old Francis (who was already Count of Angoulême after the death of his own father two years earlier) became the heir presumptive to the throne of France in 1498 and was vested with the title of Duke of Valois. In 1505, Louis XII, having fallen ill, ordered for his daughter Claude and Francis to be married immediately, but only through an assembly of nobles were the two engaged. Claude was heir presumptive to the Duchy of Brittany through her mother, Anne of Brittany. Following Anne\'s death, the marriage took place on 18 May 1514. On 1 January 1515, Louis died, and Francis inherited the throne. He was crowned King of France in the Cathedral of Reims on 25 January 1515, with Claude as his queen consort. As Francis was receiving his education, ideas emerging from the Italian Renaissance were influential in France. Some of his tutors, such as François Desmoulins de Rochefort (his Latin instructor, who later during the reign of Francis was named Grand Aumônier de France) and Christophe de Longueil (a Brabantian humanist), were attracted by these new ways of thinking and attempted to influence Francis. His academic education had been in arithmetic, geography, grammar, history, reading, spelling, and writing and he became proficient in Hebrew, Italian, Latin and Spanish. Francis came to learn chivalry, dancing, and music, and he loved archery, f ...
#      'source_text': '{{short description|King of the House of Valois-Angoulême (1494–1547, r. 1515–47)}}\n{{Use dmy dates|date=July 2020}}\n{{Infobox royalty\n| name         = Francis I\n| image        = François Ier Louvre.jpg\n| caption      = Portrait by [[Jean Clouet]], c. 1530\n| alt          = Portrait of King Francis I in his {{age|format=ordinal|1494|1530}} year\n| succession   = [[King of France]]\n| moretext     = ([[Style of the French sovereign|more...]])\n| reign        = 1 January 1515 – {{nowrap|31 March 1547}}\n| coronation   = 25 January 1515\n| cor-type     = france\n| predecessor  = [[Louis XII of France|Louis XII]]\n| successor    = [[Henry II of France|Henry II]]\n| birth_date   = 12 September 1494\n| birth_place  = [[Château de Cognac]], [[Cognac, France|Cognac]], France\n| death_date   = {{Death date and age|df=yes|1547|3|31|1494|9|12}}\n| death_place  = [[Château de Rambouillet]], France\n| burial_date  = 23 May 1547\n| burial_place = [[Basilica of St Denis]], France\n| spouse       = {{marriage|[[Claude, Duchess of Brittany]]|1514}}<br/>\n{{marriage|[[Eleanor of Austria]]|1530}}\n| issue        = [[Francis III, Duke of Brittany]]<br />[[Henry II of France]]<br />[[Madeleine of France (1520-1537)|Madeleine, Queen of Scots]]<br />[[Charles II de Valois, Duke of Orléans|Charles, Duke of Orléans]]<br />[[Margaret of France, Duchess of Berry|Margaret, Duchess of Savoy]]\n| issue-link   = #Marriage and issue\n| issue-pipe   = among others...\n| house        = [[House of Valois-Angoulême|Valois-Angoulême]]\n| father       = [[Charles, Count of Angoulême]]\n| mother       = [[Louise of Savoy]]\n| signature    = King Francis I Signature.svg\n| religion     = [[Catholic Church|Roman Catholicism]]\n|}}\n\n\'\'\'Francis I\'\'\' ({{lang-fr|François I<sup>er</sup>}}; {{lang-frm|Francoys}}; 12 September 1494 – 31 March 1547) was [[King of France]] from 1515 until his death in 1547. He was the son of [[Charles, Count of Angoulême]], and [[Louise of Savoy]]. He succeeded his first cousin once removed [[Louis XII of France|Louis XII]], who died without a son.\n\nA prodigious [[patron of the arts]], he promoted the emergent [[French Renaissance]] by attracting many Italian artists to work for him, including [[Leonardo da Vinci]], who brought the \'\'[[Mona Lisa]]\'\' with him, which Francis had acquired. Francis\' reign saw important cultural changes with the growth of central power in France, the spread of [[humanism]] and [[Protestantism]], and the beginning of French exploration of the [[New World]]. [[Jacques Cartier]] and others claimed lands in the Americas for France and paved the way for the expansion of the first [[French colonial empire]].\n\nFor his role in the development and promotion of a standardized French language, he became known as \'\'le Père et Restaurateur des Lettres\'\' (the \'Father and Restorer of Letters\').<ref name="Knecht">Knecht, R.J. \'\'Francis I\'\', (Cambridge University Press, 1984), 1–2.</ref> He was also known as \'\'François au Grand Nez\'\' (\'Francis of the Large Nose\'), the \'\'Grand Colas\'\', and the \'\'Roi-Chevalier\'\' (the \'Knight-King\')<ref name="Knecht" /> for his personal involvement in the wars against his great rival [[Emperor Charles V]], who was also [[King of Spain]].\n\nFollowing the policy of his predecessors, Francis continued the [[Italian Wars]]. The succession of Charles V to the Burgundian Netherlands, the throne of Spain, and his subsequent election as [[Holy Roman Emperor]], meant that France was geographically encircled by the [[House of Habsburg|Habsburg monarchy]]. In his struggle against Imperial hegemony, Francis sought the support of [[Henry VIII of England]] at the [[Field of the Cloth of Gold]].<ref>Knecht, R.J. \'\'Francis I\'\', 77–78.</ref> When this was unsuccessful, he formed a [[Franco-Ottoman alliance]] with the Muslim sultan [[Suleiman the Magnificent]], a controversial move for a Christian king at the time.<ref>Knecht, R.J. \'\'Francis I ...
#      'text_bytes': 52547,
#      'content_model': 'wikitext',
#      'coordinates': [],
#      'wikibase_item': 'Q129857',
#      'language': 'en',
#      'heading': ['Early life and accession',
#       'Reign',
#       'Patron of the arts',
#       'Man of letters',
#       'Construction',
#       'Military action',
#       'Relations with the New World and Asia',
#       'Americas',
#       'Far East Asia',
#       'Ottoman Empire',
#       'Bureaucratic reform and language policy',
#       'Religious policies',
#       'Death',
#       'Image and reputation',
#       'Marriage and issue',
#       'Francis I in films, stage and literature',
#       'Ancestors',
#       'Further reading'],
#      'opening_text': "Francis I (French: François Ier; Middle French: Francoys; 12 September 1494 – 31 March 1547) was King of France from 1515 until his death in 1547. He was the son of Charles, Count of Angoulême, and Louise of Savoy. He succeeded his first cousin once removed Louis XII, who died without a son. A prodigious patron of the arts, he promoted the emergent French Renaissance by attracting many Italian artists to work for him, including Leonardo da Vinci, who brought the Mona Lisa with him, which Francis had acquired. Francis' reign saw important cultural changes with the growth of central power in France, the spread of humanism and Protestantism, and the beginning of French exploration of the New World. Jacques Cartier and others claimed lands in the Americas for France and paved the way for the expansion of the first French colonial empire. For his role in the development and promotion of a standardized French language, he became known as le Père et Restaurateur des Lettres (the 'Father and Restorer of Letters'). He was also known as François au Grand Nez ('Francis of the Large Nose'), the Grand Colas, and the Roi-Chevalier (the 'Knight-King') for his personal involvement in the wars against his great rival Emperor Charles V, who was also King of Spain. Following the policy of his predecessors, Francis continued the Italian Wars. The succession of Charles V to the Burgundian Netherlands, the throne of Spain, and his subsequent election as Holy Roman Emperor, meant that France was geographically encircled by the Habsburg monarchy. In his struggle against Imperial hegemony, Francis sought the support of Henry VIII of England at the Field of the Cloth of Gold. When this was unsuccessful, he formed a Franco-Ottoman alliance with the Muslim sultan Suleiman the Magnificent, a controversial move for a Christian king at the time.",
#      'auxiliary_text': ['Francis I Portrait by Jean Clouet, c. 1530 King of France (more...) Reign 1 January 1515 – 31 March 1547 Coronation 25 January 1515 Predecessor Louis XII Successor Henry II Born 12 September 1494 Château de Cognac, Cognac, France Died 31 March 1547(1547-03-31) (aged\xa052) Château de Rambouillet, France Burial 23 May 1547 Basilica of St Denis, France Spouse Claude, Duchess of Brittany \u200b \u200b (m.\xa01514)\u200b Eleanor of Austria \u200b (m.\xa01530)\u200b Issue among others... Francis III, Duke of Brittany Henry II of France Madeleine, Queen of Scots Charles, Duke of Orléans Margaret, Duchess of Savoy House Valois-Angoulême Father Charles, Count of Angoulême Mother Louise of Savoy Religion Roman Catholicism Signature',
#       'Ancestors of Francis I of France',
#       '16. Charles V of France 8. Louis I, Duke of Orléans 17. Joanna of Bourbon 4. John, Count of Angoulême 18. Gian Galeazzo Visconti 9. Valentina Visconti 19. Isabelle of Valois 2. Charles, Count of Angoulême 20. Alain VIII, Viscount of Rohan 10. Alain IX, Viscount of Rohan 21. Béatrix de Clisson 5. Marguerite de Rohan 22. John IV, Duke of Brittany 11. Margaret of Brittany 23. Joan of Navarre 1. Francis I of France 24. Antipope Felix V 12. Louis, Duke of Savoy 25. Mary of Burgundy 6. Philip II, Duke of Savoy 26. Janus of Cyprus 13. Anne of Cyprus 27. Charlotte of Bourbon 3. Louise of Savoy 28. John I, Duke of Bourbon 14. Charles I, Duke of Bourbon 29. Marie, Duchess of Auvergne 7. Margaret of Bourbon 30. John II, Duke of Burgundy 15. Agnes of Burgundy 31. Margaret of Bavaria',
#       'Francis I of France House of Valois, Orléans-Angoulême branch Cadet branch of the Capetian dynasty Born: 12 September 1494\xa0Died: 31 March 1547 Regnal titles Preceded\xa0by Louis XII King of France 1 January 1515 – 31 March 1547 Succeeded\xa0by Henry II Preceded\xa0by Claude as sole duchess Duke of Brittany 18 May 1514 – 1 January 1515 with Claude Succeeded\xa0by Claude as sole duchess Preceded\xa0by Maximilian Sforza Duke of Milan 1515–1521 Succeeded\xa0by Francis II Sforza Preceded\xa0by Francis II Sforza Duke of Milan 1524–1525 French nobility Vacant Merged in the crown Title last held by Louis Duke of Valois 1498 – 1 January 1515 Vacant Merged in the crown Title next held by Margaret Preceded\xa0by Charles Count of Angoulême 1 January 1496 – 1 January 1515 Vacant Merged in the crown Title next held by Louise',
#       'Authority control BIBSYS: 90236426 BNE: XX1501310 BNF: cb120127827 (data) CANTIC: a11379029 GND: 118534947 HDS: 029215 ICCU: IT\\ICCU\\BVEV\\022053 ISNI: 0000 0001 2102 9337 LCCN: n50038638 NDL: 001193472 NKC: jn20000700556 NLA: 49861380 NLI: 000048459 NLP: A11869732 NTA: 069995168 PLWABN: 9810695005505606 RKD: 441278 SELIBR: 187794 SUDOC: 028254287 Trove: 1526264 ULAN: 500122500 VcBA: 495/72801 VIAF: 88805531 WorldCat Identities: lccn-n50038638',
#       'Francis I painted in 1515',
#       'Giovanni Maria Pomedelli, François I, (obverse)',
#       'Francis I receiving the last breath of Leonardo da Vinci in 1519, by Ingres, painted in 1818',
#       "Francis's Château de Chambord displays a distinct French Renaissance architecture.",
#       'Francis I and Charles V, Holy Roman Emperor made peace at the Truce of Nice in 1538. Francis actually refused to meet Charles in person, and the treaty was signed in separate rooms.',
#       'Francis I at the Battle of Marignano',
#       'Detail of a tapestry depicting the Battle of Pavia, woven from a cartoon by Bernard van Orley (c. 1531)',
#       'The voyage of Giovanni da Verrazzano in 1524',
#       'An example of the Dieppe maps showing Sumatra. Nicholas Vallard, 1547.',
#       'Francis I (left) and Suleiman the Magnificent (right) initiated a Franco-Ottoman alliance. Both were separately painted by Titian circa 1530.',
#       'The Ordinance of Villers-Cotterêts in August 1539 prescribed the use of French in official documents.',
#       'Massacre of Mérindol in 1545',
#       "Grand culverin of Francis I, with his emblem and motto. A gift to his Ottoman allies recovered in Algiers in 1830. Musée de l'Armée.",
#       'King of the House of Valois-Angoulême (1494–1547, r. 1515–47)',
#       'King of France'],
#      'defaultsort': 'Francis 01 of France',
#      'display_title': None}}}}}

# %%
print(r02.json().keys())
print(r02.json()['query'].keys())
print(r02.json()['query']['pages'].keys())
print(r02.json()['query']['pages']['50012'].keys())
print(r02.json()['query']['pages']['50012']['cirrusbuilddoc'].keys())
# Out:
# dict_keys(['batchcomplete', 'query'])
# dict_keys(['normalized', 'pages'])
# dict_keys(['50012'])
# dict_keys(['pageid', 'ns', 'title', 'cirrusbuilddoc'])
# dict_keys(['version', 'wiki', 'namespace', 'namespace_text', 'title', 'timestamp', 'create_timestamp', 'redirect', 'incoming_links', 'category', 'external_link', 'outgoing_link', 'template', 'text', 'source_text', 'text_bytes', 'content_model', 'coordinates', 'wikibase_item', 'language', 'heading', 'opening_text', 'auxiliary_text', 'defaultsort', 'display_title'])

# %%
print(r02.json()['query']['pages']['50012']['cirrusbuilddoc']['incoming_links'])
# Out:
# 2187

# %%
print(len(r02.json()['query']['pages']['50012']['cirrusbuilddoc']['external_link']))
# print(r02.json()['query']['pages']['50012']['cirrusbuilddoc']['external_link'])
# Out:
# 60

# %%
print(len(r02.json()['query']['pages']['50012']['cirrusbuilddoc']['outgoing_link']))
# print(r02.json()['query']['pages']['50012']['cirrusbuilddoc']['outgoing_link'])
# Out:
# 618

# %%
print(r02.json()['query']['pages']['50012']['cirrusbuilddoc']['heading'])
# Out:
# ['Early life and accession', 'Reign', 'Patron of the arts', 'Man of letters', 'Construction', 'Military action', 'Relations with the New World and Asia', 'Americas', 'Far East Asia', 'Ottoman Empire', 'Bureaucratic reform and language policy', 'Religious policies', 'Death', 'Image and reputation', 'Marriage and issue', 'Francis I in films, stage and literature', 'Ancestors', 'Further reading']

# %%
print(len(r02.json()['query']['pages']['50012']['cirrusbuilddoc']['text']))
print(len((r02.json()['query']['pages']['50012']['cirrusbuilddoc']['text']).split(' ')))
print(r02.json()['query']['pages']['50012']['cirrusbuilddoc']['text'])
# Out:
# 36038
# 5811
# Francis I (French: François Ier; Middle French: Francoys; 12 September 1494 – 31 March 1547) was King of France from 1515 until his death in 1547. He was the son of Charles, Count of Angoulême, and Louise of Savoy. He succeeded his first cousin once removed Louis XII, who died without a son. A prodigious patron of the arts, he promoted the emergent French Renaissance by attracting many Italian artists to work for him, including Leonardo da Vinci, who brought the Mona Lisa with him, which Francis had acquired. Francis' reign saw important cultural changes with the growth of central power in France, the spread of humanism and Protestantism, and the beginning of French exploration of the New World. Jacques Cartier and others claimed lands in the Americas for France and paved the way for the expansion of the first French colonial empire. For his role in the development and promotion of a standardized French language, he became known as le Père et Restaurateur des Lettres (the 'Father and Restorer of Letters'). He was also known as François au Grand Nez ('Francis of the Large Nose'), the Grand Colas, and the Roi-Chevalier (the 'Knight-King') for his personal involvement in the wars against his great rival Emperor Charles V, who was also King of Spain. Following the policy of his predecessors, Francis continued the Italian Wars. The succession of Charles V to the Burgundian Netherlands, the throne of Spain, and his subsequent election as Holy Roman Emperor, meant that France was geographically encircled by the Habsburg monarchy. In his struggle against Imperial hegemony, Francis sought the support of Henry VIII of England at the Field of the Cloth of Gold. When this was unsuccessful, he formed a Franco-Ottoman alliance with the Muslim sultan Suleiman the Magnificent, a controversial move for a Christian king at the time. Francis of Orléans was born on 12 September 1494 at the Château de Cognac in the town of Cognac, which at that time lay in the province of Saintonge, a part of the Duchy of Aquitaine. Today the town lies in the department of Charente. Francis was the only son of Charles of Orléans, Count of Angoulême, and Louise of Savoy and a great-great-grandson of King Charles V of France. His family was not expected to inherit the throne, as his third cousin King Charles VIII was still young at the time of his birth, as was his father's cousin the Duke of Orléans, later King Louis XII. However, Charles VIII died childless in 1498 and was succeeded by Louis XII, who himself had no male heir. The Salic Law prevented women from inheriting the throne. Therefore, the four-year-old Francis (who was already Count of Angoulême after the death of his own father two years earlier) became the heir presumptive to the throne of France in 1498 and was vested with the title of Duke of Valois. In 1505, Louis XII, having fallen ill, ordered for his daughter Claude and Francis to be married immediately, but only through an assembly of nobles were the two engaged. Claude was heir presumptive to the Duchy of Brittany through her mother, Anne of Brittany. Following Anne's death, the marriage took place on 18 May 1514. On 1 January 1515, Louis died, and Francis inherited the throne. He was crowned King of France in the Cathedral of Reims on 25 January 1515, with Claude as his queen consort. As Francis was receiving his education, ideas emerging from the Italian Renaissance were influential in France. Some of his tutors, such as François Desmoulins de Rochefort (his Latin instructor, who later during the reign of Francis was named Grand Aumônier de France) and Christophe de Longueil (a Brabantian humanist), were attracted by these new ways of thinking and attempted to influence Francis. His academic education had been in arithmetic, geography, grammar, history, reading, spelling, and writing and he became proficient in Hebrew, Italian, Latin and Spanish. Francis came to learn chivalry, dancing, and music, and he loved archery, falconry, horseback ridi ...

# %%
print(r02.json()['query']['pages']['50012']['cirrusbuilddoc']['source_text'])
# Out:
# {{short description|King of the House of Valois-Angoulême (1494–1547, r. 1515–47)}}
# {{Use dmy dates|date=July 2020}}
# {{Infobox royalty
# | name         = Francis I
# | image        = François Ier Louvre.jpg
# | caption      = Portrait by [[Jean Clouet]], c. 1530
# | alt          = Portrait of King Francis I in his {{age|format=ordinal|1494|1530}} year
# | succession   = [[King of France]]
# | moretext     = ([[Style of the French sovereign|more...]])
# | reign        = 1 January 1515 – {{nowrap|31 March 1547}}
# | coronation   = 25 January 1515
# | cor-type     = france
# | predecessor  = [[Louis XII of France|Louis XII]]
# | successor    = [[Henry II of France|Henry II]]
# | birth_date   = 12 September 1494
# | birth_place  = [[Château de Cognac]], [[Cognac, France|Cognac]], France
# | death_date   = {{Death date and age|df=yes|1547|3|31|1494|9|12}}
# | death_place  = [[Château de Rambouillet]], France
# | burial_date  = 23 May 1547
# | burial_place = [[Basilica of St Denis]], France
# | spouse       = {{marriage|[[Claude, Duchess of Brittany]]|1514}}<br/>
# {{marriage|[[Eleanor of Austria]]|1530}}
# | issue        = [[Francis III, Duke of Brittany]]<br />[[Henry II of France]]<br />[[Madeleine of France (1520-1537)|Madeleine, Queen of Scots]]<br />[[Charles II de Valois, Duke of Orléans|Charles, Duke of Orléans]]<br />[[Margaret of France, Duchess of Berry|Margaret, Duchess of Savoy]]
# | issue-link   = #Marriage and issue
# | issue-pipe   = among others...
# | house        = [[House of Valois-Angoulême|Valois-Angoulême]]
# | father       = [[Charles, Count of Angoulême]]
# | mother       = [[Louise of Savoy]]
# | signature    = King Francis I Signature.svg
# | religion     = [[Catholic Church|Roman Catholicism]]
# |}}
#
# '''Francis I''' ({{lang-fr|François I<sup>er</sup>}}; {{lang-frm|Francoys}}; 12 September 1494 – 31 March 1547) was [[King of France]] from 1515 until his death in 1547. He was the son of [[Charles, Count of Angoulême]], and [[Louise of Savoy]]. He succeeded his first cousin once removed [[Louis XII of France|Louis XII]], who died without a son.
#
# A prodigious [[patron of the arts]], he promoted the emergent [[French Renaissance]] by attracting many Italian artists to work for him, including [[Leonardo da Vinci]], who brought the ''[[Mona Lisa]]'' with him, which Francis had acquired. Francis' reign saw important cultural changes with the growth of central power in France, the spread of [[humanism]] and [[Protestantism]], and the beginning of French exploration of the [[New World]]. [[Jacques Cartier]] and others claimed lands in the Americas for France and paved the way for the expansion of the first [[French colonial empire]].
#
# For his role in the development and promotion of a standardized French language, he became known as ''le Père et Restaurateur des Lettres'' (the 'Father and Restorer of Letters').<ref name="Knecht">Knecht, R.J. ''Francis I'', (Cambridge University Press, 1984), 1–2.</ref> He was also known as ''François au Grand Nez'' ('Francis of the Large Nose'), the ''Grand Colas'', and the ''Roi-Chevalier'' (the 'Knight-King')<ref name="Knecht" /> for his personal involvement in the wars against his great rival [[Emperor Charles V]], who was also [[King of Spain]].
#
# Following the policy of his predecessors, Francis continued the [[Italian Wars]]. The succession of Charles V to the Burgundian Netherlands, the throne of Spain, and his subsequent election as [[Holy Roman Emperor]], meant that France was geographically encircled by the [[House of Habsburg|Habsburg monarchy]]. In his struggle against Imperial hegemony, Francis sought the support of [[Henry VIII of England]] at the [[Field of the Cloth of Gold]].<ref>Knecht, R.J. ''Francis I'', 77–78.</ref> When this was unsuccessful, he formed a [[Franco-Ottoman alliance]] with the Muslim sultan [[Suleiman the Magnificent]], a controversial move for a Christian king at the time.<ref>Knecht, R.J. ''Francis I'', 224–225, 230.</ref>
#
# ==Early life and accession==
# '''Francis of Orléans''' was born on 12 September 1494 at the Château de Cognac in the town of [[Cognac, France|Cognac]],<ref name="Knecht" /> which at that time lay in the province of [[Saintonge]], a part of the [[Duchy of Aquitaine]].  Today the town lies in the [[Departments of France|department]] of [[Charente]].
#
# Francis was the only son of [[Charles, Count of Angoulême|Charles of Orléans, Count of Angoulême]], and [[Louise of Savoy]] and a great-great-grandson of King [[Charles V of France]].<ref>Knecht, Robert. ''The Valois'', (Hambledon Continuum, 2004), 112.</ref> His family was not expected to inherit the throne, as his third cousin King [[Charles VIII of France|Charles VIII]] was still young at the time of his birth, as was his father's cousin the [[Louis XII of France|Duke of Orléans]], later King Louis XII. However, Charles VIII died childless in 1498 and was succeeded by Louis XII, who himself had no male heir.<ref name="Knecht3">Knecht, R.J. ''Francis I'', 3.</ref> The [[Salic Law]] prevented women from inheriting the throne.  Therefore, the four-year-old Francis (who was already [[Count of Angoulême]] after the death of his own father two years earlier) became the [[heir presumptive]] to the throne of France in 1498 and was vested with the title of [[Duke of Valois]].<ref name="Knecht3" />
#
# In 1505, Louis XII, having fallen ill, ordered for his daughter [[Claude of France|Claude]] and Francis to be married immediately, but only through an assembly of nobles were the two engaged.<ref>Knecht, R.J. ''Francis I'', 8–9.</ref> Claude was heir presumptive to the [[Duchy of Brittany]] through her mother, [[Anne of Brittany]]. Following Anne's death, the marriage took place on 18 May 1514.<ref>Knecht, R.J. ''Francis I'', 11.</ref> On 1 January 1515, Louis died, and Francis inherited the throne. He was crowned King of France in the [[Cathedral of Reims]] on 25 January 1515, with Claude as his [[Queen consort of France|queen consort]].<ref>Knecht, R.J. ''Francis I'', 16.</ref>
#
# ==Reign==
# [[File:François 1515.jpg|upright|thumb|left|Francis I painted in 1515]]
# [[File:Giovanni Maria Pomedelli, François I, 1494-1547, King of France 1515 (obverse), 1515 or after, NGA 44648.jpg|thumb|Giovanni Maria Pomedelli, François I, (obverse)]]
# As Francis was receiving his education, ideas emerging from the [[Italian Renaissance]] were influential in France. Some of his tutors, such as [[François Desmoulins de Rochefort]] (his Latin instructor, who later during the reign of Francis was named [[Grand Almoner of France|''Grand Aumônier de France'']]) and [[Christophe de Longueil]] (a [[Duchy of Brabant|Brabantian]] humanist), were attracted by these new ways of thinking and attempted to influence Francis. His academic education had been in [[arithmetic]], geography, grammar, history, reading, spelling, and writing and he became proficient in [[Hebrew]], [[Italian (language)|Italian]], [[Latin]] and [[Spanish (language)|Spanish]]. Francis came to learn chivalry, dancing, and music, and he loved archery, falconry, horseback riding, hunting, jousting, [[real tennis]] and wrestling. He ended up reading philosophy and theology and he was fascinated with art, literature, poetry and science. His mother, who had a high admiration for [[Italian Renaissance art]], passed this interest on to her son. Although Francis did not receive a humanist education, he was more influenced by [[humanism]] than any previous French king.
#
# ===Patron of the arts===
# [[File:Francois Ier Leonard de Vinci-Jean Auguste Dominique Ingres.jpg|thumb|Francis I receiving the last breath of [[Leonardo da Vinci]] in 1519, by [[Ingres]], painted in 1818]]
#
# By the time he ascended the throne in 1515, the [[Renaissance]] had arrived in France, and Francis became an enthusiastic patron of the arts. At the time of his accession, the royal palaces of France were ornamented with only a scattering of great paintings, and not a single sculpture, either ancient or modern. During Francis' reign, the magnificent art collection of the French kings, which can still be seen at the [[Louvre Palace]], was begun.
#
# Francis patronized many great artists of his time, including [[Andrea del Sarto]] and [[Leonardo da Vinci]]; the latter of whom was persuaded to make France his home during his last years. While da Vinci painted very little during his years in France, he brought with him many of his greatest works, including the ''[[Mona Lisa]]'' (known in France as ''La Joconde''), and these remained in France after his death. Other major artists to receive Francis' patronage included the goldsmith [[Benvenuto Cellini]] and the painters [[Rosso Fiorentino]], [[Giulio Romano]], and [[Primaticcio]], all of whom were employed in decorating Francis' various palaces. He also invited the noted architect [[Sebastiano Serlio]] (1475–1554), who enjoyed a fruitful late career in France.<ref>{{cite book|last1=Serlio|first1=Sebastiano|title=On Architecture. Hart & Hicks (ed) Volume 2|date=1996|publisher=Yale|pages=xi}}</ref> Francis also commissioned a number of agents in Italy to procure notable works of art and ship them to France.
#
# ===Man of letters===
# Francis was also renowned as a [[man of letters]]. When Francis comes up in a conversation among characters in [[Baldassare Castiglione]]'s ''[[Book of the Courtier]]'', it is as the great hope to bring culture to the war-obsessed French nation. Not only did Francis support a number of major writers of the period, but he was also a poet himself, if not one of particular abilities. Francis worked diligently at improving the royal library. He appointed the great French humanist [[Guillaume Budé]] as chief librarian and began to expand the collection. Francis employed agents in Italy to look for rare books and manuscripts, just as he had agents looking for art works. During his reign, the size of the library greatly increased. Not only did he expand the library, there is also evidence {{Citation needed|date=March 2014}} that he read the books he bought for it, a much rarer event in the royal annals. Francis set an important precedent by opening his library to scholars from around the world in order to facilitate the diffusion of knowledge.
#
# In 1537, Francis signed the [[Ordonnance de Montpellier]], which decreed that his library be given a copy of every book to be sold in France.  Francis' older sister, [[Marguerite de Navarre|Marguerite]], [[List of Navarrese monarchs|Queen of Navarre]], was also an accomplished writer who produced the classic collection of short stories known as the ''[[Heptameron]]''.  Francis corresponded with the abbess and philosopher [[Claude de Bectoz]], of whose letters he was so fond that he would carry them around and show them to the ladies of his court.<ref>{{cite book | title=A New Universal Biography: Forming the first volume of series III | authors= Plats, John| year=1826 | publisher=Sherwood, Gilbert and Piper | page=301}}</ref>
# Together with his sister, he visited her in [[Tarascon]].<ref>{{cite book
# |title=Marguerite de Navarre: mother of the Renaissance
# |last1=Cholakian
# |first1=Patricia Francis
# |last2=Cholakian
# |first2=Rouben Charles
# |year=2006
# |publisher=[[Columbia University Press]]
# |isbn=0231134126
# |page=49
# }}</ref>{{Failed verification|date=May 2013}}
#
# ===Construction===
# [[File:France Loir-et-Cher Chambord Chateau 03.jpg|thumb|Francis's [[Château de Chambord]] displays a distinct [[French Renaissance architecture]].]]
# Francis poured vast amounts of money into new structures. He continued the work of his predecessors on the [[Château d'Amboise]] and also started renovations on the [[Château de Blois]]. Early in his reign, he began construction of the magnificent [[Château de Chambord]], inspired by the architectural styles of the Italian renaissance, and perhaps even designed by Leonardo da Vinci. Francis rebuilt the [[Château du Louvre]], transforming it from a medieval fortress into a building of Renaissance splendour. He financed the building of a new City Hall (the ''[[Hôtel de Ville, Paris|Hôtel de Ville]]'') for Paris in order to have control over the building's design. He constructed the [[Château de Madrid]] in the [[Bois de Boulogne]] and rebuilt the [[Château de Saint-Germain-en-Laye]]. The largest of Francis' building projects was the reconstruction and expansion of the [[Château de Fontainebleau]], which quickly became his favourite place of residence, as well as the residence of his official mistress, [[Anne de Pisseleu d'Heilly|Anne, Duchess of Étampes]]. Each of Francis' projects was luxuriously decorated both inside and out. Fontainebleau, for instance, had a gushing fountain in its courtyard where quantities of wine were mixed with the water.
#
# ===Military action===
# [[File:Truce of Nice 1538.jpg|thumb|left|Francis I and [[Charles V, Holy Roman Emperor]] made peace at the [[Truce of Nice]] in 1538. Francis actually refused to meet Charles in person, and the treaty was signed in separate rooms.]]
# Although the Italian Wars (1494–1559) came to dominate the reign of Francis I, the wars were not the sole focus of his policies.  Francis merely continued the incessant wars that his predecessors had started and that his successors on the throne of France would drag on after Francis' death.  Indeed, the Italian Wars had begun when Milan sent a plea to King Charles VIII of France for protection against the aggressive actions of the [[King of Naples]].<ref>Hoyt, Robert S. & Stanley Chodorow, ''Europe in the Middle Ages'' (Harcourt, Brace & Jovanovich Inc.: New York, 1976) p. 619.</ref> Militarily and diplomatically, Francis' reign was a mixed bag of success and failure.  Francis tried and failed to become [[Holy Roman Emperor]] at the [[Imperial election of 1519]].  However, there were also temporary victories, such as in the portion of the Italian Wars called the [[War of the League of Cambrai]] (1508–1516) and, more specifically, to the final stage of that war, which history refers to simply as "Francis' First Italian War" (1515–1516), when Francis routed the combined forces of the Papal States and the [[Old Swiss Confederacy]] at [[Battle of Marignano|Marignano]] on 13–15 September 1515. This victory at Marignano allowed Francis to capture the Italian city-state of [[Milan]]. Later, in November 1521, during the [[Four Years' War]] (1521–1526) and facing the advancing Imperial forces of the Holy Roman Empire and open revolt within Milan, Francis was forced to abandon Milan, thus, cancelling the triumph at Marignano.
#
# Much of the military activity of Francis's reign was focused on his sworn enemy, the Holy Roman Emperor [[Charles V, Holy Roman Emperor|Charles V]]. Francis and Charles maintained an intense personal rivalry. Charles, in fact, brashly challenged Francis to single combat multiple times. In addition to the Holy Roman Empire, Charles personally ruled Spain, Austria, and a number of smaller possessions neighboring France. He was thus a constant threat to Francis' kingdom.
#
# [[File:Francis at Marignan.jpg|thumb|Francis I at the [[Battle of Marignano]]]]
#
# Francis attempted to arrange an alliance with [[Henry VIII of England]] at the famous meeting at the [[Field of Cloth of Gold]] on 7 June 1520, but despite a lavish fortnight of diplomacy they failed to reach an agreement.<ref>{{Cite book |title=The Field of Cloth of Gold|last=Glenn|first=Richardson|year=2014|isbn=9780300160390|publisher=Yale University Press|pages=32–36|oclc=862814775}}</ref> Francis and Henry were both obsessed with dreams of power and chivalric glory; their relationship featured intense personal and dynastic rivalry. Francis was driven by his intense eagerness for retaking Milan, despite the strong opposition of other Powers. Henry was likewise determined to recapture northern France, which Francis could never allow.<ref>Glen Richardson, "Good friends and brothers?" ''History Today'' (1994) 44#9 pp 20-26.</ref>
#
# Francis suffered his most devastating defeat at the [[Battle of Pavia]] on 24 February 1525, during part of the continuing Italian Wars known as the [[Four Years' War]]. Francis was actually captured by the forces of Charles V after [[Cesare Hercolani]] was able to injure his horse, leading Francis to be captured by Diego Dávila, [[Alonso Pita da Veiga]] and [[Juan de Urbieta]], from Guipúzcoa. For this reason, Hercolani was named "Victor of the battle of Pavia". ''[[Zuppa alla Pavese]]'' was supposedly invented on the spot to feed the captive king right after the battle.<ref>Andrews, Colman. ''Country Cooking of Italy''. San Francisco: Chronicle Books, 2012, [https://books.google.com/books?id=yTqyEdU7fEcC&pg=PT61 p. 60]. {{ISBN|9781452123929}}.</ref>
#
# Francis I was held captive in Madrid. In a letter to his mother he wrote, "Of all things, nothing remains to me but honour and life, which is safe." This line has come down in history famously as "All is lost save honour."<ref>{{Cite EB1911 |wstitle=Francis I. of France | volume=10 |page=935 |first=Jules |last=Isaac |authorlink=Jules Isaac}}</ref> In the [[Treaty of Madrid (1526)|Treaty of Madrid]], signed on 14 January 1526, Francis was forced to make major concessions to Charles V before he was freed on 17 March 1526. An ultimatum from Ottoman Sultan Suleiman to Charles V also played an important role in his release. Among the concessions that Francis I yielded to Charles V were the surrender of any claims to Naples and Milan in Italy.<ref name=Mallet>Mallet, Michael and Christine Shaw, ''The Italian Wars: 1494–1559'' (Harlow, England: Pearson Education Limited, 2012) p. 153.</ref> Francis I was also forced to recognise the independence of the duchy of Burgundy, which had become part of France since the death of [[Charles, Duke of Burgundy]] on 5 January 1477,<ref>Kendall, Paul Murray. ''Louis XI: The Universal Spider'' (New York: W. W. Norton and Company, 1971) p. 314.</ref> during the reign of [[Louis XI, King of France|Louis XI]].  Francis I was allowed to return to France in exchange for his two sons, [[Francis III, Duke of Brittany|Francis]] and [[Henry II of France|Henry]], but once he was free he argued that his agreement with Charles was made under [[duress]]. He also claimed that the agreement was void because his sons were taken hostage with the implication that his word alone could not be trusted. Thus he firmly repudiated it. A renewed alliance with England enabled Francis to repudiate the treaty of Madrid. A more acceptable agreement, called the Peace of the Ladies, eventually negotiated by Francis’ mother and Charles’ aunt in 1529.<ref>Glenn Richardson, "Le roi-chevalier." ''History Today'' (May 2015) p. 41.</ref>
#
# [[File:Manif. di bruxelles su dis.di bernart von orley, arazzi della battaglia di pavia, attacco alla gendarmeria francese, IGMN144483, 1526-31.JPG|thumb|280px|left|Detail of a tapestry depicting the [[Battle of Pavia]], woven from a cartoon by [[Bernard van Orley]] (c. 1531)]]
#
# Francis persevered in his hatred of Charles V and desire to control Italy. The repudiation of the Treaty of Madrid led to the [[War of the League of Cognac]] of 1526–30. By the mid-1520s, [[Pope Clement VII]] wished to liberate Italy from foreign domination, especially that of Charles V, so to that end he negotiated with Venice to form the [[League of Cognac]]. Francis I willingly joined this anti-Imperial league in May 1526.<ref>Michael Mallett,and Christine Shaw, ''The Italian Wars: 1494–1559'', p. 155.</ref>
#
# After the league of Cognac failed, Francis concluded a secret alliance with the [[Philip I, Landgrave of Hesse|Landgrave of Hesse]] on 27 January 1534. This was directed against Charles V on the pretext of assisting the [[Ulrich, Duke of Württemberg|Duke of Wurttemberg]] to regain his traditional seat, from which Charles had removed him in 1519. Francis also obtained the help of the [[Ottoman Empire]] and renewed the contest in Italy in the [[Italian War of 1536–1538]] after the death of [[Francesco II Sforza]], the ruler of Milan. This round of fighting, which had little result, was ended by the [[Truce of Nice]]. The agreement collapsed, however, which led to Francis' final attempt on Italy in the [[Italian War of 1542–1546]]. This time Francis managed to hold off the forces of Charles V and Henry VIII. Charles V was forced to sign the [[Treaty of Crépy]] because of his financial difficulties and conflicts with the [[Schmalkaldic League]].<ref>Geoffrey Parker, ''Emperor'' (2019) pp 308–312.</ref>
#
# ===Relations with the New World and Asia===
# [[File:Viaggioverrazzano.jpg|thumb|The voyage of [[Giovanni da Verrazzano]] in 1524]]
#
# Francis had been much aggrieved at the [[papal bull]] [[Aeterni regis]]: in June 1481 Portuguese rule over Africa and the Indies was confirmed by [[Pope Sixtus IV]]. Thirteen years later, on 7 June 1494, [[Portugal]] and the [[Crown of Castile|Crown of Castille]] signed the [[Treaty of Tordesillas]] under which the newly discovered lands would be divided between the two signatories. All this prompted King Francis to declare, "The sun shines for me as it does for others. I would very much like to see the clause of Adam’s will by which I should be denied my share of the world."<ref>{{Cite book|title=Canada Quebec 1534–2000|last=Lacoursière|first=Jacques|publisher=Septentrion|year=2005|isbn=978-2894481868|location=Québec|page=28}}</ref>
#
# In order to counterbalance the power of the [[Habsburg Monarchy|Habsburg Empire]] under Charles V, especially its control of large parts of the [[New World]] through the Crown of Spain, Francis I endeavoured to develop contacts with the New World and Asia. Fleets were sent to the Americas and the Far East, and close contacts were developed with the Ottoman Empire permitting the development of French Mediterranean trade as well as the establishment of a strategic military alliance.
#
# The port city now known as [[Le Havre]] was founded in 1517 during the early years of Francis' reign. The construction of a new port was urgently needed in order to replace the ancient harbours of [[Honfleur]] and [[Harfleur]], whose utility had decreased due to silting. Le Havre was originally named ''Franciscopolis'' after the King who founded it, but this name did not survive into later reigns.
#
# ====Americas====
# {{further|France-Americas relations}}
# In 1524, Francis assisted the citizens of [[Lyon]] in financing the expedition of [[Giovanni da Verrazzano]] to North America. On this expedition, Verrazzano visited the present site of [[New York City]], naming it [[New Angoulême]], and claimed [[Newfoundland (island)|Newfoundland]] for the French crown. Verrazzano's letter to Francis of 8 July 1524 is known as the ''[[Cèllere Codex]]''.<ref>* {{cite journal|last1=Destombes|first1=M.|date=1954|title=Nautical Charts Attributed to Verrazano (1525–1528)|journal=Imago Mundi|volume=11|pages=57–66|oclc=1752690|doi=10.1080/03085695408592059}}</ref>
#
# In 1531, [[Bertrand d'Ornesan]] tried to establish a French trading post at [[Pernambuco]], Brazil.<ref>Knecht, R.J. ''Francis I'', (Cambridge University Press, 1982), 375.</ref>
#
# In 1534, Francis sent [[Jacques Cartier]] to explore the [[St. Lawrence River]] in [[Quebec]] to find "certain islands and lands where it is said there must be great quantities of gold and other riches".<ref>Knecht, R.J. ''Francis I'', 333.</ref> In 1541, Francis sent [[Jean-François Roberval|Jean-François de Roberval]] to settle Canada and to provide for the spread of "the Holy Catholic faith."
#
# ====Far East Asia====
# {{further|France-Asia relations}}
# [[File:Australia first map.jpg|thumb|An example of the [[Dieppe maps]] showing [[Sumatra]]. [[Nicholas Vallard]], 1547.]]
#
# French trade with East Asia was initiated during the reign of Francis I with the help of shipowner [[Jean Ango]]. In July 1527, a French [[Normandy|Norman]] trading ship from the city of [[Rouen]] is recorded by the Portuguese [[João de Barros]] as having arrived in the Indian city of [[Diu, India|Diu]].<ref name="Cambridge">{{cite book|url=https://books.google.com/books?id=Y-08AAAAIAAJ&pg=PA61 |title=The English history of the British Empire'' p. 61 |access-date=2012-08-23|year=1940 |last1=Benians |first1=Ernest Alfred |last2=Newton |first2=Arthur Percival |last3=Rose |first3=John Holland }}</ref> In 1529, [[Jean Parmentier (explorer)|Jean Parmentier]], on board the ''Sacre'' and the ''Pensée'', reached [[Sumatra]].<ref name="Cambridge"/><ref>{{cite book|url=https://books.google.com/books?id=HlibHoeruDUC&pg=PA123 |title=''European travellers in India'' p. 123 |access-date=2012-08-23|isbn=9788120607101 |last1=Oaten |first1=Edward Farley |year=1991 }}</ref> Upon its return, the expedition triggered the development of the [[Dieppe maps]], influencing the work of [[Dieppe, Seine-Maritime|Dieppe]] cartographers such as [[Jean Rotz]].<ref>{{cite book|url=https://books.google.com/books?id=P7OuMkzGKw0C&pg=PA57 |title=''Explorers and colonies: America, 1500–1625'', p. 57 |date= 1990-01-01|access-date=2012-08-23|isbn=9781852850241 |last1=Quinn |first1=David B. }}</ref>
#
# ====Ottoman Empire====
# {{further|Franco-Ottoman alliance|Orientalism in early modern France}}
#
# Under the reign of Francis I, France became the first country in Europe to establish formal relations with the Ottoman Empire and to set up instruction in the [[Arabic language]] under the guidance of [[Guillaume Postel]] at the [[Collège de France]].<ref>[https://books.google.com/books?id=Sl8fniRER4kC&pg=PA26 ''Eastern wisdom and learning: the study of Arabic in seventeenth-century ...''] by [[G. J. Toomer]] p.26-7</ref>
#
# [[File:Francois I Suleiman.jpg|thumb|left|Francis I (left) and [[Suleiman the Magnificent]] (right) initiated a [[Franco-Ottoman alliance]].  Both were separately painted by [[Titian]] circa 1530.]]
#
# In a watershed moment in European diplomacy, Francis came to an understanding with the Ottoman Empire that developed into a [[Franco-Ottoman alliance]]. The alliance has been called "the first nonideological diplomatic alliance of its kind between a Christian and non-Christian empire".<ref>{{cite book|url=https://books.google.com/books?id=w5iJ1tfLnnoC&q=%22Franco-Turkish+alliance%22&pg=PA62 |title=Kann, p. 62 |date=1980-11-26 |access-date=2012-08-23|isbn=9780520042063 |last1=Kann |first1=Robert A. }}</ref> It did, however, cause quite a scandal in the Christian world<ref name="Miller, p.2">Miller, p. 2</ref> and was designated "the impious alliance", or "the sacrilegious union of the [French]&nbsp;[[Fleur-de-Lis|Lily]] and the [Ottoman]&nbsp;[[Crescent]]." Nevertheless, it endured for many years, since it served the objective interests of both parties.<ref>{{cite book|url=https://books.google.com/books?id=AkMHta3C7LUC&q=%22Franco-Turkish+alliance%22&pg=PA219 |title=Merriman, p. 133 |date= March 2007|access-date=2012-08-23|isbn=9781406772722 |last1=Merriman |first1=Roger Bigelow }}</ref> The two powers colluded against Charles V, and in 1543 they even combined for a joint naval assault in the [[Siege of Nice]].
#
# In 1533, Francis I sent colonel [[Pierre de Piton]] as ambassador to [[Morocco]], initiating official [[France-Morocco relations]].<ref>"Francois I, hoping that Morocco would open up to France as easily as Mexico had to Spain, sent a commission, half commercial and half diplomatic, which he confided to one Pierre de Piton. The story of his mission is not without interest" in ''The conquest of Morocco'' by Cecil Vivian Usborne, S. Paul & co. ltd., 1936, p. 33.</ref> In a letter to Francis I dated 13 August 1533, the [[Wattassid]] ruler of [[Fes|Fez]], [[Abu al-Abbas Ahmad ibn Muhammad|Ahmed ben Mohammed]], welcomed French overtures and granted freedom of shipping and protection of French traders.
#
# ===Bureaucratic reform and language policy===
# [[File:Ordonnance de Villers Cotterets August 1539.jpg|thumb|The [[Ordinance of Villers-Cotterêts]] in August 1539 prescribed the use of French in official documents.]]
#
# Francis took several steps to eradicate the monopoly of [[Latin]] as the language of knowledge. In 1530, he declared French the national language of the kingdom, and that same year opened the Collège des trois langues, or [[Collège de France|Collège Royal]], following the recommendation of humanist [[Guillaume Budé]]. Students at the Collège could study [[Greek language|Greek]], [[Hebrew]] and [[Aramaic]], then [[Arabic]] under [[Guillaume Postel]] beginning in 1539.<ref>McCabe, Ina Baghdianitz. ''Orientalism in early modern France''. {{ISBN|978-1-84520-374-0}}, p. 25 ''ff''.</ref>
#
# In 1539, in his castle in [[Villers-Cotterêts]],<ref>{{cite book|url=https://books.google.com/books?id=nuyx5E_wp7QC&pg=PA158 |title=The rise and fall of Renaissance France, 1483–1610, p. 158 |date= 21 January 2002|access-date=2012-08-23|isbn=9780631227298 |last1=Knecht |first1=Robert J. }}</ref> Francis signed the important edict known as [[Ordinance of Villers-Cotterêts]], which, among other reforms, made French the administrative language of the kingdom as a replacement for [[Latin language|Latin]]. This same edict required priests to register births, marriages, and deaths, and to establish a registry office in every parish. This initiated the first records of vital statistics with filiations available in Europe.
#
# ===Religious policies===
# Divisions in [[Christianity]] in Western Europe during Francis' reign created lasting international rifts. [[Martin Luther]]'s preaching and writing sparked the [[Protestant Reformation]], which spread through much of Europe, including France.
#
# [[File:Massacre of the Vaudois of Merindol.jpg|thumb|left|[[Mérindol massacre|Massacre of Mérindol]] in 1545]]
#
# Initially, Francis was relatively tolerant of the new movement, under the influence of his beloved sister [[Marguerite de Navarre]], who was genuinely attracted by Luther's theology. He even considered it politically useful, as it caused many German princes to turn against his enemy Charles V. In 1533 Francis even dared to suggest to Pope Clement VII that he convene a church council in which Catholic and Protestant rulers would have an equal vote in order to settle their differences – an offer rejected by both the Pope and Charles V. Beginning in 1523, however, Francis burned several heretics at the [[Place Maubert]].<ref>[[Pierre Goubert]], ''The Course of French History'' Psychology Press, 1991, p. 92.</ref>
#
# Francis' attitude towards [[Protestantism]] changed for the worse following the "[[Affair of the Placards]]", on the night of 17 October 1534, in which notices appeared on the streets of Paris and other major cities denouncing the Catholic [[Mass (Catholicism)|mass]]. The most fervent Catholics were outraged by the notice's allegations. Francis himself came to view the movement as a plot against him and began to persecute its followers. Protestants were jailed and executed. In some areas whole villages were destroyed. In Paris, after 1540, Francis had heretics such as [[Etienne Dolet]] tortured and burned.<ref>Goubert, op. cit., p.92</ref> [[Printing]] was censored and leading [[Protestant reformers]] such as [[John Calvin]] were forced into exile. The persecutions soon numbered thousands of dead and tens of thousands of homeless.<ref>R. J. Knecht, [https://books.google.com/books?id=rvEBMIIcHQkC&pg=PA405 ''Francis I']'' pp.405–406</ref>
#
# Persecutions against Protestants were codified in the [[Edict of Fontainebleau (1540)]] issued by Francis. Major acts of violence continued, as when Francis ordered the execution of one of the historical pre-Lutheran groups, the [[Waldensians]], at the [[Massacre of Mérindol]] in 1545.
#
# ===Death===
# Francis died at the [[Château de Rambouillet]] on 31 March 1547, on his son and successor's 28th birthday. It is said that "he died complaining about the weight of a crown that he had first perceived as a gift from God".<ref>{{cite web|last1=Cavendish|first1=Richard|title=The Marriage of Mary, Queen of Scots {{!}} History Today|url=http://www.historytoday.com/richard-cavendish/marriage-mary-queen-scots|website=www.historytoday.com}}</ref> He was interred with his first wife, Claude, Duchess of Brittany, in [[Saint Denis Basilica]]. He was succeeded by his son, [[Henry II of France|Henry II]].
#
# Francis' tomb and that of his wife and mother, along with the tombs of other French kings and members of the royal family, were desecrated on 20 October 1793 during the [[Reign of Terror]] at the height of the [[French Revolution]].
#
# ===Image and reputation===
# [[File:Grand culverin of Francis I 140mm 307cm Algiers recovered in 1830.jpg|thumb|[[Calibres de France|Grand culverin]] of Francis I, with his emblem and motto. A gift to his Ottoman allies recovered in [[Algiers]] in 1830. [[Musée de l'Armée]].]]
#
# Francis I has a poor reputation in France—his 500th anniversary was little noted in 1994. Popular and scholarly historical memory ignores his building of so many fine chateaux, his stunning art collection, his lavish patronage of scholars and artists. He is seen as a playboy who disgraced France by allowing himself to be defeated and taken prisoner at Pavia. The historian [[Jules Michelet]] set the negative image.<ref>Robert J. Knecht, "'Born between two women...'Jules Michelet and Francis I." ''Renaissance Studies'' (2000) 14#3: 329-343 [https://www.jstor.org/stable/24412871 online]</ref>
#
# Francis' personal emblem was the [[Salamander (legendary creature)|salamander]] and his Latin motto was ''Nutrisco et extinguo'' ("I nourish [the good] and extinguish [the bad]").<ref>Richardson, 2015.</ref> His long nose earned him the nickname ''François du Grand Nez'' ("Francis of the Big Nose"), he was also colloquially known as the "Grand Colas" or "Bonhomme Colas". For his personal involvement in battles, he was known as ''le Roi-Chevalier'' ("the Knight-King") or the ''le Roi-Guerrier'' ("the Warrior-King").<ref>[[Éditions Larousse|Larousse]] [https://archive.is/20130213110523/http://www.larousse.fr/encyclopedie/article/Laroussefr_-_Article/11020086]</ref>
#
# British historian Glenn Richardson considers Francis a success:
# :He was a king who ruled as well as reigned. He knew the importance of war and a high international profile in staking his claim to be a great warrior-king of France. In battle he was brave, if impetuous, which led equally to triumph and disaster. Domestically, Francis exercised the spirit and letter of the royal prerogative to its fullest extent. He bargained hard over taxation and other issues with interest groups, often by appearing not to bargain at all. He enhanced royal power and concentrated decision-making in a tight personal executive but used a wide range of offices, gifts and his own personal charisma to build up an elective personal affinity among the ranks of the nobility upon whom his reign depended&nbsp;.... Under Francis, the court of France was at the height of its prestige and international influence during the 16th century. Although opinion has varied considerably over the centuries since his death, his cultural legacy to France, to its Renaissance, was immense and ought to secure his reputation as among the greatest of its kings.<ref>Richardson, 2015, p. 45.</ref>
#
# ==Marriage and issue==
# On 18 May 1514, Francis married his second cousin [[Claude of France|Claude]], the daughter of [[Louis XII of France|King Louis XII of France]] and [[Anne of Brittany|Duchess Anne of Brittany]]. The couple had seven children:
# * Louise (19 August 1515 – 21 September 1517): died young; engaged to [[Charles V, Holy Roman Emperor|Charles I of Spain]] almost from birth until death.
# * [[Charlotte of Valois|Charlotte]] (23 October 1516 – 8 September 1524): died young; engaged to [[Charles V, Holy Roman Emperor|Charles I of Spain]] from 1518 until death.
# * [[Francis III, Duke of Brittany|Francis]] (28 February 1518 – 10 August 1536), who succeeded his mother Claude as Duke of Brittany, but died aged 18, unmarried and childless.
# * [[Henry II of France|Henry II]] (31 March 1519 – 10 July 1559). Succeeded Francis I as King of France. Married [[Catherine de' Medici]], had issue.
# * [[Madeleine of France (1520-1537)|Madeleine]] (10 August 1520 – 2 July 1537), who married [[James V of Scotland]] and had no issue.
# * [[Charles de Valois, Duc d'Orléans|Charles]] (22 January 1522 – 9 September 1545), who died unmarried and childless.
# * [[Margaret of France, Duchess of Berry|Margaret]] (5 June 1523 – 14 September 1574), who married [[Emmanuel Philibert, Duke of Savoy]], in 1559 and had issue.
#
# On 7 July 1530, Francis I married his second wife [[Eleanor of Austria]],<ref>{{cite encyclopedia
# |author=Wurzbach, Constantin von
# |author-link=Constantin von Wurzbach
# |title=Habsburg, Eleonore von Oesterreich (Tochter Philipp's von Oesterreich)
# |encyclopedia=Biographisches Lexikon des Kaiserthums Oesterreich
# |year=1860
# |publisher=Verlag L. C. Zamarski
# |location=Vienna
# |url=https://de.wikisource.org/wiki/BLK%C3%96:Habsburg,_Eleonore_von_Oesterreich_%28Tochter_Philipp%E2%80%99s_von_Oesterreich%29
# }}</ref>
# a sister of the Emperor Charles V. The couple had no children. During his reign, Francis kept two official mistresses at court. The first was [[Françoise de Foix]], Countess of [[Châteaubriant]]. In 1526, she was replaced by the blonde-haired, cultured [[Anne de Pisseleu d'Heilly]], Duchess of Étampes who, with the death of Queen Claude two years earlier, wielded far more political power at court than her predecessor had done. Another of his earlier mistresses was allegedly [[Mary Boleyn]], mistress of King [[Henry VIII of England|Henry VIII]] and sister of Henry's future wife, [[Anne Boleyn]].<ref>Letters and Papers of the Reign of Henry VIII, X, no.450</ref>
#
# ==Francis I in films, stage and literature==
# The amorous exploits of Francis inspired the 1832 play by [[Fanny Kemble]], ''Francis the First'', and the 1832 play by [[Victor Hugo]], ''[[Le Roi s'amuse]]'' ("The King's Amusement"), which featured the jester [[Triboulet]], the inspiration for the 1851 opera ''[[Rigoletto (opera)|Rigoletto]]'' by [[Giuseppe Verdi]].
#
# Francis was first played in a [[George Méliès]] movie by an unknown actor in 1907, and has also been played by Claude Garry (1910), [[Aimé Simon-Girard]] (1937), [[Sacha Guitry]] (1937), [[Gérard Oury]] (1953), [[Jean Marais]] (1955), [[Pedro Armendáriz]] (1956), [[Claude Titre]] (1962), Bernard Pierre Donnadieu (1990). [[Timothy West]] (1998) and [[Emmanuel Leconte]] (2007– 2010).
#
# Francis was portrayed by [[Peter Gilmore]] in the comedy film ''[[Carry On Henry]]'' charting the fictitious two extra wives of Henry VIII (including Marie cousin of King Francis).
#
# Francis receives a mention in a minor story in [[Laurence Sterne]]'s novel ''[[Tristram Shandy]]''. The narrator claims that the king, wishing to win the favour of Switzerland, offers to make the country the godmother of his son. When, however, their choice of name conflicts, he declares war.
#
# He is also mentioned in Jean de la Brète's novel ''Reine – Mon oncle et mon curé'', where the main character Reine de Lavalle idolises him after reading his biography, much to the dismay of the local priest.
#
# He often receives mentions in novels on the lives of either of the Boleyn sisters – [[Mary Boleyn]] (d. 1543) and her sister, Queen [[Anne Boleyn]] (executed 1536), both of whom were for a time educated at his court. Mary had, according to several accounts, been Francis' one-time mistress and Anne had been a favourite of his sister: the novels ''The Lady in the Tower'', ''[[The Other Boleyn Girl]],'' ''The Last Boleyn'', ''Dear Heart, How Like You This?'' and ''Mademoiselle Boleyn'' feature Francis in their story. He appears in [[Hilary Mantel]]'s ''Wolf Hall'' about Henry VIII's minister [[Thomas Cromwell]] and is often referred to in its sequel, ''Bring Up the Bodies''.
#
# Francis is portrayed in Diane Haeger's novel ''Courtesan'' about Diane de Poitiers and Henri II.
#
# Francis appears as the patron of [[Benvenuto Cellini]] in the 1843 French novel ''L'Orfèvre du roi, ou Ascanio'' by [[Alexandre Dumas, père]].
#
# [[Samuel Shellabarger]]'s novel ''The King's Cavalier'' describes Francis the man, and the cultural and political circumstances of his reign, in some detail.
#
# He was a recurring character in the Showtime series ''[[The Tudors]]'', opposite [[Jonathan Rhys Meyers]] as [[Henry VIII of England|Henry VIII]] and [[Natalie Dormer]] as [[Anne Boleyn]]. Francis is played by French actor, Emmanuel Leconte.
#
# He and his court set the scene for [[Friedrich Schiller]]'s ballad ''[[Der Handschuh]]'' (''The Glove'').
#
# Francis I (played by [[Timothy West]]) and Francis's son Henry II (played by [[Dougray Scott]]) are central figures in the 1998 movie ''[[Ever After]]'', a retelling of the [[Cinderella]] story.  The plot includes [[Leonardo da Vinci]] (played by [[Patrick Godfrey]]) arriving at Francis's court with the ''[[Mona Lisa]]''.
#
# He is played by [[Alfonso Bassave]] in the [[Televisión Española|TVE]] series ''[[Carlos, rey emperador]]'', opposite [[Álvaro Cervantes]] as [[Charles V, Holy Roman Emperor|Charles V]].
#
# ==Ancestors==
# {{ahnentafel
# |collapsed=yes |align=center
# | boxstyle_1 = background-color: #fcc;
# | boxstyle_2 = background-color: #fb9;
# | boxstyle_3 = background-color: #ffc;
# | boxstyle_4 = background-color: #bfc;
# | boxstyle_5 = background-color: #9fe;
# | 1 = 1. '''Francis I of France'''
# | 2 = 2. [[Charles, Count of Angoulême]]
# | 3 = 3. [[Louise of Savoy]]
# | 4 = 4. [[John, Count of Angoulême]]<ref name="Adams2010">{{cite book |first=Tracy |last=Adams |title=The Life and Afterlife of Isabeau of Bavaria |publisher=Johns Hopkins University Press |year=2010 |page=255}}</ref>
# | 5 = 5. [[Marguerite de Rohan, Countess of Angoulême|Marguerite de Rohan]]<ref name="Gicquel1986">{{cite book|last=Gicquel|first=Yvonig|author-link=:fr:Yvonig Gicquel|title=Alain IX de Rohan, 1382–1462: un grand seigneur de l'âge d'or de la Bretagne|url=https://books.google.com/books?id=pGgfAAAAMAAJ|year=1986|publisher=Éditions Jean Picollec|language=fr|isbn=9782864770718|page=480}}</ref>
# | 6 = 6. [[Philip II, Duke of Savoy]]<ref name="Jackson-Laufer">{{cite book |first=Guida Myrl |last=Jackson-Laufer |title=Women Rulers Throughout the Ages: An Illustrated Guide |url=https://archive.org/details/isbn_9791576070917 |url-access=registration |publisher=ABC-CLIO |year=1999 |page=[https://archive.org/details/isbn_9791576070917/page/231 231]}}</ref>
# | 7 = 7. [[Margaret of Bourbon (1438–1483)|Margaret of Bourbon]]<ref name="Jackson-Laufer"/>
# | 8 = 8. [[Louis I, Duke of Orléans]]<ref name="Adams2010"/>
# | 9 = 9. [[Valentina Visconti]]<ref name="Adams2010"/>
# |10 =10. [[Alain IX, Viscount of Rohan]]<ref name="Gicquel1986"/>
# |11 =11. [[Margaret of Brittany (1392–1428)|Margaret of Brittany]]<ref name="Gicquel1986"/>
# |12 =12. [[Louis, Duke of Savoy]]<ref name="APG">{{cite web |url=http://www.sabaudia.org/3180-la-maison-de-savoie.htm |title=La Maison de Savoie |language=fr |first=André |last=Palluel-Guillard |publisher=Conseil Savoie Mont Blanc |access-date=2018-06-28}}</ref>
# |13 =13. [[Anne of Cyprus]]<ref name="APG"/>
# |14 =14. [[Charles I, Duke of Bourbon]]<ref name="Leguai">{{cite book |last=Leguai |first=André |chapter=Agnès de Bourgogne, duchesse de Bourbon (1405?–1476) |title=Les ducs de Bourbon, le Bourbonnais et le royaume de France à la fin du Moyen Age |trans-title=The dukes of Bourbon, the Bourbonnais and the kingdom of France at the end of the Middle Ages |publisher=Société bourbonnaise des études locales |location=Yzeure |year=2005 |pages=145–160 |language=fr}}</ref>
# |15 =15. [[Agnes of Burgundy, Duchess of Bourbon|Agnes of Burgundy]]<ref name="Leguai"/>
# |16 =16. [[Charles V of France]]<ref name="Anselme">{{cite book |title=Histoire généalogique et chronologique de la maison royale de France |volume=1 |trans-title=Genealogical and chronological history of the royal house of France |last=Anselme de Sainte-Marie |first=Père |url=https://gallica.bnf.fr/ark:/12148/bpt6k76026j/f125.image |publisher=La compagnie des libraires |location=Paris |page=110 |language=fr |edition=3rd |year=1726 }}</ref>
# |17 =17. [[Joanna of Bourbon]]<ref name="Anselme"/>
# |18 =18. [[Gian Galeazzo Visconti]]<ref name="Azzolini120">{{cite book |first=Monica |last=Azzolini |title=The Duke and the Stars: Astrology and Politics in Renaissance Milan |publisher=Harvard University Press |year=2013 |page=120}}</ref>
# |19 =19. [[Isabella, Countess of Vertus|Isabelle of Valois]]<ref name="Azzolini120"/>
# |20 =20. [[Alain VIII, Viscount of Rohan]]<ref name="Gicquel1986-2">Y. Gicquel, ''Alain IX de Rohan'', p. 97</ref>
# |21 =21. [[Béatrix de Clisson]]<ref name="Gicquel1986-2"/>
# |22 =22. [[John IV, Duke of Brittany]]<ref name="Jones1988">{{cite book|last=Jones|first=Michael |title=The Creation of Brittany |url=https://archive.org/details/creationbrittany00jone|url-access=limited|publisher=Hambledon Press |location=London |year=1988 |isbn=090762880X |page=[https://archive.org/details/creationbrittany00jone/page/n137 123]}}</ref>
# |23 =23. [[Joan of Navarre, Queen of England|Joan of Navarre]]<ref name="Jones1988"/>
# |24 =24. [[Amadeus VIII, Duke of Savoy|Antipope Felix V]]<ref name="APG"/>
# |25 =25. [[Mary of Burgundy, Duchess of Savoy|Mary of Burgundy]]<ref name="APG"/>
# |26 =26. [[Janus of Cyprus]]<ref name="Hill2010">{{cite book|last=Hill|first=George|title=A History of Cyprus|chapter-url=https://books.google.com/books?id=SnCWSuZ-58oC&pg=PA468|year=2010|publisher=Cambridge University Press|isbn=9781108020633|page=468|chapter=Janus (1398–1432)}}</ref>
# |27 =27. [[Charlotte of Bourbon, Queen of Cyprus|Charlotte of Bourbon]]<ref name="Hill2010"/>
# |28 =28. [[John I, Duke of Bourbon]]<ref name="Anselme2">Anselme, vol. 3, p. 137</ref>
# |29 =29. [[Marie, Duchess of Auvergne]]<ref name="Anselme2"/>
# |30 =30. [[John the Fearless|John II, Duke of Burgundy]]<ref name="O'Reilly1921">{{cite book|last=O'Reilly|first=Elizabeth Boyle|title=How France Built Her Cathedrals: A Study in the Twelfth and Thirteenth Centuries|url=https://books.google.com/books?id=DA1tMNYiny0C&pg=PA265|year=1921|publisher=Harper & Brothers|page=265}}</ref>
# |31 =31. [[Margaret of Bavaria]]<ref>{{cite web |url=http://resources.huygens.knaw.nl/vrouwenlexicon/lemmata/data/MargarethaVanBeieren |title=Margaretha van Beieren (1363–1424) |trans-title=Margaret of Bavaria |work=Online Dictionary of Dutch Women |publisher=Digitaal Vrouwenlexicon van Nederland |date=2014-01-13 |first=Mieke |last=van Leeuwen-Canneman |access-date=2018-06-29}}</ref>
# }}
#
# ==See also==
# {{Portal|Biography|France}}
# * [[Castell del Patriarca]]
# * [[Franco-Ottoman alliance]]
#
# ==References==
# {{Reflist}}
#
# ==Further reading==
# * Clough, C.H., "Francis I and the Courtiers of Castiglione’s Courtier." ''European Studies Review.'' vol 8, 1978.
# * Denieul-Cormier, Anne. ''The Renaissance in France.'' trans. [[Anne Fremantle]] and Christopher Fremantle. London: George Allen and Unwin Ltd., 1969.
# * Grant, A.J. ''The French Monarchy, Volume I.'' New York: Howard Fertig, 1970.
# * Guy, John. ''Tudor England.'' Oxford: Oxford University Press, 1988.
# * Isom-Verhaaren, Christine. "'Barbarossa and His Army Who Came to Succor All of Us': Ottoman and French Views of Their Joint Campaign of 1543–1544." ''French Historical Studies'' 30:3 (2007): 395-425 [https://www.academia.edu/download/34174247/FHS030-03-03Isom-Verhaaren1pp.pdf online].
# * Jensen, De Lamar. “The Ottoman Turks in Sixteenth Century French Diplomacy” ''Sixteenth Century Journal'' 16:4 (1985): 451–470. [http://www.jstor.com/stable/2541220 online]
# * Jensen, De Lamar, ed. ''Renaissance Europe.'' Lexington: D.C. Heath and Company, 1992.
# * Knecht, R.J. ''Renaissance Warrior and Patron: The Reign of Francis I.'' Cambridge: Cambridge University Press, 1994. [https://books.google.com/books?hl=en&lr=lang_en&id=zGvoIW6Y_xAC&oi=fnd&pg=PR11&dq=Knecht,+R.J.+%27%27Francis+I%27%27&ots=a8JSfDN6I9&sig=Sd7eVr6LETir1zdzDntoU77owuE#v=onepage&q=Knecht%2C%20R.J.%20''Francis%20I''&f=false online]
# * Knecht, Robert J. "A Battle of Giants." ''History Today'' (2016) 88#1 pp 49–54 on  Battle of Marignano, Italy in 1515.
# * Knecht, R.J. ''Francis I'' (Cambridge University Press, 1982) [https://archive.org/details/francisi00knec/page/n3/mode/2up online]
# * Knecht, R.J. ''French Renaissance Monarchy: Francis I and Henry II'' (2nd ed. 1997), historiography [https://www.amazon.com/French-Renaissance-Monarchy-Francis-1984-03-19/dp/B01K0S5WQI/  excerpt]
# * Knecht, R. J. "An Update on the Reign of Francis I." ''History Compass'' 1.1 (2003) pp 1–9.
# * Knecht, R. J. "Francis and Paris" ''History'' 66#216 (1981) [https://doi-org/10.1111/j.1468-229X.1981.tb01357.x onl;ine]
# * Knecht, Robert J. "'Born between two women...'Jules Michelet and Francis I." ''Renaissance Studies'' (2000) 14#3: 329-343 [https://www.jstor.org/stable/24412871 online].
# * Major, J. Russell. ''From Renaissance Monarchy to Absolute Monarchy.'' (Johns Hopkins UP, 1994).
# * Mansfield, Lisa. '' Representations of Renaissance monarchy: Francis I and the image-makers''  (2016).
# * Parker, Geoffrey. ''Emperor: A New Life of Charles V'' (Yale UP, 2019).
# * Potter, D. L. ''Renaissance France at War – Armies, Culture and Society, c.1480–1560.'' (Boydell Press., 2008).
# * Reston Jr, James. ''Defenders of the Faith: Christianity and Islam Battle for the Soul of Europe, 1520-1536'' (Penguin, 2009), popular history.
# * Richardson, Glenn. "Le roi-chevalier." ''History Today'' (May 2015) 65#5 pp 39–45 short biography of Francis I by a scholar
# * Richardson, Glenn. "Field of the Cloth of Gold" ''History Today'' (July 2020) 70#7 pp 28–39.
# * Richardson, Glenn. "Good friends and brothers?" ''History Today'' (1994) 44#9 pp 20–26, his relations with Henry VIII.
# * Seward, Desmond.  ''Franco-Ottoman Alliance of Francis I Prince of the Renaissance.'' New York: MacMillan, 1973. [https://archive.org/details/princeofrenaiss000desm online]
#
# ==External links==
# * {{Commons category-inline|Francis I of France}}
#
# {{S-start}}
# {{S-hou|[[House of Valois|House of Valois, Orléans-Angoulême branch]]|12 September|1494|31 March|1547|[[Capetian dynasty]]}}
# {{S-reg|}}
# {{S-bef|rows=1|before=[[Louis XII of France|Louis XII]]}}
# {{S-ttl|title=[[List of French monarchs|King of France]]|years=1 January 1515 – 31 March 1547}}
# {{S-aft|rows=1|after=[[Henry II of France|Henry II]]}}
# |-
# {{S-bef|rows=1|before=[[Claude, Duchess of Brittany|Claude]]|as=sole duchess}}
# {{S-ttl|title=[[Duke of Brittany]]|regent1=[[Claude of France|Claude]]|years=18 May 1514 – 1 January 1515}}
# {{S-aft|rows=1|after=[[Claude, Duchess of Brittany|Claude]]|as=sole duchess}}
# |-
# {{S-bef|before=[[Maximilian Sforza]]}}
# {{S-ttl|title=[[List of rulers of Milan|Duke of Milan]]|years=1515–1521}}
# {{S-aft|after=[[Francesco II Sforza|Francis II Sforza]]|rows=2}}
# |-
# {{S-bef|before=[[Francesco II Sforza|Francis II Sforza]]}}
# {{S-ttl|title=[[List of rulers of Milan|Duke of Milan]]|years=1524–1525}}
# {{S-reg|fr}}
# |-
# {{S-vac|last=[[Louis XII of France|Louis]]|reason=Merged in the crown}}
# {{S-ttl|title=[[List of Counts and Dukes of Valois|Duke of Valois]]|years=1498 – 1 January 1515}}
# {{S-vac|next=[[Margaret of Valois|Margaret]]|reason=Merged in the crown}}
# |-
# {{S-bef|before=[[Charles, Count of Angoulême|Charles]]}}
# {{S-ttl|title=[[Counts and dukes of Angoulême|Count of Angoulême]]|years=1 January 1496 – 1 January 1515}}
# {{S-vac|next=[[Louise of Savoy|Louise]]|reason=Merged in the crown}}
# {{S-end}}
#
# {{Breton monarchs}}
# {{Monarchs of France}}
# {{France topics}}
#
# {{Authority control}}
#
# {{DEFAULTSORT:Francis 01 of France}}
# [[Category:Francis I of France| ]]
# [[Category:1494 births]]
# [[Category:1547 deaths]]
# [[Category:16th-century kings of France]]
# [[Category:16th-century dukes of Brittany]]
# [[Category:Ancien Régime in France]]
# [[Category:Counts of Angoulême]]
# [[Category:Dauphins of Viennois]]
# [[Category:Dauphins of France]]
# [[Category:Dukes of Milan]]
# [[Category:Dukes of Valois]]
# [[Category:French people of Cypriot descent]]
# [[Category:French Roman Catholics]]
# [[Category:House of Valois-Angoulême]]
# [[Category:Knights of the Garter]]
# [[Category:Knights of the Golden Fleece]]
# [[Category:People from Cognac]]
# [[Category:Burials at the Basilica of Saint-Denis]]
# [[Category:1510s in France]]
# [[Category:1520s in France]]
# [[Category:1530s in France]]
# [[Category:1540s in France]]
# [[Category:15th-century peers of France]]
# [[Category:16th-century peers of France]]
# [[Category:French art patrons]]
# [[Category:Monarchs imprisoned and detained during war]]

# %%
print(r02.json()['query']['pages']['50012']['cirrusbuilddoc']['text_bytes'])
# Out:
# 52547

# %%
print(r02.json()['query']['pages']['50012']['cirrusbuilddoc']['coordinates'])
# Out:
# []

# %%
print(r02.json()['query']['pages']['50012']['cirrusbuilddoc']['opening_text'])
# Out:
# Francis I (French: François Ier; Middle French: Francoys; 12 September 1494 – 31 March 1547) was King of France from 1515 until his death in 1547. He was the son of Charles, Count of Angoulême, and Louise of Savoy. He succeeded his first cousin once removed Louis XII, who died without a son. A prodigious patron of the arts, he promoted the emergent French Renaissance by attracting many Italian artists to work for him, including Leonardo da Vinci, who brought the Mona Lisa with him, which Francis had acquired. Francis' reign saw important cultural changes with the growth of central power in France, the spread of humanism and Protestantism, and the beginning of French exploration of the New World. Jacques Cartier and others claimed lands in the Americas for France and paved the way for the expansion of the first French colonial empire. For his role in the development and promotion of a standardized French language, he became known as le Père et Restaurateur des Lettres (the 'Father and Restorer of Letters'). He was also known as François au Grand Nez ('Francis of the Large Nose'), the Grand Colas, and the Roi-Chevalier (the 'Knight-King') for his personal involvement in the wars against his great rival Emperor Charles V, who was also King of Spain. Following the policy of his predecessors, Francis continued the Italian Wars. The succession of Charles V to the Burgundian Netherlands, the throne of Spain, and his subsequent election as Holy Roman Emperor, meant that France was geographically encircled by the Habsburg monarchy. In his struggle against Imperial hegemony, Francis sought the support of Henry VIII of England at the Field of the Cloth of Gold. When this was unsuccessful, he formed a Franco-Ottoman alliance with the Muslim sultan Suleiman the Magnificent, a controversial move for a Christian king at the time.

# %%
print(r02.json()['query']['pages']['50012']['cirrusbuilddoc']['auxiliary_text'])
# Out:
# ['Francis I Portrait by Jean Clouet, c. 1530 King of France (more...) Reign 1 January 1515 – 31 March 1547 Coronation 25 January 1515 Predecessor Louis XII Successor Henry II Born 12 September 1494 Château de Cognac, Cognac, France Died 31 March 1547(1547-03-31) (aged\xa052) Château de Rambouillet, France Burial 23 May 1547 Basilica of St Denis, France Spouse Claude, Duchess of Brittany \u200b \u200b (m.\xa01514)\u200b Eleanor of Austria \u200b (m.\xa01530)\u200b Issue among others... Francis III, Duke of Brittany Henry II of France Madeleine, Queen of Scots Charles, Duke of Orléans Margaret, Duchess of Savoy House Valois-Angoulême Father Charles, Count of Angoulême Mother Louise of Savoy Religion Roman Catholicism Signature', 'Ancestors of Francis I of France', '16. Charles V of France 8. Louis I, Duke of Orléans 17. Joanna of Bourbon 4. John, Count of Angoulême 18. Gian Galeazzo Visconti 9. Valentina Visconti 19. Isabelle of Valois 2. Charles, Count of Angoulême 20. Alain VIII, Viscount of Rohan 10. Alain IX, Viscount of Rohan 21. Béatrix de Clisson 5. Marguerite de Rohan 22. John IV, Duke of Brittany 11. Margaret of Brittany 23. Joan of Navarre 1. Francis I of France 24. Antipope Felix V 12. Louis, Duke of Savoy 25. Mary of Burgundy 6. Philip II, Duke of Savoy 26. Janus of Cyprus 13. Anne of Cyprus 27. Charlotte of Bourbon 3. Louise of Savoy 28. John I, Duke of Bourbon 14. Charles I, Duke of Bourbon 29. Marie, Duchess of Auvergne 7. Margaret of Bourbon 30. John II, Duke of Burgundy 15. Agnes of Burgundy 31. Margaret of Bavaria', 'Francis I of France House of Valois, Orléans-Angoulême branch Cadet branch of the Capetian dynasty Born: 12 September 1494\xa0Died: 31 March 1547 Regnal titles Preceded\xa0by Louis XII King of France 1 January 1515 – 31 March 1547 Succeeded\xa0by Henry II Preceded\xa0by Claude as sole duchess Duke of Brittany 18 May 1514 – 1 January 1515 with Claude Succeeded\xa0by Claude as sole duchess Preceded\xa0by Maximilian Sforza Duke of Milan 1515–1521 Succeeded\xa0by Francis II Sforza Preceded\xa0by Francis II Sforza Duke of Milan 1524–1525 French nobility Vacant Merged in the crown Title last held by Louis Duke of Valois 1498 – 1 January 1515 Vacant Merged in the crown Title next held by Margaret Preceded\xa0by Charles Count of Angoulême 1 January 1496 – 1 January 1515 Vacant Merged in the crown Title next held by Louise', 'Authority control BIBSYS: 90236426 BNE: XX1501310 BNF: cb120127827 (data) CANTIC: a11379029 GND: 118534947 HDS: 029215 ICCU: IT\\ICCU\\BVEV\\022053 ISNI: 0000 0001 2102 9337 LCCN: n50038638 NDL: 001193472 NKC: jn20000700556 NLA: 49861380 NLI: 000048459 NLP: A11869732 NTA: 069995168 PLWABN: 9810695005505606 RKD: 441278 SELIBR: 187794 SUDOC: 028254287 Trove: 1526264 ULAN: 500122500 VcBA: 495/72801 VIAF: 88805531 WorldCat Identities: lccn-n50038638', 'Francis I painted in 1515', 'Giovanni Maria Pomedelli, François I, (obverse)', 'Francis I receiving the last breath of Leonardo da Vinci in 1519, by Ingres, painted in 1818', "Francis's Château de Chambord displays a distinct French Renaissance architecture.", 'Francis I and Charles V, Holy Roman Emperor made peace at the Truce of Nice in 1538. Francis actually refused to meet Charles in person, and the treaty was signed in separate rooms.', 'Francis I at the Battle of Marignano', 'Detail of a tapestry depicting the Battle of Pavia, woven from a cartoon by Bernard van Orley (c. 1531)', 'The voyage of Giovanni da Verrazzano in 1524', 'An example of the Dieppe maps showing Sumatra. Nicholas Vallard, 1547.', 'Francis I (left) and Suleiman the Magnificent (right) initiated a Franco-Ottoman alliance. Both were separately painted by Titian circa 1530.', 'The Ordinance of Villers-Cotterêts in August 1539 prescribed the use of French in official documents.', 'Massacre of Mérindol in 1545', "Grand culverin of Francis I, with his emblem and motto. A gift to his Ottoman allies recovered in Algiers in 1830. Musée de l'Armée.", 'King of the House of Valo ...

# %%
print(r02.json()['query']['pages']['50012']['cirrusbuilddoc']['display_title'])
# Out:
# None

# %% [markdown]
# ### 3. prop = cirruscompsuggestbuilddoc
# **Note:**
# - this returns useful results:
#     - score:
#         - an indicator directly correlated with the popularity of a page
#         - in r03.json()['query']['pages']['50012']['cirruscompsuggestbuilddoc']['50012t']['score_explanation']['value']

# %%
params = {'titles': 'Francis_I_of_France',
          'action': 'query',
          'format': 'json',
          'prop': 'cirruscompsuggestbuilddoc'}

r03 = requests.get(url = URL, headers = HEADERS, params = params)
r03.status_code
# Out:
# 200

# %%
r03.json()
# Out:
# {'batchcomplete': '',
#  'query': {'normalized': [{'from': 'Francis_I_of_France',
#     'to': 'Francis I of France'}],
#   'pages': {'50012': {'pageid': 50012,
#     'ns': 0,
#     'title': 'Francis I of France',
#     'cirruscompsuggestbuilddoc': {'50012t': {'batch_id': 1612821052,
#       'source_doc_id': '50012',
#       'target_title': {'title': 'Francis I of France', 'namespace': 0},
#       'suggest': {'input': ['Francis I of France',
#         'Francis I of france',
#         'Francois I of France',
#         'Francis 1 of France',
#         'Francis i of france'],
#        'weight': 4335931},
#       'suggest-stop': {'input': ['Francis I of France',
#         'Francis I of france',
#         'Francois I of France',
#         'Francis 1 of France',
#         'Francis i of france'],
#        'weight': 4335931},
#       'score_explanation': {'value': 4335931,
#        'description': 'Convert to an integer score: 0.4335931843777 * 10000000',
#        'details': [{'value': 0.43359318437769756,
#          'description': 'Weighted sum of doc quality score and popularity',
#          'details': {'popularity_weighted': {'value': 0.13050350884857076,
#            'description': 'popularity*weight/total; popularity = 0.45676228097, weight = 0.4, total = 1.4',
#            'details': {'popularity': {'value': 0.4567622809699976,
#              'description': 'log(1+(min(popularity,popularity_max)*max_docs), pop_logbase); popularity = 5.5469153185451E-6, popularity_max = 0.0004, max_docs = 6245777, pop_logbase = 2499.3108',
#              'details': {'pop_logbase': {'value': 2499.3108,
#                'description': '1+popularity_max*max_docs; popularity_max = 0.0004, max_docs = 6245777'}}}}},
#           'page_quality': {'value': 0.3030896755291268,
#            'description': 'quality*weight/total; quality = 0.42432554574078, weight = 1, total = 1.4',
#            'details': {'quality': {'value': 0.42432554574077747,
#              'description': 'weighted sum of document metadata',
#              'details': {'incoming_links_weighted': {'value': 0.003113424528656246,
#                'description': 'incoming_links_normalized*weight/total; incoming_links_normalized = 0.0057079449692031, weight = 0.6, total = 1.1',
#                'details': {'incoming_links_normalized': {'value': 0.005707944969203118,
#                  'description': 'log₂((min(incoming_links,max)/max)+1); incoming_links = 2476, max = 624577'}}},
#               'external_links_weighted': {'value': 0.09090909090909091,
#                'description': 'external_links_count_normalized*weight/total; external_links_count_normalized = 1, weight = 0.1, total = 1.1',
#                'details': {'external_links_count_normalized': {'value': 1,
#                  'description': 'min(external_links_count,max)/max; external_links_count = 60, max = 20'}}},
#               'text_bytes_weighted': {'value': 0.09090909090909091,
#                'description': 'text_bytes_normalized*weight/total; text_bytes_normalized = 1, weight = 0.1, total = 1.1',
#                'details': {'text_bytes_normalized': {'value': 1,
#                  'description': 'log₂((min(text_bytes,max)/max)+1); text_bytes = 52547, max = 50000'}}},
#               'headings_count_weighted': {'value': 0.16363636363636364,
#                'description': 'headings_count_normalized*weight/total; headings_count_normalized = 0.9, weight = 0.2, total = 1.1',
#                'details': {'headings_count_normalized': {'value': 0.9,
#                  'description': 'min(headings_count,max)/max; headings_count = 18, max = 20'}}},
#               'redirects_count_weighted': {'value': 0.07575757575757576,
#                'description': 'redirects_count_normalized*weight/total; redirects_count_normalized = 0.83333333333333, weight = 0.1, total = 1.1',
#                'details': {'redirects_count_normalized': {'value': 0.8333333333333334,
#                  'description': 'min(redirects_count,max)/max; redirects_count = 25, max = 30'}}}}}}}}}]}},
#      '50012r': {'batch_id': 1612821052,
#       'source_doc_id': '50012',
#       'target_title': {'title': 'Francis I of France', 'namespace': 0},
#       'suggest': {'input': ['François I of France',
#         'Francis I, King of France',
#         'François I',
#         'Francois I',
#         'King François I',
#         'François Ier',
#         'King of France François I',
#         'François 1er',
#         'Francois 1er',
#         'King Francois I',
#         'Francois Ier',
#         'King of France Francois I',
#         'King Francis I of France',
#         'François Premier',
#         'Francois Premier',
#         "François d'Angoulême",
#         "Francois d'Angouleme",
#         "D'Angoulême",
#         "D'Angouleme",
#         'François I de France',
#         'Francis, Count of Angoulême'],
#        'weight': 433593},
#       'suggest-stop': {'input': ['François I of France',
#         'Francis I, King of France',
#         'François I',
#         'Francois I',
#         'King François I',
#         'François Ier',
#         'King of France François I',
#         'François 1er',
#         'Francois 1er',
#         'King Francois I',
#         'Francois Ier',
#         'King of France Francois I',
#         'King Francis I of France',
#         'François Premier',
#         'Francois Premier',
#         "François d'Angoulême",
#         "Francois d'Angouleme",
#         "D'Angoulême",
#         "D'Angouleme",
#         'François I de France',
#         'Francis, Count of Angoulême'],
#        'weight': 433593},
#       'score_explanation': {'value': 4335931,
#        'description': 'Convert to an integer score: 0.4335931843777 * 10000000',
#        'details': [{'value': 0.43359318437769756,
#          'description': 'Weighted sum of doc quality score and popularity',
#          'details': {'popularity_weighted': {'value': 0.13050350884857076,
#            'description': 'popularity*weight/total; popularity = 0.45676228097, weight = 0.4, total = 1.4',
#            'details': {'popularity': {'value': 0.4567622809699976,
#              'description': 'log(1+(min(popularity,popularity_max)*max_docs), pop_logbase); popularity = 5.5469153185451E-6, popularity_max = 0.0004, max_docs = 6245777, pop_logbase = 2499.3108',
#              'details': {'pop_logbase': {'value': 2499.3108,
#                'description': '1+popularity_max*max_docs; popularity_max = 0.0004, max_docs = 6245777'}}}}},
#           'page_quality': {'value': 0.3030896755291268,
#            'description': 'quality*weight/total; quality = 0.42432554574078, weight = 1, total = 1.4',
#            'details': {'quality': {'value': 0.42432554574077747,
#              'description': 'weighted sum of document metadata',
#              'details': {'incoming_links_weighted': {'value': 0.003113424528656246,
#                'description': 'incoming_links_normalized*weight/total; incoming_links_normalized = 0.0057079449692031, weight = 0.6, total = 1.1',
#                'details': {'incoming_links_normalized': {'value': 0.005707944969203118,
#                  'description': 'log₂((min(incoming_links,max)/max)+1); incoming_links = 2476, max = 624577'}}},
#               'external_links_weighted': {'value': 0.09090909090909091,
#                'description': 'external_links_count_normalized*weight/total; external_links_count_normalized = 1, weight = 0.1, total = 1.1',
#                'details': {'external_links_count_normalized': {'value': 1,
#                  'description': 'min(external_links_count,max)/max; external_links_count = 60, max = 20'}}},
#               'text_bytes_weighted': {'value': 0.09090909090909091,
#                'description': 'text_bytes_normalized*weight/total; text_bytes_normalized = 1, weight = 0.1, total = 1.1',
#                'details': {'text_bytes_normalized': {'value': 1,
#                  'description': 'log₂((min(text_bytes,max)/max)+1); text_bytes = 52547, max = 50000'}}},
#               'headings_count_weighted': {'value': 0.16363636363636364,
#                'description': 'headings_count_normalized*weight/total; headings_count_normalized = 0.9, weight = 0.2, total = 1.1',
#                'details': {'headings_count_normalized': {'value': 0.9,
#                  'description': 'min(headings_count,max)/max; headings_count = 18, max = 20'}}},
#               'redirects_count_weighted': {'value': 0.07575757575757576,
#                'description': 'redirects_count_normalized*weight/total; redirects_count_normalized = 0.83333333333333, weight = 0.1, total = 1.1',
#                'details': {'redirects_count_normalized': {'value': 0.8333333333333334,
#                  'description': 'min(redirects_count,max)/max; redirects_count = 25, max = 30'}}}}}}}}}]}}}}}}}

# %%
print(r03.json().keys())
print(r03.json()['query'].keys())
print(r03.json()['query']['pages'].keys())
print(r03.json()['query']['pages']['50012'].keys())
print(r03.json()['query']['pages']['50012']['cirruscompsuggestbuilddoc'].keys())
print(r03.json()['query']['pages']['50012']['cirruscompsuggestbuilddoc']['50012t'].keys())
print(r03.json()['query']['pages']['50012']['cirruscompsuggestbuilddoc']['50012r'].keys())
print(r03.json()['query']['pages']['50012']['cirruscompsuggestbuilddoc']['50012r']['suggest'].keys())
print(r03.json()['query']['pages']['50012']['cirruscompsuggestbuilddoc']['50012r']['suggest']['weight'])
print(r03.json()['query']['pages']['50012']['cirruscompsuggestbuilddoc']['50012t']['score_explanation'].keys())
print(r03.json()['query']['pages']['50012']['cirruscompsuggestbuilddoc']['50012t']['score_explanation']['value'])
print(r03.json()['query']['pages']['50012']['cirruscompsuggestbuilddoc']['50012t']['score_explanation']['description'])
print(r03.json()['query']['pages']['50012']['cirruscompsuggestbuilddoc']['50012t']['score_explanation']['details'])
# Out:
# dict_keys(['batchcomplete', 'query'])
# dict_keys(['normalized', 'pages'])
# dict_keys(['50012'])
# dict_keys(['pageid', 'ns', 'title', 'cirruscompsuggestbuilddoc'])
# dict_keys(['50012t', '50012r'])
# dict_keys(['batch_id', 'source_doc_id', 'target_title', 'suggest', 'suggest-stop', 'score_explanation'])
# dict_keys(['batch_id', 'source_doc_id', 'target_title', 'suggest', 'suggest-stop', 'score_explanation'])
# dict_keys(['input', 'weight'])
# 433593
# dict_keys(['value', 'description', 'details'])
# 4335931
# Convert to an integer score: 0.4335931843777 * 10000000
# [{'value': 0.43359318437769756, 'description': 'Weighted sum of doc quality score and popularity', 'details': {'popularity_weighted': {'value': 0.13050350884857076, 'description': 'popularity*weight/total; popularity = 0.45676228097, weight = 0.4, total = 1.4', 'details': {'popularity': {'value': 0.4567622809699976, 'description': 'log(1+(min(popularity,popularity_max)*max_docs), pop_logbase); popularity = 5.5469153185451E-6, popularity_max = 0.0004, max_docs = 6245777, pop_logbase = 2499.3108', 'details': {'pop_logbase': {'value': 2499.3108, 'description': '1+popularity_max*max_docs; popularity_max = 0.0004, max_docs = 6245777'}}}}}, 'page_quality': {'value': 0.3030896755291268, 'description': 'quality*weight/total; quality = 0.42432554574078, weight = 1, total = 1.4', 'details': {'quality': {'value': 0.42432554574077747, 'description': 'weighted sum of document metadata', 'details': {'incoming_links_weighted': {'value': 0.003113424528656246, 'description': 'incoming_links_normalized*weight/total; incoming_links_normalized = 0.0057079449692031, weight = 0.6, total = 1.1', 'details': {'incoming_links_normalized': {'value': 0.005707944969203118, 'description': 'log₂((min(incoming_links,max)/max)+1); incoming_links = 2476, max = 624577'}}}, 'external_links_weighted': {'value': 0.09090909090909091, 'description': 'external_links_count_normalized*weight/total; external_links_count_normalized = 1, weight = 0.1, total = 1.1', 'details': {'external_links_count_normalized': {'value': 1, 'description': 'min(external_links_count,max)/max; external_links_count = 60, max = 20'}}}, 'text_bytes_weighted': {'value': 0.09090909090909091, 'description': 'text_bytes_normalized*weight/total; text_bytes_normalized = 1, weight = 0.1, total = 1.1', 'details': {'text_bytes_normalized': {'value': 1, 'description': 'log₂((min(text_bytes,max)/max)+1); text_bytes = 52547, max = 50000'}}}, 'headings_count_weighted': {'value': 0.16363636363636364, 'description': 'headings_count_normalized*weight/total; headings_count_normalized = 0.9, weight = 0.2, total = 1.1', 'details': {'headings_count_normalized': {'value': 0.9, 'description': 'min(headings_count,max)/max; headings_count = 18, max = 20'}}}, 'redirects_count_weighted': {'value': 0.07575757575757576, 'description': 'redirects_count_normalized*weight/total; redirects_count_normalized = 0.83333333333333, weight = 0.1, total = 1.1', 'details': {'redirects_count_normalized': {'value': 0.8333333333333334, 'description': 'min(redirects_count,max)/max; redirects_count = 25, max = 30'}}}}}}}}}]

# %%
r03_score = r03.json()['query']['pages']['50012']['cirruscompsuggestbuilddoc']['50012t']['score_explanation']['details']
for score in r03_score:
    for k,v in score.items():
        if not isinstance(v, dict):
            print(k, ': ', v)
        else:
            print(k)
            for k_, v_ in v.items():
                print(f'\t{k_}: {v_}')
# Out:
# value :  0.43359318437769756
# description :  Weighted sum of doc quality score and popularity
# details
# 	popularity_weighted: {'value': 0.13050350884857076, 'description': 'popularity*weight/total; popularity = 0.45676228097, weight = 0.4, total = 1.4', 'details': {'popularity': {'value': 0.4567622809699976, 'description': 'log(1+(min(popularity,popularity_max)*max_docs), pop_logbase); popularity = 5.5469153185451E-6, popularity_max = 0.0004, max_docs = 6245777, pop_logbase = 2499.3108', 'details': {'pop_logbase': {'value': 2499.3108, 'description': '1+popularity_max*max_docs; popularity_max = 0.0004, max_docs = 6245777'}}}}}
# 	page_quality: {'value': 0.3030896755291268, 'description': 'quality*weight/total; quality = 0.42432554574078, weight = 1, total = 1.4', 'details': {'quality': {'value': 0.42432554574077747, 'description': 'weighted sum of document metadata', 'details': {'incoming_links_weighted': {'value': 0.003113424528656246, 'description': 'incoming_links_normalized*weight/total; incoming_links_normalized = 0.0057079449692031, weight = 0.6, total = 1.1', 'details': {'incoming_links_normalized': {'value': 0.005707944969203118, 'description': 'log₂((min(incoming_links,max)/max)+1); incoming_links = 2476, max = 624577'}}}, 'external_links_weighted': {'value': 0.09090909090909091, 'description': 'external_links_count_normalized*weight/total; external_links_count_normalized = 1, weight = 0.1, total = 1.1', 'details': {'external_links_count_normalized': {'value': 1, 'description': 'min(external_links_count,max)/max; external_links_count = 60, max = 20'}}}, 'text_bytes_weighted': {'value': 0.09090909090909091, 'description': 'text_bytes_normalized*weight/total; text_bytes_normalized = 1, weight = 0.1, total = 1.1', 'details': {'text_bytes_normalized': {'value': 1, 'description': 'log₂((min(text_bytes,max)/max)+1); text_bytes = 52547, max = 50000'}}}, 'headings_count_weighted': {'value': 0.16363636363636364, 'description': 'headings_count_normalized*weight/total; headings_count_normalized = 0.9, weight = 0.2, total = 1.1', 'details': {'headings_count_normalized': {'value': 0.9, 'description': 'min(headings_count,max)/max; headings_count = 18, max = 20'}}}, 'redirects_count_weighted': {'value': 0.07575757575757576, 'description': 'redirects_count_normalized*weight/total; redirects_count_normalized = 0.83333333333333, weight = 0.1, total = 1.1', 'details': {'redirects_count_normalized': {'value': 0.8333333333333334, 'description': 'min(redirects_count,max)/max; redirects_count = 25, max = 30'}}}}}}}

# %%
len(r03_score)
# Out:
# 1

# %% [markdown]
# ### 4. contributors
# **Note:** results returned by this query are not needed for this project

# %%
params = {'titles': 'Francis_I_of_France',
          'action': 'query',
          'format': 'json',
          'prop': 'contributors',
          'pclimit': 500}

r04 = requests.get(url = URL, headers = HEADERS, params = params)
r04.status_code
# Out:
# 200

# %%
r04.json()
# Out:
# {'batchcomplete': '',
#  'query': {'normalized': [{'from': 'Francis_I_of_France',
#     'to': 'Francis I of France'}],
#   'pages': {'50012': {'pageid': 50012,
#     'ns': 0,
#     'title': 'Francis I of France',
#     'anoncontributors': 357,
#     'contributors': [{'userid': 1623918, 'name': 'Jayron32'},
#      {'userid': 13791031, 'name': 'Frietjes'},
#      {'userid': 27015025, 'name': 'InternetArchiveBot'},
#      {'userid': 7611264, 'name': 'AnomieBOT'},
#      {'userid': 54809, 'name': 'Utcursch'},
#      {'userid': 11292982, 'name': 'EmausBot'},
#      {'userid': 1215485, 'name': 'Cydebot'},
#      {'userid': 2790592, 'name': 'KylieTastic'},
#      {'userid': 7903804, 'name': 'Citation bot'},
#      {'userid': 7167267, 'name': 'Tide rolls'},
#      {'userid': 1808194, 'name': 'TAnthony'},
#      {'userid': 13286072, 'name': 'ClueBot NG'},
#      {'userid': 1304678, 'name': 'Doug Weller'},
#      {'userid': 313197, 'name': 'Rjensen'},
#      {'userid': 1219, 'name': 'Deb'},
#      {'userid': 2092487, 'name': 'JaGa'},
#      {'userid': 31691822, 'name': 'KolbertBot'},
#      {'userid': 2304267, 'name': 'CommonsDelinker'},
#      {'userid': 9107368, 'name': 'Tobby72'},
#      {'userid': 5288432, 'name': 'Niceguyedc'},
#      {'userid': 73920, 'name': 'Canterbury Tail'},
#      {'userid': 17859592, 'name': 'Epicgenius'},
#      {'userid': 1544984, 'name': 'Dawnseeker2000'},
#      {'userid': 736651, 'name': 'Ohconfucius'},
#      {'userid': 1752894, 'name': 'Dsp13'},
#      {'userid': 1004750, 'name': 'Courcelles'},
#      {'userid': 16852310, 'name': 'Mr. Guye'},
#      {'userid': 8372814, 'name': 'Srich32977'},
#      {'userid': 589223, 'name': 'GoodDay'},
#      {'userid': 506179, 'name': 'Gilliam'},
#      {'userid': 1398, 'name': 'William Avery'},
#      {'userid': 13922443, 'name': 'Rezabot'},
#      {'userid': 10951369, 'name': 'Onel5969'},
#      {'userid': 19912518, 'name': 'Serial Number 54129'},
#      {'userid': 10239913, 'name': 'Gerda Arendt'},
#      {'userid': 280945, 'name': 'Arado'},
#      {'userid': 433328, 'name': 'SmackBot'},
#      {'userid': 4928500, 'name': 'ClueBot'},
#      {'userid': 203434, 'name': 'Rjwilmsi'},
#      {'userid': 113357, 'name': 'Nsaa'},
#      {'userid': 7178666, 'name': 'Lightbot'},
#      {'userid': 7328338, 'name': 'Yobot'},
#      {'userid': 1862829, 'name': 'Magioladitis'},
#      {'userid': 6569922, 'name': 'Addbot'},
#      {'userid': 88026, 'name': 'Bender235'},
#      {'userid': 24420788, 'name': 'KasparBot'},
#      {'userid': 1382933, 'name': 'PKT'},
#      {'userid': 5635510, 'name': 'SpikeToronto'},
#      {'userid': 314721, 'name': 'Howcheng'},
#      {'userid': 18663209, 'name': 'ArmbrustBot'},
#      {'userid': 82432, 'name': 'Discospinster'},
#      {'userid': 2287105, 'name': 'Birdie'},
#      {'userid': 2387872, 'name': 'DrKay'},
#      {'userid': 6334945, 'name': 'Facts707'},
#      {'userid': 6959733, 'name': 'Glane23'},
#      {'userid': 361935, 'name': 'Laszlo Panaflex'},
#      {'userid': 14965160, 'name': 'Marcocapelle'},
#      {'userid': 508734, 'name': 'Hmains'},
#      {'userid': 7314633, 'name': "Cote d'Azur"},
#      {'userid': 675360, 'name': 'Bigturtle'},
#      {'userid': 4971583, 'name': 'Clivemacd'},
#      {'userid': 203786, 'name': 'Tim!'},
#      {'userid': 90542, 'name': 'Furius'},
#      {'userid': 7007500, 'name': 'Favonian'},
#      {'userid': 372, 'name': 'Eclecticology'},
#      {'userid': 1591, 'name': 'SimonP'},
#      {'userid': 70142, 'name': 'Ukexpat'},
#      {'userid': 2654847, 'name': 'AntiSpamBot'},
#      {'userid': 29231347, 'name': 'Debiit'},
#      {'userid': 8066546, 'name': 'Xqbot'},
#      {'userid': 11555324, 'name': 'GoingBatty'},
#      {'userid': 1358233, 'name': 'Robert.Allen'},
#      {'userid': 728889, 'name': 'Bejnar'},
#      {'userid': 82835, 'name': 'Rich Farmbrough'},
#      {'userid': 7852030, 'name': 'Materialscientist'},
#      {'userid': 10996774, 'name': 'RjwilmsiBot'},
#      {'userid': 14508071, 'name': 'BG19bot'},
#      {'userid': 30707369, 'name': 'Magic links bot'},
#      {'userid': 2300502, 'name': "R'n'B"},
#      {'userid': 917223, 'name': 'Dl2000'},
#      {'userid': 14909828, 'name': 'LouisAlain'},
#      {'userid': 91088, 'name': 'Ylee'},
#      {'userid': 24812038, 'name': 'JJMC89'},
#      {'userid': 31706, 'name': 'Auric'},
#      {'userid': 470788, 'name': 'Verne Equinox'},
#      {'userid': 1574574, 'name': 'AntiVandalBot'},
#      {'userid': 12436806, 'name': 'Darthkenobi0'},
#      {'userid': 16228717, 'name': 'Cloptonson'},
#      {'userid': 33566, 'name': 'JackofOz'},
#      {'userid': 32762897, 'name': 'Maximajorian Viridio'},
#      {'userid': 428795, 'name': 'Attilios'},
#      {'userid': 2038644, 'name': 'Dirac66'},
#      {'userid': 2731577, 'name': 'Kansas Bear'},
#      {'userid': 21621158, 'name': 'Sigehelmus'},
#      {'userid': 653982, 'name': 'Stevenmitchell'},
#      {'userid': 1865063, 'name': 'Connormah'},
#      {'userid': 39755, 'name': 'Flordeneu'},
#      {'userid': 214542, 'name': 'Funnyhat'},
#      {'userid': 31083192, 'name': 'Hrodvarsson'},
#      {'userid': 6912407, 'name': 'Download'},
#      {'userid': 9021902, 'name': 'FrescoBot'},
#      {'userid': 9676078, 'name': 'I dream of horses'},
#      {'userid': 6488475, 'name': 'Surtsicna'},
#      {'userid': 24496035, 'name': 'DivermanAU'},
#      {'userid': 159678, 'name': 'Woohookitty'},
#      {'userid': 16460235, 'name': 'Khazar2'},
#      {'userid': 332841, 'name': 'Tony1'},
#      {'userid': 2625968, 'name': 'Balthazarduju'},
#      {'userid': 259798, 'name': 'Chobot'},
#      {'userid': 31541467, 'name': 'Векочел'},
#      {'userid': 12744454, 'name': 'Donner60'},
#      {'userid': 27823944, 'name': 'GreenC bot'},
#      {'userid': 609725, 'name': 'Tamfang'},
#      {'userid': 16333418, 'name': 'ChrisGualtieri'},
#      {'userid': 937705, 'name': 'Iridescent'},
#      {'userid': 7580, 'name': 'Ahoerstemeier'},
#      {'userid': 2198658, 'name': 'MartinBot'},
#      {'userid': 92203, 'name': 'El C'},
#      {'userid': 31910160, 'name': 'MinorEnglishMajor'},
#      {'userid': 12978, 'name': 'Charles Matthews'},
#      {'userid': 5402993, 'name': 'Auntof6'},
#      {'userid': 12824384, 'name': 'Chewings72'},
#      {'userid': 11969601, 'name': 'ZéroBot'},
#      {'userid': 3138265, 'name': 'WOSlinker'},
#      {'userid': 1108604, 'name': 'Eric'},
#      {'userid': 5894, 'name': 'Gabbe'},
#      {'userid': 12109580, 'name': 'Jenks24'},
#      {'userid': 32493339, 'name': 'Go-Chlodio'},
#      {'userid': 55876, 'name': 'Opera hat'},
#      {'userid': 7320905, 'name': 'Luckas-bot'},
#      {'userid': 3035831, 'name': 'VolkovBot'},
#      {'userid': 690391, 'name': 'Dreadstar'},
#      {'userid': 3171782, 'name': 'TXiKiBoT'},
#      {'userid': 6455386, 'name': 'Johnkatz1972'},
#      {'userid': 11987994, 'name': 'John Cline'},
#      {'userid': 24198, 'name': 'Dimadick'},
#      {'userid': 125787, 'name': 'Ricky81682'},
#      {'userid': 5499713, 'name': 'Excirial'},
#      {'userid': 17114440, 'name': 'TwoTwoHello'},
#      {'userid': 107440, 'name': 'Nk'},
#      {'userid': 8272776, 'name': 'Sodacan'},
#      {'userid': 4005189, 'name': 'SieBot'},
#      {'userid': 97951, 'name': 'Bobo192'},
#      {'userid': 4796325, 'name': 'Randy Kryn'},
#      {'userid': 15183719, 'name': 'Iamthecheese44'},
#      {'userid': 842922, 'name': 'JHunterJ'},
#      {'userid': 301395, 'name': 'NawlinWiki'},
#      {'userid': 6326132, 'name': 'Mitch Ames'},
#      {'userid': 64875, 'name': 'Icairns'},
#      {'userid': 2366721, 'name': 'Shellwood'},
#      {'userid': 1179038, 'name': 'Richard Keatinge'},
#      {'userid': 16710, 'name': 'Tpbradbury'},
#      {'userid': 25648618, 'name': 'Skjölker'},
#      {'userid': 3479822, 'name': 'BotKung'},
#      {'userid': 244946, 'name': 'Str1977'},
#      {'userid': 49920, 'name': 'Macrakis'},
#      {'userid': 4626, 'name': 'Michael Hardy'},
#      {'userid': 19500131, 'name': 'UY Scuti'},
#      {'userid': 277086, 'name': 'Spleodrach'},
#      {'userid': 5327619, 'name': 'P. S. Burton'},
#      {'userid': 9385, 'name': 'Error'},
#      {'userid': 6127189, 'name': 'Boleyn'},
#      {'userid': 9887272, 'name': 'Bmclaughlin9'},
#      {'userid': 10512, 'name': 'John K'},
#      {'userid': 10440891, 'name': 'Callanecc'},
#      {'userid': 228773, 'name': 'FlaBot'},
#      {'userid': 948536, 'name': 'Grblomerth'},
#      {'userid': 100426, 'name': 'Smalljim'},
#      {'userid': 8672553, 'name': 'AMPERIO'},
#      {'userid': 182902, 'name': 'Zzyzx11'},
#      {'userid': 15582606, 'name': 'Simonc30'},
#      {'userid': 11743424, 'name': 'Tommy2010'},
#      {'userid': 674008, 'name': 'Jwy'},
#      {'userid': 26398660, 'name': 'CLCStudent'},
#      {'userid': 21160672, 'name': 'M. Armando'},
#      {'userid': 10756337, 'name': 'Peacedance'},
#      {'userid': 203730, 'name': 'Angusmclellan'},
#      {'userid': 206678, 'name': 'Gryffindor'},
#      {'userid': 1725149, 'name': 'JAnDbot'},
#      {'userid': 1589971, 'name': 'Aldebaran69'},
#      {'userid': 5705, 'name': 'Dan Koehl'},
#      {'userid': 1009783, 'name': 'Adam sk'},
#      {'userid': 2, 'name': 'AxelBoldt'},
#      {'userid': 11406674, 'name': 'Look2See1'},
#      {'userid': 70570, 'name': 'Hardouin'},
#      {'userid': 74199, 'name': 'Esperant'},
#      {'userid': 25261, 'name': 'Robbot'},
#      {'userid': 1064243, 'name': 'JForget'},
#      {'userid': 9333421, 'name': 'Masterknighted'},
#      {'userid': 2206920, 'name': 'Grandia01'},
#      {'userid': 360736, 'name': 'Pil56'},
#      {'userid': 14462949, 'name': 'Regulov'},
#      {'userid': 2206974, 'name': 'STBot'},
#      {'userid': 4503208, 'name': 'Dallyripple'},
#      {'userid': 7185797, 'name': 'Kiril Simeonovski'},
#      {'userid': 3236687, 'name': 'Technopat'},
#      {'userid': 20957809, 'name': 'WikiOriginal-9'},
#      {'userid': 25497795, 'name': 'Jaylouwalk'},
#      {'userid': 20483999, 'name': 'Monkbot'},
#      {'userid': 28078513, 'name': 'Celia Homeford'},
#      {'userid': 14572732, 'name': 'JeBonSer'},
#      {'userid': 1879647, 'name': 'VoABot II'},
#      {'userid': 2691489, 'name': 'NewEnglandYankee'},
#      {'userid': 258000, 'name': 'King of Hearts'},
#      {'userid': 452631, 'name': 'KnowledgeOfSelf'},
#      {'userid': 3813685, 'name': 'AlleborgoBot'},
#      {'userid': 28830, 'name': 'Naddy'},
#      {'userid': 36352, 'name': 'Alan Liefting'},
#      {'userid': 22369145, 'name': 'Guise'},
#      {'userid': 135639, 'name': 'Ksnow'},
#      {'userid': 210350, 'name': 'BlueMoonlet'},
#      {'userid': 3378, 'name': 'Montrealais'},
#      {'userid': 74131, 'name': 'Lacrimosus'},
#      {'userid': 1292390, 'name': 'Amandajm'},
#      {'userid': 22096151, 'name': 'TJH2018'},
#      {'userid': 273237, 'name': 'RobotE'},
#      {'userid': 271058, 'name': 'YurikBot'},
#      {'userid': 3808, 'name': 'Olivier'},
#      {'userid': 33103, 'name': 'Hadal'},
#      {'userid': 17725786, 'name': 'Blaue Max'},
#      {'userid': 2901026, 'name': 'Inwind'},
#      {'userid': 196471, 'name': 'Qwertyus'},
#      {'userid': 5511, 'name': 'Jtdirl'},
#      {'userid': 87110, 'name': 'Pavel Vozenilek'},
#      {'userid': 6549, 'name': 'IZAK'},
#      {'userid': 397664, 'name': 'Curpsbot-unicodify'},
#      {'userid': 1130387, 'name': 'ThreeBlindMice'},
#      {'userid': 3891047, 'name': 'EmxBot'},
#      {'userid': 15935372, 'name': 'Vvven'},
#      {'userid': 6192846, 'name': 'RogDel'},
#      {'userid': 557976, 'name': 'Stevage'},
#      {'userid': 6917606, 'name': 'LaaknorBot'},
#      {'userid': 3029314, 'name': 'Caspian blue'},
#      {'userid': 18104, 'name': 'Whaleyland'},
#      {'userid': 6216240, 'name': 'Wertuose'},
#      {'userid': 363693, 'name': 'Iamvered'},
#      {'userid': 8578431, 'name': 'SassoBot'},
#      {'userid': 94806, 'name': 'RoyBoy'},
#      {'userid': 20198732, 'name': 'Loose eel'},
#      {'userid': 2048686, 'name': 'Allstarecho'},
#      {'userid': 1892329, 'name': 'Dentren'},
#      {'userid': 4704783, 'name': 'Katzenfrucht'},
#      {'userid': 185089, 'name': 'Fxer'},
#      {'userid': 170884, 'name': 'Jeff3000'},
#      {'userid': 1525317, 'name': 'Lunamaria'},
#      {'userid': 4414625, 'name': 'Oxymoron83'},
#      {'userid': 198939, 'name': 'JIP'},
#      {'userid': 62594, 'name': 'Gauss'},
#      {'userid': 10840240, 'name': 'Lady Meg'},
#      {'userid': 35352892, 'name': 'ProcrastinatingHistorian'},
#      {'userid': 3336329, 'name': 'Piperh'},
#      {'userid': 7390477, 'name': 'Amirobot'},
#      {'userid': 3362, 'name': 'Isis~enwiki'},
#      {'userid': 14017497, 'name': 'Peaceingalaxy'},
#      {'userid': 379519, 'name': 'NYArtsnWords'},
#      {'userid': 4357109, 'name': 'Monegasque'},
#      {'userid': 73985, 'name': 'ELApro'},
#      {'userid': 132224, 'name': 'Zeborah'},
#      {'userid': 7713040, 'name': 'JackieBot'},
#      {'userid': 733, 'name': 'JeLuF'},
#      {'userid': 133241, 'name': 'Mysdaao'},
#      {'userid': 9089258, 'name': 'LucienBOT'},
#      {'userid': 479849, 'name': 'Popo le Chien'},
#      {'userid': 7029070, 'name': 'LinkFA-Bot'},
#      {'userid': 321855, 'name': 'Stijn Calle'},
#      {'userid': 1128843, 'name': 'Renamed user abcedarium'},
#      {'userid': 29, 'name': 'JHK'},
#      {'userid': 957447, 'name': 'Joseph Solis in Australia'},
#      {'userid': 602293, 'name': 'NYKevin'},
#      {'userid': 7614868, 'name': 'KDS4444'},
#      {'userid': 21492, 'name': 'Wetman'},
#      {'userid': 8316, 'name': 'CatherineMunro'},
#      {'userid': 1302553, 'name': 'DavidRF'},
#      {'userid': 2964546, 'name': 'Idioma-bot'},
#      {'userid': 20371397, 'name': 'CatcherStorm'},
#      {'userid': 125791, 'name': 'Craigy144'},
#      {'userid': 18034, 'name': 'Taxman'},
#      {'userid': 7417578, 'name': "The Emperor's New Spy"},
#      {'userid': 4937482, 'name': 'LAX'},
#      {'userid': 15009458, 'name': 'Solomon7968'},
#      {'userid': 24872841, 'name': 'Adert'},
#      {'userid': 33610286, 'name': 'KingofGangsters'},
#      {'userid': 34619835, 'name': 'Brwz'},
#      {'userid': 8453292, 'name': 'GrouchoBot'},
#      {'userid': 62, 'name': 'Mav'},
#      {'userid': 69025, 'name': 'Marcus2'},
#      {'userid': 1461809, 'name': 'Cwtyler'},
#      {'userid': 22307207, 'name': 'ArisMethymna'},
#      {'userid': 838239, 'name': 'RandomCritic'},
#      {'userid': 59, 'name': 'Vicki Rosenzweig'},
#      {'userid': 83, 'name': 'Tarquin'},
#      {'userid': 117331, 'name': 'Zachlipton'},
#      {'userid': 6800840, 'name': 'Jeanne boleyn'},
#      {'userid': 240401, 'name': 'Shadow007'},
#      {'userid': 6687298, 'name': 'Queenmomcat'},
#      {'userid': 743015, 'name': 'SashatoBot'},
#      {'userid': 15648048, 'name': 'Polmandc'},
#      {'userid': 384797, 'name': '2fort5r'},
#      {'userid': 149824, 'name': 'John W. Kennedy'},
#      {'userid': 4430968, 'name': 'AngelOfSadness'},
#      {'userid': 373051, 'name': 'Sotakeit'},
#      {'userid': 7118326, 'name': 'Numbo3-bot'},
#      {'userid': 513372, 'name': 'Daysleeper47'},
#      {'userid': 12163449, 'name': 'Anir1uph'},
#      {'userid': 17456, 'name': 'Itai'},
#      {'userid': 3258344, 'name': 'Rei-bot'},
#      {'userid': 16924, 'name': 'Maximus Rex'},
#      {'userid': 18, 'name': 'MichaelTinkler'},
#      {'userid': 166, 'name': '-- April'},
#      {'userid': 3376, 'name': 'DW'},
#      {'userid': 7520, 'name': 'ArnoLagrange'},
#      {'userid': 8201, 'name': 'Muriel Gottrop~enwiki'},
#      {'userid': 9938, 'name': 'Rotem Dan'},
#      {'userid': 10481, 'name': 'Rl'},
#      {'userid': 10915, 'name': 'Raven in Orbit'},
#      {'userid': 11437, 'name': 'Marc Tobias Wenzel~enwiki'},
#      {'userid': 15941, 'name': 'Timc'},
#      {'userid': 16603, 'name': 'Maya~enwiki'},
#      {'userid': 20178, 'name': 'Lord Emsworth'},
#      {'userid': 33312, 'name': 'Modeha'},
#      {'userid': 35295, 'name': 'Lzur'},
#      {'userid': 38472, 'name': 'Pmaguire'},
#      {'userid': 42065, 'name': 'Hasafienda'},
#      {'userid': 48150, 'name': 'Yekrats'},
#      {'userid': 48296, 'name': 'Per Honor et Gloria'},
#      {'userid': 50242, 'name': 'JillandJack'},
#      {'userid': 78345, 'name': 'AliveFreeHappy'},
#      {'userid': 97097, 'name': 'Bill Thayer'},
#      {'userid': 121422, 'name': 'StanZegel'},
#      {'userid': 128763, 'name': 'Oev21'},
#      {'userid': 142444, 'name': 'Sciurinæ'},
#      {'userid': 170381, 'name': 'JeremyA'},
#      {'userid': 175520, 'name': 'Grika'},
#      {'userid': 187401, 'name': 'Formeruser0910'},
#      {'userid': 206999, 'name': 'Carl Logan'},
#      {'userid': 226984, 'name': 'Jeremie'},
#      {'userid': 239513, 'name': 'Caesarscott'},
#      {'userid': 245557, 'name': 'Enon'},
#      {'userid': 270244, 'name': 'Roboto de Ajvol'},
#      {'userid': 284384, 'name': 'Hede2000'},
#      {'userid': 292168, 'name': 'Akamad'},
#      {'userid': 308697, 'name': 'Jgrantduff'},
#      {'userid': 314067, 'name': 'Aristotelle'},
#      {'userid': 317522, 'name': 'Windsamurai'},
#      {'userid': 322894, 'name': 'Cenedi'},
#      {'userid': 406711, 'name': 'HansM'},
#      {'userid': 412498, 'name': 'Asterion'},
#      {'userid': 425440, 'name': 'BomBom'},
#      {'userid': 425865, 'name': 'Wai Hong'},
#      {'userid': 429452, 'name': 'Phinnaeus'},
#      {'userid': 451977, 'name': 'Jscherer42'},
#      {'userid': 467891, 'name': 'TFMcQ'},
#      {'userid': 504493, 'name': 'Marktreut'},
#      {'userid': 524424, 'name': 'Saros136'},
#      {'userid': 602245, 'name': 'Yaf'},
#      {'userid': 681072, 'name': 'Jared'},
#      {'userid': 695292, 'name': 'KRBN'},
#      {'userid': 720532, 'name': 'Le baron'},
#      {'userid': 731640, 'name': 'Dannywalker'},
#      {'userid': 746380, 'name': 'Cedric du Zob'},
#      {'userid': 768042, 'name': 'Rayaxe'},
#      {'userid': 788567, 'name': 'Macronia'},
#      {'userid': 1085593, 'name': 'Csoto'},
#      {'userid': 1186399, 'name': 'Sketchglasses'},
#      {'userid': 1306859, 'name': 'Donmillsbridge'},
#      {'userid': 1477992, 'name': 'Suedois'},
#      {'userid': 1673192, 'name': 'Rcduggan'},
#      {'userid': 1680593, 'name': 'Camptown'},
#      {'userid': 1680917, 'name': 'Pconlon'},
#      {'userid': 1743314, 'name': 'Magnouloux'},
#      {'userid': 1756151, 'name': 'Inbetweener'},
#      {'userid': 2027736, 'name': 'Georgejunker~enwiki'},
#      {'userid': 2299784, 'name': 'Kostisl'},
#      {'userid': 2312724, 'name': 'Shuppiluliuma'},
#      {'userid': 2528034, 'name': 'Gzkn'},
#      {'userid': 2541953, 'name': 'Elchimba'},
#      {'userid': 2553375, 'name': 'PaoloMarcenaro'},
#      {'userid': 2657653, 'name': 'HustonJMarble'},
#      {'userid': 2796964, 'name': 'STBotD'},
#      {'userid': 2956901, 'name': 'DemonicInfluence'},
#      {'userid': 3096998, 'name': 'AlnoktaBOT'},
#      {'userid': 3105794, 'name': "Lear's Fool"},
#      {'userid': 3131613, 'name': 'Pendragon09'},
#      {'userid': 3217096, 'name': 'BertSen'},
#      {'userid': 3235016, 'name': 'Godingo'},
#      {'userid': 3236748, 'name': 'A4bot'},
#      {'userid': 3469596, 'name': 'BOBgoneunder13'},
#      {'userid': 3477151, 'name': 'Cremepuff222'},
#      {'userid': 3544204, 'name': 'Mimich'},
#      {'userid': 3608554, 'name': 'Itahist'},
#      {'userid': 3660796, 'name': 'FinnWiki'},
#      {'userid': 3793020, 'name': 'Eddie-ginnley'},
#      {'userid': 3965603, 'name': 'Frania Wisniewska'},
#      {'userid': 4150759, 'name': 'SE7'},
#      {'userid': 4244035, 'name': 'Ketone16'},
#      {'userid': 4322725, 'name': 'Somelazyartist'},
#      {'userid': 4377148, 'name': 'Robotchampion'},
#      {'userid': 4422330, 'name': 'Decoratrix'},
#      {'userid': 4536516, 'name': 'BenoniBot~enwiki'},
#      {'userid': 5306707, 'name': 'David Trochos'},
#      {'userid': 5376600, 'name': 'Markus man9'},
#      {'userid': 5384910, 'name': 'Jrwingfield'},
#      {'userid': 5457568, 'name': 'Ellanow'},
#      {'userid': 5620908, 'name': 'Mquinn8'},
#      {'userid': 5757174, 'name': 'Zwo~enwiki'},
#      {'userid': 5877666, 'name': 'La Pianista'},
#      {'userid': 5975252, 'name': 'Bashir100'},
#      {'userid': 6085077, 'name': 'Sunquanliangxiuhao'},
#      {'userid': 6170464, 'name': 'Matteao'},
#      {'userid': 6173459, 'name': 'Terry J. Carter'},
#      {'userid': 6484918, 'name': 'Thatguyflint'},
#      {'userid': 6827823, 'name': 'Feťour'},
#      {'userid': 7082942, 'name': 'The Quill'},
#      {'userid': 7091566, 'name': 'Sardur'},
#      {'userid': 7409846, 'name': 'WellsSouth'},
#      {'userid': 7777104, 'name': 'Kingpin13'},
#      {'userid': 8574593, 'name': 'RibotBOT'},
#      {'userid': 8579727, 'name': 'JhanCRUSH'},
#      {'userid': 8605902, 'name': 'Celticecho'},
#      {'userid': 8886066, 'name': 'Vlastimil Svoboda'},
#      {'userid': 9939443, 'name': 'SpaceFlight89'},
#      {'userid': 10548104, 'name': 'Chnou'},
#      {'userid': 10670169, 'name': 'Frankerer'},
#      {'userid': 11027086, 'name': 'VimalaNowlis'},
#      {'userid': 11386456, 'name': 'Immunize'},
#      {'userid': 11711625, 'name': 'Calthrina450'},
#      {'userid': 12308086, 'name': 'Ebrambot'},
#      {'userid': 12723813, 'name': 'Reigen'},
#      {'userid': 12792828, 'name': 'Sailsbystars'},
#      {'userid': 13384957, 'name': 'Alexcoldcasefan'},
#      {'userid': 13765403, 'name': 'Krshwunk'},
#      {'userid': 13781742, 'name': 'Bazuz'},
#      {'userid': 13924130, 'name': 'Pikrodafni'},
#      {'userid': 14665423, 'name': '2601andrew'},
#      {'userid': 14667234, 'name': 'PilgrimGT'},
#      {'userid': 14797524, 'name': 'Oratio Mundi'},
#      {'userid': 15527667, 'name': 'Ernio48'},
#      {'userid': 15635588, 'name': 'KennethSides'},
#      {'userid': 16096422, 'name': 'IrisFancier'},
#      {'userid': 17320126, 'name': 'Lequenne Gwendoline'},
#      {'userid': 17525773, 'name': 'HStrong'},
#      {'userid': 17692954, 'name': 'Nimetapoeg'},
#      {'userid': 17862855, 'name': 'Moagim'},
#      {'userid': 18122122, 'name': 'Lingzhi'},
#      {'userid': 18186387, 'name': 'Hsraatz'},
#      {'userid': 18455154, 'name': 'Penguins53'},
#      {'userid': 18772099, 'name': 'Oakenchips'},
#      {'userid': 18781437, 'name': 'Jbeck8924'},
#      {'userid': 18926583, 'name': 'Jesseka197'},
#      {'userid': 19606579, 'name': 'Ceiscoran'},
#      {'userid': 21157057, 'name': 'Chandlerwthomas'},
#      {'userid': 24312449, 'name': 'Aesthetics101'},
#      {'userid': 25124328, 'name': 'Therealeditor1234'},
#      {'userid': 25316322, 'name': 'Aharran'},
#      {'userid': 26141869, 'name': 'DowntonAbbeyFan'},
#      {'userid': 26449835, 'name': 'Rollingcontributor'},
#      {'userid': 29149387, 'name': 'Matthewn5'},
#      {'userid': 29356569, 'name': 'Alksdjrae'},
#      {'userid': 30038334, 'name': 'ORANSIGLOT'},
#      {'userid': 31424484, 'name': 'Sobreelazuldelmar'},
#      {'userid': 35936988, 'name': 'JJMC89 bot III'},
#      {'userid': 36874135, 'name': 'Manas of bhashik'},
#      {'userid': 37999332, 'name': 'DVD Vision'},
#      {'userid': 38905475, 'name': 'TheImaCow'},
#      {'userid': 39959165, 'name': 'Saturdayopen'}]}}}}

# %% [markdown]
# ### 5. extracts
# **Note:**
# - useful results:
#     - extract with param 'exintro' gives the first paragraphs of a page (before detailed sections begin). It's useful and easier to clean up than the results returned by prop cirrusbuilddoc
#     - r05_1.json()['query']['pages']['50012']['extract']

# %%
params = {'titles': 'Francis_I_of_France',
          'action': 'query',
          'format': 'json',
          'prop': 'extracts'}

r05 = requests.get(url = URL, headers = HEADERS, params = params)
r05.status_code
# Out:
# 200

# %%
r05.json()
# Out:
# {'batchcomplete': '',
#  'warnings': {'extracts': {'*': 'HTML may be malformed and/or unbalanced and may omit inline images. Use at your own risk. Known problems are listed at https://www.mediawiki.org/wiki/Special:MyLanguage/Extension:TextExtracts#Caveats.'}},
#  'query': {'normalized': [{'from': 'Francis_I_of_France',
#     'to': 'Francis I of France'}],
#   'pages': {'50012': {'pageid': 50012,
#     'ns': 0,
#     'title': 'Francis I of France',
#     'extract': '<p class="mw-empty-elt">\n</p>\n\n<p><b>Francis I</b> (French: <i lang="fr">François I<sup>er</sup></i>; Middle French: <i lang="frm">Francoys</i>; 12 September 1494 – 31 March 1547) was King of France from 1515 until his death in 1547. He was the son of Charles, Count of Angoulême, and Louise of Savoy. He succeeded his first cousin once removed Louis XII, who died without a son.\n</p><p>A prodigious patron of the arts, he promoted the emergent French Renaissance by attracting many Italian artists to work for him, including Leonardo da Vinci, who brought the <i>Mona Lisa</i> with him, which Francis had acquired. Francis\' reign saw important cultural changes with the growth of central power in France, the spread of humanism and Protestantism, and the beginning of French exploration of the New World. Jacques Cartier and others claimed lands in the Americas for France and paved the way for the expansion of the first French colonial empire.\n</p><p>For his role in the development and promotion of a standardized French language, he became known as <i>le Père et Restaurateur des Lettres</i> (the \'Father and Restorer of Letters\'). He was also known as <i>François au Grand Nez</i> (\'Francis of the Large Nose\'), the <i>Grand Colas</i>, and the <i>Roi-Chevalier</i> (the \'Knight-King\') for his personal involvement in the wars against his great rival Emperor Charles V, who was also King of Spain.\n</p><p>Following the policy of his predecessors, Francis continued the Italian Wars. The succession of Charles V to the Burgundian Netherlands, the throne of Spain, and his subsequent election as Holy Roman Emperor, meant that France was geographically encircled by the Habsburg monarchy. In his struggle against Imperial hegemony, Francis sought the support of Henry VIII of England at the Field of the Cloth of Gold. When this was unsuccessful, he formed a Franco-Ottoman alliance with the Muslim sultan Suleiman the Magnificent, a controversial move for a Christian king at the time.</p>\n\n\n<h2><span id="Early_life_and_accession">Early life and accession</span></h2>\n<p><b>Francis of Orléans</b> was born on 12 September 1494 at the Château de Cognac in the town of Cognac, which at that time lay in the province of Saintonge, a part of the Duchy of Aquitaine.  Today the town lies in the department of Charente.\n</p><p>Francis was the only son of Charles of Orléans, Count of Angoulême, and Louise of Savoy and a great-great-grandson of King Charles V of France. His family was not expected to inherit the throne, as his third cousin King Charles VIII was still young at the time of his birth, as was his father\'s cousin the Duke of Orléans, later King Louis XII. However, Charles VIII died childless in 1498 and was succeeded by Louis XII, who himself had no male heir. The Salic Law prevented women from inheriting the throne.  Therefore, the four-year-old Francis (who was already Count of Angoulême after the death of his own father two years earlier) became the heir presumptive to the throne of France in 1498 and was vested with the title of Duke of Valois.</p><p>In 1505, Louis XII, having fallen ill, ordered for his daughter Claude and Francis to be married immediately, but only through an assembly of nobles were the two engaged. Claude was heir presumptive to the Duchy of Brittany through her mother, Anne of Brittany. Following Anne\'s death, the marriage took place on 18 May 1514. On 1 January 1515, Louis died, and Francis inherited the throne. He was crowned King of France in the Cathedral of Reims on 25 January 1515, with Claude as his queen consort.</p>\n<h2><span id="Reign">Reign</span></h2>\n\n\n<p>As Francis was receiving his education, ideas emerging from the Italian Renaissance were influential in France. Some of his tutors, such as François Desmoulins de Rochefort (his Latin instructor, who later during the reign of Francis was named <i>Grand Aumônier de France</i>) and Christophe de Longueil (a Brabantian humanist), were ...

# %%
params = {'titles': 'Francis_I_of_France',
          'action': 'query',
          'format': 'json',
          'prop': 'extracts',
          'exintro': True}

r05_1 = requests.get(url = URL, headers = HEADERS, params = params)
r05_1.status_code
# Out:
# 200

# %%
r05_1.json()
# Out:
# {'batchcomplete': '',
#  'warnings': {'extracts': {'*': 'HTML may be malformed and/or unbalanced and may omit inline images. Use at your own risk. Known problems are listed at https://www.mediawiki.org/wiki/Special:MyLanguage/Extension:TextExtracts#Caveats.'}},
#  'query': {'normalized': [{'from': 'Francis_I_of_France',
#     'to': 'Francis I of France'}],
#   'pages': {'50012': {'pageid': 50012,
#     'ns': 0,
#     'title': 'Francis I of France',
#     'extract': '<p class="mw-empty-elt">\n</p>\n\n<p><b>Francis I</b> (French: <i lang="fr">François I<sup>er</sup></i>; Middle French: <i lang="frm">Francoys</i>; 12 September 1494 – 31 March 1547) was King of France from 1515 until his death in 1547. He was the son of Charles, Count of Angoulême, and Louise of Savoy. He succeeded his first cousin once removed Louis XII, who died without a son.\n</p><p>A prodigious patron of the arts, he promoted the emergent French Renaissance by attracting many Italian artists to work for him, including Leonardo da Vinci, who brought the <i>Mona Lisa</i> with him, which Francis had acquired. Francis\' reign saw important cultural changes with the growth of central power in France, the spread of humanism and Protestantism, and the beginning of French exploration of the New World. Jacques Cartier and others claimed lands in the Americas for France and paved the way for the expansion of the first French colonial empire.\n</p><p>For his role in the development and promotion of a standardized French language, he became known as <i>le Père et Restaurateur des Lettres</i> (the \'Father and Restorer of Letters\'). He was also known as <i>François au Grand Nez</i> (\'Francis of the Large Nose\'), the <i>Grand Colas</i>, and the <i>Roi-Chevalier</i> (the \'Knight-King\') for his personal involvement in the wars against his great rival Emperor Charles V, who was also King of Spain.\n</p><p>Following the policy of his predecessors, Francis continued the Italian Wars. The succession of Charles V to the Burgundian Netherlands, the throne of Spain, and his subsequent election as Holy Roman Emperor, meant that France was geographically encircled by the Habsburg monarchy. In his struggle against Imperial hegemony, Francis sought the support of Henry VIII of England at the Field of the Cloth of Gold. When this was unsuccessful, he formed a Franco-Ottoman alliance with the Muslim sultan Suleiman the Magnificent, a controversial move for a Christian king at the time.</p>'}}}}

# %%
r05_1.json().keys()
# Out:
# dict_keys(['batchcomplete', 'warnings', 'query'])

# %%
s05 = BeautifulSoup(r05_1.json()['query']['pages']['50012']['extract'])
s05.text
# Out:
# "\n\nFrancis I (French: François Ier; Middle French: Francoys; 12 September 1494 – 31 March 1547) was King of France from 1515 until his death in 1547. He was the son of Charles, Count of Angoulême, and Louise of Savoy. He succeeded his first cousin once removed Louis XII, who died without a son.\nA prodigious patron of the arts, he promoted the emergent French Renaissance by attracting many Italian artists to work for him, including Leonardo da Vinci, who brought the Mona Lisa with him, which Francis had acquired. Francis' reign saw important cultural changes with the growth of central power in France, the spread of humanism and Protestantism, and the beginning of French exploration of the New World. Jacques Cartier and others claimed lands in the Americas for France and paved the way for the expansion of the first French colonial empire.\nFor his role in the development and promotion of a standardized French language, he became known as le Père et Restaurateur des Lettres (the 'Father and Restorer of Letters'). He was also known as François au Grand Nez ('Francis of the Large Nose'), the Grand Colas, and the Roi-Chevalier (the 'Knight-King') for his personal involvement in the wars against his great rival Emperor Charles V, who was also King of Spain.\nFollowing the policy of his predecessors, Francis continued the Italian Wars. The succession of Charles V to the Burgundian Netherlands, the throne of Spain, and his subsequent election as Holy Roman Emperor, meant that France was geographically encircled by the Habsburg monarchy. In his struggle against Imperial hegemony, Francis sought the support of Henry VIII of England at the Field of the Cloth of Gold. When this was unsuccessful, he formed a Franco-Ottoman alliance with the Muslim sultan Suleiman the Magnificent, a controversial move for a Christian king at the time."

# %% [markdown]
# ### 6. info
# **Note:**
# - useful info:
#     - page size:
#         - r06.json()['query']['pages']['50012']['length']
#         - same data as text_bytes when prop=cirrusbuilddoc

# %%
params = {'titles': 'Francis_I_of_France',
          'action': 'query',
          'format': 'json',
          'prop': 'info'}

r06 = requests.get(url = URL, headers = HEADERS, params = params)
r06.status_code
# Out:
# 200

# %%
r06.json()
# Out:
# {'batchcomplete': '',
#  'query': {'normalized': [{'from': 'Francis_I_of_France',
#     'to': 'Francis I of France'}],
#   'pages': {'50012': {'pageid': 50012,
#     'ns': 0,
#     'title': 'Francis I of France',
#     'contentmodel': 'wikitext',
#     'pagelanguage': 'en',
#     'pagelanguagehtmlcode': 'en',
#     'pagelanguagedir': 'ltr',
#     'touched': '2021-02-08T00:05:26Z',
#     'lastrevid': 1005165190,
#     'length': 52547}}}}

# %%
print(r06.json()['query']['pages']['50012'].keys())
print(r06.json()['query']['pages']['50012']['length'])
# Out:
# dict_keys(['pageid', 'ns', 'title', 'contentmodel', 'pagelanguage', 'pagelanguagehtmlcode', 'pagelanguagedir', 'touched', 'lastrevid', 'length'])
# 52547

# %% [markdown]
# ### 7. pageimages
# **Note:**
# - useful info:
#     - image thumbnail
#         - in r07.json()['query']['pages']['50012']['thumbnail']
#         - need regex to get to full size image (or extra param piprop=original, but this doesn't return pageimage)
#     - pageimage
#         - in r07.json()['query']['pages']['50012']['pageimage']
#         - (?) useful in image data (i.e. license, author, etc)

# %%
params = {'titles': 'Francis_I_of_France',
          'action': 'query',
          'format': 'json',
          'prop': 'pageimages'}

r07 = requests.get(url = URL, headers = HEADERS, params = params)
r07.status_code
# Out:
# 200

# %%
r07.json()
# Out:
# {'batchcomplete': '',
#  'query': {'normalized': [{'from': 'Francis_I_of_France',
#     'to': 'Francis I of France'}],
#   'pages': {'50012': {'pageid': 50012,
#     'ns': 0,
#     'title': 'Francis I of France',
#     'thumbnail': {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/87/Fran%C3%A7ois_Ier_Louvre.jpg/39px-Fran%C3%A7ois_Ier_Louvre.jpg',
#      'width': 39,
#      'height': 50},
#     'pageimage': 'François_Ier_Louvre.jpg'}}}}

# %%
print(r07.json()['query']['pages']['50012']['thumbnail'])
print(r07.json()['query']['pages']['50012']['pageimage'])
# Out:
# {'source': 'https://upload.wikimedia.org/wikipedia/commons/thumb/8/87/Fran%C3%A7ois_Ier_Louvre.jpg/39px-Fran%C3%A7ois_Ier_Louvre.jpg', 'width': 39, 'height': 50}
# François_Ier_Louvre.jpg

# %%
params = {'titles': 'Francis_I_of_France',
          'action': 'query',
          'format': 'json',
          'prop': 'pageimages',
          'piprop': 'original'}

r07_1 = requests.get(url = URL, headers = HEADERS, params = params)
r07_1.status_code
# Out:
# 200

# %%
r07_1.json()
# Out:
# {'batchcomplete': '',
#  'query': {'normalized': [{'from': 'Francis_I_of_France',
#     'to': 'Francis I of France'}],
#   'pages': {'50012': {'pageid': 50012,
#     'ns': 0,
#     'title': 'Francis I of France',
#     'original': {'source': 'https://upload.wikimedia.org/wikipedia/commons/8/87/Fran%C3%A7ois_Ier_Louvre.jpg',
#      'width': 2048,
#      'height': 2648}}}}}

# %% [markdown]
# ### 8. pageprops

# %%
params = {'titles': 'Francis_I_of_France',
          'action': 'query',
          'format': 'json',
          'prop': 'pageprops'}

r08 = requests.get(url = URL, headers = HEADERS, params = params)
r08.status_code
# Out:
# 200

# %%
r08.json()
# Out:
# {'batchcomplete': '',
#  'query': {'normalized': [{'from': 'Francis_I_of_France',
#     'to': 'Francis I of France'}],
#   'pages': {'50012': {'pageid': 50012,
#     'ns': 0,
#     'title': 'Francis I of France',
#     'pageprops': {'defaultsort': 'Francis 01 of France',
#      'page_image_free': 'François_Ier_Louvre.jpg',
#      'wikibase-shortdesc': 'King of the House of Valois-Angoulême (1494–1547, r. 1515–47)',
#      'wikibase_item': 'Q129857'}}}}}

# %% [markdown]
# ### 9. pageterms

# %%
params = {'titles': 'Francis_I_of_France',
          'action': 'query',
          'format': 'json',
          'prop': 'pageterms'}

r09 = requests.get(url = URL, headers = HEADERS, params = params)
r09.status_code
# Out:
# 200

# %%
r09.json()
# Out:
# {'batchcomplete': '',
#  'query': {'normalized': [{'from': 'Francis_I_of_France',
#     'to': 'Francis I of France'}],
#   'pages': {'50012': {'pageid': 50012,
#     'ns': 0,
#     'title': 'Francis I of France',
#     'terms': {'alias': ['François I',
#       're di Francia François I',
#       'King of France Franz I',
#       'King of France François I',
#       'King of France Francesco I',
#       'roi de France François I',
#       'roi de France François Ier',
#       'King of France Francisco I',
#       'King of France Francis I',
#       'König Franz I. Frankreich',
#       'Duke of Lorraine François Stefan'],
#      'label': ['Francis I of France'],
#      'description': ['King of France (1494-1547)']}}}}}

# %% [markdown]
# ### 10. pageviews

# %%
params = {'titles': 'Francis_I_of_France',
          'action': 'query',
          'format': 'json',
          'prop': 'pageviews'}

r10 = requests.get(url = URL, headers = HEADERS, params = params)
r10.status_code
# Out:
# 200

# %%
r10.json()
# Out:
# {'batchcomplete': '',
#  'query': {'normalized': [{'from': 'Francis_I_of_France',
#     'to': 'Francis I of France'}],
#   'pages': {'50012': {'pageid': 50012,
#     'ns': 0,
#     'title': 'Francis I of France',
#     'pageviews': {'2020-12-11': 1571,
#      '2020-12-12': 1505,
#      '2020-12-13': 1667,
#      '2020-12-14': 1743,
#      '2020-12-15': 1579,
#      '2020-12-16': 1633,
#      '2020-12-17': 1539,
#      '2020-12-18': 2491,
#      '2020-12-19': 1514,
#      '2020-12-20': 1660,
#      '2020-12-21': 1563,
#      '2020-12-22': 1617,
#      '2020-12-23': 1540,
#      '2020-12-24': 1362,
#      '2020-12-25': 1197,
#      '2020-12-26': 1364,
#      '2020-12-27': 1797,
#      '2020-12-28': 1764,
#      '2020-12-29': 1770,
#      '2020-12-30': 1882,
#      '2020-12-31': 1555,
#      '2021-01-01': 1921,
#      '2021-01-02': 1921,
#      '2021-01-03': 2011,
#      '2021-01-04': 1713,
#      '2021-01-05': 1792,
#      '2021-01-06': 1587,
#      '2021-01-07': 1373,
#      '2021-01-08': 1533,
#      '2021-01-09': 1625,
#      '2021-01-10': 1794,
#      '2021-01-11': 1631,
#      '2021-01-12': 1698,
#      '2021-01-13': 1598,
#      '2021-01-14': 1642,
#      '2021-01-15': 1806,
#      '2021-01-16': 1687,
#      '2021-01-17': 1773,
#      '2021-01-18': 1717,
#      '2021-01-19': 1718,
#      '2021-01-20': 1672,
#      '2021-01-21': 1644,
#      '2021-01-22': 1545,
#      '2021-01-23': 1633,
#      '2021-01-24': 1786,
#      '2021-01-25': 2025,
#      '2021-01-26': 1743,
#      '2021-01-27': 1593,
#      '2021-01-28': 1510,
#      '2021-01-29': 1458,
#      '2021-01-30': 1820,
#      '2021-01-31': 1821,
#      '2021-02-01': 1804,
#      '2021-02-02': 1609,
#      '2021-02-03': 1586,
#      '2021-02-04': 1595,
#      '2021-02-05': 1538,
#      '2021-02-06': 1501,
#      '2021-02-07': 1681,
#      '2021-02-08': 1646}}}}}

# %%
print(len(r10.json()['query']['pages']['50012']['pageviews']))
# Out:
# 60

# %%
params = {'titles': 'Francis_I_of_France',
          'action': 'query',
          'format': 'json',
          'prop': 'pageviews',
          'pvipcontinue': True}

r10_1 = requests.get(url = URL, headers = HEADERS, params = params)
r10_1.status_code
# Out:
# 200

# %%
r10_1.json()
# Out:
# {'batchcomplete': '',
#  'query': {'normalized': [{'from': 'Francis_I_of_France',
#     'to': 'Francis I of France'}],
#   'pages': {'50012': {'pageid': 50012,
#     'ns': 0,
#     'title': 'Francis I of France'}}}}
