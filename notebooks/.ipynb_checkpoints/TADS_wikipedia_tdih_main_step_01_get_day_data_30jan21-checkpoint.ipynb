# %% [markdown]
# # Wikipedia - this day in history <small>(step 1)</small>
# ---
# **Goal:** create a dataset of this-day-in-history events
#
# **Context:**  I need a starting dataset of world history events (name, short description, long description, image, and location). I couldn't find public datasets. I'm building one using the wikipedia this day in history data.
#
# **Notes about the project:**
# - I first tried to get the data by scraping it from wikipedia because the wikipedia API is confusing. After reading more about the API, I decided to re-do the project.
# - this notebook is for the first step of this project. This first step consists of:
#     - using the Wikipedia api to get the events for each day of the year
#     - parsing the Wikipedia data, cleaning it up, and getting it in the right format needed for the SQLite database created for this project
# - step two is:
#     - take the data from step one and rank each item based on page views, page length, and links to page
#     - get image (and licence details) for each item in the data from step one
# - to get data for a specific day run day_data_main(day_name). It returns a dictionary with day data.
#
# **Notes about the data:**
# - most days have data in the following format:
#     - for 'Events', 'Births', 'Deaths':
#         - { year_link } - { link_to_event or link_to_person } some text
#     - for 'Holidays_and_observances':
#         - { holiday_link } some text
# - edge cases I found:
#     - 'Events' data is separated into sections based on different calendars (see January_1 page)
#     - 'Deaths' data has nested lists (see February_29 page)
#     - 'Holidays_and_observances' has more than one level deep nested lists (see January_1 page)

# %%
import os
import time
import random
import requests
import re
import datetime as dt
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %%
pd.options.display.max_rows = None
pd.options.display.max_columns = None

# %%
# %%html
# <div style='box-sizing: border-box; margin: 0; padding: 0; display: flex; justify-content: space-between'>
#     <img src='../images/img_ss_wikipedia_edge_case_01_for_jan_1_19jan21.jpg' width='300px'/>
#     <img src='../images/img_ss_wikipedia_edge_case_02_for_jan_1_19jan21.jpg' width='300px'/>
#     <img src='../images/img_ss_wikipedia_edge_case_01_for_feb_29_19jan21.jpg' width='300px'/>
# </div>
# Out:
# <div style='box-sizing: border-box; margin: 0; padding: 0; display: flex; justify-content: space-between'>
#     <img src='../images/img_ss_wikipedia_edge_case_01_for_jan_1_19jan21.jpg' width='300px'/>
#     <img src='../images/img_ss_wikipedia_edge_case_02_for_jan_1_19jan21.jpg' width='300px'/>
#     <img src='../images/img_ss_wikipedia_edge_case_01_for_feb_29_19jan21.jpg' width='300px'/>
# </div>

# %% [markdown]
# ### TO-DO:
# ---
# 1. get the day data from https://en.wikipedia.org/w/api.php/Month_day (eg.https://en.wikipedia.org/w/api.php/January_15)
# 2. process the day data
#     - I decided to process the data for the page
#     - the alternative is a multi-step process:
#         1. get the data
#         2. find the section number for each type of event
#         2. find possible subsections for each section (see January_1 page)
#         4. make separate API calls for each section or subsection
#         5. process the data for each section or subsection
#     - processing the data for the whole page reduces the number of API calls by a factor of 4 or more (since there are four types of events, and some types might have subsections)
# 3. for the first link in each event, get:
#     - revision history statistics https://xtools.wmflabs.org/articleinfo/en.wikipedia.org/Henry_III_of_England
#     - page view statistics https://pageviews.toolforge.org/pageviews/?project=en.wikipedia.org&platform=all-access&agent=user&redirects=0&range=latest-20&pages=Henry_III_of_England
#     - picture

# %%
EVENT_TYPES = ['Events', 'Births', 'Deaths', 'Holidays_and_observances']

URL = 'https://en.wikipedia.org/w/api.php/'
HEADERS = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 11_1_0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.141 Safari/537.36'}
PARAMS = {'format': 'json',
         'action': 'parse'}

# %%
def day_data_main(day_name, url = 'https://en.wikipedia.org/w/api.php/', event_types = EVENT_TYPES):
    """
    Main function for getting and processing the data for a specific day.
    It uses several helper functions to break down the process into simple steps.
    
    Params:
        day_name: the name of the day to be processed
                  (needs to be a string in the format Month_dd (eg. 'January_1'))
        url: url for the wikipedia API
        event_types: list of events to request and process data for
                     (event_types common to all days are:
                         - Events
                         - Births
                         - Deaths
                         - Holidays_and_observances)
        
    Returns:
        day_data_dict: a dictionary with day_data
                       eg. {'day': 1,
                            'month': 1,
                            'status_code': status_code,
                            'day_soup': day_soup,
                            'events': events_list_items,
                            'births': 'births_list_items',
                            'deaths': deaths_list_items,
                            'holidays_and_observances' : holidays_list_items
                            'no_event_for': no_event_for_list}
    """
    # request day_data
    status_code, day_soup = get_day_data(day_name = day_name)
    
    # check that status_code is OK by looking at the day_soup
    # day_soup is an empty string if request for data came back with a status_code different than 'ok'
    if day_soup:
        # call process_day_soup to process day_soup and get the starting day_data_dict
        day_data_dict = process_day_soup(day_soup, event_types)
    else:
        day_data_dict = {'events': np.nan,
                         'births': np.nan,
                         'deaths': np.nan,
                         'holidays_and_observances': np.nan,
                         'no_event_for': np.nan}
        
    # add 'day', 'month', 'status_code', and 'day_soup' data to the day_data_dict  
    # (adding '_2020' to day_name to avoid ValueError caused by 'February_29')
    day_data_dict['day'] = dt.datetime.strptime(day_name + '_2020', '%B_%d_%Y').day
    day_data_dict['month'] = dt.datetime.strptime(day_name + '_2020', '%B_%d_%Y').month
    day_data_dict['status_code'] = status_code
    day_data_dict['day_soup'] = day_soup
            
    return day_data_dict

# %%
def get_day_data(day_name = 'January_1', url = 'https://en.wikipedia.org/w/api.php/', headers=HEADERS, params = PARAMS):
    """
    Use requests to get day_data from wikipedia API.
    
    Params:
        day_name: needs to be in the format Month_dd (eg. 'January_1')
        url: first part of the Wikipedia API url for each day of the year
        headers: dictionary of headers data such as user_agent, etc
        params: dictionary of params used in requests.get, such as 'format', 'action', etc
        
    Returns:
        status_code: status code of the request
        day_text_soup: BeautifulSoup object of the response text
        
    """
    params['page'] = day_name
    url = f'{url}{day_name}'
    result = requests.get(url, headers=headers, params=params)
    
    if result.status_code == requests.codes.ok:
        # result is json file with one key ('parse') whose value is a nested dictionary
        # data is in result['parse']['text']['*']
        result_text = result.json()['parse']['text']['*']
        day_text_soup = BeautifulSoup(result_text, 'html.parser')
    else:
        day_text_soup = ''
        
    return result.status_code, day_text_soup

# %%
def process_day_soup(day_soup, event_types = EVENT_TYPES):
    """
    Take the raw data for a specific day, clean it up, and format it as needed for the database.
    
    Params:
        day_soup: BeautifulSoup object representing the raw data for a specific day
        event_types: list of event_types for which to extract event items 
        
    Returns:
        day_data_dict: dictionary with day_data
                       e.g. {'events': events_list_items,
                             'births': 'births_list_items',
                             'deaths': deaths_list_items,
                             'holidays_and_observances' : holidays_list_items,
                             'no_event_for': no_event_for_list}
    """
    # initialize day_data_dict
    day_data_dict = {}
    
    # keep track of event types that don't have event items
    # this list is expected to stay empty
    no_event_for = []
    day_data_dict['no_event_for'] = no_event_for
    
    for event_type in event_types:
        # find section_span
        # events are in an <ul> element preceeded by an <h2> with two <span> children
        # the first <span> child has an id equal to the event_type (eg. <span class="mw-headline" id="Events">)
        section_span = day_soup.find(id = event_type)
        # if there are no events for the event_type
        if not section_span:
            # add the event_type for which there are no events to the list no_event_for
            no_event_for.append(event_type)
            day_data_dict['no_event_for'] = no_event_for
            # assign np.nan to day_data_dict[event_type]
            day_data_dict[event_type.lower()] = np.nan
            continue

        # if there are events for event_type
        section_h2 = section_span.find_parent()

        # event_type 'holiday' items have different data format than 'events', 'deaths', 'births'
        # need to process differently (they don't have year data)
        if 'holiday' in event_type.lower():
            day_data_dict[event_type.lower()] = extract_and_process_holiday_data(section_h2)

        else:
            day_data_dict[event_type.lower()] = extract_and_process_event_data(section_h2)
            
    return day_data_dict

# %%
def extract_and_process_holiday_data(section_h2, event_category = np.nan):
    """
    Process holiday data.
    
    Params:
        section_h2: a BeautifulSoup object (<h2> element) marking the start of event_type 'holiday'
        event_category: indicates if event is 'Christian feast day' or not
        
    Returns:
        holiday_list: list of dictionaries (each holiday item is a dictionary)        
    
    """
    holiday_list = []
    
    # section_h2 has one or more <ul> siblings
    sibling = section_h2.next_sibling
    
    # another <h2> sibling indicates the current section is over and another section starts
    # check that we are not into a new section
    while sibling.name != 'h2':
        
        # if sibling is empty string or a new line character ('\n'), continue to next sibling
        if not str(sibling).strip():
            sibling = sibling.next_sibling
            continue
    
        # check sibling is indeed ul_element and loop through its <li> children (they contain holiday data)
        if sibling.name == 'ul':
            # loop through the <li> items
            for child in sibling.children:
                
                # check if child is emtpy string or new line character; continue to next child if yes
                if not str(child).strip():
                    continue
                    
                # check if child has sub lists
                if child.find('ul'):
                # check if child is list of 'Christian feast day' elements
                    if is_christian_feast_day(child):
                        # change event_category
                        # don't add child data to holiday_list (even though it's an <li> item, it is just a category name)
                        event_category = 'christian feast day'

                    else:
                        # add child to holiday_list
                        child_data_dict = extract_single_li_event_data(child,
                                                                       get_li_element_contents = False,
                                                                       event_category = event_category)
                        holiday_list.append(child_data_dict)

                    # get the data for sub_items and add it to holiday_list
                    sub_items_data_list = get_sub_items_data(child, event_category = event_category)
                    holiday_list.extend(sub_items_data_list)

                    # re-set event_category to np.nan
                    event_category = np.nan
                
                else:
                    # child does not have nested lists
                    # add child data to holiday_list
                    child_data_dict = extract_single_li_event_data(child,
                                                                   get_li_element_contents = False,
                                                                   event_category = event_category)
                    holiday_list.append(child_data_dict)
                    
            sibling = sibling.next_sibling
                
    return holiday_list

# %%
def extract_and_process_event_data(section_h2):
    """
    Extract and process event_data for event of type 'Events', 'Births', or 'Deaths'
    
    Params:
        section_h2: a BeautifulSoup object (<h2> element) marking the start of event_type 'Events', 'Births', or 'Deaths'
        event_category: indicates if event date is specific to a certain calendar 
                        (eg. Pre-Julian calendar, Julian calendar, Gregorian calendar, etc)
                        (see wikipedia page for January_1)
        
    Returns:
        event_list: list of dictionaries (each event item is a dictionary) 
    """
    event_list = []
    
    # only small number of events are grouped in sub_lists based on the type of calendar used for their date
    # the event_category is changed if section_h2 has <h3> elements (they contain calendar data)
    event_category = np.nan
    
    # section_h2 usually has just one <ul> sibling (except days like January_1, which is divided in 
    # three parts based on the type of calendar used)
    sibling = section_h2.next_sibling
    
    while sibling.name != 'h2':
        
        # if sibling is empty string or a new line character ('\n'), continue to next sibling
        if not str(sibling).strip():
            sibling = sibling.next_sibling
            continue
            
        # if sibling is an <h3> element, it containg the name of the calendar under which several events are grouped
        # (eg. Julian Calendar, Gregorian Calendar, etc)
        # (see wikipedia page for January_1)
        if sibling.name == 'h3':
            event_category = sibling.text.replace('[edit]', '') # '[edit]' is included in text of <h3> elements
            sibling = sibling.next_sibling
            continue
            
        if sibling.name == 'ul': # this is the list that has the <li> events
            # each <li> should hold one event and have no sub_lists
            # in some instances (see February_29), the year is in <li> element and the actual events are 
            # sub_items of the year (according to the Wikipedia page, this needs to be fixed)
            for child in sibling.children:
                
                # if child is empty string or a new line character ('\n') continue to next child
                if not str(child).strip():
                    continue
                    
                # check if child has sub_lists
                if child.find_all('li'):
                    # the child.text is the year under which several events are grouped
                    # use regex to eliminate '-' or empty spaces
                    year, bc_ad, bc_ad_note = get_year(child.text)
                    for li in child.find_all('li'):
                        child_data_dict = extract_single_li_event_data(li, event_category = event_category, year = year)
                        child_data_dict['bc_ad'] = bc_ad
                        child_data_dict['bc_ad_note'] = 'nested year ' + bc_ad_note
                        event_list.append(child_data_dict)
                    continue

                    
                child_data_dict = extract_single_li_event_data(child, event_category = event_category)
                # finds the year (using the first or second element in child.contents)
                # most of the time year data is in first element
                # exception: style data is in first element (see January_1, years 193, 404, and 417)
                year_element = [str(child.contents[0]), str(child.contents[1])]
                year, bc_ad, bc_ad_note = get_year(year_element[0])
                if not year or year == '0':
                    year, bc_ad, bc_ad_note = get_year(year_element[1], bc_ad_note = 'content_2_')
                # add year data to child_data_dict
                child_data_dict['year'] = year
                child_data_dict['bc_ad'] = bc_ad
                child_data_dict['bc_ad_note'] = bc_ad_note
                event_list.append(child_data_dict)
                    
        sibling = sibling.next_sibling
        
    return event_list

# %%
def get_year(year_element, bc_ad_note = ''):
    """
    Get the year from the year_element of an event
    
    Params:
        year_element: the first item in the contents of an <li> element for an event 
                      (passed in from extract_event_data)
        bc_ad_note: defaults to np.nan
                    changes value if year pattern in found in first element of an <li> event element
                    helps identify exception <li> elements (see wikipedia page for January_1)
                                                            years 193, 404, and 417 have style data in their
                                                            first element)
        
    Returns:
        year:
        bc_ad:
        bc_ad_note: indicates if bc_ad info was included in wikipedia link, or it is assumed to be 'ad'
    """
    year= ''
    bc_ad = ''
    bc_ad_note = bc_ad_note

    # pattern: wiki/ad_100 or wiki/100
    year_pattern_1 = re.compile(r'wiki/(bc|ad)_{0,1}(\d{1,4})', re.IGNORECASE)
    # pattern: wiki/100_ad or wiki/100
    year_pattern_2 = re.compile(r'wiki/(\d{1,4})_{0,1}(bc|ad)', re.IGNORECASE)
    # pattern: wiki/100
    year_pattern_3 = re.compile(r'wiki/(\d{1,4})')
    # pattern: 1919 -  (note: if one year has several events, only the first year occurence has link to wikipedia year page)
    year_pattern_4 = re.compile(r'\b(\d{1,4})\b')
    
    result = year_pattern_1.search(year_element)
    if result:  
        bc_ad = result.groups()[0].lower()
        year = result.groups()[1]
        bc_ad_note += 'included'
        return year, bc_ad, bc_ad_note

    result = year_pattern_2.search(year_element)
    if result:  
        bc_ad = result.groups()[1].lower()
        year = result.groups()[0]
        bc_ad_note += 'included'
        return year, bc_ad, bc_ad_note
    
    result = year_pattern_3.search(year_element)
    if result:  
        bc_ad = 'ad'
        year = result.groups()[0]
        bc_ad_note += 'assumed'
        return year, bc_ad, bc_ad_note
    
    result = year_pattern_4.search(year_element)
    if result:  
        bc_ad = 'ad'
        year = result.groups()[0]
        bc_ad_note += 'assumed'
        return year, bc_ad, bc_ad_note

    return year, bc_ad, bc_ad_note

# %%
def get_first_link(element_links_list):
    """
    Get the first non-year link (i.e. it doesn't link to the year of the event, but to something in the event)
    
    Params:
        element_links_list: list of links in the element (extracted with function extract_links_data)
        
    Returns:
        first_link
    """
    # match patterns like: wiki/AD_100, wiki/AD100, wiki/100, wiki/100_AD, wiki/100AD (for AD or BC)
    # in most cases these are links to wikipedia page for a specific year
    event_year = re.compile(r'(wiki/ad_*\d{1,4})|(wiki/bc_*\d{1,4})|(wiki/\d{1,4})|(wiki/\d{1,4}_*ad)|(wiki/\d{1,4}_*bc)', re.IGNORECASE)
    first_link = ''
    for link in element_links_list:
        if not event_year.search(link):
            if not first_link:
                first_link = link
    return first_link

# %%
def extract_links_data(li_element, exclude_reference_links = True):
    """
    Get element_links_list and first_link for li_element.
    
    Params:
        li_element: <li> element to extract data for
        
    Returns:
        element_links_list: a list of links in the element (exclude links in <sup> tags - they link to references)
        first_link: the first link that is not a link to a year
    """
    element_links_list = []
    first_link = ''
    
    for element in li_element.find_all('a'):
        if exclude_reference_links:
            if element.parent.name != 'sup':
                # append the element's href to the 
                element_links_list.append(element['href'])
        else:
            element_links_list.append(element['href'])
            
    # get the first link that is not a year link
    first_link = get_first_link(element_links_list)
    
    return element_links_list, first_link

# %%
def extract_single_li_event_data(li_element, get_li_element_contents = False, 
                                 event_category = np.nan, year = np.nan):
    """
    Extract data for a single <li> element represent an event (regardless of the event_type, of whether the 
    <li> element is a sub_item of a different <li> element, etc)
    
    Params:
        li_element:
        get_li_element_contents: True only if I need to get li_element contents to troubleshoot missing li_element data
                                 (otherwise seems unncessary - waste of memory)
        event_category: used to mark 'Christian feast day' holidays or events grouped by calendar type (see January_1)
        year: applies to 'Events', 'Births', 'Deaths', not 'Holidays_and_observances'
              defaults to np.nan
              if needed, it is passed from extract_and_process_event_data, or assigned within that function
        
    Returns:
        li_element_dict: dictionary of fields common to all event elements (regardless of event_type, etc)
                         eg. {'year': ,
                              'event_description': ,
                              'event_links_list': ,
                              'event_first_link': ,
                              'event_category': ,
                              'event_contents_list': (optional)
                              }
    """
    li_element_dict = {}

    # get li_element data and build li_element_dict
    li_element_dict['year'] = year
    li_element_dict['event_description'] = get_event_description(li_element.text)
    
    try:        
        li_element_dict['event_links_list'], li_element_dict['event_first_link'] = extract_links_data(li_element)
    except:
        li_element_dict['event_links_list'] = 'NavigableString'
        li_element_dict['event_first_link'] = 'NavigableString'
    
    li_element_dict['event_category'] = event_category
    
    
    # seems unncessary, but get li_element contents in case I need to troubleshoot missing li_element data
    if get_li_element_contents:
        li_element_dict['event_contents_list'] = li_element.contents
        
    return li_element_dict

# %%
# changed from get_sub_items to get_sub_items_data
def get_sub_items_data(child, event_category = np.nan):
    """
    Get data of sub_items of child event element.
    Loops through sub_items, uses function extract_single_li_event_data to extract sub_item data.
    
    Params:
        child:
        event_category: indicates if item is a 'Christian feast day' event type
        
    Returns:
        sub_items_data_list: list of dictionaries
                             each dictionary has fields common to all event elements
                             eg. {'event_description': ,
                                  'event_links_list': ,
                                  'event_first_link': ,
                                  'event_category': ,
                                  'event_contents_list': (optional)
                                  }
    """
    sub_items_data_list = []
    
    for li in child.find_all('li'):
        sub_item_dict = extract_single_li_event_data(li, event_category = event_category)
        sub_items_data_list.append(sub_item_dict)
            
    return sub_items_data_list

# %%
def is_christian_feast_day(ul_element):
    """
    Check if <ul> element is a list of 'Christian feast day' holidays
    
    Params:
        ul_element
        
    Returns:
        True or False
    """
    is_christian_feast_day = False
    
    # get the first line of the ul_element
    first_line = ul_element.text.split('\n')[0].lower()
    if 'christian' in first_line and 'feast' in first_line and 'day' in first_line:
        is_christian_feast_day = True

    return is_christian_feast_day

# %%
def get_event_description(li_element_text):
    """
    Get the description of an event using the event's li_element_text.
    Eliminate the year data from the event description (it is already captured in a field called 'year')
    
    Params:
        li_element_text: a string containing the text of the li_element
        
    Returns:
        li_element_description: the li_element description stripped of year data
    """
    # strip li_element_text of any white spaces
    li_element_text = li_element_text.strip()
    
    # compile year_pattern (year is at the beginning of li_element_text)
    # \W character is for matching - and –
    year_pattern = re.compile(r'^\d{1,4}\s{0,2}\W\s{0,2}')
    
    # if year_pattern in li_element_text, replace with ''
    li_element_description = year_pattern.sub('', li_element_text)
    
    return li_element_description

# %% [markdown]
# ## Test day_data_main

# %%
d1 = day_data_main('February_29')
d1
# Out:
# {'no_event_for': [],
#  'events': [{'year': '1504',
#    'event_description': 'Christopher Columbus uses his knowledge of a lunar eclipse that night to convince Jamaican natives to provide him with supplies.',
#    'event_links_list': ['/wiki/1504',
#     '/wiki/Christopher_Columbus',
#     '/wiki/March_1504_lunar_eclipse'],
#    'event_first_link': '/wiki/Christopher_Columbus',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1644',
#    'event_description': "Abel Tasman's second Pacific voyage begins.",
#    'event_links_list': ['/wiki/1644', '/wiki/Abel_Tasman'],
#    'event_first_link': '/wiki/Abel_Tasman',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1704',
#    'event_description': "Queen Anne's War: French forces and Native Americans stage a raid on Deerfield, Massachusetts Bay Colony, killing 56 villagers and taking more than 100 captive.",
#    'event_links_list': ['/wiki/1704',
#     '/wiki/Queen_Anne%27s_War',
#     '/wiki/Native_American_(U.S.)',
#     '/wiki/Raid_on_Deerfield'],
#    'event_first_link': '/wiki/Queen_Anne%27s_War',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1712',
#    'event_description': 'February 29 is followed by February 30 in Sweden, in a move to abolish the Swedish calendar for a return to the Julian calendar.',
#    'event_links_list': ['/wiki/1712',
#     '/wiki/February_30',
#     '/wiki/Swedish_calendar',
#     '/wiki/Julian_calendar'],
#    'event_first_link': '/wiki/February_30',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1720',
#    'event_description': 'Ulrika Eleonora, Queen of Sweden abdicates in favour of her husband, who becomes King Frederick I on March 24.',
#    'event_links_list': ['/wiki/1720',
#     '/wiki/Ulrika_Eleonora,_Queen_of_Sweden',
#     '/wiki/Frederick_I_of_Sweden'],
#    'event_first_link': '/wiki/Ulrika_Eleonora,_Queen_of_Sweden',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1752',
#    'event_description': 'King Alaungpaya founds Konbaung Dynasty, the last dynasty of Burmese monarchy.',
#    'event_links_list': ['/wiki/1752',
#     '/wiki/Alaungpaya',
#     '/wiki/Konbaung_Dynasty'],
#    'event_first_link': '/wiki/Alaungpaya',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1768',
#    'event_description': 'Polish nobles form the Bar Confederation.',
#    'event_links_list': ['/wiki/1768', '/wiki/Bar_Confederation'],
#    'event_first_link': '/wiki/Bar_Confederation',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1796',
#    'event_description': 'The Jay Treaty between the United States and Great Britain comes into force, facilitating ten years of peaceful trade between the two nations.',
#    'event_links_list': ['/wiki/1796', '/wiki/Jay_Treaty'],
#    'event_first_link': '/wiki/Jay_Treaty',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1864',
#    'event_description': 'American Civil War: Kilpatrick–Dahlgren Raid fails: Plans to free 15,000 Union soldiers being held near Richmond, Virginia are thwarted.',
#    'event_links_list': ['/wiki/1864',
#     '/wiki/American_Civil_War',
#     '/wiki/Kilpatrick%E2%80%93Dahlgren_Raid',
#     '/wiki/United_States',
#     '/wiki/Richmond,_Virginia'],
#    'event_first_link': '/wiki/American_Civil_War',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1892',
#    'event_description': 'St. Petersburg, Florida is incorporated.',
#    'event_links_list': ['/wiki/1892', '/wiki/St._Petersburg,_Florida'],
#    'event_first_link': '/wiki/St._Petersburg,_Florida',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1912',
#    'event_description': 'The Piedra Movediza (Moving Stone) of Tandil falls and breaks.',
#    'event_links_list': ['/wiki/1912', '/wiki/Piedra_Movediza', '/wiki/Tandil'],
#    'event_first_link': '/wiki/Piedra_Movediza',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1916',
#    'event_description': 'Tokelau is annexed by the United Kingdom.',
#    'event_links_list': ['/wiki/1916', '/wiki/Tokelau'],
#    'event_first_link': '/wiki/Tokelau',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1916',
#    'event_description': '– Child labor: In South Carolina, the minimum working age for factory, mill, and mine workers is raised from 12 to 14 years old.',
#    'event_links_list': ['/wiki/Child_labor',
#     '/wiki/South_Carolina',
#     '/wiki/Working_age'],
#    'event_first_link': '/wiki/Child_labor',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1920',
#    'event_description': 'Czechoslovak National Assembly adopts the Constitution.',
#    'event_links_list': ['/wiki/1920',
#     '/wiki/Czechoslovakia',
#     '/wiki/Czechoslovak_Constitution_of_1920'],
#    'event_first_link': '/wiki/Czechoslovakia',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1936',
#    'event_description': 'February 26 Incident in Tokyo ends.',
#    'event_links_list': ['/wiki/1936', '/wiki/February_26_Incident'],
#    'event_first_link': '/wiki/February_26_Incident',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1940',
#    'event_description': '12th Academy Awards: For her performance as "Mammy" in Gone with the Wind, Hattie McDaniel becomes the first African American to win an Academy Award.',
#    'event_links_list': ['/wiki/1940',
#     '/wiki/12th_Academy_Awards',
#     '/wiki/Gone_with_the_Wind_(film)',
#     '/wiki/Hattie_McDaniel',
#     '/wiki/African_American',
#     '/wiki/Academy_Awards'],
#    'event_first_link': '/wiki/Gone_with_the_Wind_(film)',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1940',
#    'event_description': '– Finland initiates Winter War peace negotiations.',
#    'event_links_list': ['/wiki/Winter_War'],
#    'event_first_link': '/wiki/Winter_War',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1940',
#    'event_description': "– In a ceremony held in Berkeley, California, physicist Ernest Lawrence receives the 1939 Nobel Prize in Physics from Sweden's Consul General in San Francisco.",
#    'event_links_list': ['/wiki/Berkeley,_California',
#     '/wiki/Ernest_Lawrence',
#     '/wiki/Nobel_Prize_in_Physics',
#     '/wiki/Consul_General',
#     '/wiki/San_Francisco'],
#    'event_first_link': '/wiki/Berkeley,_California',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1944',
#    'event_description': 'World War II: The Admiralty Islands are invaded in Operation Brewer led by American General Douglas MacArthur.',
#    'event_links_list': ['/wiki/1944',
#     '/wiki/Admiralty_Islands',
#     '/wiki/Operation_Brewer',
#     '/wiki/Douglas_MacArthur'],
#    'event_first_link': '/wiki/Admiralty_Islands',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1960',
#    'event_description': 'The 5.7\xa0Mw\u202f Agadir earthquake shakes coastal Morocco with a maximum perceived intensity of X (Extreme), destroying Agadir, and leaving 12,000 dead and another 12,000 injured.',
#    'event_links_list': ['/wiki/1960',
#     '/wiki/1960_Agadir_earthquake',
#     '/wiki/Morocco',
#     '/wiki/Mercalli_intensity_scale'],
#    'event_first_link': '/wiki/Morocco',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1972',
#    'event_description': 'Vietnam War: Vietnamization: South Korea withdraws 11,000 of its 48,000 troops from Vietnam.',
#    'event_links_list': ['/wiki/1972',
#     '/wiki/Vietnam_War',
#     '/wiki/Vietnamization',
#     '/wiki/Vietnam'],
#    'event_first_link': '/wiki/Vietnam_War',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1980',
#    'event_description': 'Gordie Howe of the Hartford Whalers makes NHL history as he scores his 800th goal.',
#    'event_links_list': ['/wiki/1980',
#     '/wiki/Gordie_Howe',
#     '/wiki/Hartford_Whalers',
#     '/wiki/National_Hockey_League'],
#    'event_first_link': '/wiki/Gordie_Howe',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1984',
#    'event_description': 'Pierre Trudeau announces his retirement as Liberal Party leader and Prime Minister of Canada.',
#    'event_links_list': ['/wiki/1984',
#     '/wiki/Pierre_Trudeau',
#     '/wiki/Liberal_Party_of_Canada',
#     '/wiki/Prime_Minister_of_Canada'],
#    'event_first_link': '/wiki/Pierre_Trudeau',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1988',
#    'event_description': 'South African archbishop Desmond Tutu is arrested along with one hundred other clergymen during a five-day anti-apartheid demonstration in Cape Town.',
#    'event_links_list': ['/wiki/1988',
#     '/wiki/Desmond_Tutu',
#     '/wiki/Apartheid',
#     '/wiki/Cape_Town'],
#    'event_first_link': '/wiki/Desmond_Tutu',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1988',
#    'event_description': '– Svend Robinson becomes the first member of the House of Commons of Canada to come out as gay.',
#    'event_links_list': ['/wiki/Svend_Robinson',
#     '/wiki/House_of_Commons_of_Canada',
#     '/wiki/Coming_out'],
#    'event_first_link': '/wiki/Svend_Robinson',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1992',
#    'event_description': 'First day of Bosnia and Herzegovina independence referendum.',
#    'event_links_list': ['/wiki/1992',
#     '/wiki/Bosnian_independence_referendum,_1992'],
#    'event_first_link': '/wiki/Bosnian_independence_referendum,_1992',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1996',
#    'event_description': 'Faucett Flight 251 crashes in the Andes; all 123 passengers and crew die.',
#    'event_links_list': ['/wiki/1996', '/wiki/Faucett_Flight_251'],
#    'event_first_link': '/wiki/Faucett_Flight_251',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1996',
#    'event_description': '– Siege of Sarajevo officially ends.',
#    'event_links_list': ['/wiki/Siege_of_Sarajevo'],
#    'event_first_link': '/wiki/Siege_of_Sarajevo',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '2000',
#    'event_description': 'Second Chechen War: Eighty-four Russian paratroopers are killed in a rebel attack on a guard post near Ulus Kert.',
#    'event_links_list': ['/wiki/2000', '/wiki/Second_Chechen_War'],
#    'event_first_link': '/wiki/Second_Chechen_War',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '2004',
#    'event_description': 'Jean-Bertrand Aristide is removed as President of Haiti following a coup.',
#    'event_links_list': ['/wiki/2004',
#     '/wiki/Jean-Bertrand_Aristide',
#     '/wiki/Haiti',
#     '/wiki/2004_Haitian_coup_d%27%C3%A9tat'],
#    'event_first_link': '/wiki/Jean-Bertrand_Aristide',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '2008',
#    'event_description': 'The United Kingdom\'s Ministry of Defence decides to withdraw Prince Harry from a tour of Afghanistan "immediately" after a leak leads to his deployment being reported by foreign media.',
#    'event_links_list': ['/wiki/2008',
#     '/wiki/Ministry_of_Defence_(United_Kingdom)',
#     '/wiki/Prince_Harry',
#     '/wiki/Operation_Herrick'],
#    'event_first_link': '/wiki/Ministry_of_Defence_(United_Kingdom)',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '2008',
#    'event_description': '– Misha Defonseca admits to fabricating her memoir, Misha: A Mémoire of the Holocaust Years, in which she claims to have lived with a pack of wolves in the woods during the Holocaust.',
#    'event_links_list': ['/wiki/Misha_Defonseca',
#     '/wiki/Misha:_A_M%C3%A9moire_of_the_Holocaust_Years',
#     '/wiki/The_Holocaust'],
#    'event_first_link': '/wiki/Misha_Defonseca',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '2020',
#    'event_description': '2020 Democratic Party presidential primaries: Joe Biden wins the South Carolina Democratic Party primary election.[2]',
#    'event_links_list': ['/wiki/2020',
#     '/wiki/2020_Democratic_Party_presidential_primaries',
#     '/wiki/Joe_Biden',
#     '/wiki/Democratic_Party_(United_States)'],
#    'event_first_link': '/wiki/Joe_Biden',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '2020',
#    'event_description': '– COVID-19 pandemic: South Korea reports a total of 3,150 confirmed cases of COVID-19.[3]',
#    'event_links_list': ['/wiki/COVID-19_pandemic', '/wiki/COVID-19'],
#    'event_first_link': '/wiki/COVID-19_pandemic',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'}],
#  'births': [{'year': '1468',
#    'event_description': 'Pope Paul III (d. 1549)',
#    'event_links_list': ['/wiki/1468', '/wiki/Pope_Paul_III'],
#    'event_first_link': '/wiki/Pope_Paul_III',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1528',
#    'event_description': 'Albert V, Duke of Bavaria (d. 1579)',
#    'event_links_list': ['/wiki/1528', '/wiki/Albert_V,_Duke_of_Bavaria'],
#    'event_first_link': '/wiki/Albert_V,_Duke_of_Bavaria',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1528',
#    'event_description': '– Domingo Báñez, Spanish theologian (d. 1604)',
#    'event_links_list': ['/wiki/Domingo_B%C3%A1%C3%B1ez'],
#    'event_first_link': '/wiki/Domingo_B%C3%A1%C3%B1ez',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1572',
#    'event_description': 'Edward Cecil, 1st Viscount Wimbledon (d. 1638)',
#    'event_links_list': ['/wiki/1572',
#     '/wiki/Edward_Cecil,_1st_Viscount_Wimbledon'],
#    'event_first_link': '/wiki/Edward_Cecil,_1st_Viscount_Wimbledon',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1576',
#    'event_description': 'Antonio Neri, Florentine priest and glassmaker (d. 1614)',
#    'event_links_list': ['/wiki/1576', '/wiki/Antonio_Neri'],
#    'event_first_link': '/wiki/Antonio_Neri',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1640',
#    'event_description': "Benjamin Keach, Particular Baptist preacher and author whose name was given to Keach's Catechism (d. 1704)",
#    'event_links_list': ['/wiki/1640',
#     '/wiki/Benjamin_Keach',
#     '/wiki/Particular_Baptist',
#     '/wiki/Keach%27s_Catechism'],
#    'event_first_link': '/wiki/Benjamin_Keach',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1692',
#    'event_description': 'John Byrom, English poet and educator (d. 1763)',
#    'event_links_list': ['/wiki/1692', '/wiki/John_Byrom'],
#    'event_first_link': '/wiki/John_Byrom',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1724',
#    'event_description': 'Eva Marie Veigel, Austrian-English dancer (d. 1822)',
#    'event_links_list': ['/wiki/1724', '/wiki/Eva_Marie_Veigel'],
#    'event_first_link': '/wiki/Eva_Marie_Veigel',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1736',
#    'event_description': 'Ann Lee, English-American religious leader, founded the Shakers (d. 1784)',
#    'event_links_list': ['/wiki/1736', '/wiki/Ann_Lee', '/wiki/Shakers'],
#    'event_first_link': '/wiki/Ann_Lee',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1792',
#    'event_description': 'Gioachino Rossini, Italian composer (d. 1868)',
#    'event_links_list': ['/wiki/1792', '/wiki/Gioachino_Rossini'],
#    'event_first_link': '/wiki/Gioachino_Rossini',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1812',
#    'event_description': 'James Milne Wilson, Scottish-Australian soldier and politician, 8th Premier of Tasmania (d. February 29, 1880)',
#    'event_links_list': ['/wiki/1812',
#     '/wiki/James_Milne_Wilson',
#     '/wiki/Premier_of_Tasmania'],
#    'event_first_link': '/wiki/James_Milne_Wilson',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1828',
#    'event_description': 'Emmeline B. Wells, American journalist, poet, and activist (d. 1921)',
#    'event_links_list': ['/wiki/1828', '/wiki/Emmeline_B._Wells'],
#    'event_first_link': '/wiki/Emmeline_B._Wells',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1836',
#    'event_description': 'Dickey Pearce, American baseball player and manager (d. 1908)',
#    'event_links_list': ['/wiki/1836', '/wiki/Dickey_Pearce'],
#    'event_first_link': '/wiki/Dickey_Pearce',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1852',
#    'event_description': 'Frank Gavan Duffy, Irish-Australian lawyer and judge, 4th Chief Justice of Australia (d. 1936)',
#    'event_links_list': ['/wiki/1852',
#     '/wiki/Frank_Gavan_Duffy',
#     '/wiki/Chief_Justice_of_Australia'],
#    'event_first_link': '/wiki/Frank_Gavan_Duffy',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1860',
#    'event_description': 'Herman Hollerith, American statistician and businessman, co-founded the Computing-Tabulating-Recording Company (d. 1929)',
#    'event_links_list': ['/wiki/1860',
#     '/wiki/Herman_Hollerith',
#     '/wiki/Computing-Tabulating-Recording_Company'],
#    'event_first_link': '/wiki/Herman_Hollerith',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1876',
#    'event_description': 'William Stewart, Scottish footballer',
#    'event_links_list': ['/wiki/1876',
#     '/wiki/William_Stewart_(footballer,_born_1876)'],
#    'event_first_link': '/wiki/William_Stewart_(footballer,_born_1876)',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1884',
#    'event_description': 'Richard S. Aldrich, American lawyer and politician (d. 1941)',
#    'event_links_list': ['/wiki/1884', '/wiki/Richard_S._Aldrich'],
#    'event_first_link': '/wiki/Richard_S._Aldrich',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1892',
#    'event_description': 'Augusta Savage, American sculptor (d. 1962)',
#    'event_links_list': ['/wiki/1892', '/wiki/Augusta_Savage'],
#    'event_first_link': '/wiki/Augusta_Savage',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1896',
#    'event_description': 'Morarji Desai, Indian civil servant and politician, 4th Prime Minister of India (d. 1995)',
#    'event_links_list': ['/wiki/1896',
#     '/wiki/Morarji_Desai',
#     '/wiki/Prime_Minister_of_India'],
#    'event_first_link': '/wiki/Morarji_Desai',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1896',
#    'event_description': '– William A. Wellman, American actor, director, producer, and screenwriter (d. 1975)',
#    'event_links_list': ['/wiki/William_A._Wellman'],
#    'event_first_link': '/wiki/William_A._Wellman',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1904',
#    'event_description': 'Jimmy Dorsey, American saxophonist, composer, and bandleader (d. 1957)',
#    'event_links_list': ['/wiki/1904', '/wiki/Jimmy_Dorsey'],
#    'event_first_link': '/wiki/Jimmy_Dorsey',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1904',
#    'event_description': '– Pepper Martin, American baseball player and manager (d. 1965)',
#    'event_links_list': ['/wiki/Pepper_Martin'],
#    'event_first_link': '/wiki/Pepper_Martin',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1908',
#    'event_description': 'Balthus, French-Swiss painter and illustrator (d. 2001)',
#    'event_links_list': ['/wiki/1908', '/wiki/Balthus'],
#    'event_first_link': '/wiki/Balthus',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1908',
#    'event_description': '– Dee Brown, American historian and author (d. 2002)',
#    'event_links_list': ['/wiki/Dee_Brown_(writer)'],
#    'event_first_link': '/wiki/Dee_Brown_(writer)',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1908',
#    'event_description': '– Alf Gover, English cricketer and coach (d. 2001)',
#    'event_links_list': ['/wiki/Alf_Gover'],
#    'event_first_link': '/wiki/Alf_Gover',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1908',
#    'event_description': '– Louie Myfanwy Thomas, Welsh writer (d. 1968)',
#    'event_links_list': ['/wiki/Louie_Myfanwy_Thomas'],
#    'event_first_link': '/wiki/Louie_Myfanwy_Thomas',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1916',
#    'event_description': 'Dinah Shore, American singer and actress (d. 1994)',
#    'event_links_list': ['/wiki/1916', '/wiki/Dinah_Shore'],
#    'event_first_link': '/wiki/Dinah_Shore',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1916',
#    'event_description': '– James B. Donovan, American lawyer (d. 1970)',
#    'event_links_list': ['/wiki/James_B._Donovan'],
#    'event_first_link': '/wiki/James_B._Donovan',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1916',
#    'event_description': '– Leonard Shoen, founder of U-Haul Corp. (d. 1999)',
#    'event_links_list': ['/wiki/Leonard_Shoen', '/wiki/U-Haul'],
#    'event_first_link': '/wiki/Leonard_Shoen',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1920',
#    'event_description': 'Fyodor Abramov, Russian author and critic (d. 1983)',
#    'event_links_list': ['/wiki/1920', '/wiki/Fyodor_Abramov'],
#    'event_first_link': '/wiki/Fyodor_Abramov',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1920',
#    'event_description': '– Arthur Franz, American actor (d. 2006)',
#    'event_links_list': ['/wiki/Arthur_Franz'],
#    'event_first_link': '/wiki/Arthur_Franz',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1920',
#    'event_description': '– James Mitchell, American actor and dancer (d. 2010)',
#    'event_links_list': ['/wiki/James_Mitchell_(actor)'],
#    'event_first_link': '/wiki/James_Mitchell_(actor)',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1920',
#    'event_description': '– Michèle Morgan, French-American actress and singer (d. 2016)',
#    'event_links_list': ['/wiki/Mich%C3%A8le_Morgan'],
#    'event_first_link': '/wiki/Mich%C3%A8le_Morgan',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1920',
#    'event_description': '– Howard Nemerov, American poet and academic (d. 1991)',
#    'event_links_list': ['/wiki/Howard_Nemerov'],
#    'event_first_link': '/wiki/Howard_Nemerov',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1920',
#    'event_description': '– Rolland W. Redlin, American lawyer and politician (d. 2011)',
#    'event_links_list': ['/wiki/Rolland_W._Redlin'],
#    'event_first_link': '/wiki/Rolland_W._Redlin',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1924',
#    'event_description': 'David Beattie, New Zealand judge and politician, 14th Governor-General of New Zealand (d. 2001)',
#    'event_links_list': ['/wiki/1924',
#     '/wiki/David_Beattie',
#     '/wiki/Governor-General_of_New_Zealand'],
#    'event_first_link': '/wiki/David_Beattie',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1924',
#    'event_description': '– Carlos Humberto Romero, Salvadoran politician, President of El Salvador (d. 2017)',
#    'event_links_list': ['/wiki/Carlos_Humberto_Romero',
#     '/wiki/President_of_El_Salvador'],
#    'event_first_link': '/wiki/Carlos_Humberto_Romero',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1924',
#    'event_description': '– Al Rosen, American baseball player and manager (d. 2015)',
#    'event_links_list': ['/wiki/Al_Rosen'],
#    'event_first_link': '/wiki/Al_Rosen',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1928',
#    'event_description': 'Joss Ackland, English actor',
#    'event_links_list': ['/wiki/1928', '/wiki/Joss_Ackland'],
#    'event_first_link': '/wiki/Joss_Ackland',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1928',
#    'event_description': '– Jean Adamson, British writer and illustrator[4]',
#    'event_links_list': ['/wiki/Jean_Adamson'],
#    'event_first_link': '/wiki/Jean_Adamson',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1928',
#    'event_description': '– Vance Haynes, American archaeologist, geologist, and author',
#    'event_links_list': ['/wiki/Vance_Haynes'],
#    'event_first_link': '/wiki/Vance_Haynes',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1928',
#    'event_description': '– Seymour Papert, South African mathematician and computer scientist, co-created the Logo programming language (d. 2016)',
#    'event_links_list': ['/wiki/Seymour_Papert',
#     '/wiki/Logo_(programming_language)'],
#    'event_first_link': '/wiki/Seymour_Papert',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1932',
#    'event_description': 'Gene H. Golub, American mathematician and academic (d. 2007)',
#    'event_links_list': ['/wiki/1932', '/wiki/Gene_H._Golub'],
#    'event_first_link': '/wiki/Gene_H._Golub',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1932',
#    'event_description': '– Masten Gregory, American race car driver (d. 1985)',
#    'event_links_list': ['/wiki/Masten_Gregory'],
#    'event_first_link': '/wiki/Masten_Gregory',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1932',
#    'event_description': '– Reri Grist, American soprano and actress',
#    'event_links_list': ['/wiki/Reri_Grist'],
#    'event_first_link': '/wiki/Reri_Grist',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1932',
#    'event_description': '– Jaguar, Brazilian cartoonist',
#    'event_links_list': ['/wiki/Jaguar_(cartoonist)'],
#    'event_first_link': '/wiki/Jaguar_(cartoonist)',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1932',
#    'event_description': '– Gavin Stevens, Australian cricketer',
#    'event_links_list': ['/wiki/Gavin_Stevens'],
#    'event_first_link': '/wiki/Gavin_Stevens',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1936',
#    'event_description': 'Jack Lousma, American colonel, astronaut, and politician',
#    'event_links_list': ['/wiki/1936', '/wiki/Jack_Lousma'],
#    'event_first_link': '/wiki/Jack_Lousma',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1936',
#    'event_description': '– Henri Richard, Canadian ice hockey player (d. 2020)',
#    'event_links_list': ['/wiki/Henri_Richard'],
#    'event_first_link': '/wiki/Henri_Richard',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1936',
#    'event_description': '– Alex Rocco, American actor (d. 2015)',
#    'event_links_list': ['/wiki/Alex_Rocco'],
#    'event_first_link': '/wiki/Alex_Rocco',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1936',
#    'event_description': '– Nh. Dini, Indonesian writer (d. 2018)',
#    'event_links_list': ['/wiki/Nh._Dini'],
#    'event_first_link': '/wiki/Nh._Dini',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1940',
#    'event_description': 'Sonja Barend, Dutch talk show host',
#    'event_links_list': ['/wiki/1940', '/wiki/Sonja_Barend'],
#    'event_first_link': '/wiki/Sonja_Barend',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1940',
#    'event_description': '– Bartholomew I of Constantinople',
#    'event_links_list': ['/wiki/Bartholomew_I_of_Constantinople'],
#    'event_first_link': '/wiki/Bartholomew_I_of_Constantinople',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1940',
#    'event_description': '– William H. Turner, Jr., American horse trainer',
#    'event_links_list': ['/wiki/William_H._Turner,_Jr.'],
#    'event_first_link': '/wiki/William_H._Turner,_Jr.',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1944',
#    'event_description': 'Ene Ergma, Estonian physicist and politician',
#    'event_links_list': ['/wiki/1944', '/wiki/Ene_Ergma'],
#    'event_first_link': '/wiki/Ene_Ergma',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1944',
#    'event_description': '– Dennis Farina, American police officer and actor (d. 2013)',
#    'event_links_list': ['/wiki/Dennis_Farina'],
#    'event_first_link': '/wiki/Dennis_Farina',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1944',
#    'event_description': '– Nicholas Frayling, English priest and academic',
#    'event_links_list': ['/wiki/Nicholas_Frayling'],
#    'event_first_link': '/wiki/Nicholas_Frayling',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1944',
#    'event_description': '– Phyllis Frelich, American actress (d. 2014)',
#    'event_links_list': ['/wiki/Phyllis_Frelich'],
#    'event_first_link': '/wiki/Phyllis_Frelich',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1944',
#    'event_description': '– Steve Mingori, American baseball player (d. 2008)',
#    'event_links_list': ['/wiki/Steve_Mingori'],
#    'event_first_link': '/wiki/Steve_Mingori',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1944',
#    'event_description': '– Paolo Eleuteri Serpieri, Italian author and illustrator',
#    'event_links_list': ['/wiki/Paolo_Eleuteri_Serpieri'],
#    'event_first_link': '/wiki/Paolo_Eleuteri_Serpieri',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1944',
#    'event_description': '– Lennart Svedberg, Swedish ice hockey player (d. 1972).[5]',
#    'event_links_list': ['/wiki/Lennart_Svedberg'],
#    'event_first_link': '/wiki/Lennart_Svedberg',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1948',
#    'event_description': 'Hermione Lee, English author, critic, and academic',
#    'event_links_list': ['/wiki/1948', '/wiki/Hermione_Lee'],
#    'event_first_link': '/wiki/Hermione_Lee',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1948',
#    'event_description': '– Manoel Maria, Brazilian footballer',
#    'event_links_list': ['/wiki/Manoel_Maria'],
#    'event_first_link': '/wiki/Manoel_Maria',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1948',
#    'event_description': '– Patricia A. McKillip, American author',
#    'event_links_list': ['/wiki/Patricia_A._McKillip'],
#    'event_first_link': '/wiki/Patricia_A._McKillip',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1948',
#    'event_description': '– Henry Small, American-born Canadian singer',
#    'event_links_list': ['/wiki/Henry_Small_(singer)'],
#    'event_first_link': '/wiki/Henry_Small_(singer)',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1952',
#    'event_description': 'Sharon Dahlonega Raiford Bush, American journalist and producer',
#    'event_links_list': ['/wiki/1952', '/wiki/Sharon_Dahlonega_Raiford_Bush'],
#    'event_first_link': '/wiki/Sharon_Dahlonega_Raiford_Bush',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1952',
#    'event_description': '– Tim Powers, American author and educator',
#    'event_links_list': ['/wiki/Tim_Powers'],
#    'event_first_link': '/wiki/Tim_Powers',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1952',
#    'event_description': '– Raisa Smetanina, Russian cross-country skier',
#    'event_links_list': ['/wiki/Raisa_Smetanina'],
#    'event_first_link': '/wiki/Raisa_Smetanina',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1952',
#    'event_description': '– Bart Stupak, American police officer and politician',
#    'event_links_list': ['/wiki/Bart_Stupak'],
#    'event_first_link': '/wiki/Bart_Stupak',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1956',
#    'event_description': 'Jonathan Coleman, English-Australian radio and television host',
#    'event_links_list': ['/wiki/1956', '/wiki/Jonathan_Coleman_(presenter)'],
#    'event_first_link': '/wiki/Jonathan_Coleman_(presenter)',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1956',
#    'event_description': '– Bob Speller, Canadian businessman and politician, 30th Canadian Minister of Agriculture',
#    'event_links_list': ['/wiki/Bob_Speller',
#     '/wiki/Minister_of_Agriculture_(Canada)'],
#    'event_first_link': '/wiki/Bob_Speller',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1956',
#    'event_description': '– Aileen Wuornos, American serial killer (d. 2002)',
#    'event_links_list': ['/wiki/Aileen_Wuornos'],
#    'event_first_link': '/wiki/Aileen_Wuornos',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1960',
#    'event_description': 'Lucian Grainge, English businessman',
#    'event_links_list': ['/wiki/1960', '/wiki/Lucian_Grainge'],
#    'event_first_link': '/wiki/Lucian_Grainge',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1960',
#    'event_description': '– Khaled, Algerian singer-songwriter',
#    'event_links_list': ['/wiki/Khaled_(musician)'],
#    'event_first_link': '/wiki/Khaled_(musician)',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1960',
#    'event_description': '– Richard Ramirez, American serial killer (d. 2013)',
#    'event_links_list': ['/wiki/Richard_Ramirez'],
#    'event_first_link': '/wiki/Richard_Ramirez',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1964',
#    'event_description': 'Dave Brailsford, English cyclist and coach',
#    'event_links_list': ['/wiki/1964', '/wiki/Dave_Brailsford'],
#    'event_first_link': '/wiki/Dave_Brailsford',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1964',
#    'event_description': '– Lyndon Byers, Canadian ice hockey player and radio host',
#    'event_links_list': ['/wiki/Lyndon_Byers'],
#    'event_first_link': '/wiki/Lyndon_Byers',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1964',
#    'event_description': '– Mervyn Warren, American tenor, composer, and producer',
#    'event_links_list': ['/wiki/Mervyn_Warren'],
#    'event_first_link': '/wiki/Mervyn_Warren',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1968',
#    'event_description': 'Chucky Brown, American basketball player and coach',
#    'event_links_list': ['/wiki/1968', '/wiki/Chucky_Brown'],
#    'event_first_link': '/wiki/Chucky_Brown',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1968',
#    'event_description': '– Gareth Farr, New Zealand composer and percussionist',
#    'event_links_list': ['/wiki/Gareth_Farr'],
#    'event_first_link': '/wiki/Gareth_Farr',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1968',
#    'event_description': '– Pete Fenson, American curler and sportscaster',
#    'event_links_list': ['/wiki/Pete_Fenson'],
#    'event_first_link': '/wiki/Pete_Fenson',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1968',
#    'event_description': '– Naoko Iijima, Japanese actress and model',
#    'event_links_list': ['/wiki/Naoko_Iijima'],
#    'event_first_link': '/wiki/Naoko_Iijima',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1968',
#    'event_description': '– Bryce Paup, American football player and coach',
#    'event_links_list': ['/wiki/Bryce_Paup'],
#    'event_first_link': '/wiki/Bryce_Paup',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1968',
#    'event_description': '– Howard Tayler, American author and illustrator',
#    'event_links_list': ['/wiki/Howard_Tayler'],
#    'event_first_link': '/wiki/Howard_Tayler',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1968',
#    'event_description': '– Eugene Volokh, Ukrainian-American lawyer and educator',
#    'event_links_list': ['/wiki/Eugene_Volokh'],
#    'event_first_link': '/wiki/Eugene_Volokh',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1968',
#    'event_description': '– Frank Woodley, Australian actor, producer, and screenwriter',
#    'event_links_list': ['/wiki/Frank_Woodley'],
#    'event_first_link': '/wiki/Frank_Woodley',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1972',
#    'event_description': 'Mike Pollitt, English footballer and coach',
#    'event_links_list': ['/wiki/1972', '/wiki/Mike_Pollitt'],
#    'event_first_link': '/wiki/Mike_Pollitt',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1972',
#    'event_description': '– Sylvie Lubamba, Italian showgirl',
#    'event_links_list': ['/wiki/Sylvie_Lubamba'],
#    'event_first_link': '/wiki/Sylvie_Lubamba',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1972',
#    'event_description': '– Antonio Sabàto Jr., Italian-American model and actor',
#    'event_links_list': ['/wiki/Antonio_Sab%C3%A0to_Jr.'],
#    'event_first_link': '/wiki/Antonio_Sab%C3%A0to_Jr.',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1972',
#    'event_description': '– Pedro Sánchez, Prime Minister of Spain',
#    'event_links_list': ['/wiki/Pedro_S%C3%A1nchez_(Spanish_politician)',
#     '/wiki/Prime_Minister_of_Spain'],
#    'event_first_link': '/wiki/Pedro_S%C3%A1nchez_(Spanish_politician)',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1972',
#    'event_description': '– Dave Williams, American singer (d. 2002)',
#    'event_links_list': ['/wiki/Dave_Williams_(singer)'],
#    'event_first_link': '/wiki/Dave_Williams_(singer)',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1972',
#    'event_description': '– Saul Williams, American singer-songwriter[6]',
#    'event_links_list': ['/wiki/Saul_Williams'],
#    'event_first_link': '/wiki/Saul_Williams',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1972',
#    'event_description': '– Pedro Zamora, Cuban-American activist and educator (d. 1994)',
#    'event_links_list': ['/wiki/Pedro_Zamora'],
#    'event_first_link': '/wiki/Pedro_Zamora',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1976',
#    'event_description': 'Vonteego Cummings, American basketball player',
#    'event_links_list': ['/wiki/1976', '/wiki/Vonteego_Cummings'],
#    'event_first_link': '/wiki/Vonteego_Cummings',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1976',
#    'event_description': '– Gehad Grisha, Egyptian soccer referee',
#    'event_links_list': ['/wiki/Gehad_Grisha'],
#    'event_first_link': '/wiki/Gehad_Grisha',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1976',
#    'event_description': '– Katalin Kovács, Hungarian sprint kayaker[7]',
#    'event_links_list': ['/wiki/Katalin_Kov%C3%A1cs'],
#    'event_first_link': '/wiki/Katalin_Kov%C3%A1cs',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1976',
#    'event_description': '– Terrence Long, American baseball player',
#    'event_links_list': ['/wiki/Terrence_Long'],
#    'event_first_link': '/wiki/Terrence_Long',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1976',
#    'event_description': '– Ja Rule, American rapper and actor',
#    'event_links_list': ['/wiki/Ja_Rule'],
#    'event_first_link': '/wiki/Ja_Rule',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1980',
#    'event_description': 'Çağdaş Atan, Turkish footballer and coach',
#    'event_links_list': ['/wiki/1980', '/wiki/%C3%87a%C4%9Fda%C5%9F_Atan'],
#    'event_first_link': '/wiki/%C3%87a%C4%9Fda%C5%9F_Atan',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1980',
#    'event_description': '– Chris Conley, American singer-songwriter and guitarist',
#    'event_links_list': ['/wiki/Chris_Conley'],
#    'event_first_link': '/wiki/Chris_Conley',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1980',
#    'event_description': '– Patrick Côté, Canadian mixed martial artist',
#    'event_links_list': ['/wiki/Patrick_C%C3%B4t%C3%A9_(fighter)'],
#    'event_first_link': '/wiki/Patrick_C%C3%B4t%C3%A9_(fighter)',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1980',
#    'event_description': '– Simon Gagné, Canadian ice hockey player',
#    'event_links_list': ['/wiki/Simon_Gagn%C3%A9'],
#    'event_first_link': '/wiki/Simon_Gagn%C3%A9',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1980',
#    'event_description': '– Rubén Plaza, Spanish cyclist',
#    'event_links_list': ['/wiki/Rub%C3%A9n_Plaza'],
#    'event_first_link': '/wiki/Rub%C3%A9n_Plaza',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1980',
#    'event_description': '– Peter Scanavino, American actor',
#    'event_links_list': ['/wiki/Peter_Scanavino'],
#    'event_first_link': '/wiki/Peter_Scanavino',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1980',
#    'event_description': '– Clinton Toopi, New Zealand rugby league player',
#    'event_links_list': ['/wiki/Clinton_Toopi'],
#    'event_first_link': '/wiki/Clinton_Toopi',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1980',
#    'event_description': '– Taylor Twellman, American soccer player and sportscaster[8]',
#    'event_links_list': ['/wiki/Taylor_Twellman'],
#    'event_first_link': '/wiki/Taylor_Twellman',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1984',
#    'event_description': 'Rica Imai, Japanese model and actress',
#    'event_links_list': ['/wiki/1984', '/wiki/Rica_Imai'],
#    'event_first_link': '/wiki/Rica_Imai',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1984',
#    'event_description': '– Cullen Jones, American swimmer[9]',
#    'event_links_list': ['/wiki/Cullen_Jones'],
#    'event_first_link': '/wiki/Cullen_Jones',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1984',
#    'event_description': '– Nuria Martínez, Spanish basketball player',
#    'event_links_list': ['/wiki/Nuria_Mart%C3%ADnez'],
#    'event_first_link': '/wiki/Nuria_Mart%C3%ADnez',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1984',
#    'event_description': '– Lena Raine, American video game composer and producer [10]',
#    'event_links_list': ['/wiki/Lena_Raine'],
#    'event_first_link': '/wiki/Lena_Raine',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1984',
#    'event_description': '– Adam Sinclair, Indian field hockey player',
#    'event_links_list': ['/wiki/Adam_Sinclair'],
#    'event_first_link': '/wiki/Adam_Sinclair',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1984',
#    'event_description': '– Rakhee Thakrar, English actress',
#    'event_links_list': ['/wiki/Rakhee_Thakrar'],
#    'event_first_link': '/wiki/Rakhee_Thakrar',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1984',
#    'event_description': '– Dennis Walger, German rugby player',
#    'event_links_list': ['/wiki/Dennis_Walger'],
#    'event_first_link': '/wiki/Dennis_Walger',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1984',
#    'event_description': '– Cam Ward, Canadian ice hockey player',
#    'event_links_list': ['/wiki/Cam_Ward'],
#    'event_first_link': '/wiki/Cam_Ward',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1984',
#    'event_description': '– Mark Foster, American singer, songwriter and musician',
#    'event_links_list': ['/wiki/Mark_Foster_(singer)'],
#    'event_first_link': '/wiki/Mark_Foster_(singer)',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1988',
#    'event_description': 'Lena Gercke, German model and television host',
#    'event_links_list': ['/wiki/1988', '/wiki/Lena_Gercke'],
#    'event_first_link': '/wiki/Lena_Gercke',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1988',
#    'event_description': '– Benedikt Höwedes, German footballer',
#    'event_links_list': ['/wiki/Benedikt_H%C3%B6wedes'],
#    'event_first_link': '/wiki/Benedikt_H%C3%B6wedes',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1988',
#    'event_description': '– Brent Macaffer, Australian Rules footballer[11]',
#    'event_links_list': ['/wiki/Brent_Macaffer'],
#    'event_first_link': '/wiki/Brent_Macaffer',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1988',
#    'event_description': '– Bobby Sanguinetti, American ice hockey player',
#    'event_links_list': ['/wiki/Bobby_Sanguinetti'],
#    'event_first_link': '/wiki/Bobby_Sanguinetti',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1988',
#    'event_description': '– Milan Melindo, Filipino boxer',
#    'event_links_list': ['/wiki/Milan_Melindo'],
#    'event_first_link': '/wiki/Milan_Melindo',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1992',
#    'event_description': 'Sean Abbott, Australian cricketer',
#    'event_links_list': ['/wiki/1992', '/wiki/Sean_Abbott'],
#    'event_first_link': '/wiki/Sean_Abbott',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1992',
#    'event_description': '– Ben Hampton, Australian rugby league player',
#    'event_links_list': ['/wiki/Ben_Hampton'],
#    'event_first_link': '/wiki/Ben_Hampton',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1992',
#    'event_description': '– Eric Kendricks, American football player[12]',
#    'event_links_list': ['/wiki/Eric_Kendricks'],
#    'event_first_link': '/wiki/Eric_Kendricks',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1992',
#    'event_description': '– Caitlin EJ Meyer, American actress',
#    'event_links_list': ['/wiki/Caitlin_EJ_Meyer'],
#    'event_first_link': '/wiki/Caitlin_EJ_Meyer',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1996',
#    'event_description': 'Nelson Asofa-Solomona, New Zealand rugby league player',
#    'event_links_list': ['/wiki/1996', '/wiki/Nelson_Asofa-Solomona'],
#    'event_first_link': '/wiki/Nelson_Asofa-Solomona',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1996',
#    'event_description': '– Reece Prescod, British sprinter[13]',
#    'event_links_list': ['/wiki/Reece_Prescod'],
#    'event_first_link': '/wiki/Reece_Prescod',
#    'event_category': nan,
#    'bc_ad': 'ad',
#    'bc_ad_note': 'assumed'},
#   {'year': '1996',
# ...
#  <li><a href="/wiki/June_13" title="June 13">13</a></li>
#  <li><a href="/wiki/June_14" title="June 14">14</a></li>
#  <li><a href="/wiki/June_15" title="June 15">15</a></li>
#  <li><a href="/wiki/June_16" title="June 16">16</a></li>
#  <li><a href="/wiki/June_17" title="June 17">17</a></li>
#  <li><a href="/wiki/June_18" title="June 18">18</a></li>
#  <li><a href="/wiki/June_19" title="June 19">19</a></li>
#  <li><a href="/wiki/June_20" title="June 20">20</a></li>
#  <li><a href="/wiki/June_21" title="June 21">21</a></li>
#  <li><a href="/wiki/June_22" title="June 22">22</a></li>
#  <li><a href="/wiki/June_23" title="June 23">23</a></li>
#  <li><a href="/wiki/June_24" title="June 24">24</a></li>
#  <li><a href="/wiki/June_25" title="June 25">25</a></li>
#  <li><a href="/wiki/June_26" title="June 26">26</a></li>
#  <li><a href="/wiki/June_27" title="June 27">27</a></li>
#  <li><a href="/wiki/June_28" title="June 28">28</a></li>
#  <li><a href="/wiki/June_29" title="June 29">29</a></li>
#  <li><a href="/wiki/June_30" title="June 30">30</a></li></ul>
#  </div></td></tr><tr><th class="navbox-group" scope="row" style="width:1%"><a href="/wiki/July" title="July">July</a></th><td class="navbox-list navbox-odd hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
#  <ul><li><a href="/wiki/July_1" title="July 1">1</a></li>
#  <li><a href="/wiki/July_2" title="July 2">2</a></li>
#  <li><a href="/wiki/July_3" title="July 3">3</a></li>
#  <li><a href="/wiki/July_4" title="July 4">4</a></li>
#  <li><a href="/wiki/July_5" title="July 5">5</a></li>
#  <li><a href="/wiki/July_6" title="July 6">6</a></li>
#  <li><a href="/wiki/July_7" title="July 7">7</a></li>
#  <li><a href="/wiki/July_8" title="July 8">8</a></li>
#  <li><a href="/wiki/July_9" title="July 9">9</a></li>
#  <li><a href="/wiki/July_10" title="July 10">10</a></li>
#  <li><a href="/wiki/July_11" title="July 11">11</a></li>
#  <li><a href="/wiki/July_12" title="July 12">12</a></li>
#  <li><a href="/wiki/July_13" title="July 13">13</a></li>
#  <li><a href="/wiki/July_14" title="July 14">14</a></li>
#  <li><a href="/wiki/July_15" title="July 15">15</a></li>
#  <li><a href="/wiki/July_16" title="July 16">16</a></li>
#  <li><a href="/wiki/July_17" title="July 17">17</a></li>
#  <li><a href="/wiki/July_18" title="July 18">18</a></li>
#  <li><a href="/wiki/July_19" title="July 19">19</a></li>
#  <li><a href="/wiki/July_20" title="July 20">20</a></li>
#  <li><a href="/wiki/July_21" title="July 21">21</a></li>
#  <li><a href="/wiki/July_22" title="July 22">22</a></li>
#  <li><a href="/wiki/July_23" title="July 23">23</a></li>
#  <li><a href="/wiki/July_24" title="July 24">24</a></li>
#  <li><a href="/wiki/July_25" title="July 25">25</a></li>
#  <li><a href="/wiki/July_26" title="July 26">26</a></li>
#  <li><a href="/wiki/July_27" title="July 27">27</a></li>
#  <li><a href="/wiki/July_28" title="July 28">28</a></li>
#  <li><a href="/wiki/July_29" title="July 29">29</a></li>
#  <li><a href="/wiki/July_30" title="July 30">30</a></li>
#  <li><a href="/wiki/July_31" title="July 31">31</a></li></ul>
#  </div></td></tr><tr><th class="navbox-group" scope="row" style="width:1%"><a href="/wiki/August" title="August">August</a></th><td class="navbox-list navbox-even hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
#  <ul><li><a href="/wiki/August_1" title="August 1">1</a></li>
#  <li><a href="/wiki/August_2" title="August 2">2</a></li>
#  <li><a href="/wiki/August_3" title="August 3">3</a></li>
#  <li><a href="/wiki/August_4" title="August 4">4</a></li>
#  <li><a href="/wiki/August_5" title="August 5">5</a></li>
#  <li><a href="/wiki/August_6" title="August 6">6</a></li>
#  <li><a href="/wiki/August_7" title="August 7">7</a></li>
#  <li><a href="/wiki/August_8" title="August 8">8</a></li>
#  <li><a href="/wiki/August_9" title="August 9">9</a></li>
#  <li><a href="/wiki/August_10" title="August 10">10</a></li>
#  <li><a href="/wiki/August_11" title="August 11">11</a></li>
#  <li><a href="/wiki/August_12" title="August 12">12</a></li>
#  <li><a href="/wiki/August_13" title="August 13">13</a></li>
#  <li><a href="/wiki/August_14" title="August 14">14</a></li>
#  <li><a href="/wiki/August_15" title="August 15">15</a></li>
#  <li><a href="/wiki/August_16" title="August 16">16</a></li>
#  <li><a href="/wiki/August_17" title="August 17">17</a></li>
#  <li><a href="/wiki/August_18" title="August 18">18</a></li>
#  <li><a href="/wiki/August_19" title="August 19">19</a></li>
#  <li><a href="/wiki/August_20" title="August 20">20</a></li>
#  <li><a href="/wiki/August_21" title="August 21">21</a></li>
#  <li><a href="/wiki/August_22" title="August 22">22</a></li>
#  <li><a href="/wiki/August_23" title="August 23">23</a></li>
#  <li><a href="/wiki/August_24" title="August 24">24</a></li>
#  <li><a href="/wiki/August_25" title="August 25">25</a></li>
#  <li><a href="/wiki/August_26" title="August 26">26</a></li>
#  <li><a href="/wiki/August_27" title="August 27">27</a></li>
#  <li><a href="/wiki/August_28" title="August 28">28</a></li>
#  <li><a href="/wiki/August_29" title="August 29">29</a></li>
#  <li><a href="/wiki/August_30" title="August 30">30</a></li>
#  <li><a href="/wiki/August_31" title="August 31">31</a></li></ul>
#  </div></td></tr><tr><th class="navbox-group" scope="row" style="width:1%"><a href="/wiki/September" title="September">September</a></th><td class="navbox-list navbox-odd hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
#  <ul><li><a href="/wiki/September_1" title="September 1">1</a></li>
#  <li><a href="/wiki/September_2" title="September 2">2</a></li>
#  <li><a href="/wiki/September_3" title="September 3">3</a></li>
#  <li><a href="/wiki/September_4" title="September 4">4</a></li>
#  <li><a href="/wiki/September_5" title="September 5">5</a></li>
#  <li><a href="/wiki/September_6" title="September 6">6</a></li>
#  <li><a href="/wiki/September_7" title="September 7">7</a></li>
#  <li><a href="/wiki/September_8" title="September 8">8</a></li>
#  <li><a href="/wiki/September_9" title="September 9">9</a></li>
#  <li><a href="/wiki/September_10" title="September 10">10</a></li>
#  <li><a href="/wiki/September_11" title="September 11">11</a></li>
#  <li><a href="/wiki/September_12" title="September 12">12</a></li>
#  <li><a href="/wiki/September_13" title="September 13">13</a></li>
#  <li><a href="/wiki/September_14" title="September 14">14</a></li>
#  <li><a href="/wiki/September_15" title="September 15">15</a></li>
#  <li><a href="/wiki/September_16" title="September 16">16</a></li>
#  <li><a href="/wiki/September_17" title="September 17">17</a></li>
#  <li><a href="/wiki/September_18" title="September 18">18</a></li>
#  <li><a href="/wiki/September_19" title="September 19">19</a></li>
#  <li><a href="/wiki/September_20" title="September 20">20</a></li>
#  <li><a href="/wiki/September_21" title="September 21">21</a></li>
#  <li><a href="/wiki/September_22" title="September 22">22</a></li>
#  <li><a href="/wiki/September_23" title="September 23">23</a></li>
#  <li><a href="/wiki/September_24" title="September 24">24</a></li>
#  <li><a href="/wiki/September_25" title="September 25">25</a></li>
#  <li><a href="/wiki/September_26" title="September 26">26</a></li>
#  <li><a href="/wiki/September_27" title="September 27">27</a></li>
#  <li><a href="/wiki/September_28" title="September 28">28</a></li>
#  <li><a href="/wiki/September_29" title="September 29">29</a></li>
#  <li><a href="/wiki/September_30" title="September 30">30</a></li></ul>
#  </div></td></tr><tr><th class="navbox-group" scope="row" style="width:1%"><a href="/wiki/October" title="October">October</a></th><td class="navbox-list navbox-even hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
#  <ul><li><a href="/wiki/October_1" title="October 1">1</a></li>
#  <li><a href="/wiki/October_2" title="October 2">2</a></li>
#  <li><a href="/wiki/October_3" title="October 3">3</a></li>
#  <li><a href="/wiki/October_4" title="October 4">4</a></li>
#  <li><a href="/wiki/October_5" title="October 5">5</a></li>
#  <li><a href="/wiki/October_6" title="October 6">6</a></li>
#  <li><a href="/wiki/October_7" title="October 7">7</a></li>
#  <li><a href="/wiki/October_8" title="October 8">8</a></li>
#  <li><a href="/wiki/October_9" title="October 9">9</a></li>
#  <li><a href="/wiki/October_10" title="October 10">10</a></li>
#  <li><a href="/wiki/October_11" title="October 11">11</a></li>
#  <li><a href="/wiki/October_12" title="October 12">12</a></li>
#  <li><a href="/wiki/October_13" title="October 13">13</a></li>
#  <li><a href="/wiki/October_14" title="October 14">14</a></li>
#  <li><a href="/wiki/October_15" title="October 15">15</a></li>
#  <li><a href="/wiki/October_16" title="October 16">16</a></li>
#  <li><a href="/wiki/October_17" title="October 17">17</a></li>
#  <li><a href="/wiki/October_18" title="October 18">18</a></li>
#  <li><a href="/wiki/October_19" title="October 19">19</a></li>
#  <li><a href="/wiki/October_20" title="October 20">20</a></li>
#  <li><a href="/wiki/October_21" title="October 21">21</a></li>
#  <li><a href="/wiki/October_22" title="October 22">22</a></li>
#  <li><a href="/wiki/October_23" title="October 23">23</a></li>
#  <li><a href="/wiki/October_24" title="October 24">24</a></li>
#  <li><a href="/wiki/October_25" title="October 25">25</a></li>
#  <li><a href="/wiki/October_26" title="October 26">26</a></li>
#  <li><a href="/wiki/October_27" title="October 27">27</a></li>
#  <li><a href="/wiki/October_28" title="October 28">28</a></li>
#  <li><a href="/wiki/October_29" title="October 29">29</a></li>
#  <li><a href="/wiki/October_30" title="October 30">30</a></li>
#  <li><a href="/wiki/October_31" title="October 31">31</a></li></ul>
#  </div></td></tr><tr><th class="navbox-group" scope="row" style="width:1%"><a href="/wiki/November" title="November">November</a></th><td class="navbox-list navbox-odd hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
#  <ul><li><a href="/wiki/November_1" title="November 1">1</a></li>
#  <li><a href="/wiki/November_2" title="November 2">2</a></li>
#  <li><a href="/wiki/November_3" title="November 3">3</a></li>
#  <li><a href="/wiki/November_4" title="November 4">4</a></li>
#  <li><a href="/wiki/November_5" title="November 5">5</a></li>
#  <li><a href="/wiki/November_6" title="November 6">6</a></li>
#  <li><a href="/wiki/November_7" title="November 7">7</a></li>
#  <li><a href="/wiki/November_8" title="November 8">8</a></li>
#  <li><a href="/wiki/November_9" title="November 9">9</a></li>
#  <li><a href="/wiki/November_10" title="November 10">10</a></li>
#  <li><a href="/wiki/November_11" title="November 11">11</a></li>
#  <li><a href="/wiki/November_12" title="November 12">12</a></li>
#  <li><a href="/wiki/November_13" title="November 13">13</a></li>
#  <li><a href="/wiki/November_14" title="November 14">14</a></li>
#  <li><a href="/wiki/November_15" title="November 15">15</a></li>
#  <li><a href="/wiki/November_16" title="November 16">16</a></li>
#  <li><a href="/wiki/November_17" title="November 17">17</a></li>
#  <li><a href="/wiki/November_18" title="November 18">18</a></li>
#  <li><a href="/wiki/November_19" title="November 19">19</a></li>
#  <li><a href="/wiki/November_20" title="November 20">20</a></li>
#  <li><a href="/wiki/November_21" title="November 21">21</a></li>
#  <li><a href="/wiki/November_22" title="November 22">22</a></li>
#  <li><a href="/wiki/November_23" title="November 23">23</a></li>
#  <li><a href="/wiki/November_24" title="November 24">24</a></li>
#  <li><a href="/wiki/November_25" title="November 25">25</a></li>
#  <li><a href="/wiki/November_26" title="November 26">26</a></li>
#  <li><a href="/wiki/November_27" title="November 27">27</a></li>
#  <li><a href="/wiki/November_28" title="November 28">28</a></li>
#  <li><a href="/wiki/November_29" title="November 29">29</a></li>
#  <li><a href="/wiki/November_30" title="November 30">30</a></li></ul>
#  </div></td></tr><tr><th class="navbox-group" scope="row" style="width:1%"><a href="/wiki/December" title="December">December</a></th><td class="navbox-list navbox-even hlist" style="text-align:left;border-left-width:2px;border-left-style:solid;width:100%;padding:0px"><div style="padding:0em 0.25em">
#  <ul><li><a href="/wiki/December_1" title="December 1">1</a></li>
#  <li><a href="/wiki/December_2" title="December 2">2</a></li>
#  <li><a href="/wiki/December_3" title="December 3">3</a></li>
#  <li><a href="/wiki/December_4" title="December 4">4</a></li>
#  <li><a href="/wiki/December_5" title="December 5">5</a></li>
#  <li><a href="/wiki/December_6" title="December 6">6</a></li>
#  <li><a href="/wiki/December_7" title="December 7">7</a></li>
#  <li><a href="/wiki/December_8" title="December 8">8</a></li>
#  <li><a href="/wiki/December_9" title="December 9">9</a></li>
#  <li><a href="/wiki/December_10" title="December 10">10</a></li>
#  <li><a href="/wiki/December_11" title="December 11">11</a></li>
#  <li><a href="/wiki/December_12" title="December 12">12</a></li>
#  <li><a href="/wiki/December_13" title="December 13">13</a></li>
#  <li><a href="/wiki/December_14" title="December 14">14</a></li>
#  <li><a href="/wiki/December_15" title="December 15">15</a></li>
#  <li><a href="/wiki/December_16" title="December 16">16</a></li>
#  <li><a href="/wiki/December_17" title="December 17">17</a></li>
#  <li><a href="/wiki/December_18" title="December 18">18</a></li>
#  <li><a href="/wiki/December_19" title="December 19">19</a></li>
#  <li><a href="/wiki/December_20" title="December 20">20</a></li>
#  <li><a href="/wiki/December_21" title="December 21">21</a></li>
#  <li><a href="/wiki/December_22" title="December 22">22</a></li>
#  <li><a href="/wiki/December_23" title="December 23">23</a></li>
#  <li><a href="/wiki/December_24" title="December 24">24</a></li>
#  <li><a href="/wiki/December_25" title="December 25">25</a></li>
#  <li><a href="/wiki/December_26" title="December 26">26</a></li>
#  <li><a href="/wiki/December_27" title="December 27">27</a></li>
#  <li><a href="/wiki/December_28" title="December 28">28</a></li>
#  <li><a href="/wiki/December_29" title="December 29">29</a></li>
#  <li><a href="/wiki/December_30" title="December 30">30</a></li>
#  <li><a href="/wiki/December_31" title="December 31">31</a></li></ul>
#  </div></td></tr><tr><td class="navbox-abovebelow hlist" colspan="2"><div>
#  <ul><li>Related: <a href="/wiki/List_of_non-standard_dates" title="List of non-standard dates">List of non-standard dates</a></li></ul>
#  </div></td></tr></tbody></table></div>
#  <!--
#  NewPP limit report
#  Parsed by mw1282
#  Cached time: 20210130210921
#  Cache expiry: 3600
#  Dynamic content: true
#  Complications: [vary‐revision‐sha1]
#  CPU time usage: 0.684 seconds
#  Real time usage: 1.076 seconds
#  Preprocessor visited node count: 2975/1000000
#  Post‐expand include size: 89358/2097152 bytes
#  Template argument size: 5936/2097152 bytes
#  Highest expansion depth: 24/40
#  Expensive parser function count: 17/500
#  Unstrip recursion depth: 1/20
#  Unstrip post‐expand size: 45455/5000000 bytes
#  Lua time usage: 0.282/10.000 seconds
#  Lua memory usage: 7100660/52428800 bytes
#  Number of Wikibase entities loaded: 1/400
#  -->
#  <!--
#  Transclusion expansion time report (%,ms,calls,template)
#  100.00%  865.282      1 -total
#   23.96%  207.338      1 Template:Reflist
#   14.98%  129.599      1 Template:Short_description
#   14.03%  121.430      1 Template:Cite_encyclopedia
#   10.94%   94.701      1 Template:This_date_in_recent_years
#   10.65%   92.187      1 Template:This_date_in_recent_years/validate
#   10.24%   88.605      1 Template:Pagetype
#   10.23%   88.538      1 Template:ThisDateInRecentYears/title
#    9.83%   85.091      1 Template:Calendar
#    9.62%   83.212      1 Template:ThisDateInRecentYears/prevleap
#  -->
#  <!-- Saved in parser cache with key enwiki:pcache:idhash:10936-0!canonical and timestamp 20210130210920 and revision id 1001261771. Serialized with JSON.
#   -->
#  </div>}

# %%
d1.keys()
# Out:
# dict_keys(['no_event_for', 'events', 'births', 'deaths', 'holidays_and_observances', 'day', 'month', 'status_code', 'day_soup'])

# %%
dfev = pd.DataFrame(d1['events'])
dfev
# Out:
#     year                                  event_description  \
# 0   1504  Christopher Columbus uses his knowledge of a l...
# 1   1644        Abel Tasman's second Pacific voyage begins.
# 2   1704  Queen Anne's War: French forces and Native Ame...
# 3   1712  February 29 is followed by February 30 in Swed...
# 4   1720  Ulrika Eleonora, Queen of Sweden abdicates in ...
# 5   1752  King Alaungpaya founds Konbaung Dynasty, the l...
# 6   1768          Polish nobles form the Bar Confederation.
# 7   1796  The Jay Treaty between the United States and G...
# 8   1864  American Civil War: Kilpatrick–Dahlgren Raid f...
# 9   1892           St. Petersburg, Florida is incorporated.
# 10  1912  The Piedra Movediza (Moving Stone) of Tandil f...
# 11  1916          Tokelau is annexed by the United Kingdom.
# 12  1916  – Child labor: In South Carolina, the minimum ...
# 13  1920  Czechoslovak National Assembly adopts the Cons...
# 14  1936                February 26 Incident in Tokyo ends.
# 15  1940  12th Academy Awards: For her performance as "M...
# 16  1940  – Finland initiates Winter War peace negotiati...
# 17  1940  – In a ceremony held in Berkeley, California, ...
# 18  1944  World War II: The Admiralty Islands are invade...
# 19  1960  The 5.7 Mw  Agadir earthquake shakes coastal M...
# 20  1972  Vietnam War: Vietnamization: South Korea withd...
# 21  1980  Gordie Howe of the Hartford Whalers makes NHL ...
# 22  1984  Pierre Trudeau announces his retirement as Lib...
# 23  1988  South African archbishop Desmond Tutu is arres...
# 24  1988  – Svend Robinson becomes the first member of t...
# 25  1992  First day of Bosnia and Herzegovina independen...
# 26  1996  Faucett Flight 251 crashes in the Andes; all 1...
# 27  1996               – Siege of Sarajevo officially ends.
# 28  2000  Second Chechen War: Eighty-four Russian paratr...
# 29  2004  Jean-Bertrand Aristide is removed as President...
# 30  2008  The United Kingdom's Ministry of Defence decid...
# 31  2008  – Misha Defonseca admits to fabricating her me...
# 32  2020  2020 Democratic Party presidential primaries: ...
# 33  2020  – COVID-19 pandemic: South Korea reports a tot...
#
#                                      event_links_list  \
# 0   [/wiki/1504, /wiki/Christopher_Columbus, /wiki...
# 1                     [/wiki/1644, /wiki/Abel_Tasman]
# 2   [/wiki/1704, /wiki/Queen_Anne%27s_War, /wiki/N...
# 3   [/wiki/1712, /wiki/February_30, /wiki/Swedish_...
# 4   [/wiki/1720, /wiki/Ulrika_Eleonora,_Queen_of_S...
# 5   [/wiki/1752, /wiki/Alaungpaya, /wiki/Konbaung_...
# 6               [/wiki/1768, /wiki/Bar_Confederation]
# 7                      [/wiki/1796, /wiki/Jay_Treaty]
# 8   [/wiki/1864, /wiki/American_Civil_War, /wiki/K...
# 9         [/wiki/1892, /wiki/St._Petersburg,_Florida]
# 10  [/wiki/1912, /wiki/Piedra_Movediza, /wiki/Tandil]
# 11                        [/wiki/1916, /wiki/Tokelau]
# 12  [/wiki/Child_labor, /wiki/South_Carolina, /wik...
# 13  [/wiki/1920, /wiki/Czechoslovakia, /wiki/Czech...
# 14           [/wiki/1936, /wiki/February_26_Incident]
# 15  [/wiki/1940, /wiki/12th_Academy_Awards, /wiki/...
# 16                                 [/wiki/Winter_War]
# 17  [/wiki/Berkeley,_California, /wiki/Ernest_Lawr...
# 18  [/wiki/1944, /wiki/Admiralty_Islands, /wiki/Op...
# 19  [/wiki/1960, /wiki/1960_Agadir_earthquake, /wi...
# 20  [/wiki/1972, /wiki/Vietnam_War, /wiki/Vietnami...
# 21  [/wiki/1980, /wiki/Gordie_Howe, /wiki/Hartford...
# 22  [/wiki/1984, /wiki/Pierre_Trudeau, /wiki/Liber...
# 23  [/wiki/1988, /wiki/Desmond_Tutu, /wiki/Aparthe...
# 24  [/wiki/Svend_Robinson, /wiki/House_of_Commons_...
# 25  [/wiki/1992, /wiki/Bosnian_independence_refere...
# 26             [/wiki/1996, /wiki/Faucett_Flight_251]
# 27                          [/wiki/Siege_of_Sarajevo]
# 28             [/wiki/2000, /wiki/Second_Chechen_War]
# 29  [/wiki/2004, /wiki/Jean-Bertrand_Aristide, /wi...
# 30  [/wiki/2008, /wiki/Ministry_of_Defence_(United...
# 31  [/wiki/Misha_Defonseca, /wiki/Misha:_A_M%C3%A9...
# 32  [/wiki/2020, /wiki/2020_Democratic_Party_presi...
# 33          [/wiki/COVID-19_pandemic, /wiki/COVID-19]
#
#                                event_first_link  event_category bc_ad  \
# 0                    /wiki/Christopher_Columbus             NaN    ad
# 1                             /wiki/Abel_Tasman             NaN    ad
# 2                      /wiki/Queen_Anne%27s_War             NaN    ad
# 3                             /wiki/February_30             NaN    ad
# 4        /wiki/Ulrika_Eleonora,_Queen_of_Sweden             NaN    ad
# 5                              /wiki/Alaungpaya             NaN    ad
# 6                       /wiki/Bar_Confederation             NaN    ad
# 7                              /wiki/Jay_Treaty             NaN    ad
# 8                      /wiki/American_Civil_War             NaN    ad
# 9                 /wiki/St._Petersburg,_Florida             NaN    ad
# 10                        /wiki/Piedra_Movediza             NaN    ad
# 11                                /wiki/Tokelau             NaN    ad
# 12                            /wiki/Child_labor             NaN    ad
# 13                         /wiki/Czechoslovakia             NaN    ad
# 14                   /wiki/February_26_Incident             NaN    ad
# 15              /wiki/Gone_with_the_Wind_(film)             NaN    ad
# 16                             /wiki/Winter_War             NaN    ad
# 17                   /wiki/Berkeley,_California             NaN    ad
# 18                      /wiki/Admiralty_Islands             NaN    ad
# 19                                /wiki/Morocco             NaN    ad
# 20                            /wiki/Vietnam_War             NaN    ad
# 21                            /wiki/Gordie_Howe             NaN    ad
# 22                         /wiki/Pierre_Trudeau             NaN    ad
# 23                           /wiki/Desmond_Tutu             NaN    ad
# 24                         /wiki/Svend_Robinson             NaN    ad
# 25  /wiki/Bosnian_independence_referendum,_1992             NaN    ad
# 26                     /wiki/Faucett_Flight_251             NaN    ad
# 27                      /wiki/Siege_of_Sarajevo             NaN    ad
# 28                     /wiki/Second_Chechen_War             NaN    ad
# 29                 /wiki/Jean-Bertrand_Aristide             NaN    ad
# 30   /wiki/Ministry_of_Defence_(United_Kingdom)             NaN    ad
# 31                        /wiki/Misha_Defonseca             NaN    ad
# 32                              /wiki/Joe_Biden             NaN    ad
# 33                      /wiki/COVID-19_pandemic             NaN    ad
#
#    bc_ad_note
# 0     assumed
# 1     assumed
# 2     assumed
# 3     assumed
# 4     assumed
# 5     assumed
# 6     assumed
# 7     assumed
# 8     assumed
# 9     assumed
# 10    assumed
# 11    assumed
# 12    assumed
# 13    assumed
# 14    assumed
# 15    assumed
# 16    assumed
# 17    assumed
# 18    assumed
# 19    assumed
# 20    assumed
# 21    assumed
# 22    assumed
# 23    assumed
# 24    assumed
# 25    assumed
# 26    assumed
# 27    assumed
# 28    assumed
# 29    assumed
# 30    assumed
# 31    assumed
# 32    assumed
# 33    assumed

# %%
ddea = pd.DataFrame(d1['deaths'])
ddea
# Out:
#     year                                  event_description  \
# 0    468                                468 – Pope Hilarius
# 1    992  992 – Oswald of Worcester, Anglo-Saxon archbis...
# 2   1212  1212 – Hōnen, Japanese monk, founded Jōdo-shū ...
# 3   1460  1460 – Albert III, Duke of Bavaria-Munich (b. ...
# 4   1528  1528 – Patrick Hamilton, Scottish Protestant r...
# 5   1592  1592 – Alessandro Striggio, Italian composer a...
# 6   1600  1600 – Caspar Hennenberger, German pastor, his...
# 7   1604  1604 – John Whitgift, English archbishop and a...
# 8   1740  1740 – Pietro Ottoboni, Italian cardinal (b. 1...
# 9   1744  1744 – John Theophilus Desaguliers, French-Eng...
# 10  1792  1792 – Johann Andreas Stein, German piano buil...
# 11  1820  1820 – Johann Joachim Eschenburg, German histo...
# 12  1848  1848 – Louis-François Lejeune, French general,...
# 13  1852  1852 – Matsudaira Katataka, Japanese daimyō (b...
# 14  1868               1868 – Ludwig I of Bavaria (b. 1786)
# 15  1880  1880 – James Milne Wilson, Scottish-Australian...
# 16  1908            Pat Garrett, American sheriff (b. 1850)
# 17  1908  John Hope, 1st Marquess of Linlithgow, Scottis...
# 18  1920  1920 – Ernie Courtney, American baseball playe...
# 19  1928  Adolphe Appia, Swiss architect and theorist (b...
# 20  1928  Ina Coolbrith, American poet and librarian (b....
# 21  1940  1940 – E. F. Benson, English archaeologist and...
# 22  1944  1944 – Pehr Evind Svinhufvud, Finnish lawyer, ...
# 23  1948  Robert Barrington-Ward, English lawyer and jou...
# 24  1948  Rebel Oakes, American baseball player and mana...
# 25  1952  1952 – Quo Tai-chi, Chinese politician and dip...
# 26  1956  1956 – Elpidio Quirino, Filipino lawyer and po...
# 27  1960  Melvin Purvis, American police officer and  FB...
# 28  1960  Walter Yust, American journalist and author (b...
# 29  1964  1964 – Frank Albertson, American actor and sin...
# 30  1968  Lena Blackburne, American baseball player, coa...
# 31  1968  Tore Ørjasæter, Norwegian poet and educator (b...
# 32  1972  1972 – Tom Davies, American football player an...
# 33  1976  1976 – Florence P. Dwyer, American politician ...
# 34  1980  Yigal Allon, Israeli general and politician,  ...
# 35  1980  Gil Elvgren, American painter and illustrator ...
# 36  1984  1984 – Ludwik Starski, Polish screenwriter and...
# 37  1988  1988 – Sidney Harmon, American screenwriter an...
# 38  1992  1992 – Ruth Pitter, English poet and author (b...
# 39  1996  Wes Farrell, American singer-songwriter and pr...
# 40  1996  Ralph Rowe, American baseball player, coach an...
# 41  2000  2000 – Dennis Danell, American guitarist (b. 1...
# 42  2004  Kagamisato Kiyoji, Japanese sumo wrestler, the...
# 43  2004  Jerome Lawrence, American playwright and autho...
# 44  2004  Harold Bernard St. John, Barbadian lawyer and ...
# 45  2004   Lorrie Wilmot, South African cricketer (b. 1943)
# 46  2008             Janet Kagan, American author (b. 1946)
# 47  2008  Erik Ortvad, Danish painter and illustrator (b...
# 48  2008  Akira Yamada, Japanese scholar and philosopher...
# 49  2012      Roland Bautista, American guitarist (b. 1951)
# 50  2012  Davy Jones, English singer, guitarist and acto...
# 51  2012    Sheldon Moldoff, American illustrator (b. 1920)
# 52  2012  P. K. Narayana Panicker, Indian social leader ...
# 53  2016  Wenn V. Deramas, Filipino director and screenw...
# 54  2016  Gil Hill, American police officer, actor and p...
# 55  2016          Josefin Nilsson, Swedish singer (b. 1969)
# 56  2016      Louise Rennison, English author (b. 1951)[14]
# 57  2016     Mumtaz Qadri, Pakistani assassin (b. 1985)[15]
# 58  2020  Dieter Laser, German actor (Lexx, The Ogre, Th...
# 59  2020  Éva Székely, Hungarian Hall of Fame swimmer, O...
#
#                                      event_links_list  \
# 0                    [/wiki/468, /wiki/Pope_Hilarius]
# 1              [/wiki/992, /wiki/Oswald_of_Worcester]
# 2   [/wiki/1212, /wiki/H%C5%8Dnen, /wiki/J%C5%8Ddo...
# 3     [/wiki/1460, /wiki/Albert_III,_Duke_of_Bavaria]
# 4       [/wiki/1528, /wiki/Patrick_Hamilton_(martyr)]
# 5             [/wiki/1592, /wiki/Alessandro_Striggio]
# 6             [/wiki/1600, /wiki/Caspar_Hennenberger]
# 7                   [/wiki/1604, /wiki/John_Whitgift]
# 8      [/wiki/1740, /wiki/Pietro_Ottoboni_(cardinal)]
# 9     [/wiki/1744, /wiki/John_Theophilus_Desaguliers]
# 10           [/wiki/1792, /wiki/Johann_Andreas_Stein]
# 11      [/wiki/1820, /wiki/Johann_Joachim_Eschenburg]
# 12    [/wiki/1848, /wiki/Louis-Fran%C3%A7ois_Lejeune]
# 13            [/wiki/1852, /wiki/Matsudaira_Katataka]
# 14            [/wiki/1868, /wiki/Ludwig_I_of_Bavaria]
# 15  [/wiki/1880, /wiki/James_Milne_Wilson, /wiki/P...
# 16                                [/wiki/Pat_Garrett]
# 17  [/wiki/John_Hope,_1st_Marquess_of_Linlithgow, ...
# 18                 [/wiki/1920, /wiki/Ernie_Courtney]
# 19                              [/wiki/Adolphe_Appia]
# 20                              [/wiki/Ina_Coolbrith]
# 21                   [/wiki/1940, /wiki/E._F._Benson]
# 22  [/wiki/1944, /wiki/Pehr_Evind_Svinhufvud, /wik...
# 23                     [/wiki/Robert_Barrington-Ward]
# 24                                [/wiki/Rebel_Oakes]
# 25  [/wiki/1952, /wiki/Quo_Tai-chi, /wiki/Permanen...
# 26  [/wiki/1956, /wiki/Elpidio_Quirino, /wiki/Pres...
# 27                   [/wiki/Melvin_Purvis, /wiki/FBI]
# 28                                [/wiki/Walter_Yust]
# 29                [/wiki/1964, /wiki/Frank_Albertson]
# 30                            [/wiki/Lena_Blackburne]
# 31                   [/wiki/Tore_%C3%98rjas%C3%A6ter]
# 32  [/wiki/1972, /wiki/Tom_Davies_(American_footba...
# 33              [/wiki/1976, /wiki/Florence_P._Dwyer]
# 34  [/wiki/Yigal_Allon, /wiki/Prime_Minister_of_Is...
# 35                                [/wiki/Gil_Elvgren]
# 36                 [/wiki/1984, /wiki/Ludwik_Starski]
# 37                  [/wiki/1988, /wiki/Sidney_Harmon]
# 38                    [/wiki/1992, /wiki/Ruth_Pitter]
# 39                                [/wiki/Wes_Farrell]
# 40                                 [/wiki/Ralph_Rowe]
# 41                  [/wiki/2000, /wiki/Dennis_Danell]
# 42          [/wiki/Kagamisato_Kiyoji, /wiki/Yokozuna]
# 43                            [/wiki/Jerome_Lawrence]
# 44  [/wiki/Harold_Bernard_St._John, /wiki/Prime_Mi...
# 45                              [/wiki/Lorrie_Wilmot]
# 46                                [/wiki/Janet_Kagan]
# 47                                [/wiki/Erik_Ortvad]
# 48                               [/wiki/Akira_Yamada]
# 49                            [/wiki/Roland_Bautista]
# 50                      [/wiki/Davy_Jones_(musician)]
# 51                            [/wiki/Sheldon_Moldoff]
# 52                    [/wiki/P._K._Narayana_Panicker]
# 53                            [/wiki/Wenn_V._Deramas]
# 54                                   [/wiki/Gil_Hill]
# 55                            [/wiki/Josefin_Nilsson]
# 56                            [/wiki/Louise_Rennison]
# 57                               [/wiki/Mumtaz_Qadri]
# 58  [/wiki/Dieter_Laser, /wiki/Lexx, /wiki/The_Ogr...
# 59  [/wiki/%C3%89va_Sz%C3%A9kely, /wiki/Internatio...
#
#                                event_first_link  event_category bc_ad  \
# 0                           /wiki/Pope_Hilarius             NaN    ad
# 1                     /wiki/Oswald_of_Worcester             NaN    ad
# 2                              /wiki/H%C5%8Dnen             NaN    ad
# 3             /wiki/Albert_III,_Duke_of_Bavaria             NaN    ad
# 4               /wiki/Patrick_Hamilton_(martyr)             NaN    ad
# 5                     /wiki/Alessandro_Striggio             NaN    ad
# 6                     /wiki/Caspar_Hennenberger             NaN    ad
# 7                           /wiki/John_Whitgift             NaN    ad
# 8              /wiki/Pietro_Ottoboni_(cardinal)             NaN    ad
# 9             /wiki/John_Theophilus_Desaguliers             NaN    ad
# 10                   /wiki/Johann_Andreas_Stein             NaN    ad
# 11              /wiki/Johann_Joachim_Eschenburg             NaN    ad
# 12            /wiki/Louis-Fran%C3%A7ois_Lejeune             NaN    ad
# 13                    /wiki/Matsudaira_Katataka             NaN    ad
# 14                    /wiki/Ludwig_I_of_Bavaria             NaN    ad
# 15                     /wiki/James_Milne_Wilson             NaN    ad
# 16                            /wiki/Pat_Garrett             NaN    ad
# 17  /wiki/John_Hope,_1st_Marquess_of_Linlithgow             NaN    ad
# 18                         /wiki/Ernie_Courtney             NaN    ad
# 19                          /wiki/Adolphe_Appia             NaN    ad
# 20                          /wiki/Ina_Coolbrith             NaN    ad
# 21                           /wiki/E._F._Benson             NaN    ad
# 22                  /wiki/Pehr_Evind_Svinhufvud             NaN    ad
# 23                 /wiki/Robert_Barrington-Ward             NaN    ad
# 24                            /wiki/Rebel_Oakes             NaN    ad
# 25                            /wiki/Quo_Tai-chi             NaN    ad
# 26                        /wiki/Elpidio_Quirino             NaN    ad
# 27                          /wiki/Melvin_Purvis             NaN    ad
# 28                            /wiki/Walter_Yust             NaN    ad
# 29                        /wiki/Frank_Albertson             NaN    ad
# 30                        /wiki/Lena_Blackburne             NaN    ad
# 31               /wiki/Tore_%C3%98rjas%C3%A6ter             NaN    ad
# 32         /wiki/Tom_Davies_(American_football)             NaN    ad
# 33                      /wiki/Florence_P._Dwyer             NaN    ad
# 34                            /wiki/Yigal_Allon             NaN    ad
# 35                            /wiki/Gil_Elvgren             NaN    ad
# 36                         /wiki/Ludwik_Starski             NaN    ad
# 37                          /wiki/Sidney_Harmon             NaN    ad
# 38                            /wiki/Ruth_Pitter             NaN    ad
# 39                            /wiki/Wes_Farrell             NaN    ad
# 40                             /wiki/Ralph_Rowe             NaN    ad
# 41                          /wiki/Dennis_Danell             NaN    ad
# 42                      /wiki/Kagamisato_Kiyoji             NaN    ad
# 43                        /wiki/Jerome_Lawrence             NaN    ad
# 44                /wiki/Harold_Bernard_St._John             NaN    ad
# 45                          /wiki/Lorrie_Wilmot             NaN    ad
# 46                            /wiki/Janet_Kagan             NaN    ad
# 47                            /wiki/Erik_Ortvad             NaN    ad
# 48                           /wiki/Akira_Yamada             NaN    ad
# 49                        /wiki/Roland_Bautista             NaN    ad
# 50                  /wiki/Davy_Jones_(musician)             NaN    ad
# 51                        /wiki/Sheldon_Moldoff             NaN    ad
# 52                /wiki/P._K._Narayana_Panicker             NaN    ad
# 53                        /wiki/Wenn_V._Deramas             NaN    ad
# 54                               /wiki/Gil_Hill             NaN    ad
# 55                        /wiki/Josefin_Nilsson             NaN    ad
# 56                        /wiki/Louise_Rennison             NaN    ad
# 57                           /wiki/Mumtaz_Qadri             NaN    ad
# 58                           /wiki/Dieter_Laser             NaN    ad
# 59                  /wiki/%C3%89va_Sz%C3%A9kely             NaN    ad
#
#              bc_ad_note
# 0               assumed
# 1               assumed
# 2               assumed
# 3               assumed
# 4               assumed
# 5               assumed
# 6               assumed
# 7               assumed
# 8               assumed
# 9               assumed
# 10              assumed
# 11              assumed
# 12              assumed
# 13              assumed
# 14              assumed
# 15              assumed
# 16  nested year assumed
# 17  nested year assumed
# 18              assumed
# 19  nested year assumed
# 20  nested year assumed
# 21              assumed
# 22              assumed
# 23  nested year assumed
# 24  nested year assumed
# 25              assumed
# 26              assumed
# 27  nested year assumed
# 28  nested year assumed
# 29              assumed
# 30  nested year assumed
# 31  nested year assumed
# 32              assumed
# 33              assumed
# 34  nested year assumed
# 35  nested year assumed
# 36              assumed
# 37              assumed
# 38              assumed
# 39  nested year assumed
# 40  nested year assumed
# 41              assumed
# 42  nested year assumed
# 43  nested year assumed
# 44  nested year assumed
# 45  nested year assumed
# 46  nested year assumed
# 47  nested year assumed
# 48  nested year assumed
# 49  nested year assumed
# 50  nested year assumed
# 51  nested year assumed
# 52  nested year assumed
# 53  nested year assumed
# 54  nested year assumed
# 55  nested year assumed
# 56  nested year assumed
# 57  nested year assumed
# 58  nested year assumed
# 59  nested year assumed

# %%
dfhol = pd.DataFrame(d1['holidays_and_observances'])
dfhol
# Out:
#    year                                  event_description  \
# 0   NaN  Auguste Chapdelaine (one of the Martyr Saints ...
# 1   NaN            Oswald of Worcester (in leap year only)
# 2   NaN                                 Saint John Cassian
# 3   NaN                 February 29 in the Orthodox church
# 4   NaN  The fourth day of Ayyám-i-Há (Baháʼí Faith) (o...
# 5   NaN  Rare Disease Day (in leap years; celebrated in...
# 6   NaN           Bachelor's Day (Ireland, United Kingdom)
#
#                                     event_links_list  \
# 0  [/wiki/Auguste_Chapdelaine, /wiki/Martyr_Saint...
# 1                        [/wiki/Oswald_of_Worcester]
# 2                               [/wiki/John_Cassian]
# 3   [/wiki/February_29_(Eastern_Orthodox_liturgics)]
# 4  [/wiki/Ayy%C3%A1m-i-H%C3%A1, /wiki/Bah%C3%A1%C...
# 5                           [/wiki/Rare_Disease_Day]
# 6  [/wiki/Bachelor%27s_Day_(tradition), /wiki/Rep...
#
#                                  event_first_link       event_category
# 0                       /wiki/Auguste_Chapdelaine  christian feast day
# 1                       /wiki/Oswald_of_Worcester  christian feast day
# 2                              /wiki/John_Cassian  christian feast day
# 3  /wiki/February_29_(Eastern_Orthodox_liturgics)  christian feast day
# 4                      /wiki/Ayy%C3%A1m-i-H%C3%A1                  NaN
# 5                          /wiki/Rare_Disease_Day                  NaN
# 6              /wiki/Bachelor%27s_Day_(tradition)                  NaN
